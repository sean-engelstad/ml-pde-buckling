# %%
# buckling inputs
# ----------------

# aluminum plate material properties
E = 70e9; nu = 0.3; thick = 0.005
D = E * thick**3 / 12.0 / (1 - nu**2)
# D = 1

# choose loading type (first just uniaxial loading in x-direction)
# axial = True
axial = True
if axial:
    Nxx, Nxy, Nyy = (1e3, 0, 0)
else:
    Nxx, Nxy, Nyy = (0, 1e2, 0)

a, b = (1, 1)
# (a, b) = (3, 1)

# predict the buckling load factor (BLF)
pi = 3.14159
if axial:
    pred_buckling_load = pi**2 * D / b**2 * 4.0 
    pred_load_factor = pred_buckling_load / Nxx
    sigma = 0.5 * pred_load_factor
    print(f"{pred_load_factor=}")
# Out:
# pred_load_factor=31.633294000320518

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

num_domain = 10000
num_test = 500

DTYPE = tf.float32

# set the boundary of the panel
xmin = 0; xmax = a
ymin = 0; ymax = b

lb = tf.constant([xmin, ymin], dtype=DTYPE)
ub = tf.constant([xmax, ymax], dtype=DTYPE)

# generate the collocation points on the interior
def gen_collocation_points(num_domain, minval, maxval):
    x_r = tf.random.uniform((num_domain,1), minval[0], maxval[0], dtype=DTYPE)
    y_r = tf.random.uniform((num_domain,1), minval[1], maxval[1], dtype=DTYPE)
    X_r = tf.concat([x_r, y_r], axis=1)
    # data_init = tf.random_uniform_initializer(minval=minval, maxval=maxval, seed=0)
    # return tf.Variable(data_init(shape=[num_domain, 1]), dtype=tf.float32)
    return tf.Variable(X_r, dtype=DTYPE)

x_train = gen_collocation_points(num_domain, lb, ub)
x_test = gen_collocation_points(num_test, lb, ub)
print(f"{type(x_train)=}")

x = x_train[:,0:1]
y = x_train[:,1:2]

# generate boundary domain points
N_b = 100
x_b1 = tf.random.uniform((N_b,1), lb[0], ub[0], dtype=DTYPE)
y_b1 = lb[1] + (ub[1] - lb[1]) * \
    tf.keras.backend.random_bernoulli((N_b,1), 0.5, dtype=DTYPE)
X_b1 = tf.concat([x_b1, y_b1], axis=0)

# boundary data on x edges
y_b2 = tf.random.uniform((N_b,1), lb[1], ub[1], dtype=DTYPE)
x_b2 = lb[0] + (ub[0] - lb[0]) * \
    tf.keras.backend.random_bernoulli((N_b,1), 0.5, dtype=DTYPE)
X_b2 = tf.concat([x_b2, y_b2], axis=0)
# print(f"{x_b2=}")

x_bndry = tf.Variable(tf.concat([X_b1, X_b2], axis=1), dtype=DTYPE)

# plot the data to check
plt.scatter(x_bndry[:,0], x_bndry[:,1])
plt.scatter(x_train[:1000,0], x_train[:1000,1]) # only show 1000 of the points
plt.show()
# Out:
# type(x_train)=<class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>

# %%
from tensorflow.keras.initializers import HeNormal

# now start building the tensorflow model
n_inputs = 2
n_outputs = 1
hidden_units = [50, 50, 50]
# activation = 'tanh'
activation = 'relu'

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Input((n_inputs,)))

for units in hidden_units:
  model.add(tf.keras.layers.Dense(units=units, activation=activation, kernel_initializer=HeNormal()))
  # debug : add dropout layers?
  # model.add(tf.keras.layers.Dropout(0.4))

last_activation = 'tanh' # for normalized output since eigenmode
# last_activation = None 
model.add(tf.keras.layers.Dense(units=n_outputs, activation=last_activation, kernel_initializer=HeNormal()))
model.summary()

# also add lambda the eigenvalue trainable parameter to update
guess = pred_load_factor # cheat guess first
lambda_var = model.add_weight(name="lambda_var", initializer=tf.keras.initializers.Constant(guess), trainable=True)
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_32 (Dense)                │ (None, 50)             │           150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,301 (20.71 KB)
#  Trainable params: 5,301 (20.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# plot the initial buckling mode prediction
import matplotlib.pyplot as plt
import numpy as np

def plot_mode(n=50):
    n = 50
    x_vec = np.linspace(0, a, n)
    y_vec = np.linspace(0, b, n)
    X, Y = np.meshgrid(x_vec, y_vec)
    x_flat = np.reshape(X, newshape=(n*n,1))
    y_flat = np.reshape(Y, newshape=(n*n,1))
    grid_inputs = np.concatenate([x_flat, y_flat], axis=1)
    w = model(grid_inputs)
    W = np.reshape(w, newshape=(n,n))

    # plt.figure(figsize=(8, 6))
    # colors = plt.contourf(X, Y, W, levels=20, cmap='viridis', alpha=0.75)  # Filled contours
    # plt.colorbar(colors, label="w(x,y)")  # Colorbar for reference

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    surface = ax.plot_surface(X, Y, W, cmap='viridis')

    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")
    # plt.title("2D Contour Plot")
    plt.show()

plot_mode()

# %%
# fit and optimize the model
epochs = 1000
# epochs = 5000
# epochs = 100
# epochs = 50
learning_rate = 0.0005
import time

optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

losses_hist = []

# print(f"{type(x_train)=}")

best_weights = model.get_weights()
best_loss = 1e8

for i in range(epochs + 1):
  start_time = time.time()

  with tf.GradientTape(persistent=False) as tape_model:

    # pde loss
    with tf.GradientTape(persistent=True) as tape3:
      tape3.watch(x)
      tape3.watch(y)
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(x)  # Ensure that x is watched by tape1
        tape2.watch(y)  # Ensure that y is watched by tape1
        with tf.GradientTape(persistent=True) as tape1:
            tape1.watch(x)  # Ensure that x is watched by tape1
            tape1.watch(y)  # Ensure that y is watched by tape1
            w_raw = model(tf.stack([x[:, 0], y[:, 0]], axis=1), training=True)
            # normalize the eigenmode so it focuses on shape of eigenmode instead of just trying to make the
            # magnitudes smaller..
            w = w_raw / tf.norm(w_raw)
            # print(f"{w=}")
            
            # Compute gradients with respect to x and y
            dx = tape1.gradient(w, x)
            dy = tape1.gradient(w, y)
            # print(f"{dx=} {dy=}")

        # Compute the second derivative of dx with respect to x
        d2x = tape1.gradient(dx, x)
        dxy = tape1.gradient(dx, y)
        d2y = tape1.gradient(dy, y)
        # print(f"{d2x=} {dxy=} {d2y=}")

      d3x = tape2.gradient(d2x, x)
      d2xy = tape2.gradient(d2x, y)
      d3y = tape2.gradient(d2y, y)
      # print(f"{d3x=}")

    d4x = tape3.gradient(d3x, x)
    d2x2y = tape3.gradient(d2xy, y)
    d4y = tape3.gradient(d3y, y)
    # print(f"{d4x=} {d2x2y=} {d4y=}")

    # now compute PDE residual
    # consider normalizing PDE residual a bit.. so more comparable to BC loss
    res_pde = (d4x + 2. * d2x2y + d4y) - lambda_var * \
            (Nxx * d2x + 2. * Nxy * dxy + Nyy * d2y) / D    
    # print(f"{res_pde=}")

    # boundary condition loss, SS w = 0
    w_raw_bndry = model(x_bndry, training=True)
    # normalize the eigenmode prediction
    w_norm = tf.norm(model(x_train, training=True))
    res_bndry = w_raw_bndry / w_norm
    # print(f"{res_bndry=}")

    # compute mse loss function
    scale = 1e3
    # scale = 1e2
    bndry_mse = tf.math.reduce_mean(tf.math.square(scale * res_bndry), axis=0)
    pde_mse = tf.math.reduce_mean(tf.math.square(res_pde), axis=0)
    total_mse = pde_mse + bndry_mse 

    # debug try just bndry loss
    # total_mse = bndry_mse

  # compute training gradients (ML model and lambd teh eigenvalue)
  # grads_lambda = tape_model.gradient(total_mse, lambd)
  model_update_gradients = tape_model.gradient(total_mse, model.trainable_variables)
  # print(f"{grads_lambda=}")
  # bndry_gradients = tape_model.gradient(bndry_mse, model.trainable_variables)
  # print(f"{model_update_gradients=}")
  # print(f"{bndry_gradients=}")
  # exit(0)

  del tape1, tape2, tape3

  # apply optimizer updates to ML model and predicted eigenvalue
  optimizer.apply_gradients(
    zip(model_update_gradients, model.trainable_variables)
  )  
  # optimizer.apply_gradients([(grads_lambda, lambd)])

  del tape_model

  train_loss = total_mse.numpy()[0]
  eigval = lambda_var.numpy()
  pde_loss = pde_mse.numpy()[0]
  bndry_loss = bndry_mse.numpy()[0]
  dt = time.time() - start_time
  print(f"Epoch: {i}\t{train_loss=}\t{pde_loss=}\t{bndry_loss=}\t{eigval=}\t{dt=}")

  if train_loss < best_loss:
    best_loss = train_loss
    best_weights = model.get_weights()
    # print(f"{best_weights=}")

  losses_hist += [
    {'pde' : pde_loss, 'bndry' : bndry_loss, 'train' : train_loss}
  ]

  if abs(train_loss) < 0.01: # error based stopping criterion
    break

  if i % 1000 == 0:
    # y_preds = model(x_test)
    test_mse = tf.constant(-1)
    # test_mse = tf.math.reduce_mean(tf.math.square(y_preds - tf.math.sin(np.pi*x_test)), axis=0)
    print('Epoch: {}\tTrain Loss = {},\tTest Loss = {}'.format(i, total_mse.numpy()[0], test_mse.numpy()))

# set best weights back in
model.set_weights(best_weights)
# Out:
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# Epoch: 0	train_loss=99.31204	pde_loss=3.1767156	bndry_loss=96.13533	eigval=31.632793	dt=0.7533919811248779
# Epoch: 0	Train Loss = 99.31204223632812,	Test Loss = -1
# Epoch: 1	train_loss=97.31825	pde_loss=2.5144234	bndry_loss=94.803825	eigval=31.632296	dt=0.7123322486877441
# Epoch: 2	train_loss=96.237724	pde_loss=2.5575683	bndry_loss=93.68015	eigval=31.631798	dt=0.7364304065704346
# Epoch: 3	train_loss=95.146484	pde_loss=2.3876715	bndry_loss=92.75881	eigval=31.6313	dt=0.7138869762420654
# Epoch: 4	train_loss=94.2331	pde_loss=2.195286	bndry_loss=92.03781	eigval=31.630804	dt=0.9814302921295166
# Epoch: 5	train_loss=93.5518	pde_loss=2.0703933	bndry_loss=91.48141	eigval=31.630312	dt=0.7262191772460938
# Epoch: 6	train_loss=92.99197	pde_loss=1.9780179	bndry_loss=91.01395	eigval=31.629824	dt=0.7147989273071289
# Epoch: 7	train_loss=92.51912	pde_loss=1.9219416	bndry_loss=90.597176	eigval=31.62934	dt=0.7177243232727051
# Epoch: 8	train_loss=92.08897	pde_loss=1.8609787	bndry_loss=90.22799	eigval=31.62886	dt=0.7413797378540039
# Epoch: 9	train_loss=91.89239	pde_loss=2.0168593	bndry_loss=89.87553	eigval=31.628386	dt=0.715308427810669
# Epoch: 10	train_loss=91.48508	pde_loss=1.942086	bndry_loss=89.54299	eigval=31.627916	dt=0.7101013660430908
# Epoch: 11	train_loss=90.94671	pde_loss=1.7193465	bndry_loss=89.22736	eigval=31.627453	dt=0.7222263813018799
# Epoch: 12	train_loss=90.66172	pde_loss=1.7575912	bndry_loss=88.90413	eigval=31.626995	dt=0.7255234718322754
# Epoch: 13	train_loss=90.36586	pde_loss=1.7627963	bndry_loss=88.603065	eigval=31.626543	dt=0.7228682041168213
# Epoch: 14	train_loss=90.11538	pde_loss=1.8292658	bndry_loss=88.28611	eigval=31.626097	dt=0.7226705551147461
# Epoch: 15	train_loss=89.84826	pde_loss=1.9047989	bndry_loss=87.94346	eigval=31.625654	dt=0.7240333557128906
# Epoch: 16	train_loss=89.52521	pde_loss=1.959001	bndry_loss=87.56621	eigval=31.625216	dt=0.7250957489013672
# Epoch: 17	train_loss=89.21353	pde_loss=2.0280328	bndry_loss=87.1855	eigval=31.624783	dt=0.7094976902008057
# Epoch: 18	train_loss=88.896935	pde_loss=2.0922685	bndry_loss=86.804665	eigval=31.624353	dt=0.7056224346160889
# Epoch: 19	train_loss=88.55014	pde_loss=2.1614718	bndry_loss=86.38867	eigval=31.623928	dt=0.7216811180114746
# Epoch: 20	train_loss=88.12868	pde_loss=2.2145526	bndry_loss=85.91412	eigval=31.623507	dt=0.7265000343322754
# Epoch: 21	train_loss=87.61873	pde_loss=2.240359	bndry_loss=85.37837	eigval=31.62309	dt=0.707221269607544
# Epoch: 22	train_loss=87.04052	pde_loss=2.2609859	bndry_loss=84.77953	eigval=31.62268	dt=0.7252368927001953
# Epoch: 23	train_loss=86.458244	pde_loss=2.2963996	bndry_loss=84.16184	eigval=31.622276	dt=0.7128865718841553
# Epoch: 24	train_loss=85.86799	pde_loss=2.4223986	bndry_loss=83.44559	eigval=31.62188	dt=0.7122485637664795
# Epoch: 25	train_loss=85.21554	pde_loss=2.5875304	bndry_loss=82.628006	eigval=31.62149	dt=0.7632842063903809
# Epoch: 26	train_loss=84.385185	pde_loss=2.6580763	bndry_loss=81.72711	eigval=31.621107	dt=0.7033877372741699
# Epoch: 27	train_loss=83.54504	pde_loss=2.7362046	bndry_loss=80.80883	eigval=31.62073	dt=0.7218005657196045
# Epoch: 28	train_loss=82.79369	pde_loss=3.0031576	bndry_loss=79.790535	eigval=31.620358	dt=0.7081875801086426
# Epoch: 29	train_loss=82.02396	pde_loss=3.3436112	bndry_loss=78.68034	eigval=31.61999	dt=0.7159056663513184
# Epoch: 30	train_loss=81.39273	pde_loss=3.774353	bndry_loss=77.61838	eigval=31.619623	dt=0.7252922058105469
# Epoch: 31	train_loss=80.704506	pde_loss=4.1307726	bndry_loss=76.57373	eigval=31.619255	dt=0.7189910411834717
# Epoch: 32	train_loss=80.26695	pde_loss=4.6921406	bndry_loss=75.574814	eigval=31.618881	dt=0.7165141105651855
# Epoch: 33	train_loss=80.110306	pde_loss=5.383054	bndry_loss=74.72725	eigval=31.618498	dt=0.7225630283355713
# Epoch: 34	train_loss=79.93271	pde_loss=5.835865	bndry_loss=74.09685	eigval=31.6181	dt=0.7226848602294922
# Epoch: 35	train_loss=79.990265	pde_loss=6.3331146	bndry_loss=73.65715	eigval=31.61768	dt=0.7206900119781494
# Epoch: 36	train_loss=79.36161	pde_loss=5.9493966	bndry_loss=73.41222	eigval=31.617235	dt=0.7119321823120117
# Epoch: 37	train_loss=78.6127	pde_loss=5.2930565	bndry_loss=73.31964	eigval=31.616762	dt=0.7210049629211426
# Epoch: 38	train_loss=78.217865	pde_loss=4.9203057	bndry_loss=73.29756	eigval=31.616259	dt=0.7263827323913574
# Epoch: 39	train_loss=77.89992	pde_loss=4.6057873	bndry_loss=73.29413	eigval=31.615725	dt=0.7312040328979492
# Epoch: 40	train_loss=77.772835	pde_loss=4.5021563	bndry_loss=73.270676	eigval=31.61516	dt=0.7255761623382568
# Epoch: 41	train_loss=77.691284	pde_loss=4.550806	bndry_loss=73.14048	eigval=31.614567	dt=0.7176103591918945
# Epoch: 42	train_loss=77.464355	pde_loss=4.5655274	bndry_loss=72.89883	eigval=31.613949	dt=0.7285454273223877
# Epoch: 43	train_loss=76.92363	pde_loss=4.3807554	bndry_loss=72.54288	eigval=31.61331	dt=0.9176688194274902
# Epoch: 44	train_loss=76.430664	pde_loss=4.2741365	bndry_loss=72.156525	eigval=31.612654	dt=0.7305984497070312
# Epoch: 45	train_loss=75.97376	pde_loss=4.275828	bndry_loss=71.69794	eigval=31.611984	dt=0.7083063125610352
# Epoch: 46	train_loss=75.60932	pde_loss=4.4013495	bndry_loss=71.20797	eigval=31.611307	dt=0.7038693428039551
# Epoch: 47	train_loss=75.35102	pde_loss=4.404242	bndry_loss=70.94678	eigval=31.610624	dt=0.7220785617828369
# Epoch: 48	train_loss=75.21837	pde_loss=4.4136796	bndry_loss=70.80469	eigval=31.60994	dt=0.7192363739013672
# Epoch: 49	train_loss=75.09929	pde_loss=4.4318843	bndry_loss=70.667404	eigval=31.609257	dt=0.6961729526519775
# Epoch: 50	train_loss=74.96311	pde_loss=4.4143476	bndry_loss=70.54877	eigval=31.608578	dt=0.7344293594360352
# Epoch: 51	train_loss=74.79795	pde_loss=4.3681927	bndry_loss=70.429756	eigval=31.6079	dt=0.7464680671691895
# Epoch: 52	train_loss=74.582535	pde_loss=4.27153	bndry_loss=70.311005	eigval=31.607227	dt=0.729604959487915
# Epoch: 53	train_loss=74.39339	pde_loss=4.176813	bndry_loss=70.216576	eigval=31.606556	dt=0.7034032344818115
# Epoch: 54	train_loss=74.169235	pde_loss=4.006085	bndry_loss=70.16315	eigval=31.605886	dt=0.720191240310669
# Epoch: 55	train_loss=73.89618	pde_loss=3.7739239	bndry_loss=70.12225	eigval=31.60522	dt=0.7123243808746338
# Epoch: 56	train_loss=73.679565	pde_loss=3.602623	bndry_loss=70.07694	eigval=31.604559	dt=0.7101163864135742
# Epoch: 57	train_loss=73.50981	pde_loss=3.479857	bndry_loss=70.02995	eigval=31.6039	dt=0.7072544097900391
# Epoch: 58	train_loss=73.33846	pde_loss=3.3835382	bndry_loss=69.954926	eigval=31.603247	dt=0.7245025634765625
# Epoch: 59	train_loss=73.1383	pde_loss=3.3058188	bndry_loss=69.83248	eigval=31.602596	dt=0.7142438888549805
# Epoch: 60	train_loss=72.95062	pde_loss=3.2595544	bndry_loss=69.69107	eigval=31.601948	dt=0.7101585865020752
# Epoch: 61	train_loss=72.768295	pde_loss=3.2299604	bndry_loss=69.53834	eigval=31.601301	dt=0.7044548988342285
# Epoch: 62	train_loss=72.58876	pde_loss=3.21286	bndry_loss=69.3759	eigval=31.600655	dt=0.704693078994751
# Epoch: 63	train_loss=72.42576	pde_loss=3.2078464	bndry_loss=69.21791	eigval=31.600008	dt=0.7123265266418457
# Epoch: 64	train_loss=72.24639	pde_loss=3.1737423	bndry_loss=69.07265	eigval=31.599361	dt=0.7097017765045166
# Epoch: 65	train_loss=72.05843	pde_loss=3.1136384	bndry_loss=68.94479	eigval=31.598717	dt=0.7189044952392578
# Epoch: 66	train_loss=71.894226	pde_loss=3.0605562	bndry_loss=68.83367	eigval=31.598074	dt=0.7190432548522949
# Epoch: 67	train_loss=71.77069	pde_loss=3.0650032	bndry_loss=68.70569	eigval=31.597435	dt=0.723151683807373
# Epoch: 68	train_loss=71.61202	pde_loss=3.0148952	bndry_loss=68.59713	eigval=31.596798	dt=0.7265787124633789
# Epoch: 69	train_loss=71.44985	pde_loss=2.9604626	bndry_loss=68.48939	eigval=31.596167	dt=0.7128403186798096
# Epoch: 70	train_loss=71.275024	pde_loss=2.8768935	bndry_loss=68.39813	eigval=31.59554	dt=0.705681562423706
# Epoch: 71	train_loss=71.09377	pde_loss=2.7830942	bndry_loss=68.31068	eigval=31.594917	dt=0.7433018684387207
# Epoch: 72	train_loss=70.94539	pde_loss=2.7135577	bndry_loss=68.231834	eigval=31.594301	dt=0.6933746337890625
# Epoch: 73	train_loss=70.853264	pde_loss=2.718001	bndry_loss=68.13526	eigval=31.59369	dt=0.7223906517028809
# Epoch: 74	train_loss=70.80264	pde_loss=2.8238654	bndry_loss=67.978775	eigval=31.593084	dt=0.7134017944335938
# Epoch: 75	train_loss=70.7359	pde_loss=2.964498	bndry_loss=67.7714	eigval=31.592482	dt=0.7063474655151367
# Epoch: 76	train_loss=70.73207	pde_loss=3.1588345	bndry_loss=67.573235	eigval=31.591879	dt=0.7077763080596924
# Epoch: 77	train_loss=70.72223	pde_loss=3.2929564	bndry_loss=67.429276	eigval=31.591276	dt=0.7080423831939697
# Epoch: 78	train_loss=70.68686	pde_loss=3.305579	bndry_loss=67.38128	eigval=31.590675	dt=0.7166569232940674
# Epoch: 79	train_loss=70.648865	pde_loss=3.2365367	bndry_loss=67.41233	eigval=31.590075	dt=0.7138912677764893
# Epoch: 80	train_loss=70.55574	pde_loss=3.0789766	bndry_loss=67.47676	eigval=31.589478	dt=0.7149250507354736
# Epoch: 81	train_loss=70.529045	pde_loss=3.0161996	bndry_loss=67.51285	eigval=31.588884	dt=0.7164647579193115
# Epoch: 82	train_loss=70.47611	pde_loss=2.9783733	bndry_loss=67.49774	eigval=31.588295	dt=0.9058728218078613
# Epoch: 83	train_loss=70.37592	pde_loss=2.9460132	bndry_loss=67.42991	eigval=31.58771	dt=0.71744704246521
# Epoch: 84	train_loss=70.28093	pde_loss=2.9610398	bndry_loss=67.31989	eigval=31.587126	dt=0.7211592197418213
# Epoch: 85	train_loss=70.23335	pde_loss=3.0366137	bndry_loss=67.19674	eigval=31.586544	dt=0.7383580207824707
# Epoch: 86	train_loss=70.156265	pde_loss=3.0423386	bndry_loss=67.11393	eigval=31.585962	dt=0.7109615802764893
# Epoch: 87	train_loss=70.07737	pde_loss=2.9823215	bndry_loss=67.09505	eigval=31.585382	dt=0.7089226245880127
# Epoch: 88	train_loss=69.9747	pde_loss=2.8297923	bndry_loss=67.144905	eigval=31.584805	dt=0.7255346775054932
# Epoch: 89	train_loss=69.90871	pde_loss=2.6872663	bndry_loss=67.22144	eigval=31.58423	dt=0.6956281661987305
# Epoch: 90	train_loss=69.863266	pde_loss=2.595276	bndry_loss=67.26799	eigval=31.58366	dt=0.7132823467254639
# Epoch: 91	train_loss=69.79523	pde_loss=2.5516384	bndry_loss=67.24359	eigval=31.583096	dt=0.7008230686187744
# Epoch: 92	train_loss=69.75077	pde_loss=2.5970576	bndry_loss=67.15371	eigval=31.582535	dt=0.7136824131011963
# Epoch: 93	train_loss=69.67423	pde_loss=2.635476	bndry_loss=67.03876	eigval=31.581978	dt=0.7207462787628174
# Epoch: 94	train_loss=69.6178	pde_loss=2.677653	bndry_loss=66.94015	eigval=31.581425	dt=0.7321016788482666
# Epoch: 95	train_loss=69.54104	pde_loss=2.6527836	bndry_loss=66.88825	eigval=31.580873	dt=0.7089910507202148
# Epoch: 96	train_loss=69.46807	pde_loss=2.5933657	bndry_loss=66.8747	eigval=31.580326	dt=0.7324602603912354
# Epoch: 97	train_loss=69.38838	pde_loss=2.5086513	bndry_loss=66.87973	eigval=31.579782	dt=0.7108602523803711
# Epoch: 98	train_loss=69.32289	pde_loss=2.4527016	bndry_loss=66.87019	eigval=31.57924	dt=0.7244534492492676
# Epoch: 99	train_loss=69.25485	pde_loss=2.4349246	bndry_loss=66.81993	eigval=31.578703	dt=0.714714527130127
# Epoch: 100	train_loss=69.16954	pde_loss=2.4574811	bndry_loss=66.71206	eigval=31.578167	dt=0.7199203968048096
# Epoch: 101	train_loss=69.079384	pde_loss=2.5041006	bndry_loss=66.57529	eigval=31.577633	dt=0.7072522640228271
# Epoch: 102	train_loss=68.97765	pde_loss=2.5401602	bndry_loss=66.43749	eigval=31.5771	dt=0.7250232696533203
# Epoch: 103	train_loss=68.84518	pde_loss=2.5495124	bndry_loss=66.29566	eigval=31.576569	dt=0.6993832588195801
# Epoch: 104	train_loss=68.675735	pde_loss=2.5256896	bndry_loss=66.15005	eigval=31.576038	dt=0.7269554138183594
# Epoch: 105	train_loss=68.55237	pde_loss=2.4930508	bndry_loss=66.05932	eigval=31.57551	dt=0.7046918869018555
# Epoch: 106	train_loss=68.43168	pde_loss=2.439902	bndry_loss=65.991776	eigval=31.574986	dt=0.7332823276519775
# Epoch: 107	train_loss=68.30542	pde_loss=2.3753474	bndry_loss=65.93007	eigval=31.574465	dt=0.7172596454620361
# Epoch: 108	train_loss=68.167725	pde_loss=2.3248522	bndry_loss=65.84287	eigval=31.573948	dt=0.7028534412384033
# Epoch: 109	train_loss=68.01132	pde_loss=2.3046436	bndry_loss=65.70668	eigval=31.573437	dt=0.7192182540893555
# Epoch: 110	train_loss=67.845436	pde_loss=2.3214567	bndry_loss=65.52398	eigval=31.57293	dt=0.7092485427856445
# Epoch: 111	train_loss=67.66249	pde_loss=2.3500702	bndry_loss=65.31242	eigval=31.572426	dt=0.7304103374481201
# Epoch: 112	train_loss=67.468636	pde_loss=2.3621798	bndry_loss=65.10645	eigval=31.571926	dt=0.7109417915344238
# Epoch: 113	train_loss=67.26872	pde_loss=2.3303792	bndry_loss=64.93835	eigval=31.57143	dt=0.7153565883636475
# Epoch: 114	train_loss=67.05736	pde_loss=2.2648172	bndry_loss=64.79254	eigval=31.570938	dt=0.7242066860198975
# Epoch: 115	train_loss=66.823845	pde_loss=2.1973019	bndry_loss=64.62654	eigval=31.570452	dt=0.713226318359375
# Epoch: 116	train_loss=66.60458	pde_loss=2.1910977	bndry_loss=64.41348	eigval=31.569971	dt=0.7428467273712158
# Epoch: 117	train_loss=66.382256	pde_loss=2.240776	bndry_loss=64.14148	eigval=31.569494	dt=0.7169232368469238
# Epoch: 118	train_loss=66.11874	pde_loss=2.282152	bndry_loss=63.836582	eigval=31.56902	dt=0.7129535675048828
# Epoch: 119	train_loss=65.80797	pde_loss=2.237462	bndry_loss=63.570503	eigval=31.568544	dt=0.739591121673584
# Epoch: 120	train_loss=65.46468	pde_loss=2.1270747	bndry_loss=63.33761	eigval=31.56807	dt=0.7306582927703857
# Epoch: 121	train_loss=65.12954	pde_loss=2.0838628	bndry_loss=63.045677	eigval=31.567593	dt=0.9483087062835693
# Epoch: 122	train_loss=64.79339	pde_loss=2.148002	bndry_loss=62.645386	eigval=31.567112	dt=0.7273440361022949
# Epoch: 123	train_loss=64.43559	pde_loss=2.2636642	bndry_loss=62.171925	eigval=31.566622	dt=0.7304480075836182
# Epoch: 124	train_loss=63.99346	pde_loss=2.2780628	bndry_loss=61.715397	eigval=31.566122	dt=0.7171385288238525
# Epoch: 125	train_loss=63.45896	pde_loss=2.3002386	bndry_loss=61.158722	eigval=31.565615	dt=0.7254023551940918
# Epoch: 126	train_loss=62.826515	pde_loss=2.538884	bndry_loss=60.287632	eigval=31.565094	dt=0.7446231842041016
# Epoch: 127	train_loss=62.090904	pde_loss=2.8673496	bndry_loss=59.223557	eigval=31.564558	dt=0.7374062538146973
# Epoch: 128	train_loss=61.28367	pde_loss=3.0109448	bndry_loss=58.272724	eigval=31.564007	dt=0.7015924453735352
# Epoch: 129	train_loss=60.277115	pde_loss=3.0936458	bndry_loss=57.183468	eigval=31.56344	dt=0.7389650344848633
# Epoch: 130	train_loss=59.092003	pde_loss=3.8178976	bndry_loss=55.274105	eigval=31.562853	dt=0.7363495826721191
# Epoch: 131	train_loss=57.73389	pde_loss=3.9748585	bndry_loss=53.759033	eigval=31.562244	dt=0.7090699672698975
# Epoch: 132	train_loss=56.145527	pde_loss=4.397406	bndry_loss=51.74812	eigval=31.561617	dt=0.7333106994628906
# Epoch: 133	train_loss=54.239304	pde_loss=5.041582	bndry_loss=49.197723	eigval=31.560965	dt=0.7184946537017822
# Epoch: 134	train_loss=52.156162	pde_loss=4.805737	bndry_loss=47.350426	eigval=31.560297	dt=0.7038788795471191
# Epoch: 135	train_loss=50.374153	pde_loss=6.953448	bndry_loss=43.420704	eigval=31.559593	dt=0.734015941619873
# Epoch: 136	train_loss=50.985474	pde_loss=2.3664188	bndry_loss=48.619053	eigval=31.558907	dt=0.7271935939788818
# Epoch: 137	train_loss=48.678658	pde_loss=6.7363186	bndry_loss=41.942337	eigval=31.558182	dt=0.719839334487915
# Epoch: 138	train_loss=48.600536	pde_loss=7.692121	bndry_loss=40.908417	eigval=31.557413	dt=0.7044212818145752
# Epoch: 139	train_loss=49.610718	pde_loss=2.6234903	bndry_loss=46.98723	eigval=31.556664	dt=0.721790075302124
# Epoch: 140	train_loss=48.05808	pde_loss=3.80516	bndry_loss=44.25292	eigval=31.555916	dt=0.7115879058837891
# Epoch: 141	train_loss=49.149334	pde_loss=11.849492	bndry_loss=37.299843	eigval=31.555096	dt=0.722222089767456
# Epoch: 142	train_loss=47.605793	pde_loss=3.50469	bndry_loss=44.101105	eigval=31.55429	dt=0.7413034439086914
# Epoch: 143	train_loss=48.64945	pde_loss=2.467856	bndry_loss=46.18159	eigval=31.553513	dt=0.7114989757537842
# Epoch: 144	train_loss=46.401985	pde_loss=4.239399	bndry_loss=42.162586	eigval=31.552734	dt=0.7283761501312256
# Epoch: 145	train_loss=46.846046	pde_loss=11.481352	bndry_loss=35.364693	eigval=31.551895	dt=0.711735725402832
# Epoch: 146	train_loss=44.854412	pde_loss=6.9611897	bndry_loss=37.893223	eigval=31.551039	dt=0.7246043682098389
# Epoch: 147	train_loss=45.19661	pde_loss=3.9755616	bndry_loss=41.221046	eigval=31.550198	dt=0.7179465293884277
# Epoch: 148	train_loss=44.58664	pde_loss=4.1102753	bndry_loss=40.476364	eigval=31.549366	dt=0.7171146869659424
# Epoch: 149	train_loss=43.100132	pde_loss=7.0499506	bndry_loss=36.050182	eigval=31.548515	dt=0.7033107280731201
# Epoch: 150	train_loss=43.412483	pde_loss=10.797549	bndry_loss=32.614933	eigval=31.547617	dt=0.7366490364074707
# Epoch: 151	train_loss=42.07156	pde_loss=6.380049	bndry_loss=35.69151	eigval=31.546715	dt=0.7090804576873779
# Epoch: 152	train_loss=42.34511	pde_loss=4.5050707	bndry_loss=37.840042	eigval=31.545826	dt=0.703336238861084
# Epoch: 153	train_loss=41.47768	pde_loss=5.259748	bndry_loss=36.217934	eigval=31.544943	dt=0.7376093864440918
# Epoch: 154	train_loss=40.82703	pde_loss=8.509503	bndry_loss=32.317528	eigval=31.544037	dt=0.6991868019104004
# Epoch: 155	train_loss=40.617302	pde_loss=9.451448	bndry_loss=31.165855	eigval=31.543106	dt=0.7269179821014404
# Epoch: 156	train_loss=39.96199	pde_loss=6.1215177	bndry_loss=33.840473	eigval=31.542183	dt=0.7150015830993652
# Epoch: 157	train_loss=39.9992	pde_loss=5.048364	bndry_loss=34.950836	eigval=31.541279	dt=0.7209253311157227
# Epoch: 158	train_loss=39.221443	pde_loss=6.355809	bndry_loss=32.865635	eigval=31.54038	dt=0.7297286987304688
# Epoch: 159	train_loss=39.069202	pde_loss=9.325831	bndry_loss=29.74337	eigval=31.539465	dt=0.7502739429473877
# Epoch: 160	train_loss=38.574257	pde_loss=8.439507	bndry_loss=30.134748	eigval=31.538544	dt=0.9324460029602051
# Epoch: 161	train_loss=38.396275	pde_loss=6.089441	bndry_loss=32.306835	eigval=31.537638	dt=0.7104861736297607
# Epoch: 162	train_loss=38.239677	pde_loss=5.8582554	bndry_loss=32.38142	eigval=31.536747	dt=0.7138514518737793
# Epoch: 163	train_loss=37.723873	pde_loss=7.621597	bndry_loss=30.102276	eigval=31.535858	dt=0.7413570880889893
# Epoch: 164	train_loss=37.7605	pde_loss=9.369887	bndry_loss=28.390615	eigval=31.53496	dt=0.7099401950836182
# Epoch: 165	train_loss=37.34854	pde_loss=7.446792	bndry_loss=29.90175	eigval=31.534067	dt=0.7006967067718506
# Epoch: 166	train_loss=37.3346	pde_loss=6.0041075	bndry_loss=31.33049	eigval=31.533192	dt=0.7192234992980957
# Epoch: 167	train_loss=36.9888	pde_loss=6.585706	bndry_loss=30.403095	eigval=31.532328	dt=0.7311668395996094
# Epoch: 168	train_loss=36.667618	pde_loss=8.396974	bndry_loss=28.270645	eigval=31.531464	dt=0.7380626201629639
# Epoch: 169	train_loss=36.44531	pde_loss=8.511975	bndry_loss=27.933334	eigval=31.530598	dt=0.7187352180480957
# Epoch: 170	train_loss=36.180256	pde_loss=6.7890267	bndry_loss=29.39123	eigval=31.529743	dt=0.7152748107910156
# Epoch: 171	train_loss=36.047623	pde_loss=6.309514	bndry_loss=29.738108	eigval=31.528904	dt=0.7149820327758789
# Epoch: 172	train_loss=35.69001	pde_loss=7.340392	bndry_loss=28.349619	eigval=31.528072	dt=0.7207949161529541
# Epoch: 173	train_loss=35.50525	pde_loss=8.499132	bndry_loss=27.006119	eigval=31.527243	dt=0.7298378944396973
# Epoch: 174	train_loss=35.15982	pde_loss=7.531275	bndry_loss=27.628546	eigval=31.52642	dt=0.737581729888916
# Epoch: 175	train_loss=34.95273	pde_loss=6.527899	bndry_loss=28.424828	eigval=31.525612	dt=0.713524580001831
# Epoch: 176	train_loss=34.653168	pde_loss=6.912718	bndry_loss=27.74045	eigval=31.524815	dt=0.7175142765045166
# Epoch: 177	train_loss=34.464058	pde_loss=7.9860096	bndry_loss=26.478046	eigval=31.524021	dt=0.7285213470458984
# Epoch: 178	train_loss=34.235443	pde_loss=7.6183076	bndry_loss=26.617136	eigval=31.523232	dt=0.7203655242919922
# Epoch: 179	train_loss=34.097916	pde_loss=6.659822	bndry_loss=27.438093	eigval=31.522453	dt=0.7075700759887695
# Epoch: 180	train_loss=33.94036	pde_loss=6.742053	bndry_loss=27.198309	eigval=31.521683	dt=0.7236576080322266
# Epoch: 181	train_loss=33.7648	pde_loss=7.649845	bndry_loss=26.114956	eigval=31.520912	dt=0.7193014621734619
# Epoch: 182	train_loss=33.65443	pde_loss=7.8241076	bndry_loss=25.830322	eigval=31.52014	dt=0.7509944438934326
# Epoch: 183	train_loss=33.550564	pde_loss=7.0567174	bndry_loss=26.493847	eigval=31.51937	dt=0.7165043354034424
# Epoch: 184	train_loss=33.48424	pde_loss=6.9442296	bndry_loss=26.54001	eigval=31.518599	dt=0.7409987449645996
# Epoch: 185	train_loss=33.40654	pde_loss=7.7025094	bndry_loss=25.70403	eigval=31.517822	dt=0.7105536460876465
# Epoch: 186	train_loss=33.38822	pde_loss=8.085784	bndry_loss=25.302437	eigval=31.517036	dt=0.7017357349395752
# Epoch: 187	train_loss=33.30572	pde_loss=7.4235673	bndry_loss=25.882153	eigval=31.516245	dt=0.7130348682403564
# Epoch: 188	train_loss=33.22638	pde_loss=7.119803	bndry_loss=26.106575	eigval=31.515451	dt=0.7266435623168945
# Epoch: 189	train_loss=33.157486	pde_loss=7.6935406	bndry_loss=25.463945	eigval=31.51465	dt=0.6853938102722168
# Epoch: 190	train_loss=33.132492	pde_loss=8.116248	bndry_loss=25.016245	eigval=31.513842	dt=0.7057967185974121
# Epoch: 191	train_loss=33.12411	pde_loss=7.6360774	bndry_loss=25.488035	eigval=31.513027	dt=0.7165427207946777
# Epoch: 192	train_loss=33.105854	pde_loss=7.238563	bndry_loss=25.867292	eigval=31.512213	dt=0.6947851181030273
# Epoch: 193	train_loss=33.061527	pde_loss=7.632587	bndry_loss=25.42894	eigval=31.511396	dt=0.7390906810760498
# Epoch: 194	train_loss=33.047047	pde_loss=8.118179	bndry_loss=24.928867	eigval=31.510576	dt=0.7154898643493652
# Epoch: 195	train_loss=32.99229	pde_loss=7.7834344	bndry_loss=25.208857	eigval=31.509754	dt=0.7139205932617188
# Epoch: 196	train_loss=32.96312	pde_loss=7.380162	bndry_loss=25.582958	eigval=31.508936	dt=0.7011339664459229
# Epoch: 197	train_loss=32.89887	pde_loss=7.569646	bndry_loss=25.329224	eigval=31.50812	dt=0.7176578044891357
# Epoch: 198	train_loss=32.92985	pde_loss=8.072195	bndry_loss=24.857656	eigval=31.507303	dt=0.7243683338165283
# Epoch: 199	train_loss=32.91671	pde_loss=7.8366923	bndry_loss=25.080019	eigval=31.506489	dt=0.9387989044189453
# Epoch: 200	train_loss=32.890842	pde_loss=7.3561454	bndry_loss=25.534697	eigval=31.505678	dt=0.7402076721191406
# Epoch: 201	train_loss=32.827908	pde_loss=7.45866	bndry_loss=25.369247	eigval=31.504873	dt=0.728571891784668
# Epoch: 202	train_loss=32.808613	pde_loss=7.9380608	bndry_loss=24.870552	eigval=31.50407	dt=0.7010738849639893
# Epoch: 203	train_loss=32.728065	pde_loss=7.8143806	bndry_loss=24.913685	eigval=31.503271	dt=0.7067849636077881
# Epoch: 204	train_loss=32.7268	pde_loss=7.437478	bndry_loss=25.289322	eigval=31.502478	dt=0.7257430553436279
# Epoch: 205	train_loss=32.71528	pde_loss=7.444108	bndry_loss=25.27117	eigval=31.501692	dt=0.7067501544952393
# Epoch: 206	train_loss=32.701035	pde_loss=7.7632256	bndry_loss=24.937807	eigval=31.500912	dt=0.7128422260284424
# Epoch: 207	train_loss=32.7118	pde_loss=7.808967	bndry_loss=24.902834	eigval=31.500137	dt=0.7085723876953125
# Epoch: 208	train_loss=32.718403	pde_loss=7.533086	bndry_loss=25.185318	eigval=31.49937	dt=0.6970243453979492
# Epoch: 209	train_loss=32.703278	pde_loss=7.4077377	bndry_loss=25.295538	eigval=31.498611	dt=0.7162108421325684
# Epoch: 210	train_loss=32.654922	pde_loss=7.5516315	bndry_loss=25.10329	eigval=31.497858	dt=0.7133908271789551
# Epoch: 211	train_loss=32.619568	pde_loss=7.658054	bndry_loss=24.961514	eigval=31.49711	dt=0.7192761898040771
# Epoch: 212	train_loss=32.562817	pde_loss=7.461625	bndry_loss=25.10119	eigval=31.496368	dt=0.7214226722717285
# Epoch: 213	train_loss=32.4979	pde_loss=7.336941	bndry_loss=25.160957	eigval=31.49563	dt=0.7077968120574951
# Epoch: 214	train_loss=32.41001	pde_loss=7.47046	bndry_loss=24.93955	eigval=31.494896	dt=0.7155885696411133
# Epoch: 215	train_loss=32.33279	pde_loss=7.6114163	bndry_loss=24.721373	eigval=31.494162	dt=0.7220141887664795
# Epoch: 216	train_loss=32.334087	pde_loss=7.5744424	bndry_loss=24.759644	eigval=31.49343	dt=0.7008025646209717
# Epoch: 217	train_loss=32.36874	pde_loss=7.460153	bndry_loss=24.908588	eigval=31.492699	dt=0.7251358032226562
# Epoch: 218	train_loss=32.353336	pde_loss=7.4868436	bndry_loss=24.866493	eigval=31.491968	dt=0.7177350521087646
# Epoch: 219	train_loss=32.361202	pde_loss=7.6879478	bndry_loss=24.673256	eigval=31.491238	dt=0.7088603973388672
# Epoch: 220	train_loss=32.389866	pde_loss=7.6958413	bndry_loss=24.694023	eigval=31.490507	dt=0.7060656547546387
# Epoch: 221	train_loss=32.376247	pde_loss=7.470063	bndry_loss=24.906183	eigval=31.489779	dt=0.7173902988433838
# Epoch: 222	train_loss=32.41711	pde_loss=7.5036077	bndry_loss=24.913502	eigval=31.489052	dt=0.7114956378936768
# Epoch: 223	train_loss=32.43261	pde_loss=7.6211534	bndry_loss=24.811455	eigval=31.488325	dt=0.715625524520874
# Epoch: 224	train_loss=32.506172	pde_loss=7.672415	bndry_loss=24.833757	eigval=31.487598	dt=0.711418867111206
# Epoch: 225	train_loss=32.526657	pde_loss=7.489664	bndry_loss=25.036993	eigval=31.486874	dt=0.7117271423339844
# Epoch: 226	train_loss=32.538425	pde_loss=7.4879827	bndry_loss=25.050444	eigval=31.486153	dt=0.7237789630889893
# Epoch: 227	train_loss=32.51518	pde_loss=7.6397963	bndry_loss=24.875381	eigval=31.485434	dt=0.7380788326263428
# Epoch: 228	train_loss=32.532394	pde_loss=7.719488	bndry_loss=24.812908	eigval=31.484716	dt=0.7353870868682861
# Epoch: 229	train_loss=32.51966	pde_loss=7.5350018	bndry_loss=24.984657	eigval=31.484001	dt=0.7248013019561768
# Epoch: 230	train_loss=32.527634	pde_loss=7.4885345	bndry_loss=25.0391	eigval=31.483288	dt=0.718696117401123
# Epoch: 231	train_loss=32.55315	pde_loss=7.6457233	bndry_loss=24.907427	eigval=31.482576	dt=0.7279913425445557
# Epoch: 232	train_loss=32.583565	pde_loss=7.6862764	bndry_loss=24.89729	eigval=31.481867	dt=0.7230558395385742
# Epoch: 233	train_loss=32.61979	pde_loss=7.5425096	bndry_loss=25.07728	eigval=31.48116	dt=0.7103374004364014
# Epoch: 234	train_loss=32.622097	pde_loss=7.446681	bndry_loss=25.175417	eigval=31.480453	dt=0.7010507583618164
# Epoch: 235	train_loss=32.610207	pde_loss=7.5745416	bndry_loss=25.035664	eigval=31.47975	dt=0.6993978023529053
# Epoch: 236	train_loss=32.598846	pde_loss=7.6693783	bndry_loss=24.929466	eigval=31.479046	dt=0.7119643688201904
# Epoch: 237	train_loss=32.590298	pde_loss=7.5657673	bndry_loss=25.02453	eigval=31.478344	dt=0.9247665405273438
# Epoch: 238	train_loss=32.563538	pde_loss=7.4419556	bndry_loss=25.121582	eigval=31.477644	dt=0.7020308971405029
# Epoch: 239	train_loss=32.55361	pde_loss=7.5447955	bndry_loss=25.008818	eigval=31.476946	dt=0.7200839519500732
# Epoch: 240	train_loss=32.593822	pde_loss=7.7097845	bndry_loss=24.884039	eigval=31.47625	dt=0.7023825645446777
# Epoch: 241	train_loss=32.58755	pde_loss=7.570087	bndry_loss=25.017464	eigval=31.475554	dt=0.7044463157653809
# Epoch: 242	train_loss=32.548565	pde_loss=7.440328	bndry_loss=25.108238	eigval=31.47486	dt=0.7172548770904541
# Epoch: 243	train_loss=32.515007	pde_loss=7.6083217	bndry_loss=24.906687	eigval=31.474167	dt=0.7032384872436523
# Epoch: 244	train_loss=32.489777	pde_loss=7.769925	bndry_loss=24.71985	eigval=31.473475	dt=0.7238516807556152
# Epoch: 245	train_loss=32.409252	pde_loss=7.58575	bndry_loss=24.823502	eigval=31.472784	dt=0.7229056358337402
# Epoch: 246	train_loss=32.36097	pde_loss=7.4705267	bndry_loss=24.890444	eigval=31.472095	dt=0.7019693851470947
# Epoch: 247	train_loss=32.267315	pde_loss=7.5210295	bndry_loss=24.746284	eigval=31.471409	dt=0.7271192073822021
# Epoch: 248	train_loss=32.17171	pde_loss=7.5743265	bndry_loss=24.597383	eigval=31.470722	dt=0.7040035724639893
# Epoch: 249	train_loss=32.142056	pde_loss=7.5329523	bndry_loss=24.609102	eigval=31.470037	dt=0.7067112922668457
# Epoch: 250	train_loss=32.1042	pde_loss=7.3843045	bndry_loss=24.719893	eigval=31.469353	dt=0.7222058773040771
# Epoch: 251	train_loss=32.04867	pde_loss=7.3714423	bndry_loss=24.67723	eigval=31.46867	dt=0.7174105644226074
# Epoch: 252	train_loss=31.98057	pde_loss=7.480064	bndry_loss=24.500505	eigval=31.467989	dt=0.6973061561584473
# Epoch: 253	train_loss=31.963703	pde_loss=7.5285954	bndry_loss=24.435108	eigval=31.467308	dt=0.7106280326843262
# Epoch: 254	train_loss=31.9493	pde_loss=7.3734174	bndry_loss=24.575884	eigval=31.466629	dt=0.706005334854126
# Epoch: 255	train_loss=31.908974	pde_loss=7.3094807	bndry_loss=24.599493	eigval=31.465952	dt=0.7092602252960205
# Epoch: 256	train_loss=31.871784	pde_loss=7.478508	bndry_loss=24.393276	eigval=31.465275	dt=0.7069106101989746
# Epoch: 257	train_loss=31.845173	pde_loss=7.533083	bndry_loss=24.31209	eigval=31.464598	dt=0.7093737125396729
# Epoch: 258	train_loss=31.802555	pde_loss=7.3354516	bndry_loss=24.467104	eigval=31.463923	dt=0.716500997543335
# Epoch: 259	train_loss=31.786663	pde_loss=7.310503	bndry_loss=24.47616	eigval=31.46325	dt=0.7086353302001953
# Epoch: 260	train_loss=31.749887	pde_loss=7.449341	bndry_loss=24.300547	eigval=31.462576	dt=0.7033512592315674
# Epoch: 261	train_loss=31.719538	pde_loss=7.4900603	bndry_loss=24.229477	eigval=31.461905	dt=0.7207026481628418
# Epoch: 262	train_loss=31.670408	pde_loss=7.338899	bndry_loss=24.331509	eigval=31.461233	dt=0.7142126560211182
# Epoch: 263	train_loss=31.638607	pde_loss=7.331975	bndry_loss=24.306633	eigval=31.460564	dt=0.7193729877471924
# Epoch: 264	train_loss=31.619661	pde_loss=7.4736423	bndry_loss=24.146019	eigval=31.459896	dt=0.7165212631225586
# Epoch: 265	train_loss=31.602713	pde_loss=7.4504523	bndry_loss=24.15226	eigval=31.459229	dt=0.702308177947998
# Epoch: 266	train_loss=31.573515	pde_loss=7.324194	bndry_loss=24.249321	eigval=31.458563	dt=0.7209725379943848
# Epoch: 267	train_loss=31.560112	pde_loss=7.384194	bndry_loss=24.175919	eigval=31.4579	dt=0.7129907608032227
# Epoch: 268	train_loss=31.509521	pde_loss=7.4411626	bndry_loss=24.06836	eigval=31.457235	dt=0.7196986675262451
# Epoch: 269	train_loss=31.47165	pde_loss=7.4023314	bndry_loss=24.069319	eigval=31.456573	dt=0.7158646583557129
# Epoch: 270	train_loss=31.462986	pde_loss=7.3671064	bndry_loss=24.09588	eigval=31.455914	dt=0.7115609645843506
# Epoch: 271	train_loss=31.4368	pde_loss=7.3632197	bndry_loss=24.07358	eigval=31.455254	dt=0.7051310539245605
# Epoch: 272	train_loss=31.402685	pde_loss=7.409172	bndry_loss=23.993513	eigval=31.454596	dt=0.7324810028076172
# Epoch: 273	train_loss=31.398485	pde_loss=7.412386	bndry_loss=23.9861	eigval=31.45394	dt=0.7176892757415771
# Epoch: 274	train_loss=31.391262	pde_loss=7.341119	bndry_loss=24.050142	eigval=31.453283	dt=0.6953938007354736
# Epoch: 275	train_loss=31.384258	pde_loss=7.3577986	bndry_loss=24.02646	eigval=31.45263	dt=0.9123992919921875
# Epoch: 276	train_loss=31.338524	pde_loss=7.3749547	bndry_loss=23.96357	eigval=31.451977	dt=0.6977846622467041
# Epoch: 277	train_loss=31.306002	pde_loss=7.377516	bndry_loss=23.928486	eigval=31.451324	dt=0.7182507514953613
# Epoch: 278	train_loss=31.292416	pde_loss=7.329958	bndry_loss=23.962458	eigval=31.450672	dt=0.6982433795928955
# Epoch: 279	train_loss=31.26751	pde_loss=7.2903376	bndry_loss=23.977173	eigval=31.450022	dt=0.7083535194396973
# Epoch: 280	train_loss=31.237247	pde_loss=7.3521795	bndry_loss=23.885069	eigval=31.449371	dt=0.7237579822540283
# Epoch: 281	train_loss=31.217682	pde_loss=7.408267	bndry_loss=23.809414	eigval=31.44872	dt=0.7172210216522217
# Epoch: 282	train_loss=31.186218	pde_loss=7.3472047	bndry_loss=23.839014	eigval=31.44807	dt=0.7130684852600098
# Epoch: 283	train_loss=31.143036	pde_loss=7.3239813	bndry_loss=23.819054	eigval=31.447422	dt=0.7341587543487549
# Epoch: 284	train_loss=31.09462	pde_loss=7.402881	bndry_loss=23.691738	eigval=31.446774	dt=0.7123267650604248
# Epoch: 285	train_loss=31.048672	pde_loss=7.3761187	bndry_loss=23.672554	eigval=31.446125	dt=0.7152180671691895
# Epoch: 286	train_loss=31.01921	pde_loss=7.284553	bndry_loss=23.734657	eigval=31.445478	dt=0.7599413394927979
# Epoch: 287	train_loss=30.977917	pde_loss=7.2797327	bndry_loss=23.698183	eigval=31.444832	dt=0.6982357501983643
# Epoch: 288	train_loss=30.959858	pde_loss=7.3706174	bndry_loss=23.589241	eigval=31.444187	dt=0.6978201866149902
# Epoch: 289	train_loss=30.928701	pde_loss=7.2894654	bndry_loss=23.639236	eigval=31.443542	dt=0.7496070861816406
# Epoch: 290	train_loss=30.901974	pde_loss=7.222336	bndry_loss=23.679638	eigval=31.4429	dt=0.7050309181213379
# Epoch: 291	train_loss=30.881409	pde_loss=7.333661	bndry_loss=23.547749	eigval=31.442257	dt=0.732616662979126
# Epoch: 292	train_loss=30.867598	pde_loss=7.361344	bndry_loss=23.506254	eigval=31.441614	dt=0.7085704803466797
# Epoch: 293	train_loss=30.847397	pde_loss=7.2486978	bndry_loss=23.5987	eigval=31.440973	dt=0.7383944988250732
# Epoch: 294	train_loss=30.834175	pde_loss=7.2891374	bndry_loss=23.545038	eigval=31.440332	dt=0.7063617706298828
# Epoch: 295	train_loss=30.825357	pde_loss=7.3837447	bndry_loss=23.441612	eigval=31.439692	dt=0.6985635757446289
# Epoch: 296	train_loss=30.803078	pde_loss=7.295054	bndry_loss=23.508024	eigval=31.43905	dt=0.6932744979858398
# Epoch: 297	train_loss=30.790466	pde_loss=7.2523537	bndry_loss=23.538113	eigval=31.43841	dt=0.7265923023223877
# Epoch: 298	train_loss=30.753532	pde_loss=7.322217	bndry_loss=23.431316	eigval=31.437769	dt=0.7499160766601562
# Epoch: 299	train_loss=30.743149	pde_loss=7.3497314	bndry_loss=23.393417	eigval=31.437128	dt=0.7315769195556641
# Epoch: 300	train_loss=30.731316	pde_loss=7.2358046	bndry_loss=23.49551	eigval=31.436487	dt=0.7251043319702148
# Epoch: 301	train_loss=30.723646	pde_loss=7.2666264	bndry_loss=23.45702	eigval=31.435846	dt=0.6965391635894775
# Epoch: 302	train_loss=30.72287	pde_loss=7.3439	bndry_loss=23.37897	eigval=31.435205	dt=0.7090425491333008
# Epoch: 303	train_loss=30.685759	pde_loss=7.2259693	bndry_loss=23.45979	eigval=31.434565	dt=0.7184293270111084
# Epoch: 304	train_loss=30.671795	pde_loss=7.228834	bndry_loss=23.44296	eigval=31.433926	dt=0.7079031467437744
# Epoch: 305	train_loss=30.668499	pde_loss=7.315891	bndry_loss=23.352608	eigval=31.433287	dt=0.7380590438842773
# Epoch: 306	train_loss=30.67429	pde_loss=7.26295	bndry_loss=23.411339	eigval=31.432648	dt=0.7073266506195068
# Epoch: 307	train_loss=30.671127	pde_loss=7.197318	bndry_loss=23.473808	eigval=31.43201	dt=0.7259395122528076
# Epoch: 308	train_loss=30.651764	pde_loss=7.253625	bndry_loss=23.39814	eigval=31.431374	dt=0.727506160736084
# Epoch: 309	train_loss=30.639574	pde_loss=7.3139844	bndry_loss=23.32559	eigval=31.430737	dt=0.7289280891418457
# Epoch: 310	train_loss=30.649786	pde_loss=7.240517	bndry_loss=23.40927	eigval=31.430101	dt=0.7083742618560791
# Epoch: 311	train_loss=30.664577	pde_loss=7.1659703	bndry_loss=23.498608	eigval=31.429468	dt=0.7046308517456055
# Epoch: 312	train_loss=30.660576	pde_loss=7.261119	bndry_loss=23.399458	eigval=31.428835	dt=0.7232999801635742
# Epoch: 313	train_loss=30.640875	pde_loss=7.25625	bndry_loss=23.384624	eigval=31.428204	dt=0.9314000606536865
# Epoch: 314	train_loss=30.635548	pde_loss=7.179948	bndry_loss=23.4556	eigval=31.427572	dt=0.686255931854248
# Epoch: 315	train_loss=30.606018	pde_loss=7.1944666	bndry_loss=23.411552	eigval=31.426943	dt=0.7207794189453125
# Epoch: 316	train_loss=30.597942	pde_loss=7.3032694	bndry_loss=23.294672	eigval=31.426313	dt=0.7265725135803223
# Epoch: 317	train_loss=30.589653	pde_loss=7.182364	bndry_loss=23.40729	eigval=31.425686	dt=0.7362086772918701
# Epoch: 318	train_loss=30.583559	pde_loss=7.177447	bndry_loss=23.406113	eigval=31.42506	dt=0.7131919860839844
# Epoch: 319	train_loss=30.607044	pde_loss=7.3365483	bndry_loss=23.270496	eigval=31.424435	dt=0.738262414932251
# Epoch: 320	train_loss=30.610662	pde_loss=7.2461185	bndry_loss=23.364544	eigval=31.42381	dt=0.6904270648956299
# Epoch: 321	train_loss=30.61744	pde_loss=7.2318125	bndry_loss=23.385626	eigval=31.423185	dt=0.7201406955718994
# Epoch: 322	train_loss=30.62559	pde_loss=7.328148	bndry_loss=23.297441	eigval=31.422562	dt=0.7056214809417725
# Epoch: 323	train_loss=30.623295	pde_loss=7.2662935	bndry_loss=23.357002	eigval=31.421938	dt=0.7073936462402344
# Epoch: 324	train_loss=30.611858	pde_loss=7.2102327	bndry_loss=23.401627	eigval=31.421316	dt=0.7267534732818604
# Epoch: 325	train_loss=30.604252	pde_loss=7.298537	bndry_loss=23.305716	eigval=31.420694	dt=0.7166059017181396
# Epoch: 326	train_loss=30.600174	pde_loss=7.252789	bndry_loss=23.347385	eigval=31.420074	dt=0.7150421142578125
# Epoch: 327	train_loss=30.599064	pde_loss=7.2078485	bndry_loss=23.391216	eigval=31.419455	dt=0.7054438591003418
# Epoch: 328	train_loss=30.598793	pde_loss=7.269327	bndry_loss=23.329466	eigval=31.418837	dt=0.7230639457702637
# Epoch: 329	train_loss=30.594818	pde_loss=7.260631	bndry_loss=23.334187	eigval=31.418219	dt=0.7154152393341064
# Epoch: 330	train_loss=30.586514	pde_loss=7.2031326	bndry_loss=23.38338	eigval=31.417603	dt=0.7072546482086182
# Epoch: 331	train_loss=30.549644	pde_loss=7.205083	bndry_loss=23.34456	eigval=31.416986	dt=0.7360541820526123
# Epoch: 332	train_loss=30.547441	pde_loss=7.278286	bndry_loss=23.269156	eigval=31.41637	dt=0.7079906463623047
# Epoch: 333	train_loss=30.54519	pde_loss=7.191158	bndry_loss=23.354033	eigval=31.415756	dt=0.7009921073913574
# Epoch: 334	train_loss=30.561455	pde_loss=7.220762	bndry_loss=23.340693	eigval=31.415142	dt=0.7054548263549805
# Epoch: 335	train_loss=30.572329	pde_loss=7.289843	bndry_loss=23.282486	eigval=31.414528	dt=0.7468984127044678
# Epoch: 336	train_loss=30.57652	pde_loss=7.2449765	bndry_loss=23.331545	eigval=31.413914	dt=0.7272195816040039
# Epoch: 337	train_loss=30.636845	pde_loss=7.2853103	bndry_loss=23.351534	eigval=31.4133	dt=0.7325413227081299
# Epoch: 338	train_loss=30.712978	pde_loss=7.358389	bndry_loss=23.35459	eigval=31.412683	dt=0.703427791595459
# Epoch: 339	train_loss=30.769993	pde_loss=7.2949486	bndry_loss=23.475044	eigval=31.412066	dt=0.7125530242919922
# Epoch: 340	train_loss=30.786911	pde_loss=7.3113165	bndry_loss=23.475594	eigval=31.411448	dt=0.7096483707427979
# Epoch: 341	train_loss=30.771149	pde_loss=7.3526297	bndry_loss=23.418518	eigval=31.410828	dt=0.7201249599456787
# Epoch: 342	train_loss=30.747074	pde_loss=7.1833696	bndry_loss=23.563705	eigval=31.41021	dt=0.6937355995178223
# Epoch: 343	train_loss=30.733198	pde_loss=7.150389	bndry_loss=23.58281	eigval=31.409592	dt=0.7196378707885742
# Epoch: 344	train_loss=30.731602	pde_loss=7.2433577	bndry_loss=23.488243	eigval=31.408976	dt=0.7281615734100342
# Epoch: 345	train_loss=30.736046	pde_loss=7.111831	bndry_loss=23.624214	eigval=31.408361	dt=0.7055416107177734
# Epoch: 346	train_loss=30.729185	pde_loss=7.0167155	bndry_loss=23.71247	eigval=31.40775	dt=0.7012276649475098
# Epoch: 347	train_loss=30.716946	pde_loss=7.1303077	bndry_loss=23.586637	eigval=31.407139	dt=0.7051994800567627
# Epoch: 348	train_loss=30.700064	pde_loss=7.0825977	bndry_loss=23.617466	eigval=31.40653	dt=0.7196576595306396
# Epoch: 349	train_loss=30.687225	pde_loss=6.9908032	bndry_loss=23.696423	eigval=31.405924	dt=0.709437370300293
# Epoch: 350	train_loss=30.658983	pde_loss=7.082194	bndry_loss=23.57679	eigval=31.40532	dt=0.7273299694061279
# Epoch: 351	train_loss=30.653355	pde_loss=7.1511908	bndry_loss=23.502163	eigval=31.404715	dt=0.9104816913604736
# Epoch: 352	train_loss=30.673101	pde_loss=7.0794015	bndry_loss=23.5937	eigval=31.404112	dt=0.7186167240142822
# Epoch: 353	train_loss=30.669777	pde_loss=7.107702	bndry_loss=23.562075	eigval=31.403511	dt=0.7133030891418457
# Epoch: 354	train_loss=30.684278	pde_loss=7.2258205	bndry_loss=23.458458	eigval=31.40291	dt=0.7648348808288574
# Epoch: 355	train_loss=30.666046	pde_loss=7.065224	bndry_loss=23.600822	eigval=31.40231	dt=0.6998872756958008
# Epoch: 356	train_loss=30.649021	pde_loss=7.089992	bndry_loss=23.559029	eigval=31.40171	dt=0.6921286582946777
# Epoch: 357	train_loss=30.649462	pde_loss=7.2095017	bndry_loss=23.43996	eigval=31.401112	dt=0.7295782566070557
# Epoch: 358	train_loss=30.651958	pde_loss=7.0633516	bndry_loss=23.588608	eigval=31.400513	dt=0.7044024467468262
# Epoch: 359	train_loss=30.649567	pde_loss=7.0832806	bndry_loss=23.566286	eigval=31.399916	dt=0.7156734466552734
# Epoch: 360	train_loss=30.647106	pde_loss=7.2294607	bndry_loss=23.417646	eigval=31.399319	dt=0.7033579349517822
# Epoch: 361	train_loss=30.639069	pde_loss=7.0998406	bndry_loss=23.539228	eigval=31.398722	dt=0.729074239730835
# Epoch: 362	train_loss=30.642519	pde_loss=7.0973344	bndry_loss=23.545185	eigval=31.398127	dt=0.7150619029998779
# Epoch: 363	train_loss=30.647543	pde_loss=7.241796	bndry_loss=23.405746	eigval=31.397532	dt=0.7224862575531006
# Epoch: 364	train_loss=30.641531	pde_loss=7.14197	bndry_loss=23.499561	eigval=31.396936	dt=0.7159953117370605
# Epoch: 365	train_loss=30.630096	pde_loss=7.093089	bndry_loss=23.537006	eigval=31.396343	dt=0.706174373626709
# Epoch: 366	train_loss=30.621248	pde_loss=7.2243	bndry_loss=23.396948	eigval=31.39575	dt=0.717400074005127
# Epoch: 367	train_loss=30.607141	pde_loss=7.107178	bndry_loss=23.499964	eigval=31.395157	dt=0.7227847576141357
# Epoch: 368	train_loss=30.606186	pde_loss=7.104994	bndry_loss=23.501192	eigval=31.394566	dt=0.715764045715332
# Epoch: 369	train_loss=30.608582	pde_loss=7.1893406	bndry_loss=23.41924	eigval=31.393974	dt=0.7195017337799072
# Epoch: 370	train_loss=30.633814	pde_loss=7.1325397	bndry_loss=23.501274	eigval=31.393383	dt=0.712700366973877
# Epoch: 371	train_loss=30.61232	pde_loss=7.01681	bndry_loss=23.59551	eigval=31.392792	dt=0.711693525314331
# Epoch: 372	train_loss=30.600052	pde_loss=7.2126203	bndry_loss=23.387432	eigval=31.3922	dt=0.7012472152709961
# Epoch: 373	train_loss=30.60518	pde_loss=7.141918	bndry_loss=23.463263	eigval=31.39161	dt=0.6900732517242432
# Epoch: 374	train_loss=30.618168	pde_loss=7.0616236	bndry_loss=23.556543	eigval=31.391018	dt=0.7031867504119873
# Epoch: 375	train_loss=30.59331	pde_loss=7.1657033	bndry_loss=23.427607	eigval=31.390427	dt=0.716264009475708
# Epoch: 376	train_loss=30.60891	pde_loss=7.1859446	bndry_loss=23.422966	eigval=31.389835	dt=0.7233190536499023
# Epoch: 377	train_loss=30.607063	pde_loss=7.010707	bndry_loss=23.596355	eigval=31.389246	dt=0.7276592254638672
# Epoch: 378	train_loss=30.579597	pde_loss=7.1505985	bndry_loss=23.428999	eigval=31.388657	dt=0.724445104598999
# Epoch: 379	train_loss=30.577057	pde_loss=7.1845655	bndry_loss=23.39249	eigval=31.388065	dt=0.7074861526489258
# Epoch: 380	train_loss=30.575508	pde_loss=6.9577	bndry_loss=23.617807	eigval=31.387476	dt=0.7053980827331543
# Epoch: 381	train_loss=30.53998	pde_loss=7.0890164	bndry_loss=23.450964	eigval=31.386887	dt=0.7306063175201416
# Epoch: 382	train_loss=30.535072	pde_loss=7.2190733	bndry_loss=23.315998	eigval=31.386297	dt=0.7209582328796387
# Epoch: 383	train_loss=30.530579	pde_loss=6.6364164	bndry_loss=23.894163	eigval=31.385712	dt=0.7107229232788086
# Epoch: 384	train_loss=30.51197	pde_loss=7.25817	bndry_loss=23.253801	eigval=31.385124	dt=0.7229864597320557
# Epoch: 385	train_loss=30.481447	pde_loss=7.2949867	bndry_loss=23.18646	eigval=31.384535	dt=0.7335977554321289
# Epoch: 386	train_loss=30.478249	pde_loss=6.781786	bndry_loss=23.696463	eigval=31.383947	dt=0.710418701171875
# Epoch: 387	train_loss=30.44801	pde_loss=7.1533265	bndry_loss=23.294683	eigval=31.38336	dt=0.7269163131713867
# Epoch: 388	train_loss=30.446297	pde_loss=7.3953547	bndry_loss=23.050941	eigval=31.382772	dt=0.7142660617828369
# Epoch: 389	train_loss=30.453228	pde_loss=6.866519	bndry_loss=23.586708	eigval=31.382187	dt=0.9149603843688965
# Epoch: 390	train_loss=30.437145	pde_loss=7.0211196	bndry_loss=23.416025	eigval=31.381601	dt=0.7092888355255127
# Epoch: 391	train_loss=30.423002	pde_loss=7.324839	bndry_loss=23.098164	eigval=31.381016	dt=0.7205195426940918
# Epoch: 392	train_loss=30.419968	pde_loss=6.8852415	bndry_loss=23.534727	eigval=31.380432	dt=0.7017538547515869
# Epoch: 393	train_loss=30.421494	pde_loss=6.9451494	bndry_loss=23.476345	eigval=31.379848	dt=0.7252697944641113
# Epoch: 394	train_loss=30.429712	pde_loss=7.3010345	bndry_loss=23.128677	eigval=31.379265	dt=0.7452864646911621
# Epoch: 395	train_loss=30.409977	pde_loss=6.951653	bndry_loss=23.458324	eigval=31.378681	dt=0.7486681938171387
# Epoch: 396	train_loss=30.404648	pde_loss=6.976652	bndry_loss=23.427996	eigval=31.3781	dt=0.7237038612365723
# Epoch: 397	train_loss=30.40441	pde_loss=7.283928	bndry_loss=23.120481	eigval=31.377516	dt=0.755795955657959
# Epoch: 398	train_loss=30.380444	pde_loss=6.9577045	bndry_loss=23.422739	eigval=31.376932	dt=0.7503900527954102
# Epoch: 399	train_loss=30.387255	pde_loss=6.9262547	bndry_loss=23.461	eigval=31.37635	dt=0.7075200080871582
# Epoch: 400	train_loss=30.38187	pde_loss=7.189705	bndry_loss=23.192165	eigval=31.375767	dt=0.716120719909668
# Epoch: 401	train_loss=30.363783	pde_loss=7.0090985	bndry_loss=23.354685	eigval=31.375183	dt=0.7066402435302734
# Epoch: 402	train_loss=30.363567	pde_loss=6.943047	bndry_loss=23.42052	eigval=31.374601	dt=0.7291629314422607
# Epoch: 403	train_loss=30.353474	pde_loss=7.1540117	bndry_loss=23.199461	eigval=31.374018	dt=0.7023441791534424
# Epoch: 404	train_loss=30.3335	pde_loss=7.0234127	bndry_loss=23.310087	eigval=31.373436	dt=0.7164757251739502
# Epoch: 405	train_loss=30.320787	pde_loss=6.9332733	bndry_loss=23.387514	eigval=31.372854	dt=0.7021005153656006
# Epoch: 406	train_loss=30.311213	pde_loss=7.106872	bndry_loss=23.20434	eigval=31.372272	dt=0.7326090335845947
# Epoch: 407	train_loss=30.302305	pde_loss=7.020792	bndry_loss=23.281513	eigval=31.371693	dt=0.7105307579040527
# Epoch: 408	train_loss=30.290428	pde_loss=6.920251	bndry_loss=23.370176	eigval=31.371113	dt=0.7165470123291016
# Epoch: 409	train_loss=30.265888	pde_loss=7.0505924	bndry_loss=23.215296	eigval=31.370533	dt=0.7194373607635498
# Epoch: 410	train_loss=30.268091	pde_loss=7.0571313	bndry_loss=23.21096	eigval=31.369953	dt=0.7372593879699707
# Epoch: 411	train_loss=30.258976	pde_loss=6.937728	bndry_loss=23.321247	eigval=31.369375	dt=0.7149841785430908
# Epoch: 412	train_loss=30.246044	pde_loss=7.0698905	bndry_loss=23.176153	eigval=31.368797	dt=0.7358334064483643
# Epoch: 413	train_loss=30.243097	pde_loss=7.085993	bndry_loss=23.157104	eigval=31.36822	dt=0.710106372833252
# Epoch: 414	train_loss=30.245956	pde_loss=6.978075	bndry_loss=23.267881	eigval=31.367641	dt=0.7412102222442627
# Epoch: 415	train_loss=30.247458	pde_loss=7.073379	bndry_loss=23.174078	eigval=31.367064	dt=0.7346863746643066
# Epoch: 416	train_loss=30.243876	pde_loss=7.081915	bndry_loss=23.16196	eigval=31.366486	dt=0.7214975357055664
# Epoch: 417	train_loss=30.234346	pde_loss=6.978721	bndry_loss=23.255625	eigval=31.36591	dt=0.7377336025238037
# Epoch: 418	train_loss=30.230797	pde_loss=7.069019	bndry_loss=23.161777	eigval=31.365334	dt=0.7228176593780518
# Epoch: 419	train_loss=30.230486	pde_loss=7.098528	bndry_loss=23.131958	eigval=31.364758	dt=0.7171652317047119
# Epoch: 420	train_loss=30.235426	pde_loss=7.0023093	bndry_loss=23.233116	eigval=31.364182	dt=0.7368826866149902
# Epoch: 421	train_loss=30.231289	pde_loss=7.0845795	bndry_loss=23.14671	eigval=31.363605	dt=0.7079918384552002
# Epoch: 422	train_loss=30.240078	pde_loss=7.121216	bndry_loss=23.118862	eigval=31.363028	dt=0.7504656314849854
# Epoch: 423	train_loss=30.23343	pde_loss=6.999983	bndry_loss=23.233448	eigval=31.36245	dt=0.7042014598846436
# Epoch: 424	train_loss=30.246231	pde_loss=7.1169844	bndry_loss=23.129248	eigval=31.361872	dt=0.7355363368988037
# Epoch: 425	train_loss=30.23199	pde_loss=7.074773	bndry_loss=23.157217	eigval=31.361292	dt=0.7232494354248047
# Epoch: 426	train_loss=30.228748	pde_loss=7.022072	bndry_loss=23.206676	eigval=31.360712	dt=0.7066383361816406
# Epoch: 427	train_loss=30.224453	pde_loss=7.0574946	bndry_loss=23.166958	eigval=31.360132	dt=0.9078688621520996
# Epoch: 428	train_loss=30.217419	pde_loss=7.055314	bndry_loss=23.162104	eigval=31.359552	dt=0.7216498851776123
# Epoch: 429	train_loss=30.213552	pde_loss=7.0594654	bndry_loss=23.154087	eigval=31.358973	dt=0.7129743099212646
# Epoch: 430	train_loss=30.210155	pde_loss=7.0664244	bndry_loss=23.14373	eigval=31.358393	dt=0.7064909934997559
# Epoch: 431	train_loss=30.211546	pde_loss=7.0834107	bndry_loss=23.128136	eigval=31.357813	dt=0.6959524154663086
# ...
# Epoch: 856	train_loss=29.88743	pde_loss=5.863295	bndry_loss=24.024136	eigval=31.12563	dt=0.7228529453277588
# Epoch: 857	train_loss=29.850132	pde_loss=8.50033	bndry_loss=21.349802	eigval=31.125095	dt=0.7059235572814941
# Epoch: 858	train_loss=29.890736	pde_loss=5.864419	bndry_loss=24.026318	eigval=31.124567	dt=0.700514554977417
# Epoch: 859	train_loss=29.790524	pde_loss=8.181302	bndry_loss=21.60922	eigval=31.124033	dt=0.724747896194458
# Epoch: 860	train_loss=29.750278	pde_loss=6.4917493	bndry_loss=23.25853	eigval=31.123503	dt=0.726081371307373
# Epoch: 861	train_loss=29.706936	pde_loss=7.428455	bndry_loss=22.27848	eigval=31.12297	dt=0.7228455543518066
# Epoch: 862	train_loss=29.700132	pde_loss=7.3030033	bndry_loss=22.39713	eigval=31.122438	dt=0.7246448993682861
# Epoch: 863	train_loss=29.705994	pde_loss=6.677929	bndry_loss=23.028065	eigval=31.121908	dt=0.7325983047485352
# Epoch: 864	train_loss=29.72321	pde_loss=7.9161468	bndry_loss=21.807062	eigval=31.121374	dt=0.7079248428344727
# Epoch: 865	train_loss=29.748173	pde_loss=6.228547	bndry_loss=23.519625	eigval=31.120846	dt=0.7030994892120361
# Epoch: 866	train_loss=29.717587	pde_loss=8.081441	bndry_loss=21.636147	eigval=31.120312	dt=0.7117712497711182
# Epoch: 867	train_loss=29.716389	pde_loss=6.3477693	bndry_loss=23.36862	eigval=31.119781	dt=0.7043471336364746
# Epoch: 868	train_loss=29.675146	pde_loss=7.7129326	bndry_loss=21.962214	eigval=31.11925	dt=0.7208433151245117
# Epoch: 869	train_loss=29.653057	pde_loss=6.916186	bndry_loss=22.736872	eigval=31.118717	dt=0.7104449272155762
# Epoch: 870	train_loss=29.640102	pde_loss=7.0816283	bndry_loss=22.558474	eigval=31.118187	dt=0.7549898624420166
# Epoch: 871	train_loss=29.64967	pde_loss=7.4971533	bndry_loss=22.152515	eigval=31.117655	dt=0.7461578845977783
# Epoch: 872	train_loss=29.668785	pde_loss=6.596725	bndry_loss=23.07206	eigval=31.117125	dt=0.6943323612213135
# Epoch: 873	train_loss=29.685333	pde_loss=7.8088	bndry_loss=21.876534	eigval=31.11659	dt=0.7106928825378418
# Epoch: 874	train_loss=29.693384	pde_loss=6.4917293	bndry_loss=23.201654	eigval=31.11606	dt=0.7057034969329834
# Epoch: 875	train_loss=29.679884	pde_loss=7.732242	bndry_loss=21.947641	eigval=31.115526	dt=0.7110550403594971
# Epoch: 876	train_loss=29.673937	pde_loss=6.758075	bndry_loss=22.915861	eigval=31.114994	dt=0.736703634262085
# Epoch: 877	train_loss=29.660105	pde_loss=7.3554	bndry_loss=22.304705	eigval=31.114462	dt=0.7185459136962891
# Epoch: 878	train_loss=29.649715	pde_loss=7.1743813	bndry_loss=22.475334	eigval=31.113928	dt=0.7149708271026611
# Epoch: 879	train_loss=29.65609	pde_loss=6.9506288	bndry_loss=22.705462	eigval=31.113396	dt=0.7099332809448242
# Epoch: 880	train_loss=29.661283	pde_loss=7.505878	bndry_loss=22.155405	eigval=31.112862	dt=0.6974325180053711
# Epoch: 881	train_loss=29.67876	pde_loss=6.6825294	bndry_loss=22.996231	eigval=31.11233	dt=0.7175874710083008
# Epoch: 882	train_loss=29.681566	pde_loss=7.666514	bndry_loss=22.015053	eigval=31.111795	dt=0.7051353454589844
# Epoch: 883	train_loss=29.678284	pde_loss=6.676511	bndry_loss=23.001772	eigval=31.111263	dt=0.9655566215515137
# Epoch: 884	train_loss=29.678732	pde_loss=7.545572	bndry_loss=22.13316	eigval=31.11073	dt=0.7154233455657959
# Epoch: 885	train_loss=29.665783	pde_loss=6.889094	bndry_loss=22.77669	eigval=31.110197	dt=0.757194995880127
# Epoch: 886	train_loss=29.659767	pde_loss=7.256919	bndry_loss=22.402847	eigval=31.109663	dt=0.7110025882720947
# Epoch: 887	train_loss=29.672003	pde_loss=7.1867313	bndry_loss=22.485271	eigval=31.109129	dt=0.7355613708496094
# Epoch: 888	train_loss=29.68189	pde_loss=6.9582486	bndry_loss=22.723642	eigval=31.108597	dt=0.7275683879852295
# Epoch: 889	train_loss=29.691616	pde_loss=7.445118	bndry_loss=22.246498	eigval=31.108063	dt=0.7045073509216309
# Epoch: 890	train_loss=29.694023	pde_loss=6.789936	bndry_loss=22.904087	eigval=31.10753	dt=0.7107405662536621
# Epoch: 891	train_loss=29.698444	pde_loss=7.5174813	bndry_loss=22.180964	eigval=31.106997	dt=0.723118782043457
# Epoch: 892	train_loss=29.693703	pde_loss=6.7873373	bndry_loss=22.906364	eigval=31.106464	dt=0.7116518020629883
# Epoch: 893	train_loss=29.691929	pde_loss=7.434083	bndry_loss=22.257847	eigval=31.10593	dt=0.713972806930542
# Epoch: 894	train_loss=29.689602	pde_loss=6.939061	bndry_loss=22.75054	eigval=31.105396	dt=0.722569465637207
# Epoch: 895	train_loss=29.690704	pde_loss=7.238375	bndry_loss=22.45233	eigval=31.104862	dt=0.7284419536590576
# Epoch: 896	train_loss=29.688446	pde_loss=7.1628904	bndry_loss=22.525555	eigval=31.104328	dt=0.7352728843688965
# Epoch: 897	train_loss=29.687403	pde_loss=7.0406303	bndry_loss=22.646772	eigval=31.103794	dt=0.7038674354553223
# Epoch: 898	train_loss=29.696943	pde_loss=7.3237023	bndry_loss=22.373241	eigval=31.103258	dt=0.7087209224700928
# Epoch: 899	train_loss=29.70272	pde_loss=6.9196486	bndry_loss=22.783072	eigval=31.102724	dt=0.7338624000549316
# Epoch: 900	train_loss=29.701643	pde_loss=7.376219	bndry_loss=22.325424	eigval=31.102188	dt=0.7199623584747314
# Epoch: 901	train_loss=29.715704	pde_loss=6.955807	bndry_loss=22.759897	eigval=31.101652	dt=0.7210335731506348
# Epoch: 902	train_loss=29.717602	pde_loss=7.2908344	bndry_loss=22.426767	eigval=31.101116	dt=0.7325427532196045
# Epoch: 903	train_loss=29.71914	pde_loss=7.090938	bndry_loss=22.6282	eigval=31.10058	dt=0.7466082572937012
# Epoch: 904	train_loss=29.72334	pde_loss=7.180783	bndry_loss=22.542557	eigval=31.100044	dt=0.7199962139129639
# Epoch: 905	train_loss=29.717953	pde_loss=7.1936407	bndry_loss=22.524311	eigval=31.099506	dt=0.7232134342193604
# Epoch: 906	train_loss=29.718304	pde_loss=7.0872064	bndry_loss=22.631098	eigval=31.098969	dt=0.7005329132080078
# Epoch: 907	train_loss=29.726715	pde_loss=7.261521	bndry_loss=22.465195	eigval=31.09843	dt=0.7034478187561035
# Epoch: 908	train_loss=29.733929	pde_loss=7.0395346	bndry_loss=22.694395	eigval=31.097893	dt=0.7337822914123535
# Epoch: 909	train_loss=29.74303	pde_loss=7.2798624	bndry_loss=22.46317	eigval=31.097355	dt=0.7024023532867432
# Epoch: 910	train_loss=29.747616	pde_loss=7.029128	bndry_loss=22.718489	eigval=31.096817	dt=0.7179996967315674
# Epoch: 911	train_loss=29.74771	pde_loss=7.270098	bndry_loss=22.477612	eigval=31.09628	dt=0.7123053073883057
# Epoch: 912	train_loss=29.762787	pde_loss=7.0868635	bndry_loss=22.675922	eigval=31.095741	dt=0.7333126068115234
# Epoch: 913	train_loss=29.765423	pde_loss=7.1997046	bndry_loss=22.565718	eigval=31.095201	dt=0.7306606769561768
# Epoch: 914	train_loss=29.775236	pde_loss=7.186178	bndry_loss=22.589058	eigval=31.094662	dt=0.6951560974121094
# Epoch: 915	train_loss=29.775604	pde_loss=7.098846	bndry_loss=22.676758	eigval=31.094122	dt=0.7403476238250732
# Epoch: 916	train_loss=29.782269	pde_loss=7.268463	bndry_loss=22.513805	eigval=31.093582	dt=0.7264056205749512
# Epoch: 917	train_loss=29.78396	pde_loss=7.017261	bndry_loss=22.766699	eigval=31.093042	dt=0.7431294918060303
# Epoch: 918	train_loss=29.779543	pde_loss=7.304464	bndry_loss=22.475079	eigval=31.0925	dt=0.7169134616851807
# Epoch: 919	train_loss=29.780598	pde_loss=6.9657507	bndry_loss=22.814848	eigval=31.09196	dt=0.7083132266998291
# Epoch: 920	train_loss=29.78645	pde_loss=7.3433867	bndry_loss=22.443064	eigval=31.09142	dt=0.7204549312591553
# Epoch: 921	train_loss=29.781723	pde_loss=6.9533014	bndry_loss=22.82842	eigval=31.09088	dt=0.9537312984466553
# Epoch: 922	train_loss=29.79313	pde_loss=7.3244686	bndry_loss=22.468662	eigval=31.090338	dt=0.706763505935669
# Epoch: 923	train_loss=29.813572	pde_loss=7.0318766	bndry_loss=22.781696	eigval=31.089796	dt=0.6949141025543213
# Epoch: 924	train_loss=29.829794	pde_loss=7.261102	bndry_loss=22.568691	eigval=31.089254	dt=0.7543301582336426
# Epoch: 925	train_loss=29.838419	pde_loss=7.1354594	bndry_loss=22.70296	eigval=31.088713	dt=0.7334058284759521
# Epoch: 926	train_loss=29.836178	pde_loss=7.161939	bndry_loss=22.674238	eigval=31.088171	dt=0.7256896495819092
# Epoch: 927	train_loss=29.863094	pde_loss=7.248906	bndry_loss=22.61419	eigval=31.087627	dt=0.6993002891540527
# Epoch: 928	train_loss=29.887222	pde_loss=7.0709047	bndry_loss=22.816317	eigval=31.087084	dt=0.7160458564758301
# Epoch: 929	train_loss=29.89658	pde_loss=7.3085423	bndry_loss=22.588037	eigval=31.08654	dt=0.7240340709686279
# Epoch: 930	train_loss=29.906706	pde_loss=7.0582047	bndry_loss=22.848501	eigval=31.085997	dt=0.7310225963592529
# Epoch: 931	train_loss=29.912155	pde_loss=7.285445	bndry_loss=22.626709	eigval=31.085453	dt=0.7067971229553223
# Epoch: 932	train_loss=29.930332	pde_loss=7.111378	bndry_loss=22.818954	eigval=31.08491	dt=0.7169239521026611
# Epoch: 933	train_loss=29.931637	pde_loss=7.207217	bndry_loss=22.724419	eigval=31.084366	dt=0.7087278366088867
# Epoch: 934	train_loss=29.927427	pde_loss=7.1845436	bndry_loss=22.742884	eigval=31.083822	dt=0.7092020511627197
# Epoch: 935	train_loss=29.93147	pde_loss=7.1266	bndry_loss=22.80487	eigval=31.083279	dt=0.6898064613342285
# Epoch: 936	train_loss=29.937727	pde_loss=7.242884	bndry_loss=22.694843	eigval=31.082733	dt=0.7301433086395264
# Epoch: 937	train_loss=29.939655	pde_loss=7.0634437	bndry_loss=22.876211	eigval=31.08219	dt=0.7194035053253174
# Epoch: 938	train_loss=29.949026	pde_loss=7.284579	bndry_loss=22.664448	eigval=31.081644	dt=0.7146487236022949
# Epoch: 939	train_loss=29.955269	pde_loss=7.03603	bndry_loss=22.919239	eigval=31.0811	dt=0.7203149795532227
# Epoch: 940	train_loss=29.960163	pde_loss=7.314621	bndry_loss=22.645542	eigval=31.080555	dt=0.6942627429962158
# Epoch: 941	train_loss=29.98684	pde_loss=7.048242	bndry_loss=22.938597	eigval=31.080011	dt=0.7239298820495605
# Epoch: 942	train_loss=30.000294	pde_loss=7.289934	bndry_loss=22.71036	eigval=31.079466	dt=0.7018649578094482
# Epoch: 943	train_loss=30.001705	pde_loss=7.095639	bndry_loss=22.906067	eigval=31.07892	dt=0.7196636199951172
# Epoch: 944	train_loss=30.010538	pde_loss=7.2565885	bndry_loss=22.75395	eigval=31.078375	dt=0.712439775466919
# Epoch: 945	train_loss=30.011868	pde_loss=7.147166	bndry_loss=22.864702	eigval=31.07783	dt=0.7314343452453613
# Epoch: 946	train_loss=30.018604	pde_loss=7.2212048	bndry_loss=22.7974	eigval=31.077284	dt=0.7497868537902832
# Epoch: 947	train_loss=30.024061	pde_loss=7.192346	bndry_loss=22.831715	eigval=31.076738	dt=0.7064294815063477
# Epoch: 948	train_loss=30.011528	pde_loss=7.171552	bndry_loss=22.839975	eigval=31.076193	dt=0.7073867321014404
# Epoch: 949	train_loss=30.01068	pde_loss=7.236694	bndry_loss=22.773985	eigval=31.075647	dt=0.718224287033081
# Epoch: 950	train_loss=30.005405	pde_loss=7.12376	bndry_loss=22.881645	eigval=31.075102	dt=0.7109789848327637
# Epoch: 951	train_loss=29.996376	pde_loss=7.2594476	bndry_loss=22.736929	eigval=31.074556	dt=0.7104837894439697
# Epoch: 952	train_loss=29.98852	pde_loss=7.0954194	bndry_loss=22.8931	eigval=31.07401	dt=0.7163505554199219
# Epoch: 953	train_loss=29.983284	pde_loss=7.2512045	bndry_loss=22.73208	eigval=31.073465	dt=0.7037115097045898
# Epoch: 954	train_loss=29.977379	pde_loss=7.069125	bndry_loss=22.908253	eigval=31.072922	dt=0.7385969161987305
# Epoch: 955	train_loss=29.987473	pde_loss=7.284689	bndry_loss=22.702784	eigval=31.072376	dt=0.7319562435150146
# Epoch: 956	train_loss=29.978882	pde_loss=7.0267015	bndry_loss=22.95218	eigval=31.071833	dt=0.7017030715942383
# Epoch: 957	train_loss=29.979948	pde_loss=7.3415008	bndry_loss=22.638447	eigval=31.07129	dt=0.7322664260864258
# Epoch: 958	train_loss=29.973124	pde_loss=6.9583282	bndry_loss=23.014795	eigval=31.070747	dt=0.7168598175048828
# Epoch: 959	train_loss=29.97133	pde_loss=7.4332643	bndry_loss=22.538067	eigval=31.070204	dt=0.9223160743713379
# Epoch: 960	train_loss=29.96391	pde_loss=6.861979	bndry_loss=23.10193	eigval=31.069662	dt=0.7083404064178467
# Epoch: 961	train_loss=29.962011	pde_loss=7.5259533	bndry_loss=22.436058	eigval=31.069118	dt=0.7359371185302734
# Epoch: 962	train_loss=29.953403	pde_loss=6.767232	bndry_loss=23.186172	eigval=31.068579	dt=0.7116940021514893
# Epoch: 963	train_loss=29.969854	pde_loss=7.6311436	bndry_loss=22.33871	eigval=31.068035	dt=0.7004106044769287
# Epoch: 964	train_loss=29.973793	pde_loss=6.6677904	bndry_loss=23.306002	eigval=31.067495	dt=0.7299230098724365
# Epoch: 965	train_loss=29.974758	pde_loss=7.72691	bndry_loss=22.247849	eigval=31.066954	dt=0.7245135307312012
# Epoch: 966	train_loss=29.975677	pde_loss=6.5815234	bndry_loss=23.394154	eigval=31.066414	dt=0.7164242267608643
# Epoch: 967	train_loss=29.98422	pde_loss=7.788004	bndry_loss=22.196217	eigval=31.065872	dt=0.7242188453674316
# Epoch: 968	train_loss=29.983583	pde_loss=6.5194774	bndry_loss=23.464106	eigval=31.065334	dt=0.7181644439697266
# Epoch: 969	train_loss=29.983526	pde_loss=7.8492875	bndry_loss=22.13424	eigval=31.064793	dt=0.7175486087799072
# Epoch: 970	train_loss=29.98722	pde_loss=6.463931	bndry_loss=23.52329	eigval=31.064255	dt=0.7200162410736084
# Epoch: 971	train_loss=29.985603	pde_loss=7.882243	bndry_loss=22.10336	eigval=31.063713	dt=0.7033748626708984
# Epoch: 972	train_loss=29.991676	pde_loss=6.4922166	bndry_loss=23.49946	eigval=31.063175	dt=0.718026876449585
# Epoch: 973	train_loss=29.985098	pde_loss=7.8209834	bndry_loss=22.164114	eigval=31.062635	dt=0.7259843349456787
# Epoch: 974	train_loss=29.980892	pde_loss=6.610132	bndry_loss=23.37076	eigval=31.062098	dt=0.7163915634155273
# Epoch: 975	train_loss=29.987473	pde_loss=7.693878	bndry_loss=22.293594	eigval=31.061558	dt=0.7132670879364014
# Epoch: 976	train_loss=29.977425	pde_loss=6.768556	bndry_loss=23.208868	eigval=31.06102	dt=0.7077538967132568
# Epoch: 977	train_loss=29.984554	pde_loss=7.541839	bndry_loss=22.442715	eigval=31.06048	dt=0.7037692070007324
# Epoch: 978	train_loss=29.98182	pde_loss=6.9258666	bndry_loss=23.055952	eigval=31.059942	dt=0.7450718879699707
# Epoch: 979	train_loss=29.989494	pde_loss=7.4009156	bndry_loss=22.58858	eigval=31.059402	dt=0.7214264869689941
# Epoch: 980	train_loss=29.982555	pde_loss=7.057233	bndry_loss=22.925322	eigval=31.058863	dt=0.7069611549377441
# Epoch: 981	train_loss=29.985178	pde_loss=7.2734694	bndry_loss=22.711708	eigval=31.058323	dt=0.7135088443756104
# Epoch: 982	train_loss=29.976816	pde_loss=7.144995	bndry_loss=22.831821	eigval=31.057783	dt=0.7227506637573242
# Epoch: 983	train_loss=29.981293	pde_loss=7.1906047	bndry_loss=22.790688	eigval=31.057243	dt=0.7232897281646729
# Epoch: 984	train_loss=29.985615	pde_loss=7.214686	bndry_loss=22.77093	eigval=31.056704	dt=0.7126247882843018
# Epoch: 985	train_loss=29.98688	pde_loss=7.1129327	bndry_loss=22.873947	eigval=31.056166	dt=0.7330315113067627
# Epoch: 986	train_loss=29.985237	pde_loss=7.262508	bndry_loss=22.722729	eigval=31.055626	dt=0.703906774520874
# Epoch: 987	train_loss=29.996666	pde_loss=7.0766764	bndry_loss=22.91999	eigval=31.055088	dt=0.7314739227294922
# Epoch: 988	train_loss=29.987469	pde_loss=7.2995615	bndry_loss=22.687908	eigval=31.05455	dt=0.7042806148529053
# Epoch: 989	train_loss=29.990318	pde_loss=7.0623655	bndry_loss=22.927952	eigval=31.054012	dt=0.7022089958190918
# Epoch: 990	train_loss=29.998049	pde_loss=7.3280735	bndry_loss=22.669975	eigval=31.053474	dt=0.7350718975067139
# Epoch: 991	train_loss=30.001553	pde_loss=7.039328	bndry_loss=22.962225	eigval=31.052938	dt=0.6936705112457275
# Epoch: 992	train_loss=30.002275	pde_loss=7.365332	bndry_loss=22.636944	eigval=31.0524	dt=0.7083370685577393
# Epoch: 993	train_loss=29.997946	pde_loss=6.9797287	bndry_loss=23.018217	eigval=31.051865	dt=0.7109904289245605
# Epoch: 994	train_loss=30.008963	pde_loss=7.444675	bndry_loss=22.564287	eigval=31.051327	dt=0.7376365661621094
# Epoch: 995	train_loss=30.00634	pde_loss=6.8819704	bndry_loss=23.12437	eigval=31.05079	dt=0.7124369144439697
# Epoch: 996	train_loss=30.014658	pde_loss=7.5856194	bndry_loss=22.429039	eigval=31.050253	dt=0.7168593406677246
# Epoch: 997	train_loss=30.018724	pde_loss=6.6915765	bndry_loss=23.327148	eigval=31.049719	dt=0.901611328125
# Epoch: 998	train_loss=30.044418	pde_loss=7.805315	bndry_loss=22.239103	eigval=31.049183	dt=0.724109411239624
# Epoch: 999	train_loss=30.064066	pde_loss=6.4133096	bndry_loss=23.650757	eigval=31.04865	dt=0.7095623016357422
# Epoch: 1000	train_loss=30.083519	pde_loss=8.100083	bndry_loss=21.983437	eigval=31.048115	dt=0.7205584049224854
# Epoch: 1000	Train Loss = 30.083518981933594,	Test Loss = -1

# %%
# plot buckling mode again
plot_mode()

# %%
# plot the training losses
import matplotlib.pyplot as plt
import numpy as np
import niceplots
import ml_buckling as mlb

plt.style.use(niceplots.get_style())
ncolors = 3
# colors = plt.cm.jet(np.linspace(0.0, 1.0, ncolors))
colors = mlb.four_colors4
num_epochs = len(losses_hist)
epochs = [_ for _ in range(1, num_epochs + 1)]
# losses_hist += [
#     {'pde' : pde_loss, 'bndry' : bndry_loss, 'train' : train_loss}]
i = 0
for key in ['train', 'bndry', 'pde']:
    loss = [_[key] for _ in losses_hist]
    plt.plot(epochs, loss, label=key, color=colors[i])
    i+= 1
plt.yscale('log')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.margins(x=0.05, y=0.05)
plt.legend()

# %%
# compute L2 norm of the solution
w_pred = model(x_train)
w_true = np.sin(np.pi * x) * np.sin(np.pi * y) * np.max(np.abs(w_pred))
# print(f"{w_true=}")
rel_err = np.max(np.abs(w_true - w_pred)) / np.max(np.abs(w_true))
print(f"{rel_err=}")
# Out:
# rel_err=0.4438585
