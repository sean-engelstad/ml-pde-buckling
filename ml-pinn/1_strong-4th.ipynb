# %%
# buckling inputs
# ----------------

# aluminum plate material properties
E = 70e9; nu = 0.3; thick = 0.005
D = E * thick**3 / 12.0 / (1 - nu**2)
# D = 1

# choose loading type (first just uniaxial loading in x-direction)
# axial = True
axial = True
if axial:
    Nxx, Nxy, Nyy = (1e3, 0, 0)
else:
    Nxx, Nxy, Nyy = (0, 1e2, 0)

a, b = (1, 1)

# predict the buckling load factor (BLF)
pi = 3.14159
if axial:
    pred_buckling_load = pi**2 * D / b**2 * 4.0 
    pred_load_factor = pred_buckling_load / Nxx
    sigma = 0.5 * pred_load_factor
    print(f"{pred_load_factor=}")
# Out:
# pred_load_factor=31.633294000320518

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

num_domain = 10000
num_test = 500

DTYPE = tf.float32

# set the boundary of the panel
xmin = 0; xmax = a
ymin = 0; ymax = b

lb = tf.constant([xmin, ymin], dtype=DTYPE)
ub = tf.constant([xmax, ymax], dtype=DTYPE)

# generate the collocation points on the interior
def gen_collocation_points(num_domain, minval, maxval):
    x_r = tf.random.uniform((num_domain,1), minval[0], maxval[0], dtype=DTYPE)
    y_r = tf.random.uniform((num_domain,1), minval[1], maxval[1], dtype=DTYPE)
    X_r = tf.concat([x_r, y_r], axis=1)
    # data_init = tf.random_uniform_initializer(minval=minval, maxval=maxval, seed=0)
    # return tf.Variable(data_init(shape=[num_domain, 1]), dtype=tf.float32)
    return tf.Variable(X_r, dtype=DTYPE)

x_train = gen_collocation_points(num_domain, lb, ub)
x_test = gen_collocation_points(num_test, lb, ub)
print(f"{type(x_train)=}")

x = x_train[:,0:1]
y = x_train[:,1:2]

# generate boundary domain points
N_b = 100
x_b1 = tf.random.uniform((N_b,1), lb[0], ub[0], dtype=DTYPE)
y_b1 = lb[1] + (ub[1] - lb[1]) * \
    tf.keras.backend.random_bernoulli((N_b,1), 0.5, dtype=DTYPE)
X_b1 = tf.concat([x_b1, y_b1], axis=0)

# boundary data on x edges
y_b2 = tf.random.uniform((N_b,1), lb[1], ub[1], dtype=DTYPE)
x_b2 = lb[0] + (ub[0] - lb[0]) * \
    tf.keras.backend.random_bernoulli((N_b,1), 0.5, dtype=DTYPE)
X_b2 = tf.concat([x_b2, y_b2], axis=0)
# print(f"{x_b2=}")

x_bndry = tf.Variable(tf.concat([X_b1, X_b2], axis=1), dtype=DTYPE)

# plot the data to check
plt.scatter(x_bndry[:,0], x_bndry[:,1])
plt.scatter(x_train[:1000,0], x_train[:1000,1]) # only show 1000 of the points
plt.show()
# Out:
# type(x_train)=<class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>

# %%
from tensorflow.keras.initializers import HeNormal

# now start building the tensorflow model
n_inputs = 2
n_outputs = 1
hidden_units = [50, 50, 50]
# activation = 'tanh'
activation = 'relu'

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Input((n_inputs,)))

for units in hidden_units:
  model.add(tf.keras.layers.Dense(units=units, activation=activation, kernel_initializer=HeNormal()))
  # debug : add dropout layers?
  # model.add(tf.keras.layers.Dropout(0.4))

last_activation = 'tanh' # for normalized output since eigenmode
# last_activation = None 
model.add(tf.keras.layers.Dense(units=n_outputs, activation=last_activation, kernel_initializer=HeNormal()))
model.summary()

# also add lambda the eigenvalue trainable parameter to update
guess = pred_load_factor # cheat guess first
lambda_var = model.add_weight(name="lambda_var", initializer=tf.keras.initializers.Constant(guess), trainable=True)
# Out:
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_80 (Dense)                │ (None, 50)             │           150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_81 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_82 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_83 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,301 (20.71 KB)
#  Trainable params: 5,301 (20.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# plot the initial buckling mode prediction
import matplotlib.pyplot as plt
import numpy as np

def plot_mode(n=50):
    n = 50
    x_vec = np.linspace(0, a, n)
    y_vec = np.linspace(0, b, n)
    X, Y = np.meshgrid(x_vec, y_vec)
    x_flat = np.reshape(X, newshape=(n*n,1))
    y_flat = np.reshape(Y, newshape=(n*n,1))
    grid_inputs = np.concatenate([x_flat, y_flat], axis=1)
    w = model(grid_inputs)
    W = np.reshape(w, newshape=(n,n))

    # plt.figure(figsize=(8, 6))
    # colors = plt.contourf(X, Y, W, levels=20, cmap='viridis', alpha=0.75)  # Filled contours
    # plt.colorbar(colors, label="w(x,y)")  # Colorbar for reference

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    surface = ax.plot_surface(X, Y, W, cmap='viridis')

    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")
    # plt.title("2D Contour Plot")
    plt.show()

plot_mode()

# %%
# fit and optimize the model
epochs = 1000
# epochs = 50
learning_rate = 0.0005

optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# print(f"{type(x_train)=}")

for i in range(epochs + 1):
  with tf.GradientTape(persistent=False) as tape_model:

    # pde loss
    with tf.GradientTape(persistent=True) as tape3:
      tape3.watch(x)
      tape3.watch(y)
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(x)  # Ensure that x is watched by tape1
        tape2.watch(y)  # Ensure that y is watched by tape1
        with tf.GradientTape(persistent=True) as tape1:
            tape1.watch(x)  # Ensure that x is watched by tape1
            tape1.watch(y)  # Ensure that y is watched by tape1
            w_raw = model(tf.stack([x[:, 0], y[:, 0]], axis=1), training=True)
            # normalize the eigenmode so it focuses on shape of eigenmode instead of just trying to make the
            # magnitudes smaller..
            w = w_raw / tf.norm(w_raw)
            # print(f"{w=}")
            
            # Compute gradients with respect to x and y
            dx = tape1.gradient(w, x)
            dy = tape1.gradient(w, y)
            # print(f"{dx=} {dy=}")

        # Compute the second derivative of dx with respect to x
        d2x = tape1.gradient(dx, x)
        dxy = tape1.gradient(dx, y)
        d2y = tape1.gradient(dy, y)
        # print(f"{d2x=} {dxy=} {d2y=}")

      d3x = tape2.gradient(d2x, x)
      d2xy = tape2.gradient(d2x, y)
      d3y = tape2.gradient(d2y, y)
      # print(f"{d3x=}")

    d4x = tape3.gradient(d3x, x)
    d2x2y = tape3.gradient(d2xy, y)
    d4y = tape3.gradient(d3y, y)
    # print(f"{d4x=} {d2x2y=} {d4y=}")

    # now compute PDE residual
    # consider normalizing PDE residual a bit.. so more comparable to BC loss
    res_pde = (d4x + 2. * d2x2y + d4y) - lambda_var * \
            (Nxx * d2x + 2. * Nxy * dxy + Nyy * d2y) / D    
    # print(f"{res_pde=}")

    # boundary condition loss, SS w = 0
    w_raw_bndry = model(x_bndry, training=True)
    # normalize the eigenmode prediction
    w_norm = tf.norm(model(x_train, training=True))
    res_bndry = w_raw_bndry / w_norm
    # print(f"{res_bndry=}")

    # compute mse loss function
    scale = 1e3
    # scale = 1e2
    bndry_mse = tf.math.reduce_mean(tf.math.square(scale * res_bndry), axis=0)
    pde_mse = tf.math.reduce_mean(tf.math.square(res_pde), axis=0)
    total_mse = pde_mse + bndry_mse 

    # debug try just bndry loss
    # total_mse = bndry_mse

  # compute training gradients (ML model and lambd teh eigenvalue)
  # grads_lambda = tape_model.gradient(total_mse, lambd)
  model_update_gradients = tape_model.gradient(total_mse, model.trainable_variables)
  # print(f"{grads_lambda=}")
  # bndry_gradients = tape_model.gradient(bndry_mse, model.trainable_variables)
  # print(f"{model_update_gradients=}")
  # print(f"{bndry_gradients=}")
  # exit(0)

  del tape1, tape2, tape3

  # apply optimizer updates to ML model and predicted eigenvalue
  optimizer.apply_gradients(
    zip(model_update_gradients, model.trainable_variables)
  )  
  # optimizer.apply_gradients([(grads_lambda, lambd)])

  del tape_model

  train_loss = total_mse.numpy()[0]
  eigval = lambda_var.numpy()
  pde_loss = pde_mse.numpy()[0]
  bndry_loss = bndry_mse.numpy()[0]
  print(f"Epoch: {i}\t{train_loss=}\t{pde_loss=}\t{bndry_loss=}\t{eigval=}")

  if abs(train_loss) < 0.01: # error based stopping criterion
    break

  if i % 1000 == 0:
    # y_preds = model(x_test)
    test_mse = tf.constant(-1)
    # test_mse = tf.math.reduce_mean(tf.math.square(y_preds - tf.math.sin(np.pi*x_test)), axis=0)
    print('Epoch: {}\tTrain Loss = {},\tTest Loss = {}'.format(i, total_mse.numpy()[0], test_mse.numpy()))
# Out:
# Epoch: 0	train_loss=153.57756	pde_loss=33.39734	bndry_loss=120.18022	eigval=31.632793
# Epoch: 0	Train Loss = 153.5775604248047,	Test Loss = -1
# Epoch: 1	train_loss=124.07785	pde_loss=10.581659	bndry_loss=113.49619	eigval=31.632402
# Epoch: 2	train_loss=112.9894	pde_loss=4.263062	bndry_loss=108.72634	eigval=31.632118
# Epoch: 3	train_loss=107.53305	pde_loss=2.2636852	bndry_loss=105.26936	eigval=31.631914
# Epoch: 4	train_loss=104.203735	pde_loss=1.5099506	bndry_loss=102.69379	eigval=31.631765
# Epoch: 5	train_loss=101.96747	pde_loss=1.1472031	bndry_loss=100.82027	eigval=31.631655
# Epoch: 6	train_loss=100.24886	pde_loss=0.94041836	bndry_loss=99.30844	eigval=31.631573
# Epoch: 7	train_loss=98.81862	pde_loss=0.7953536	bndry_loss=98.02326	eigval=31.631512
# Epoch: 8	train_loss=97.59443	pde_loss=0.6896831	bndry_loss=96.90475	eigval=31.631466
# Epoch: 9	train_loss=96.519615	pde_loss=0.60970366	bndry_loss=95.90991	eigval=31.631432
# Epoch: 10	train_loss=95.5565	pde_loss=0.5429415	bndry_loss=95.013565	eigval=31.631407
# Epoch: 11	train_loss=94.68266	pde_loss=0.48881954	bndry_loss=94.19384	eigval=31.631388
# Epoch: 12	train_loss=93.87998	pde_loss=0.4425836	bndry_loss=93.4374	eigval=31.631374
# Epoch: 13	train_loss=93.12801	pde_loss=0.4040948	bndry_loss=92.723915	eigval=31.631365
# Epoch: 43	train_loss=76.24255	pde_loss=1.1128113	bndry_loss=75.129745	eigval=31.628311
# Epoch: 44	train_loss=75.895164	pde_loss=1.2850648	bndry_loss=74.6101	eigval=31.627874
# Epoch: 45	train_loss=75.60387	pde_loss=1.488209	bndry_loss=74.115654	eigval=31.627396
# Epoch: 46	train_loss=75.34714	pde_loss=1.7031705	bndry_loss=73.64397	eigval=31.626875
# Epoch: 47	train_loss=75.13667	pde_loss=1.9429809	bndry_loss=73.193695	eigval=31.626314
# Epoch: 48	train_loss=74.94375	pde_loss=2.1790912	bndry_loss=72.764656	eigval=31.625715
# Epoch: 49	train_loss=74.779594	pde_loss=2.4217825	bndry_loss=72.35781	eigval=31.62508
# Epoch: 50	train_loss=74.634514	pde_loss=2.652799	bndry_loss=71.98171	eigval=31.624414
# Epoch: 51	train_loss=74.48921	pde_loss=2.8637455	bndry_loss=71.625465	eigval=31.62372
# Epoch: 52	train_loss=74.33079	pde_loss=3.0421836	bndry_loss=71.288605	eigval=31.623001
# Epoch: 53	train_loss=74.18884	pde_loss=3.2059414	bndry_loss=70.9829	eigval=31.62226
# Epoch: 54	train_loss=74.05828	pde_loss=3.3465734	bndry_loss=70.71171	eigval=31.621498
# Epoch: 55	train_loss=73.91622	pde_loss=3.431484	bndry_loss=70.48474	eigval=31.62072
# Epoch: 56	train_loss=73.780785	pde_loss=3.4817407	bndry_loss=70.29904	eigval=31.619928
# Epoch: 57	train_loss=73.64843	pde_loss=3.5008032	bndry_loss=70.14763	eigval=31.619127
# Epoch: 58	train_loss=73.52785	pde_loss=3.5041735	bndry_loss=70.023674	eigval=31.618317
# Epoch: 59	train_loss=73.39671	pde_loss=3.4644809	bndry_loss=69.932236	eigval=31.6175
# Epoch: 60	train_loss=73.26336	pde_loss=3.396137	bndry_loss=69.867226	eigval=31.61668
# Epoch: 61	train_loss=73.13017	pde_loss=3.2976446	bndry_loss=69.83253	eigval=31.615858
# Epoch: 62	train_loss=73.03337	pde_loss=3.214932	bndry_loss=69.818436	eigval=31.615038
# Epoch: 63	train_loss=72.94766	pde_loss=3.139494	bndry_loss=69.80817	eigval=31.61422
# Epoch: 64	train_loss=72.85648	pde_loss=3.0682418	bndry_loss=69.78824	eigval=31.613405
# Epoch: 65	train_loss=72.77218	pde_loss=3.0161133	bndry_loss=69.756065	eigval=31.612597
# Epoch: 66	train_loss=72.70027	pde_loss=2.99348	bndry_loss=69.706795	eigval=31.611794
# Epoch: 67	train_loss=72.63179	pde_loss=2.9920473	bndry_loss=69.63974	eigval=31.610994
# Epoch: 68	train_loss=72.55687	pde_loss=3.00311	bndry_loss=69.55376	eigval=31.6102
# Epoch: 69	train_loss=72.45213	pde_loss=3.00323	bndry_loss=69.448906	eigval=31.609413
# Epoch: 70	train_loss=72.343346	pde_loss=3.0210907	bndry_loss=69.32226	eigval=31.608631
# Epoch: 71	train_loss=72.2298	pde_loss=3.0422897	bndry_loss=69.18751	eigval=31.607853
# Epoch: 72	train_loss=72.115425	pde_loss=3.0747263	bndry_loss=69.040695	eigval=31.60708
# Epoch: 972	train_loss=33.14409	pde_loss=7.8061	bndry_loss=25.33799	eigval=31.109146
# Epoch: 973	train_loss=33.144096	pde_loss=7.8674545	bndry_loss=25.27664	eigval=31.108624
# Epoch: 974	train_loss=33.145668	pde_loss=7.8621593	bndry_loss=25.28351	eigval=31.1081
# Epoch: 975	train_loss=33.1469	pde_loss=7.7988086	bndry_loss=25.348091	eigval=31.107578
# Epoch: 976	train_loss=33.147232	pde_loss=7.7932	bndry_loss=25.35403	eigval=31.107056
# Epoch: 977	train_loss=33.149555	pde_loss=7.8486624	bndry_loss=25.300892	eigval=31.106533
# Epoch: 978	train_loss=33.15248	pde_loss=7.8212	bndry_loss=25.33128	eigval=31.10601
# Epoch: 979	train_loss=33.15951	pde_loss=7.818082	bndry_loss=25.34143	eigval=31.105488
# Epoch: 980	train_loss=33.15506	pde_loss=7.829863	bndry_loss=25.325197	eigval=31.104965
# Epoch: 981	train_loss=33.154633	pde_loss=7.8488674	bndry_loss=25.305763	eigval=31.104443
# Epoch: 982	train_loss=33.156204	pde_loss=7.843811	bndry_loss=25.312393	eigval=31.10392
# Epoch: 983	train_loss=33.16011	pde_loss=7.8335485	bndry_loss=25.326563	eigval=31.103397
# Epoch: 984	train_loss=33.15387	pde_loss=7.826347	bndry_loss=25.327524	eigval=31.102875
# Epoch: 985	train_loss=33.150692	pde_loss=7.821758	bndry_loss=25.328936	eigval=31.102352
# Epoch: 986	train_loss=33.148987	pde_loss=7.8300858	bndry_loss=25.3189	eigval=31.101828
# Epoch: 987	train_loss=33.147743	pde_loss=7.8445396	bndry_loss=25.303205	eigval=31.101303
# Epoch: 988	train_loss=33.14568	pde_loss=7.850592	bndry_loss=25.295086	eigval=31.100779
# Epoch: 989	train_loss=33.15889	pde_loss=7.8660007	bndry_loss=25.29289	eigval=31.100254
# Epoch: 990	train_loss=33.16354	pde_loss=7.8438463	bndry_loss=25.319693	eigval=31.09973
# Epoch: 991	train_loss=33.157955	pde_loss=7.8065877	bndry_loss=25.351368	eigval=31.099205
# Epoch: 992	train_loss=33.156986	pde_loss=7.821919	bndry_loss=25.335068	eigval=31.09868
# Epoch: 993	train_loss=33.15613	pde_loss=7.8442764	bndry_loss=25.311855	eigval=31.098156
# Epoch: 994	train_loss=33.15554	pde_loss=7.8131127	bndry_loss=25.342426	eigval=31.097631
# Epoch: 995	train_loss=33.15459	pde_loss=7.75475	bndry_loss=25.39984	eigval=31.097109
# Epoch: 996	train_loss=33.153828	pde_loss=7.869038	bndry_loss=25.284788	eigval=31.096586
# Epoch: 997	train_loss=33.152798	pde_loss=7.950961	bndry_loss=25.201838	eigval=31.096062
# Epoch: 998	train_loss=33.146698	pde_loss=7.783696	bndry_loss=25.363003	eigval=31.09554
# Epoch: 999	train_loss=33.14171	pde_loss=7.7397423	bndry_loss=25.401966	eigval=31.095016
# Epoch: 1000	train_loss=33.131886	pde_loss=7.8705797	bndry_loss=25.261307	eigval=31.094494
# Epoch: 1000	Train Loss = 33.13188552856445,	Test Loss = -1

# %%
# plot buckling mode again
plot_mode()
