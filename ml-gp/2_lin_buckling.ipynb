# %% [markdown]
# # Linear Buckling Analysis with ML GP PDE solver

# %%
# panel linear static inputs
# buckling inputs
# ----------------

# aluminum plate material properties
E = 70e9; nu = 0.3; thick = 0.005
D = E * thick**3 / 12.0 / (1 - nu**2)
(a, b) = (3, 1)

axial = True
if axial:
    Nxx, Nxy, Nyy = (1e3, 0, 0)
else:
    Nxx, Nxy, Nyy = (0, 1e2, 0)

# choose kernel hyperparameters
Lx = 0.2; Ly = 0.4
# took out smaller lower length scale bc cause regularization to fail for now

# predict the buckling load factor (BLF)
pi = 3.14159
if axial:
    pred_buckling_load = pi**2 * D / b**2 * 4.0 
    pred_load_factor = pred_buckling_load / Nxx
    sigma = 0.5 * pred_load_factor
    print(f"{pred_load_factor=}")
# Out:
# pred_load_factor=31.633294000320518

# %%
# compute the linear static analysis inputs and mesh domain of collocation pts
# ----------------------------------------------------------------------------
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# case = 'low'
# case = 'medium'
case = 'high'

if case == 'high':
    num_domain = 300
    num_bndry = 100
    num_test = 50
elif case == 'medium':
    num_domain = 40
    num_bndry = 10
    num_test = 50
elif case == 'low':
    num_domain = 10
    num_bndry = 5
    num_test = 5

num_interior = num_domain
DTYPE = tf.float32

# set the boundary of the panel
xmin = 0; xmax = a
ymin = 0; ymax = b

lb = tf.constant([xmin, ymin], dtype=DTYPE)
ub = tf.constant([xmax, ymax], dtype=DTYPE)

# generate the collocation points on the interior
def gen_collocation_points(num_domain, minval, maxval):
    x_r = tf.random.uniform((num_domain,1), minval[0], maxval[0], dtype=DTYPE)
    y_r = tf.random.uniform((num_domain,1), minval[1], maxval[1], dtype=DTYPE)
    X_r = tf.concat([x_r, y_r], axis=1)
    # data_init = tf.random_uniform_initializer(minval=minval, maxval=maxval, seed=0)
    # return tf.Variable(data_init(shape=[num_domain, 1]), dtype=tf.float32)
    return tf.Variable(X_r, dtype=DTYPE)

x_train = gen_collocation_points(num_domain, lb, ub)
x_test = gen_collocation_points(num_test, lb, ub)
print(f"{type(x_train)=}")

x = x_train[:,0:1]
y = x_train[:,1:2]

x2 = x_test[:,0:1]
y2 = x_test[:,1:2]

# generate boundary domain points
assert num_bndry % 2 == 0
N_b = int(num_bndry / 2)
x_b1 = tf.random.uniform((N_b,1), lb[0], ub[0], dtype=DTYPE)
y_b1 = lb[1] + (ub[1] - lb[1]) * \
    tf.keras.backend.random_bernoulli((N_b,1), 0.5, dtype=DTYPE)
X_b1 = tf.concat([x_b1, y_b1], axis=1)

# boundary data on x edges
y_b2 = tf.random.uniform((N_b,1), lb[1], ub[1], dtype=DTYPE)
x_b2 = lb[0] + (ub[0] - lb[0]) * \
    tf.keras.backend.random_bernoulli((N_b,1), 0.5, dtype=DTYPE)
# print(f"{x_b2=}")
X_b2 = tf.concat([x_b2, y_b2], axis=1)
# print(f"{X_b2=}")
# print(f"{x_b2=}")

x_bndry = tf.Variable(tf.concat([X_b1, X_b2], axis=0), dtype=DTYPE)

# plot the data to check
plt.scatter(x_bndry[:,0], x_bndry[:,1])
plt.scatter(x_train[:,0], x_train[:,1]) # only show 1000 of the points
plt.show()
# Out:
# type(x_train)=<class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>

# %%
# define vectorized versions of the kernel functions
# like 1000x faster at assembling covariance functions

L_tf = tf.constant(np.array([Lx, Ly]), dtype=DTYPE)
def kernel2d_tf(x, xp):
    # x input is N x 1 x 2 array, xp is 1 x M x 2 array
    # xbar is then an N x M x 2 shape array
    # print(f"{x=} {L_tf=}")
    xbar = (x - xp) / L_tf
    # output is N x M matrix of kernel matrix
    return tf.exp(-0.5 * tf.reduce_sum(tf.pow(xbar, 2.0), axis=-1))

def d_fact(xbar, L):
    return L**(-1.0) * (-xbar)

def d2_fact(xbar, L):
    return L**(-2.0) * (-1.0 + xbar**2)

def d4_fact(xbar,L):
    return L**(-4.0) * (3.0 - 6.0 * xbar**2 + xbar**4)

def d6_fact(xbar,L):
    return L**(-6.0) * (-15 + 45 * xbar**2 - 15 * xbar**4 + xbar**6)

def d8_fact(xbar,L):
    return L**(-8.0) * (105 - 420 * xbar**2 + 210 * xbar**4 - 28 * xbar**6 + xbar**8)

def dx2_kernel_tf(x, xp):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / L_tf # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L_tf[0]; Ly = L_tf[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    # TODO : shear or general case later (just axial now)
    return K * (d2_fact(x1bar, Lx))

def doubledx2_kernel_tf(x, xp):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / L_tf # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L_tf[0]; Ly = L_tf[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    # TODO : shear or general case later (just axial now)
    return K * (d4_fact(x1bar, Lx))

def kernel2d_bilapl_tf(x, xp):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / L_tf # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L_tf[0]; Ly = L_tf[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    return K * (d4_fact(x1bar,Lx) + 2.0 * d2_fact(x1bar, Lx) * d2_fact(x2bar, Ly) + d4_fact(x2bar, Ly))

def kernel2d_double_bilapl_tf(x, xp):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / L_tf # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L_tf[0]; Ly = L_tf[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    return K * (d8_fact(x1bar,Lx) + \
                4.0 * d6_fact(x1bar, Lx) * d2_fact(x2bar, Ly) +\
                6.0 * d4_fact(x1bar, Lx) * d4_fact(x2bar, Ly) +\
                4.0 * d2_fact(x1bar, Lx) * d6_fact(x2bar, Ly) +\
                d8_fact(x2bar, Ly))

def dx2_bilapl_kernel_tf(x, xp):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / L_tf # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L_tf[0]; Ly = L_tf[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    # TODO : shear or general case later (just axial now)
    return K * \
        (d6_fact(x1bar,Lx) + 2.0 * d4_fact(x1bar, Lx) * d2_fact(x2bar, Ly) + d2_fact(x1bar, Lx) * d4_fact(x2bar, Ly))

# %%
# compute the block matrix Sigma = [cov(w_int, w_int), cov(w_int, w_bndry), cov(w_int, nabla^4 w_int),
#                                   cov(w_bndry, w_int), cov(w_bndry, w_bndry), cov(w_bndry, nabla^4 w_bndry),
#                                   cov(nabla^4 w_int, w_int), cov(nabla^4 w_int, w_bndry), cov(nabla^4 w_int, nabla^4 w_int) ]
# not a function of theta..
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

n_block = 3 * num_interior + num_bndry
x_all = tf.concat([x_train, x_bndry], axis=0)
num_all = num_interior + num_bndry

# 11 - interior+bndry self-covariance
x_all_L = tf.expand_dims(x_all, axis=1)
x_all_R = tf.expand_dims(x_all, axis=0)
K11 = tf.constant(kernel2d_tf(x_all_L, x_all_R), dtype=DTYPE)

x_interior_L = tf.expand_dims(x_train, axis=1)
x_interior_R = tf.expand_dims(x_train, axis=0)

# 12 - w with Gw
K12 = tf.constant(dx2_kernel_tf(x_all_L, x_interior_R))
# 13 - w with nabla^4 w
K13 = tf.constant(kernel2d_bilapl_tf(x_all_L, x_interior_R))
# 22 - Gw with Gw
K22 = tf.constant(doubledx2_kernel_tf(x_interior_L, x_interior_R))
# 23 - Gw with nabla^4 w
K23 = tf.constant(dx2_bilapl_kernel_tf(x_interior_L, x_interior_R))
# 33 - nabla^4 w with nabla^4 w
K33 = tf.constant(kernel2d_double_bilapl_tf(x_interior_L, x_interior_R))

print(f"{num_interior=} {num_all=}")
# print(f"{K11.shape=} {K12.shape=} {K22.shape=}")
# print(f"{K13.shape=} {K23.shape=} {K33.shape=}")

# assemble full covariance matrix
_row1 = tf.constant(tf.concat([K11, K12, K13], axis=1))
_row2 = tf.constant(tf.concat([tf.transpose(K12), K22, K23], axis=1))
_row3 = tf.constant(tf.concat([tf.transpose(K13), tf.transpose(K23), K33], axis=1))
Kblock_prereg = tf.concat([_row1, _row2, _row3], axis=0)

print(f"done with full matrix assembly..")

# apply robust regularization w.r.t. the max eigenvalue, namely we add epsilon * I term to matrix
# where epsilon = alpha * lambda_max
alpha = 1e-5
eigvals = np.linalg.eigvalsh(Kblock_prereg)
min_eigval = np.min(eigvals)
max_eigval = np.max(eigvals)
print(f"{min_eigval=} {max_eigval=}")
eps = alpha * max_eigval

print("done with eigenvalues solve")

Kblock = tf.constant(Kblock_prereg + eps * tf.eye(n_block), dtype=DTYPE)

# double check eigvals again
print("double check eivals again--")
eigvals = np.linalg.eigvalsh(Kblock)
min_eigval = np.min(eigvals)
max_eigval = np.max(eigvals)
print(f"{min_eigval=} {max_eigval=}")

# show the matrix image to see if positive definite roughly
plt.imshow(Kblock)
plt.colorbar()
# Out:
# num_interior=300 num_all=400
# done with full matrix assembly..
# min_eigval=-58.47738 max_eigval=1211483800.0
# done with eigenvalues solve
# double check eivals again--
# min_eigval=12057.5205 max_eigval=1211496000.0

# %%
# define GP vectors and factor cov matrix into LU
# -----------------------------------------------

# setup lambda as trainable parameter too
# lam = tf.Variable(pred_load_factor, trainable=True, dtype=DTYPE)

K_lu = tf.linalg.lu(Kblock)

w_ext = tf.zeros(shape=(num_bndry,1), dtype=DTYPE)
# now theta includes the w int points and Gw interior points and also lam
theta_arr = tf.zeros(shape=(num_domain * 2 + 1,1), dtype=DTYPE)
# theta_arr = np.random.rand(2 * num_domain + 1, 1)
# theta_arr = tf.ones(shape=(num_domain * 2 + 1, 1), dtype=DTYPE)
theta_arr = np.zeros(shape=(num_domain*2 + 1,1))
theta_arr[5,0] = 1.0
# [5,0] = 1.0 # best to choose some middle point as the only nonzero part?
theta = tf.Variable(theta_arr, trainable=True, dtype=DTYPE)

# print(f"{w_ext.shape=}")
# nabla4_w = 
# nabla4_w2 = tf.reshape(nabla4_w, shape=(num_domain,1))
# print(f"{nabla4_w2.shape=}")

# _temp = tf.concat([w_ext, nabla4_w2], axis=0)
# fixed_vec = tf.constant(_temp, dtype=DTYPE)

# %%
num_epochs = 5000 # 5000
learning_rate = 1e-3 # can be much higher here?
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

for epoch in range(num_epochs):
    # record the loss gradient
    with tf.GradientTape(persistent=True) as tape:
        # construct full GP f vector
        w_int = theta[:num_interior]
        Gw = theta[num_interior:-1]
        # lam = theta[-1]
        # lam = pred_load_factor # try constant for a minute
        lam = 8.0
        nabla4_w = -lam / D * Nxx * Gw
        w_full = tf.concat([w_int, w_ext, Gw, nabla4_w], axis=0)

        # normalize w_full by w_norm to prevent trivial soln in buckling analysis
        w_norm = tf.linalg.norm(w_int)
        w_full_hat = w_full / w_norm

        # print(f"{w_full=}")
        ans = tf.linalg.lu_solve(*K_lu, rhs=w_full_hat)
        # print(f"{ans=}")

        loss = tf.tensordot(tf.transpose(w_full_hat), ans, axes=1)

        # add norm regularization term to prevent trivial soln (since buckling trivial w = 0 soln is technically a soln, but not one we care about)
        # this didn't work very well => just focuses on this term not PDE solving
        # loss += (w_norm - 1)**2 # * 1e4
        # # loss *= 1e3 # *= D

    loss_gradient = tape.gradient(loss, theta)
    # print(f"{loss_gradient=}")

    # could change to Gauss-newton algorithm here instead.. would prob be better

    # gradient descent with adam optimizer
    optimizer.apply_gradients(
        [(loss_gradient, theta)]
    )
    del tape

    loss_val = loss.numpy()[0,0]
    print(f"{epoch=}\t{loss_val=}\t{lam=}")

# print(f"{theta=}")
# Out:
# epoch=0	loss_val=8.2338636e-05	lam=8.0
# epoch=1	loss_val=8.233536e-05	lam=8.0
# epoch=2	loss_val=8.233395e-05	lam=8.0
# epoch=3	loss_val=8.2332444e-05	lam=8.0
# epoch=4	loss_val=8.233128e-05	lam=8.0
# epoch=5	loss_val=8.233041e-05	lam=8.0
# epoch=6	loss_val=8.232935e-05	lam=8.0
# epoch=7	loss_val=8.232842e-05	lam=8.0
# epoch=8	loss_val=8.232799e-05	lam=8.0
# epoch=9	loss_val=8.232751e-05	lam=8.0
# epoch=10	loss_val=8.232678e-05	lam=8.0
# epoch=11	loss_val=8.2326296e-05	lam=8.0
# epoch=12	loss_val=8.232593e-05	lam=8.0
# epoch=13	loss_val=8.2325496e-05	lam=8.0
# epoch=14	loss_val=8.2325096e-05	lam=8.0
# epoch=15	loss_val=8.2324885e-05	lam=8.0
# epoch=16	loss_val=8.2324674e-05	lam=8.0
# epoch=17	loss_val=8.232446e-05	lam=8.0
# epoch=18	loss_val=8.2324295e-05	lam=8.0
# epoch=19	loss_val=8.232421e-05	lam=8.0
# epoch=20	loss_val=8.23242e-05	lam=8.0
# epoch=21	loss_val=8.232407e-05	lam=8.0
# epoch=22	loss_val=8.232402e-05	lam=8.0
# epoch=23	loss_val=8.232401e-05	lam=8.0
# epoch=24	loss_val=8.232387e-05	lam=8.0
# epoch=25	loss_val=8.232372e-05	lam=8.0
# epoch=26	loss_val=8.2323684e-05	lam=8.0
# epoch=27	loss_val=8.232368e-05	lam=8.0
# epoch=28	loss_val=8.232361e-05	lam=8.0
# epoch=29	loss_val=8.2323524e-05	lam=8.0
# epoch=30	loss_val=8.232342e-05	lam=8.0
# epoch=31	loss_val=8.232345e-05	lam=8.0
# epoch=32	loss_val=8.2323415e-05	lam=8.0
# epoch=33	loss_val=8.232331e-05	lam=8.0
# epoch=34	loss_val=8.232324e-05	lam=8.0
# epoch=35	loss_val=8.232325e-05	lam=8.0
# epoch=36	loss_val=8.232321e-05	lam=8.0
# epoch=37	loss_val=8.2323124e-05	lam=8.0
# epoch=38	loss_val=8.23232e-05	lam=8.0
# epoch=39	loss_val=8.232314e-05	lam=8.0
# epoch=40	loss_val=8.232313e-05	lam=8.0
# epoch=41	loss_val=8.23231e-05	lam=8.0
# epoch=42	loss_val=8.2323066e-05	lam=8.0
# epoch=43	loss_val=8.2323095e-05	lam=8.0
# epoch=44	loss_val=8.2323044e-05	lam=8.0
# epoch=45	loss_val=8.232308e-05	lam=8.0
# epoch=46	loss_val=8.2323044e-05	lam=8.0
# epoch=47	loss_val=8.232311e-05	lam=8.0
# epoch=48	loss_val=8.232303e-05	lam=8.0
# epoch=49	loss_val=8.232302e-05	lam=8.0
# epoch=50	loss_val=8.232301e-05	lam=8.0
# epoch=51	loss_val=8.232309e-05	lam=8.0
# epoch=52	loss_val=8.232306e-05	lam=8.0
# epoch=53	loss_val=8.2323066e-05	lam=8.0
# epoch=54	loss_val=8.2323124e-05	lam=8.0
# epoch=55	loss_val=8.2323044e-05	lam=8.0
# epoch=56	loss_val=8.2323e-05	lam=8.0
# epoch=57	loss_val=8.232304e-05	lam=8.0
# epoch=58	loss_val=8.2323066e-05	lam=8.0
# epoch=59	loss_val=8.2323124e-05	lam=8.0
# epoch=60	loss_val=8.232305e-05	lam=8.0
# epoch=61	loss_val=8.232303e-05	lam=8.0
# epoch=62	loss_val=8.2323e-05	lam=8.0
# epoch=63	loss_val=8.2323015e-05	lam=8.0
# epoch=64	loss_val=8.2322964e-05	lam=8.0
# epoch=65	loss_val=8.232302e-05	lam=8.0
# epoch=66	loss_val=8.232302e-05	lam=8.0
# epoch=67	loss_val=8.232301e-05	lam=8.0
# epoch=68	loss_val=8.2323044e-05	lam=8.0
# epoch=69	loss_val=8.2323066e-05	lam=8.0
# epoch=70	loss_val=8.232299e-05	lam=8.0
# epoch=71	loss_val=8.232305e-05	lam=8.0
# epoch=72	loss_val=8.232303e-05	lam=8.0
# epoch=73	loss_val=8.232303e-05	lam=8.0
# epoch=74	loss_val=8.2323066e-05	lam=8.0
# epoch=75	loss_val=8.2323015e-05	lam=8.0
# epoch=76	loss_val=8.2323e-05	lam=8.0
# epoch=77	loss_val=8.2323e-05	lam=8.0
# epoch=78	loss_val=8.2322986e-05	lam=8.0
# epoch=79	loss_val=8.232304e-05	lam=8.0
# epoch=80	loss_val=8.232308e-05	lam=8.0
# epoch=81	loss_val=8.232302e-05	lam=8.0
# epoch=82	loss_val=8.2323015e-05	lam=8.0
# epoch=83	loss_val=8.2323044e-05	lam=8.0
# epoch=84	loss_val=8.2323044e-05	lam=8.0
# epoch=85	loss_val=8.2323066e-05	lam=8.0
# epoch=86	loss_val=8.2323044e-05	lam=8.0
# epoch=87	loss_val=8.2323044e-05	lam=8.0
# epoch=88	loss_val=8.232298e-05	lam=8.0
# epoch=89	loss_val=8.232299e-05	lam=8.0
# epoch=90	loss_val=8.232302e-05	lam=8.0
# epoch=91	loss_val=8.2322964e-05	lam=8.0
# epoch=92	loss_val=8.232299e-05	lam=8.0
# epoch=93	loss_val=8.2323e-05	lam=8.0
# epoch=94	loss_val=8.232303e-05	lam=8.0
# epoch=95	loss_val=8.232299e-05	lam=8.0
# epoch=96	loss_val=8.232298e-05	lam=8.0
# epoch=97	loss_val=8.2323e-05	lam=8.0
# epoch=98	loss_val=8.2322964e-05	lam=8.0
# epoch=99	loss_val=8.232298e-05	lam=8.0
# epoch=100	loss_val=8.232299e-05	lam=8.0
# epoch=101	loss_val=8.232296e-05	lam=8.0
# epoch=102	loss_val=8.232296e-05	lam=8.0
# epoch=103	loss_val=8.232297e-05	lam=8.0
# epoch=104	loss_val=8.232293e-05	lam=8.0
# epoch=105	loss_val=8.232296e-05	lam=8.0
# epoch=106	loss_val=8.232294e-05	lam=8.0
# epoch=107	loss_val=8.232297e-05	lam=8.0
# epoch=108	loss_val=8.2322935e-05	lam=8.0
# epoch=109	loss_val=8.232296e-05	lam=8.0
# epoch=110	loss_val=8.232299e-05	lam=8.0
# epoch=111	loss_val=8.232295e-05	lam=8.0
# epoch=112	loss_val=8.232296e-05	lam=8.0
# epoch=113	loss_val=8.232293e-05	lam=8.0
# epoch=114	loss_val=8.232295e-05	lam=8.0
# epoch=115	loss_val=8.232295e-05	lam=8.0
# epoch=116	loss_val=8.2322935e-05	lam=8.0
# epoch=117	loss_val=8.232296e-05	lam=8.0
# epoch=118	loss_val=8.2322935e-05	lam=8.0
# epoch=119	loss_val=8.232296e-05	lam=8.0
# epoch=120	loss_val=8.232296e-05	lam=8.0
# epoch=121	loss_val=8.2323e-05	lam=8.0
# epoch=122	loss_val=8.232295e-05	lam=8.0
# epoch=123	loss_val=8.232293e-05	lam=8.0
# epoch=124	loss_val=8.232294e-05	lam=8.0
# epoch=125	loss_val=8.232295e-05	lam=8.0
# epoch=126	loss_val=8.232297e-05	lam=8.0
# epoch=127	loss_val=8.2322986e-05	lam=8.0
# epoch=128	loss_val=8.232297e-05	lam=8.0
# epoch=129	loss_val=8.232298e-05	lam=8.0
# epoch=130	loss_val=8.2322964e-05	lam=8.0
# epoch=131	loss_val=8.232295e-05	lam=8.0
# epoch=132	loss_val=8.232297e-05	lam=8.0
# epoch=133	loss_val=8.232296e-05	lam=8.0
# epoch=134	loss_val=8.232294e-05	lam=8.0
# epoch=135	loss_val=8.232292e-05	lam=8.0
# epoch=136	loss_val=8.232294e-05	lam=8.0
# epoch=137	loss_val=8.2322964e-05	lam=8.0
# epoch=138	loss_val=8.232298e-05	lam=8.0
# epoch=139	loss_val=8.232294e-05	lam=8.0
# epoch=140	loss_val=8.2322906e-05	lam=8.0
# epoch=141	loss_val=8.2322964e-05	lam=8.0
# epoch=142	loss_val=8.232294e-05	lam=8.0
# epoch=143	loss_val=8.232294e-05	lam=8.0
# epoch=144	loss_val=8.232294e-05	lam=8.0
# epoch=145	loss_val=8.232295e-05	lam=8.0
# epoch=146	loss_val=8.2322986e-05	lam=8.0
# epoch=147	loss_val=8.232297e-05	lam=8.0
# epoch=148	loss_val=8.232296e-05	lam=8.0
# epoch=149	loss_val=8.232293e-05	lam=8.0
# epoch=150	loss_val=8.232295e-05	lam=8.0
# epoch=151	loss_val=8.232297e-05	lam=8.0
# epoch=152	loss_val=8.232294e-05	lam=8.0
# epoch=153	loss_val=8.232296e-05	lam=8.0
# epoch=154	loss_val=8.2322935e-05	lam=8.0
# epoch=155	loss_val=8.232297e-05	lam=8.0
# epoch=156	loss_val=8.232297e-05	lam=8.0
# epoch=157	loss_val=8.232298e-05	lam=8.0
# epoch=158	loss_val=8.2322935e-05	lam=8.0
# epoch=159	loss_val=8.232294e-05	lam=8.0
# epoch=160	loss_val=8.232297e-05	lam=8.0
# epoch=161	loss_val=8.232293e-05	lam=8.0
# epoch=162	loss_val=8.232294e-05	lam=8.0
# epoch=163	loss_val=8.232299e-05	lam=8.0
# epoch=164	loss_val=8.232297e-05	lam=8.0
# epoch=165	loss_val=8.232294e-05	lam=8.0
# epoch=166	loss_val=8.232302e-05	lam=8.0
# epoch=167	loss_val=8.232301e-05	lam=8.0
# epoch=168	loss_val=8.232297e-05	lam=8.0
# epoch=169	loss_val=8.2322986e-05	lam=8.0
# epoch=170	loss_val=8.232298e-05	lam=8.0
# epoch=171	loss_val=8.232298e-05	lam=8.0
# epoch=172	loss_val=8.2322986e-05	lam=8.0
# epoch=173	loss_val=8.2322964e-05	lam=8.0
# epoch=174	loss_val=8.232291e-05	lam=8.0
# epoch=175	loss_val=8.232292e-05	lam=8.0
# epoch=176	loss_val=8.232294e-05	lam=8.0
# epoch=177	loss_val=8.232292e-05	lam=8.0
# epoch=178	loss_val=8.232293e-05	lam=8.0
# epoch=179	loss_val=8.232294e-05	lam=8.0
# epoch=180	loss_val=8.2322935e-05	lam=8.0
# epoch=181	loss_val=8.232295e-05	lam=8.0
# epoch=182	loss_val=8.2322906e-05	lam=8.0
# epoch=183	loss_val=8.232294e-05	lam=8.0
# epoch=184	loss_val=8.2322935e-05	lam=8.0
# epoch=185	loss_val=8.232293e-05	lam=8.0
# epoch=186	loss_val=8.232294e-05	lam=8.0
# epoch=187	loss_val=8.232296e-05	lam=8.0
# epoch=188	loss_val=8.232294e-05	lam=8.0
# epoch=189	loss_val=8.232294e-05	lam=8.0
# epoch=190	loss_val=8.232292e-05	lam=8.0
# epoch=191	loss_val=8.2322935e-05	lam=8.0
# epoch=192	loss_val=8.232295e-05	lam=8.0
# epoch=193	loss_val=8.232294e-05	lam=8.0
# epoch=194	loss_val=8.232296e-05	lam=8.0
# epoch=195	loss_val=8.232297e-05	lam=8.0
# epoch=196	loss_val=8.2322935e-05	lam=8.0
# epoch=197	loss_val=8.232298e-05	lam=8.0
# epoch=198	loss_val=8.232291e-05	lam=8.0
# epoch=199	loss_val=8.2322935e-05	lam=8.0
# epoch=200	loss_val=8.232293e-05	lam=8.0
# epoch=201	loss_val=8.232297e-05	lam=8.0
# epoch=202	loss_val=8.2322906e-05	lam=8.0
# epoch=203	loss_val=8.232292e-05	lam=8.0
# epoch=204	loss_val=8.2322935e-05	lam=8.0
# epoch=205	loss_val=8.2322906e-05	lam=8.0
# epoch=206	loss_val=8.2322884e-05	lam=8.0
# epoch=207	loss_val=8.232293e-05	lam=8.0
# epoch=208	loss_val=8.232292e-05	lam=8.0
# epoch=209	loss_val=8.232292e-05	lam=8.0
# epoch=210	loss_val=8.232292e-05	lam=8.0
# epoch=211	loss_val=8.232289e-05	lam=8.0
# epoch=212	loss_val=8.232292e-05	lam=8.0
# epoch=213	loss_val=8.232293e-05	lam=8.0
# epoch=214	loss_val=8.2322935e-05	lam=8.0
# epoch=215	loss_val=8.232292e-05	lam=8.0
# epoch=216	loss_val=8.232288e-05	lam=8.0
# epoch=217	loss_val=8.232293e-05	lam=8.0
# epoch=218	loss_val=8.2322906e-05	lam=8.0
# epoch=219	loss_val=8.232293e-05	lam=8.0
# epoch=220	loss_val=8.232289e-05	lam=8.0
# epoch=221	loss_val=8.2322906e-05	lam=8.0
# epoch=222	loss_val=8.2322884e-05	lam=8.0
# epoch=223	loss_val=8.232293e-05	lam=8.0
# epoch=224	loss_val=8.232287e-05	lam=8.0
# epoch=225	loss_val=8.232291e-05	lam=8.0
# epoch=226	loss_val=8.232294e-05	lam=8.0
# epoch=227	loss_val=8.232288e-05	lam=8.0
# epoch=228	loss_val=8.232293e-05	lam=8.0
# epoch=229	loss_val=8.23229e-05	lam=8.0
# epoch=230	loss_val=8.2322964e-05	lam=8.0
# epoch=231	loss_val=8.232294e-05	lam=8.0
# epoch=232	loss_val=8.232292e-05	lam=8.0
# epoch=233	loss_val=8.232291e-05	lam=8.0
# epoch=234	loss_val=8.232291e-05	lam=8.0
# epoch=235	loss_val=8.2322935e-05	lam=8.0
# epoch=236	loss_val=8.232291e-05	lam=8.0
# epoch=237	loss_val=8.232292e-05	lam=8.0
# epoch=238	loss_val=8.232293e-05	lam=8.0
# epoch=239	loss_val=8.232289e-05	lam=8.0
# epoch=240	loss_val=8.232292e-05	lam=8.0
# epoch=241	loss_val=8.232291e-05	lam=8.0
# epoch=242	loss_val=8.232291e-05	lam=8.0
# epoch=243	loss_val=8.232293e-05	lam=8.0
# epoch=244	loss_val=8.23229e-05	lam=8.0
# epoch=245	loss_val=8.2322855e-05	lam=8.0
# epoch=246	loss_val=8.232285e-05	lam=8.0
# epoch=247	loss_val=8.23229e-05	lam=8.0
# epoch=248	loss_val=8.232287e-05	lam=8.0
# epoch=249	loss_val=8.232286e-05	lam=8.0
# epoch=250	loss_val=8.232284e-05	lam=8.0
# epoch=251	loss_val=8.232287e-05	lam=8.0
# epoch=252	loss_val=8.232285e-05	lam=8.0
# epoch=253	loss_val=8.232285e-05	lam=8.0
# epoch=254	loss_val=8.232288e-05	lam=8.0
# epoch=255	loss_val=8.232285e-05	lam=8.0
# epoch=256	loss_val=8.232288e-05	lam=8.0
# epoch=257	loss_val=8.23228e-05	lam=8.0
# epoch=258	loss_val=8.232287e-05	lam=8.0
# epoch=259	loss_val=8.2322826e-05	lam=8.0
# epoch=260	loss_val=8.232281e-05	lam=8.0
# epoch=261	loss_val=8.232285e-05	lam=8.0
# epoch=262	loss_val=8.2322855e-05	lam=8.0
# epoch=263	loss_val=8.232291e-05	lam=8.0
# epoch=264	loss_val=8.232287e-05	lam=8.0
# epoch=265	loss_val=8.232293e-05	lam=8.0
# epoch=266	loss_val=8.2322884e-05	lam=8.0
# epoch=267	loss_val=8.232287e-05	lam=8.0
# epoch=268	loss_val=8.232288e-05	lam=8.0
# epoch=269	loss_val=8.232284e-05	lam=8.0
# epoch=270	loss_val=8.232281e-05	lam=8.0
# epoch=271	loss_val=8.232284e-05	lam=8.0
# epoch=272	loss_val=8.232282e-05	lam=8.0
# epoch=273	loss_val=8.2322826e-05	lam=8.0
# epoch=274	loss_val=8.2322826e-05	lam=8.0
# epoch=275	loss_val=8.232287e-05	lam=8.0
# epoch=276	loss_val=8.232284e-05	lam=8.0
# epoch=277	loss_val=8.2322884e-05	lam=8.0
# epoch=278	loss_val=8.2322884e-05	lam=8.0
# epoch=279	loss_val=8.232288e-05	lam=8.0
# epoch=280	loss_val=8.232285e-05	lam=8.0
# epoch=281	loss_val=8.232285e-05	lam=8.0
# epoch=282	loss_val=8.232287e-05	lam=8.0
# epoch=283	loss_val=8.232281e-05	lam=8.0
# epoch=284	loss_val=8.232287e-05	lam=8.0
# epoch=285	loss_val=8.2322855e-05	lam=8.0
# epoch=286	loss_val=8.232287e-05	lam=8.0
# epoch=287	loss_val=8.232284e-05	lam=8.0
# epoch=288	loss_val=8.232285e-05	lam=8.0
# epoch=289	loss_val=8.232285e-05	lam=8.0
# epoch=290	loss_val=8.232289e-05	lam=8.0
# epoch=291	loss_val=8.232282e-05	lam=8.0
# epoch=292	loss_val=8.232287e-05	lam=8.0
# epoch=293	loss_val=8.232286e-05	lam=8.0
# epoch=294	loss_val=8.23229e-05	lam=8.0
# epoch=295	loss_val=8.232288e-05	lam=8.0
# epoch=296	loss_val=8.232285e-05	lam=8.0
# epoch=297	loss_val=8.232285e-05	lam=8.0
# epoch=298	loss_val=8.2322855e-05	lam=8.0
# epoch=299	loss_val=8.232286e-05	lam=8.0
# epoch=300	loss_val=8.2322855e-05	lam=8.0
# epoch=301	loss_val=8.2322826e-05	lam=8.0
# epoch=302	loss_val=8.232282e-05	lam=8.0
# epoch=303	loss_val=8.232285e-05	lam=8.0
# epoch=304	loss_val=8.232283e-05	lam=8.0
# epoch=305	loss_val=8.232278e-05	lam=8.0
# epoch=306	loss_val=8.232281e-05	lam=8.0
# epoch=307	loss_val=8.232284e-05	lam=8.0
# epoch=308	loss_val=8.232286e-05	lam=8.0
# epoch=309	loss_val=8.232284e-05	lam=8.0
# epoch=310	loss_val=8.23228e-05	lam=8.0
# epoch=311	loss_val=8.2322804e-05	lam=8.0
# epoch=312	loss_val=8.2322804e-05	lam=8.0
# epoch=313	loss_val=8.232282e-05	lam=8.0
# epoch=314	loss_val=8.232277e-05	lam=8.0
# epoch=315	loss_val=8.232285e-05	lam=8.0
# epoch=316	loss_val=8.2322775e-05	lam=8.0
# epoch=317	loss_val=8.2322826e-05	lam=8.0
# epoch=318	loss_val=8.232281e-05	lam=8.0
# epoch=319	loss_val=8.2322826e-05	lam=8.0
# epoch=320	loss_val=8.2322804e-05	lam=8.0
# epoch=321	loss_val=8.232283e-05	lam=8.0
# epoch=322	loss_val=8.2322826e-05	lam=8.0
# epoch=323	loss_val=8.232282e-05	lam=8.0
# epoch=324	loss_val=8.2322826e-05	lam=8.0
# epoch=325	loss_val=8.232282e-05	lam=8.0
# epoch=326	loss_val=8.2322826e-05	lam=8.0
# epoch=327	loss_val=8.232281e-05	lam=8.0
# epoch=328	loss_val=8.232277e-05	lam=8.0
# epoch=329	loss_val=8.232281e-05	lam=8.0
# epoch=330	loss_val=8.232281e-05	lam=8.0
# epoch=331	loss_val=8.232285e-05	lam=8.0
# epoch=332	loss_val=8.2322775e-05	lam=8.0
# epoch=333	loss_val=8.232278e-05	lam=8.0
# epoch=334	loss_val=8.232279e-05	lam=8.0
# epoch=335	loss_val=8.232281e-05	lam=8.0
# epoch=336	loss_val=8.232282e-05	lam=8.0
# epoch=337	loss_val=8.2322775e-05	lam=8.0
# epoch=338	loss_val=8.2322804e-05	lam=8.0
# epoch=339	loss_val=8.232281e-05	lam=8.0
# epoch=340	loss_val=8.23228e-05	lam=8.0
# epoch=341	loss_val=8.232282e-05	lam=8.0
# epoch=342	loss_val=8.23228e-05	lam=8.0
# epoch=343	loss_val=8.232283e-05	lam=8.0
# epoch=344	loss_val=8.232285e-05	lam=8.0
# epoch=345	loss_val=8.2322804e-05	lam=8.0
# epoch=346	loss_val=8.2322826e-05	lam=8.0
# epoch=347	loss_val=8.2322804e-05	lam=8.0
# epoch=348	loss_val=8.232278e-05	lam=8.0
# epoch=349	loss_val=8.232282e-05	lam=8.0
# epoch=350	loss_val=8.23228e-05	lam=8.0
# epoch=351	loss_val=8.232281e-05	lam=8.0
# epoch=352	loss_val=8.2322804e-05	lam=8.0
# epoch=353	loss_val=8.2322804e-05	lam=8.0
# epoch=354	loss_val=8.23228e-05	lam=8.0
# epoch=355	loss_val=8.232275e-05	lam=8.0
# epoch=356	loss_val=8.23228e-05	lam=8.0
# epoch=357	loss_val=8.2322804e-05	lam=8.0
# epoch=358	loss_val=8.232282e-05	lam=8.0
# epoch=359	loss_val=8.232275e-05	lam=8.0
# epoch=360	loss_val=8.23228e-05	lam=8.0
# epoch=361	loss_val=8.232278e-05	lam=8.0
# epoch=362	loss_val=8.232273e-05	lam=8.0
# epoch=363	loss_val=8.232278e-05	lam=8.0
# epoch=364	loss_val=8.2322775e-05	lam=8.0
# epoch=365	loss_val=8.2322775e-05	lam=8.0
# epoch=366	loss_val=8.232272e-05	lam=8.0
# epoch=367	loss_val=8.232275e-05	lam=8.0
# epoch=368	loss_val=8.232272e-05	lam=8.0
# epoch=369	loss_val=8.2322746e-05	lam=8.0
# epoch=370	loss_val=8.23228e-05	lam=8.0
# epoch=371	loss_val=8.2322746e-05	lam=8.0
# epoch=372	loss_val=8.232276e-05	lam=8.0
# epoch=373	loss_val=8.232274e-05	lam=8.0
# epoch=374	loss_val=8.232273e-05	lam=8.0
# epoch=375	loss_val=8.232277e-05	lam=8.0
# epoch=376	loss_val=8.232277e-05	lam=8.0
# epoch=377	loss_val=8.232276e-05	lam=8.0
# epoch=378	loss_val=8.2322746e-05	lam=8.0
# epoch=379	loss_val=8.232278e-05	lam=8.0
# epoch=380	loss_val=8.232276e-05	lam=8.0
# epoch=381	loss_val=8.232275e-05	lam=8.0
# epoch=382	loss_val=8.232276e-05	lam=8.0
# epoch=383	loss_val=8.232272e-05	lam=8.0
# epoch=384	loss_val=8.232276e-05	lam=8.0
# epoch=385	loss_val=8.232279e-05	lam=8.0
# epoch=386	loss_val=8.232276e-05	lam=8.0
# epoch=387	loss_val=8.232275e-05	lam=8.0
# epoch=388	loss_val=8.232276e-05	lam=8.0
# epoch=389	loss_val=8.232278e-05	lam=8.0
# epoch=390	loss_val=8.232278e-05	lam=8.0
# epoch=391	loss_val=8.2322746e-05	lam=8.0
# epoch=392	loss_val=8.232274e-05	lam=8.0
# epoch=393	loss_val=8.2322746e-05	lam=8.0
# epoch=394	loss_val=8.23228e-05	lam=8.0
# epoch=395	loss_val=8.232274e-05	lam=8.0
# epoch=396	loss_val=8.232276e-05	lam=8.0
# epoch=397	loss_val=8.232276e-05	lam=8.0
# epoch=398	loss_val=8.232274e-05	lam=8.0
# epoch=399	loss_val=8.2322746e-05	lam=8.0
# epoch=400	loss_val=8.232277e-05	lam=8.0
# epoch=401	loss_val=8.232276e-05	lam=8.0
# epoch=402	loss_val=8.232277e-05	lam=8.0
# epoch=403	loss_val=8.232273e-05	lam=8.0
# epoch=404	loss_val=8.2322746e-05	lam=8.0
# epoch=405	loss_val=8.232276e-05	lam=8.0
# epoch=406	loss_val=8.2322775e-05	lam=8.0
# epoch=407	loss_val=8.232275e-05	lam=8.0
# epoch=408	loss_val=8.232273e-05	lam=8.0
# epoch=409	loss_val=8.232277e-05	lam=8.0
# epoch=410	loss_val=8.2322775e-05	lam=8.0
# epoch=411	loss_val=8.232278e-05	lam=8.0
# epoch=412	loss_val=8.2322775e-05	lam=8.0
# epoch=413	loss_val=8.232278e-05	lam=8.0
# epoch=414	loss_val=8.2322775e-05	lam=8.0
# epoch=415	loss_val=8.232278e-05	lam=8.0
# epoch=416	loss_val=8.232275e-05	lam=8.0
# epoch=417	loss_val=8.232276e-05	lam=8.0
# epoch=418	loss_val=8.232274e-05	lam=8.0
# epoch=419	loss_val=8.232276e-05	lam=8.0
# epoch=420	loss_val=8.232276e-05	lam=8.0
# epoch=421	loss_val=8.232274e-05	lam=8.0
# epoch=422	loss_val=8.2322746e-05	lam=8.0
# epoch=423	loss_val=8.232274e-05	lam=8.0
# epoch=424	loss_val=8.232276e-05	lam=8.0
# epoch=425	loss_val=8.232277e-05	lam=8.0
# epoch=426	loss_val=8.232278e-05	lam=8.0
# epoch=427	loss_val=8.23228e-05	lam=8.0
# epoch=428	loss_val=8.2322775e-05	lam=8.0
# epoch=429	loss_val=8.232271e-05	lam=8.0
# epoch=430	loss_val=8.232275e-05	lam=8.0
# epoch=431	loss_val=8.2322746e-05	lam=8.0
# epoch=432	loss_val=8.2322775e-05	lam=8.0
# epoch=433	loss_val=8.232276e-05	lam=8.0
# epoch=434	loss_val=8.2322775e-05	lam=8.0
# epoch=435	loss_val=8.232274e-05	lam=8.0
# epoch=436	loss_val=8.232275e-05	lam=8.0
# epoch=437	loss_val=8.232273e-05	lam=8.0
# epoch=438	loss_val=8.232275e-05	lam=8.0
# epoch=439	loss_val=8.232274e-05	lam=8.0
# epoch=440	loss_val=8.232271e-05	lam=8.0
# epoch=441	loss_val=8.232271e-05	lam=8.0
# epoch=442	loss_val=8.2322724e-05	lam=8.0
# epoch=443	loss_val=8.23227e-05	lam=8.0
# epoch=444	loss_val=8.23227e-05	lam=8.0
# epoch=445	loss_val=8.232274e-05	lam=8.0
# epoch=446	loss_val=8.2322724e-05	lam=8.0
# epoch=447	loss_val=8.23227e-05	lam=8.0
# epoch=448	loss_val=8.232279e-05	lam=8.0
# epoch=449	loss_val=8.232273e-05	lam=8.0
# epoch=450	loss_val=8.232274e-05	lam=8.0
# epoch=451	loss_val=8.232279e-05	lam=8.0
# epoch=452	loss_val=8.232277e-05	lam=8.0
# epoch=453	loss_val=8.232274e-05	lam=8.0
# epoch=454	loss_val=8.23227e-05	lam=8.0
# epoch=455	loss_val=8.232274e-05	lam=8.0
# epoch=456	loss_val=8.232274e-05	lam=8.0
# epoch=457	loss_val=8.2322724e-05	lam=8.0
# epoch=458	loss_val=8.23227e-05	lam=8.0
# epoch=459	loss_val=8.2322746e-05	lam=8.0
# epoch=460	loss_val=8.2322695e-05	lam=8.0
# epoch=461	loss_val=8.232272e-05	lam=8.0
# epoch=462	loss_val=8.232268e-05	lam=8.0
# epoch=463	loss_val=8.232268e-05	lam=8.0
# epoch=464	loss_val=8.232269e-05	lam=8.0
# epoch=465	loss_val=8.2322695e-05	lam=8.0
# epoch=466	loss_val=8.2322695e-05	lam=8.0
# epoch=467	loss_val=8.232271e-05	lam=8.0
# epoch=468	loss_val=8.232269e-05	lam=8.0
# epoch=469	loss_val=8.232273e-05	lam=8.0
# epoch=470	loss_val=8.232274e-05	lam=8.0
# epoch=471	loss_val=8.232267e-05	lam=8.0
# epoch=472	loss_val=8.232271e-05	lam=8.0
# epoch=473	loss_val=8.2322695e-05	lam=8.0
# epoch=474	loss_val=8.2322666e-05	lam=8.0
# epoch=475	loss_val=8.232267e-05	lam=8.0
# epoch=476	loss_val=8.2322695e-05	lam=8.0
# epoch=477	loss_val=8.2322644e-05	lam=8.0
# epoch=478	loss_val=8.232266e-05	lam=8.0
# epoch=479	loss_val=8.232269e-05	lam=8.0
# epoch=480	loss_val=8.232267e-05	lam=8.0
# epoch=481	loss_val=8.232266e-05	lam=8.0
# epoch=482	loss_val=8.232269e-05	lam=8.0
# epoch=483	loss_val=8.232269e-05	lam=8.0
# epoch=484	loss_val=8.232268e-05	lam=8.0
# epoch=485	loss_val=8.232269e-05	lam=8.0
# epoch=486	loss_val=8.232269e-05	lam=8.0
# epoch=487	loss_val=8.23227e-05	lam=8.0
# epoch=488	loss_val=8.232267e-05	lam=8.0
# epoch=489	loss_val=8.2322666e-05	lam=8.0
# epoch=490	loss_val=8.2322644e-05	lam=8.0
# epoch=491	loss_val=8.232266e-05	lam=8.0
# epoch=492	loss_val=8.2322644e-05	lam=8.0
# epoch=493	loss_val=8.232267e-05	lam=8.0
# epoch=494	loss_val=8.232265e-05	lam=8.0
# epoch=495	loss_val=8.232264e-05	lam=8.0
# epoch=496	loss_val=8.232262e-05	lam=8.0
# epoch=497	loss_val=8.2322695e-05	lam=8.0
# epoch=498	loss_val=8.23226e-05	lam=8.0
# epoch=499	loss_val=8.232269e-05	lam=8.0
# epoch=500	loss_val=8.232264e-05	lam=8.0
# epoch=501	loss_val=8.2322615e-05	lam=8.0
# epoch=502	loss_val=8.232267e-05	lam=8.0
# epoch=503	loss_val=8.232265e-05	lam=8.0
# epoch=504	loss_val=8.2322666e-05	lam=8.0
# epoch=505	loss_val=8.2322644e-05	lam=8.0
# epoch=506	loss_val=8.232263e-05	lam=8.0
# epoch=507	loss_val=8.2322666e-05	lam=8.0
# epoch=508	loss_val=8.232263e-05	lam=8.0
# epoch=509	loss_val=8.232262e-05	lam=8.0
# epoch=510	loss_val=8.232262e-05	lam=8.0
# epoch=511	loss_val=8.232262e-05	lam=8.0
# epoch=512	loss_val=8.2322644e-05	lam=8.0
# epoch=513	loss_val=8.232261e-05	lam=8.0
# epoch=514	loss_val=8.23226e-05	lam=8.0
# epoch=515	loss_val=8.2322615e-05	lam=8.0
# epoch=516	loss_val=8.232263e-05	lam=8.0
# epoch=517	loss_val=8.232263e-05	lam=8.0
# epoch=518	loss_val=8.2322586e-05	lam=8.0
# epoch=519	loss_val=8.23226e-05	lam=8.0
# epoch=520	loss_val=8.23226e-05	lam=8.0
# epoch=521	loss_val=8.2322586e-05	lam=8.0
# epoch=522	loss_val=8.232262e-05	lam=8.0
# epoch=523	loss_val=8.232262e-05	lam=8.0
# epoch=524	loss_val=8.232263e-05	lam=8.0
# epoch=525	loss_val=8.2322615e-05	lam=8.0
# epoch=526	loss_val=8.232266e-05	lam=8.0
# epoch=527	loss_val=8.232263e-05	lam=8.0
# epoch=528	loss_val=8.232261e-05	lam=8.0
# epoch=529	loss_val=8.2322644e-05	lam=8.0
# epoch=530	loss_val=8.2322644e-05	lam=8.0
# epoch=531	loss_val=8.2322586e-05	lam=8.0
# epoch=532	loss_val=8.2322586e-05	lam=8.0
# epoch=533	loss_val=8.232263e-05	lam=8.0
# epoch=534	loss_val=8.2322615e-05	lam=8.0
# epoch=535	loss_val=8.2322615e-05	lam=8.0
# epoch=536	loss_val=8.232261e-05	lam=8.0
# epoch=537	loss_val=8.232264e-05	lam=8.0
# epoch=538	loss_val=8.2322644e-05	lam=8.0
# epoch=539	loss_val=8.232266e-05	lam=8.0
# epoch=540	loss_val=8.2322644e-05	lam=8.0
# epoch=541	loss_val=8.232265e-05	lam=8.0
# epoch=542	loss_val=8.232264e-05	lam=8.0
# epoch=543	loss_val=8.232265e-05	lam=8.0
# epoch=544	loss_val=8.232257e-05	lam=8.0
# epoch=545	loss_val=8.232259e-05	lam=8.0
# epoch=546	loss_val=8.2322586e-05	lam=8.0
# epoch=547	loss_val=8.2322615e-05	lam=8.0
# epoch=548	loss_val=8.2322615e-05	lam=8.0
# epoch=549	loss_val=8.232264e-05	lam=8.0
# epoch=550	loss_val=8.232265e-05	lam=8.0
# epoch=551	loss_val=8.232261e-05	lam=8.0
# epoch=552	loss_val=8.2322615e-05	lam=8.0
# epoch=553	loss_val=8.23226e-05	lam=8.0
# epoch=554	loss_val=8.232261e-05	lam=8.0
# epoch=555	loss_val=8.232263e-05	lam=8.0
# epoch=556	loss_val=8.232262e-05	lam=8.0
# epoch=557	loss_val=8.232263e-05	lam=8.0
# epoch=558	loss_val=8.23226e-05	lam=8.0
# epoch=559	loss_val=8.232262e-05	lam=8.0
# epoch=560	loss_val=8.232262e-05	lam=8.0
# epoch=561	loss_val=8.2322586e-05	lam=8.0
# epoch=562	loss_val=8.232263e-05	lam=8.0
# epoch=563	loss_val=8.232261e-05	lam=8.0
# epoch=564	loss_val=8.232256e-05	lam=8.0
# epoch=565	loss_val=8.232258e-05	lam=8.0
# epoch=566	loss_val=8.232261e-05	lam=8.0
# epoch=567	loss_val=8.232257e-05	lam=8.0
# epoch=568	loss_val=8.232262e-05	lam=8.0
# epoch=569	loss_val=8.2322644e-05	lam=8.0
# epoch=570	loss_val=8.2322615e-05	lam=8.0
# epoch=571	loss_val=8.2322615e-05	lam=8.0
# epoch=572	loss_val=8.23226e-05	lam=8.0
# epoch=573	loss_val=8.232257e-05	lam=8.0
# epoch=574	loss_val=8.23226e-05	lam=8.0
# epoch=575	loss_val=8.2322615e-05	lam=8.0
# epoch=576	loss_val=8.232263e-05	lam=8.0
# epoch=577	loss_val=8.2322615e-05	lam=8.0
# epoch=578	loss_val=8.232258e-05	lam=8.0
# epoch=579	loss_val=8.232259e-05	lam=8.0
# epoch=580	loss_val=8.23226e-05	lam=8.0
# epoch=581	loss_val=8.232258e-05	lam=8.0
# epoch=582	loss_val=8.232259e-05	lam=8.0
# epoch=583	loss_val=8.2322615e-05	lam=8.0
# epoch=584	loss_val=8.23226e-05	lam=8.0
# epoch=585	loss_val=8.232258e-05	lam=8.0
# epoch=586	loss_val=8.232256e-05	lam=8.0
# epoch=587	loss_val=8.232256e-05	lam=8.0
# epoch=588	loss_val=8.232258e-05	lam=8.0
# epoch=589	loss_val=8.232258e-05	lam=8.0
# epoch=590	loss_val=8.2322564e-05	lam=8.0
# epoch=591	loss_val=8.232257e-05	lam=8.0
# epoch=592	loss_val=8.232257e-05	lam=8.0
# epoch=593	loss_val=8.232254e-05	lam=8.0
# epoch=594	loss_val=8.232257e-05	lam=8.0
# epoch=595	loss_val=8.23226e-05	lam=8.0
# epoch=596	loss_val=8.232258e-05	lam=8.0
# epoch=597	loss_val=8.232257e-05	lam=8.0
# epoch=598	loss_val=8.232257e-05	lam=8.0
# epoch=599	loss_val=8.232256e-05	lam=8.0
# epoch=600	loss_val=8.232256e-05	lam=8.0
# epoch=601	loss_val=8.232261e-05	lam=8.0
# epoch=602	loss_val=8.232256e-05	lam=8.0
# epoch=603	loss_val=8.2322564e-05	lam=8.0
# epoch=604	loss_val=8.232254e-05	lam=8.0
# epoch=605	loss_val=8.232254e-05	lam=8.0
# epoch=606	loss_val=8.2322586e-05	lam=8.0
# epoch=607	loss_val=8.2322564e-05	lam=8.0
# epoch=608	loss_val=8.232259e-05	lam=8.0
# epoch=609	loss_val=8.2322564e-05	lam=8.0
# epoch=610	loss_val=8.232255e-05	lam=8.0
# epoch=611	loss_val=8.232258e-05	lam=8.0
# epoch=612	loss_val=8.232257e-05	lam=8.0
# epoch=613	loss_val=8.232251e-05	lam=8.0
# epoch=614	loss_val=8.232254e-05	lam=8.0
# epoch=615	loss_val=8.232263e-05	lam=8.0
# epoch=616	loss_val=8.232259e-05	lam=8.0
# epoch=617	loss_val=8.232257e-05	lam=8.0
# epoch=618	loss_val=8.232257e-05	lam=8.0
# epoch=619	loss_val=8.2322535e-05	lam=8.0
# epoch=620	loss_val=8.2322564e-05	lam=8.0
# epoch=621	loss_val=8.232255e-05	lam=8.0
# epoch=622	loss_val=8.232259e-05	lam=8.0
# epoch=623	loss_val=8.232255e-05	lam=8.0
# epoch=624	loss_val=8.232253e-05	lam=8.0
# epoch=625	loss_val=8.232253e-05	lam=8.0
# epoch=626	loss_val=8.2322505e-05	lam=8.0
# epoch=627	loss_val=8.232249e-05	lam=8.0
# epoch=628	loss_val=8.232253e-05	lam=8.0
# epoch=629	loss_val=8.232251e-05	lam=8.0
# epoch=630	loss_val=8.2322505e-05	lam=8.0
# epoch=631	loss_val=8.232256e-05	lam=8.0
# epoch=632	loss_val=8.232255e-05	lam=8.0
# epoch=633	loss_val=8.232252e-05	lam=8.0
# epoch=634	loss_val=8.2322564e-05	lam=8.0
# epoch=635	loss_val=8.232256e-05	lam=8.0
# epoch=636	loss_val=8.232257e-05	lam=8.0
# epoch=637	loss_val=8.232256e-05	lam=8.0
# epoch=638	loss_val=8.23225e-05	lam=8.0
# epoch=639	loss_val=8.232255e-05	lam=8.0
# epoch=640	loss_val=8.2322564e-05	lam=8.0
# epoch=641	loss_val=8.232254e-05	lam=8.0
# epoch=642	loss_val=8.232257e-05	lam=8.0
# epoch=643	loss_val=8.232254e-05	lam=8.0
# epoch=644	loss_val=8.2322535e-05	lam=8.0
# epoch=645	loss_val=8.232258e-05	lam=8.0
# epoch=646	loss_val=8.232254e-05	lam=8.0
# epoch=647	loss_val=8.232252e-05	lam=8.0
# epoch=648	loss_val=8.232252e-05	lam=8.0
# epoch=649	loss_val=8.2322535e-05	lam=8.0
# epoch=650	loss_val=8.2322505e-05	lam=8.0
# epoch=651	loss_val=8.2322535e-05	lam=8.0
# epoch=652	loss_val=8.232251e-05	lam=8.0
# epoch=653	loss_val=8.2322505e-05	lam=8.0
# epoch=654	loss_val=8.232249e-05	lam=8.0
# epoch=655	loss_val=8.23225e-05	lam=8.0
# epoch=656	loss_val=8.232251e-05	lam=8.0
# epoch=657	loss_val=8.23225e-05	lam=8.0
# epoch=658	loss_val=8.232253e-05	lam=8.0
# epoch=659	loss_val=8.232253e-05	lam=8.0
# epoch=660	loss_val=8.232249e-05	lam=8.0
# epoch=661	loss_val=8.232249e-05	lam=8.0
# epoch=662	loss_val=8.232254e-05	lam=8.0
# epoch=663	loss_val=8.23225e-05	lam=8.0
# epoch=664	loss_val=8.2322505e-05	lam=8.0
# epoch=665	loss_val=8.232251e-05	lam=8.0
# epoch=666	loss_val=8.2322484e-05	lam=8.0
# epoch=667	loss_val=8.232253e-05	lam=8.0
# epoch=668	loss_val=8.2322505e-05	lam=8.0
# epoch=669	loss_val=8.2322505e-05	lam=8.0
# epoch=670	loss_val=8.23225e-05	lam=8.0
# epoch=671	loss_val=8.232249e-05	lam=8.0
# epoch=672	loss_val=8.232251e-05	lam=8.0
# epoch=673	loss_val=8.23225e-05	lam=8.0
# epoch=674	loss_val=8.232254e-05	lam=8.0
# epoch=675	loss_val=8.232251e-05	lam=8.0
# epoch=676	loss_val=8.232251e-05	lam=8.0
# epoch=677	loss_val=8.232253e-05	lam=8.0
# epoch=678	loss_val=8.232253e-05	lam=8.0
# epoch=679	loss_val=8.2322535e-05	lam=8.0
# epoch=680	loss_val=8.232254e-05	lam=8.0
# epoch=681	loss_val=8.232253e-05	lam=8.0
# epoch=682	loss_val=8.232249e-05	lam=8.0
# epoch=683	loss_val=8.23225e-05	lam=8.0
# epoch=684	loss_val=8.232247e-05	lam=8.0
# epoch=685	loss_val=8.232248e-05	lam=8.0
# epoch=686	loss_val=8.232247e-05	lam=8.0
# epoch=687	loss_val=8.232247e-05	lam=8.0
# epoch=688	loss_val=8.232248e-05	lam=8.0
# epoch=689	loss_val=8.232251e-05	lam=8.0
# epoch=690	loss_val=8.232249e-05	lam=8.0
# epoch=691	loss_val=8.232247e-05	lam=8.0
# epoch=692	loss_val=8.232247e-05	lam=8.0
# epoch=693	loss_val=8.232246e-05	lam=8.0
# epoch=694	loss_val=8.232249e-05	lam=8.0
# epoch=695	loss_val=8.2322484e-05	lam=8.0
# epoch=696	loss_val=8.23225e-05	lam=8.0
# epoch=697	loss_val=8.232249e-05	lam=8.0
# epoch=698	loss_val=8.232249e-05	lam=8.0
# epoch=699	loss_val=8.232246e-05	lam=8.0
# epoch=700	loss_val=8.2322484e-05	lam=8.0
# epoch=701	loss_val=8.23225e-05	lam=8.0
# epoch=702	loss_val=8.232247e-05	lam=8.0
# epoch=703	loss_val=8.232252e-05	lam=8.0
# epoch=704	loss_val=8.232252e-05	lam=8.0
# epoch=705	loss_val=8.232246e-05	lam=8.0
# epoch=706	loss_val=8.2322455e-05	lam=8.0
# epoch=707	loss_val=8.232249e-05	lam=8.0
# epoch=708	loss_val=8.232252e-05	lam=8.0
# epoch=709	loss_val=8.2322505e-05	lam=8.0
# epoch=710	loss_val=8.232245e-05	lam=8.0
# epoch=711	loss_val=8.23225e-05	lam=8.0
# epoch=712	loss_val=8.232246e-05	lam=8.0
# epoch=713	loss_val=8.232248e-05	lam=8.0
# epoch=714	loss_val=8.23225e-05	lam=8.0
# epoch=715	loss_val=8.23225e-05	lam=8.0
# epoch=716	loss_val=8.232247e-05	lam=8.0
# epoch=717	loss_val=8.232245e-05	lam=8.0
# epoch=718	loss_val=8.232248e-05	lam=8.0
# epoch=719	loss_val=8.232243e-05	lam=8.0
# epoch=720	loss_val=8.232247e-05	lam=8.0
# epoch=721	loss_val=8.232246e-05	lam=8.0
# epoch=722	loss_val=8.232245e-05	lam=8.0
# epoch=723	loss_val=8.232247e-05	lam=8.0
# epoch=724	loss_val=8.232243e-05	lam=8.0
# epoch=725	loss_val=8.232245e-05	lam=8.0
# epoch=726	loss_val=8.2322455e-05	lam=8.0
# epoch=727	loss_val=8.232242e-05	lam=8.0
# epoch=728	loss_val=8.2322425e-05	lam=8.0
# epoch=729	loss_val=8.23224e-05	lam=8.0
# epoch=730	loss_val=8.2322396e-05	lam=8.0
# epoch=731	loss_val=8.232248e-05	lam=8.0
# epoch=732	loss_val=8.232241e-05	lam=8.0
# epoch=733	loss_val=8.232242e-05	lam=8.0
# epoch=734	loss_val=8.232246e-05	lam=8.0
# epoch=735	loss_val=8.232249e-05	lam=8.0
# epoch=736	loss_val=8.2322484e-05	lam=8.0
# epoch=737	loss_val=8.232246e-05	lam=8.0
# epoch=738	loss_val=8.232246e-05	lam=8.0
# epoch=739	loss_val=8.232245e-05	lam=8.0
# epoch=740	loss_val=8.2322535e-05	lam=8.0
# epoch=741	loss_val=8.2322455e-05	lam=8.0
# epoch=742	loss_val=8.232247e-05	lam=8.0
# epoch=743	loss_val=8.232247e-05	lam=8.0
# epoch=744	loss_val=8.232247e-05	lam=8.0
# epoch=745	loss_val=8.232244e-05	lam=8.0
# epoch=746	loss_val=8.2322455e-05	lam=8.0
# epoch=747	loss_val=8.2322425e-05	lam=8.0
# epoch=748	loss_val=8.232246e-05	lam=8.0
# epoch=749	loss_val=8.232242e-05	lam=8.0
# epoch=750	loss_val=8.232245e-05	lam=8.0
# epoch=751	loss_val=8.232247e-05	lam=8.0
# epoch=752	loss_val=8.232244e-05	lam=8.0
# epoch=753	loss_val=8.232244e-05	lam=8.0
# epoch=754	loss_val=8.232243e-05	lam=8.0
# epoch=755	loss_val=8.232245e-05	lam=8.0
# epoch=756	loss_val=8.2322425e-05	lam=8.0
# epoch=757	loss_val=8.232238e-05	lam=8.0
# epoch=758	loss_val=8.2322425e-05	lam=8.0
# epoch=759	loss_val=8.232244e-05	lam=8.0
# epoch=760	loss_val=8.232245e-05	lam=8.0
# epoch=761	loss_val=8.232243e-05	lam=8.0
# epoch=762	loss_val=8.2322425e-05	lam=8.0
# epoch=763	loss_val=8.232243e-05	lam=8.0
# epoch=764	loss_val=8.232243e-05	lam=8.0
# epoch=765	loss_val=8.232244e-05	lam=8.0
# epoch=766	loss_val=8.2322455e-05	lam=8.0
# epoch=767	loss_val=8.232248e-05	lam=8.0
# epoch=768	loss_val=8.2322484e-05	lam=8.0
# epoch=769	loss_val=8.232243e-05	lam=8.0
# epoch=770	loss_val=8.2322455e-05	lam=8.0
# epoch=771	loss_val=8.2322425e-05	lam=8.0
# epoch=772	loss_val=8.232247e-05	lam=8.0
# epoch=773	loss_val=8.232245e-05	lam=8.0
# epoch=774	loss_val=8.2322455e-05	lam=8.0
# epoch=775	loss_val=8.232241e-05	lam=8.0
# epoch=776	loss_val=8.232244e-05	lam=8.0
# epoch=777	loss_val=8.232242e-05	lam=8.0
# epoch=778	loss_val=8.232245e-05	lam=8.0
# epoch=779	loss_val=8.232247e-05	lam=8.0
# epoch=780	loss_val=8.2322455e-05	lam=8.0
# epoch=781	loss_val=8.232247e-05	lam=8.0
# epoch=782	loss_val=8.232247e-05	lam=8.0
# epoch=783	loss_val=8.232245e-05	lam=8.0
# epoch=784	loss_val=8.232242e-05	lam=8.0
# epoch=785	loss_val=8.232244e-05	lam=8.0
# epoch=786	loss_val=8.2322455e-05	lam=8.0
# epoch=787	loss_val=8.232246e-05	lam=8.0
# epoch=788	loss_val=8.2322425e-05	lam=8.0
# epoch=789	loss_val=8.232243e-05	lam=8.0
# epoch=790	loss_val=8.2322396e-05	lam=8.0
# epoch=791	loss_val=8.232247e-05	lam=8.0
# epoch=792	loss_val=8.2322396e-05	lam=8.0
# epoch=793	loss_val=8.232245e-05	lam=8.0
# epoch=794	loss_val=8.232244e-05	lam=8.0
# epoch=795	loss_val=8.232246e-05	lam=8.0
# epoch=796	loss_val=8.2322455e-05	lam=8.0
# epoch=797	loss_val=8.23224e-05	lam=8.0
# epoch=798	loss_val=8.2322484e-05	lam=8.0
# epoch=799	loss_val=8.232244e-05	lam=8.0
# epoch=800	loss_val=8.232242e-05	lam=8.0
# epoch=801	loss_val=8.2322396e-05	lam=8.0
# epoch=802	loss_val=8.2322396e-05	lam=8.0
# epoch=803	loss_val=8.232238e-05	lam=8.0
# epoch=804	loss_val=8.232239e-05	lam=8.0
# epoch=805	loss_val=8.2322375e-05	lam=8.0
# epoch=806	loss_val=8.232239e-05	lam=8.0
# epoch=807	loss_val=8.23224e-05	lam=8.0
# epoch=808	loss_val=8.23224e-05	lam=8.0
# epoch=809	loss_val=8.232242e-05	lam=8.0
# epoch=810	loss_val=8.2322396e-05	lam=8.0
# epoch=811	loss_val=8.2322455e-05	lam=8.0
# epoch=812	loss_val=8.2322425e-05	lam=8.0
# epoch=813	loss_val=8.232237e-05	lam=8.0
# epoch=814	loss_val=8.2322375e-05	lam=8.0
# epoch=815	loss_val=8.2322396e-05	lam=8.0
# epoch=816	loss_val=8.232238e-05	lam=8.0
# epoch=817	loss_val=8.232238e-05	lam=8.0
# epoch=818	loss_val=8.232238e-05	lam=8.0
# epoch=819	loss_val=8.2322375e-05	lam=8.0
# epoch=820	loss_val=8.232236e-05	lam=8.0
# epoch=821	loss_val=8.2322345e-05	lam=8.0
# epoch=822	loss_val=8.232238e-05	lam=8.0
# epoch=823	loss_val=8.232233e-05	lam=8.0
# epoch=824	loss_val=8.2322396e-05	lam=8.0
# epoch=825	loss_val=8.232233e-05	lam=8.0
# epoch=826	loss_val=8.232237e-05	lam=8.0
# epoch=827	loss_val=8.232239e-05	lam=8.0
# epoch=828	loss_val=8.232236e-05	lam=8.0
# epoch=829	loss_val=8.232236e-05	lam=8.0
# epoch=830	loss_val=8.2322396e-05	lam=8.0
# epoch=831	loss_val=8.232237e-05	lam=8.0
# epoch=832	loss_val=8.232238e-05	lam=8.0
# epoch=833	loss_val=8.23224e-05	lam=8.0
# epoch=834	loss_val=8.2322345e-05	lam=8.0
# epoch=835	loss_val=8.2322396e-05	lam=8.0
# epoch=836	loss_val=8.232235e-05	lam=8.0
# epoch=837	loss_val=8.232235e-05	lam=8.0
# epoch=838	loss_val=8.232235e-05	lam=8.0
# epoch=839	loss_val=8.232237e-05	lam=8.0
# epoch=840	loss_val=8.232236e-05	lam=8.0
# epoch=841	loss_val=8.2322345e-05	lam=8.0
# epoch=842	loss_val=8.232237e-05	lam=8.0
# epoch=843	loss_val=8.2322316e-05	lam=8.0
# epoch=844	loss_val=8.232234e-05	lam=8.0
# epoch=845	loss_val=8.232237e-05	lam=8.0
# epoch=846	loss_val=8.2322345e-05	lam=8.0
# epoch=847	loss_val=8.232235e-05	lam=8.0
# epoch=848	loss_val=8.2322375e-05	lam=8.0
# epoch=849	loss_val=8.232236e-05	lam=8.0
# epoch=850	loss_val=8.232234e-05	lam=8.0
# epoch=851	loss_val=8.232237e-05	lam=8.0
# epoch=852	loss_val=8.2322345e-05	lam=8.0
# epoch=853	loss_val=8.2322375e-05	lam=8.0
# epoch=854	loss_val=8.232233e-05	lam=8.0
# epoch=855	loss_val=8.2322375e-05	lam=8.0
# epoch=856	loss_val=8.232236e-05	lam=8.0
# epoch=857	loss_val=8.232235e-05	lam=8.0
# epoch=858	loss_val=8.232236e-05	lam=8.0
# epoch=859	loss_val=8.232234e-05	lam=8.0
# epoch=860	loss_val=8.232238e-05	lam=8.0
# epoch=861	loss_val=8.232237e-05	lam=8.0
# epoch=862	loss_val=8.232237e-05	lam=8.0
# epoch=863	loss_val=8.232236e-05	lam=8.0
# epoch=864	loss_val=8.2322345e-05	lam=8.0
# epoch=865	loss_val=8.232233e-05	lam=8.0
# epoch=866	loss_val=8.2322345e-05	lam=8.0
# epoch=867	loss_val=8.232236e-05	lam=8.0
# epoch=868	loss_val=8.232238e-05	lam=8.0
# epoch=869	loss_val=8.232238e-05	lam=8.0
# epoch=870	loss_val=8.23224e-05	lam=8.0
# epoch=871	loss_val=8.232234e-05	lam=8.0
# epoch=872	loss_val=8.2322375e-05	lam=8.0
# epoch=873	loss_val=8.232234e-05	lam=8.0
# epoch=874	loss_val=8.232234e-05	lam=8.0
# epoch=875	loss_val=8.23223e-05	lam=8.0
# epoch=876	loss_val=8.232234e-05	lam=8.0
# epoch=877	loss_val=8.2322316e-05	lam=8.0
# epoch=878	loss_val=8.232233e-05	lam=8.0
# epoch=879	loss_val=8.232235e-05	lam=8.0
# epoch=880	loss_val=8.2322345e-05	lam=8.0
# epoch=881	loss_val=8.232233e-05	lam=8.0
# epoch=882	loss_val=8.232232e-05	lam=8.0
# epoch=883	loss_val=8.2322345e-05	lam=8.0
# epoch=884	loss_val=8.2322345e-05	lam=8.0
# epoch=885	loss_val=8.2322316e-05	lam=8.0
# epoch=886	loss_val=8.2322375e-05	lam=8.0
# epoch=887	loss_val=8.232235e-05	lam=8.0
# epoch=888	loss_val=8.232236e-05	lam=8.0
# epoch=889	loss_val=8.2322345e-05	lam=8.0
# epoch=890	loss_val=8.232234e-05	lam=8.0
# epoch=891	loss_val=8.232234e-05	lam=8.0
# epoch=892	loss_val=8.232235e-05	lam=8.0
# epoch=893	loss_val=8.232233e-05	lam=8.0
# epoch=894	loss_val=8.232238e-05	lam=8.0
# epoch=895	loss_val=8.232233e-05	lam=8.0
# epoch=896	loss_val=8.232233e-05	lam=8.0
# epoch=897	loss_val=8.232229e-05	lam=8.0
# epoch=898	loss_val=8.232231e-05	lam=8.0
# epoch=899	loss_val=8.2322294e-05	lam=8.0
# epoch=900	loss_val=8.232236e-05	lam=8.0
# epoch=901	loss_val=8.232233e-05	lam=8.0
# epoch=902	loss_val=8.232231e-05	lam=8.0
# epoch=903	loss_val=8.2322316e-05	lam=8.0
# epoch=904	loss_val=8.2322316e-05	lam=8.0
# epoch=905	loss_val=8.232231e-05	lam=8.0
# epoch=906	loss_val=8.232235e-05	lam=8.0
# epoch=907	loss_val=8.232226e-05	lam=8.0
# epoch=908	loss_val=8.232228e-05	lam=8.0
# epoch=909	loss_val=8.2322316e-05	lam=8.0
# epoch=910	loss_val=8.232229e-05	lam=8.0
# epoch=911	loss_val=8.232232e-05	lam=8.0
# epoch=912	loss_val=8.232226e-05	lam=8.0
# epoch=913	loss_val=8.2322316e-05	lam=8.0
# epoch=914	loss_val=8.232234e-05	lam=8.0
# epoch=915	loss_val=8.232228e-05	lam=8.0
# epoch=916	loss_val=8.232231e-05	lam=8.0
# epoch=917	loss_val=8.232228e-05	lam=8.0
# epoch=918	loss_val=8.2322265e-05	lam=8.0
# epoch=919	loss_val=8.232227e-05	lam=8.0
# epoch=920	loss_val=8.232233e-05	lam=8.0
# epoch=921	loss_val=8.232226e-05	lam=8.0
# epoch=922	loss_val=8.2322316e-05	lam=8.0
# epoch=923	loss_val=8.232233e-05	lam=8.0
# epoch=924	loss_val=8.2322316e-05	lam=8.0
# epoch=925	loss_val=8.23223e-05	lam=8.0
# epoch=926	loss_val=8.23223e-05	lam=8.0
# epoch=927	loss_val=8.232229e-05	lam=8.0
# epoch=928	loss_val=8.2322294e-05	lam=8.0
# epoch=929	loss_val=8.232233e-05	lam=8.0
# epoch=930	loss_val=8.232232e-05	lam=8.0
# epoch=931	loss_val=8.2322265e-05	lam=8.0
# epoch=932	loss_val=8.2322294e-05	lam=8.0
# epoch=933	loss_val=8.232227e-05	lam=8.0
# epoch=934	loss_val=8.232233e-05	lam=8.0
# epoch=935	loss_val=8.23223e-05	lam=8.0
# epoch=936	loss_val=8.2322294e-05	lam=8.0
# epoch=937	loss_val=8.232234e-05	lam=8.0
# epoch=938	loss_val=8.23223e-05	lam=8.0
# epoch=939	loss_val=8.232231e-05	lam=8.0
# epoch=940	loss_val=8.232232e-05	lam=8.0
# epoch=941	loss_val=8.2322345e-05	lam=8.0
# epoch=942	loss_val=8.232228e-05	lam=8.0
# epoch=943	loss_val=8.23223e-05	lam=8.0
# epoch=944	loss_val=8.232229e-05	lam=8.0
# epoch=945	loss_val=8.2322316e-05	lam=8.0
# epoch=946	loss_val=8.23223e-05	lam=8.0
# epoch=947	loss_val=8.232228e-05	lam=8.0
# epoch=948	loss_val=8.232228e-05	lam=8.0
# epoch=949	loss_val=8.23223e-05	lam=8.0
# epoch=950	loss_val=8.232227e-05	lam=8.0
# epoch=951	loss_val=8.2322265e-05	lam=8.0
# epoch=952	loss_val=8.2322294e-05	lam=8.0
# epoch=953	loss_val=8.2322265e-05	lam=8.0
# epoch=954	loss_val=8.232231e-05	lam=8.0
# epoch=955	loss_val=8.232231e-05	lam=8.0
# epoch=956	loss_val=8.232229e-05	lam=8.0
# epoch=957	loss_val=8.232227e-05	lam=8.0
# epoch=958	loss_val=8.232232e-05	lam=8.0
# epoch=959	loss_val=8.232225e-05	lam=8.0
# epoch=960	loss_val=8.232228e-05	lam=8.0
# epoch=961	loss_val=8.232224e-05	lam=8.0
# epoch=962	loss_val=8.232228e-05	lam=8.0
# epoch=963	loss_val=8.2322294e-05	lam=8.0
# epoch=964	loss_val=8.232227e-05	lam=8.0
# epoch=965	loss_val=8.232223e-05	lam=8.0
# epoch=966	loss_val=8.232231e-05	lam=8.0
# epoch=967	loss_val=8.232232e-05	lam=8.0
# epoch=968	loss_val=8.232229e-05	lam=8.0
# epoch=969	loss_val=8.232229e-05	lam=8.0
# epoch=970	loss_val=8.232228e-05	lam=8.0
# epoch=971	loss_val=8.2322294e-05	lam=8.0
# epoch=972	loss_val=8.232227e-05	lam=8.0
# epoch=973	loss_val=8.232227e-05	lam=8.0
# epoch=974	loss_val=8.232227e-05	lam=8.0
# epoch=975	loss_val=8.232225e-05	lam=8.0
# epoch=976	loss_val=8.232227e-05	lam=8.0
# epoch=977	loss_val=8.232223e-05	lam=8.0
# epoch=978	loss_val=8.232228e-05	lam=8.0
# epoch=979	loss_val=8.23223e-05	lam=8.0
# epoch=980	loss_val=8.232225e-05	lam=8.0
# epoch=981	loss_val=8.232225e-05	lam=8.0
# epoch=982	loss_val=8.232227e-05	lam=8.0
# epoch=983	loss_val=8.2322265e-05	lam=8.0
# epoch=984	loss_val=8.232223e-05	lam=8.0
# epoch=985	loss_val=8.232225e-05	lam=8.0
# epoch=986	loss_val=8.232226e-05	lam=8.0
# epoch=987	loss_val=8.232224e-05	lam=8.0
# epoch=988	loss_val=8.2322236e-05	lam=8.0
# epoch=989	loss_val=8.2322214e-05	lam=8.0
# epoch=990	loss_val=8.232229e-05	lam=8.0
# epoch=991	loss_val=8.2322236e-05	lam=8.0
# epoch=992	loss_val=8.2322236e-05	lam=8.0
# epoch=993	loss_val=8.2322214e-05	lam=8.0
# epoch=994	loss_val=8.232225e-05	lam=8.0
# epoch=995	loss_val=8.232224e-05	lam=8.0
# epoch=996	loss_val=8.2322236e-05	lam=8.0
# epoch=997	loss_val=8.232226e-05	lam=8.0
# epoch=998	loss_val=8.2322214e-05	lam=8.0
# epoch=999	loss_val=8.232226e-05	lam=8.0
# epoch=1000	loss_val=8.232227e-05	lam=8.0
# epoch=1001	loss_val=8.232225e-05	lam=8.0
# epoch=1002	loss_val=8.23223e-05	lam=8.0
# epoch=1003	loss_val=8.232227e-05	lam=8.0
# epoch=1004	loss_val=8.232228e-05	lam=8.0
# epoch=1005	loss_val=8.232231e-05	lam=8.0
# epoch=1006	loss_val=8.2322236e-05	lam=8.0
# epoch=1007	loss_val=8.232227e-05	lam=8.0
# epoch=1008	loss_val=8.232224e-05	lam=8.0
# epoch=1009	loss_val=8.232223e-05	lam=8.0
# epoch=1010	loss_val=8.2322265e-05	lam=8.0
# epoch=1011	loss_val=8.232224e-05	lam=8.0
# epoch=1012	loss_val=8.232228e-05	lam=8.0
# epoch=1013	loss_val=8.232225e-05	lam=8.0
# epoch=1014	loss_val=8.232225e-05	lam=8.0
# epoch=1015	loss_val=8.232225e-05	lam=8.0
# epoch=1016	loss_val=8.232224e-05	lam=8.0
# epoch=1017	loss_val=8.232224e-05	lam=8.0
# epoch=1018	loss_val=8.232226e-05	lam=8.0
# epoch=1019	loss_val=8.23222e-05	lam=8.0
# epoch=1020	loss_val=8.232223e-05	lam=8.0
# epoch=1021	loss_val=8.232224e-05	lam=8.0
# epoch=1022	loss_val=8.232221e-05	lam=8.0
# epoch=1023	loss_val=8.2322236e-05	lam=8.0
# epoch=1024	loss_val=8.232223e-05	lam=8.0
# epoch=1025	loss_val=8.232222e-05	lam=8.0
# epoch=1026	loss_val=8.2322185e-05	lam=8.0
# epoch=1027	loss_val=8.232226e-05	lam=8.0
# epoch=1028	loss_val=8.232226e-05	lam=8.0
# epoch=1029	loss_val=8.2322265e-05	lam=8.0
# epoch=1030	loss_val=8.232226e-05	lam=8.0
# epoch=1031	loss_val=8.232225e-05	lam=8.0
# epoch=1032	loss_val=8.2322214e-05	lam=8.0
# epoch=1033	loss_val=8.232224e-05	lam=8.0
# epoch=1034	loss_val=8.2322214e-05	lam=8.0
# epoch=1035	loss_val=8.232225e-05	lam=8.0
# epoch=1036	loss_val=8.232224e-05	lam=8.0
# epoch=1037	loss_val=8.232226e-05	lam=8.0
# epoch=1038	loss_val=8.2322214e-05	lam=8.0
# epoch=1039	loss_val=8.232222e-05	lam=8.0
# epoch=1040	loss_val=8.232223e-05	lam=8.0
# epoch=1041	loss_val=8.232225e-05	lam=8.0
# epoch=1042	loss_val=8.2322294e-05	lam=8.0
# epoch=1043	loss_val=8.232224e-05	lam=8.0
# epoch=1044	loss_val=8.232225e-05	lam=8.0
# epoch=1045	loss_val=8.232224e-05	lam=8.0
# epoch=1046	loss_val=8.232227e-05	lam=8.0
# epoch=1047	loss_val=8.232225e-05	lam=8.0
# epoch=1048	loss_val=8.232225e-05	lam=8.0
# epoch=1049	loss_val=8.232222e-05	lam=8.0
# epoch=1050	loss_val=8.232229e-05	lam=8.0
# epoch=1051	loss_val=8.23222e-05	lam=8.0
# epoch=1052	loss_val=8.232231e-05	lam=8.0
# epoch=1053	loss_val=8.232224e-05	lam=8.0
# epoch=1054	loss_val=8.232231e-05	lam=8.0
# epoch=1055	loss_val=8.2322265e-05	lam=8.0
# epoch=1056	loss_val=8.232223e-05	lam=8.0
# epoch=1057	loss_val=8.232224e-05	lam=8.0
# epoch=1058	loss_val=8.232224e-05	lam=8.0
# epoch=1059	loss_val=8.232224e-05	lam=8.0
# epoch=1060	loss_val=8.232228e-05	lam=8.0
# epoch=1061	loss_val=8.232224e-05	lam=8.0
# epoch=1062	loss_val=8.2322294e-05	lam=8.0
# epoch=1063	loss_val=8.232226e-05	lam=8.0
# epoch=1064	loss_val=8.2322265e-05	lam=8.0
# epoch=1065	loss_val=8.232227e-05	lam=8.0
# epoch=1066	loss_val=8.2322265e-05	lam=8.0
# epoch=1067	loss_val=8.2322236e-05	lam=8.0
# epoch=1068	loss_val=8.232223e-05	lam=8.0
# epoch=1069	loss_val=8.232231e-05	lam=8.0
# epoch=1070	loss_val=8.232223e-05	lam=8.0
# epoch=1071	loss_val=8.2322265e-05	lam=8.0
# epoch=1072	loss_val=8.232223e-05	lam=8.0
# epoch=1073	loss_val=8.232225e-05	lam=8.0
# epoch=1074	loss_val=8.232222e-05	lam=8.0
# epoch=1075	loss_val=8.232222e-05	lam=8.0
# epoch=1076	loss_val=8.232223e-05	lam=8.0
# epoch=1077	loss_val=8.232223e-05	lam=8.0
# epoch=1078	loss_val=8.232227e-05	lam=8.0
# epoch=1079	loss_val=8.232224e-05	lam=8.0
# epoch=1080	loss_val=8.2322214e-05	lam=8.0
# epoch=1081	loss_val=8.232224e-05	lam=8.0
# epoch=1082	loss_val=8.232223e-05	lam=8.0
# epoch=1083	loss_val=8.232218e-05	lam=8.0
# epoch=1084	loss_val=8.232225e-05	lam=8.0
# epoch=1085	loss_val=8.232222e-05	lam=8.0
# epoch=1086	loss_val=8.2322214e-05	lam=8.0
# epoch=1087	loss_val=8.232217e-05	lam=8.0
# epoch=1088	loss_val=8.232227e-05	lam=8.0
# epoch=1089	loss_val=8.232225e-05	lam=8.0
# epoch=1090	loss_val=8.232223e-05	lam=8.0
# epoch=1091	loss_val=8.232229e-05	lam=8.0
# epoch=1092	loss_val=8.232226e-05	lam=8.0
# epoch=1093	loss_val=8.232221e-05	lam=8.0
# epoch=1094	loss_val=8.232223e-05	lam=8.0
# epoch=1095	loss_val=8.2322185e-05	lam=8.0
# epoch=1096	loss_val=8.232224e-05	lam=8.0
# epoch=1097	loss_val=8.232217e-05	lam=8.0
# epoch=1098	loss_val=8.232223e-05	lam=8.0
# epoch=1099	loss_val=8.2322185e-05	lam=8.0
# epoch=1100	loss_val=8.2322185e-05	lam=8.0
# epoch=1101	loss_val=8.232219e-05	lam=8.0
# epoch=1102	loss_val=8.232218e-05	lam=8.0
# epoch=1103	loss_val=8.232217e-05	lam=8.0
# epoch=1104	loss_val=8.232215e-05	lam=8.0
# epoch=1105	loss_val=8.232221e-05	lam=8.0
# epoch=1106	loss_val=8.232221e-05	lam=8.0
# epoch=1107	loss_val=8.232227e-05	lam=8.0
# epoch=1108	loss_val=8.232212e-05	lam=8.0
# epoch=1109	loss_val=8.232227e-05	lam=8.0
# epoch=1110	loss_val=8.232217e-05	lam=8.0
# epoch=1111	loss_val=8.23222e-05	lam=8.0
# epoch=1112	loss_val=8.2322156e-05	lam=8.0
# epoch=1113	loss_val=8.23222e-05	lam=8.0
# epoch=1114	loss_val=8.2322156e-05	lam=8.0
# epoch=1115	loss_val=8.2322156e-05	lam=8.0
# epoch=1116	loss_val=8.232216e-05	lam=8.0
# epoch=1117	loss_val=8.23222e-05	lam=8.0
# epoch=1118	loss_val=8.23222e-05	lam=8.0
# epoch=1119	loss_val=8.23222e-05	lam=8.0
# epoch=1120	loss_val=8.232223e-05	lam=8.0
# epoch=1121	loss_val=8.2322156e-05	lam=8.0
# epoch=1122	loss_val=8.2322185e-05	lam=8.0
# epoch=1123	loss_val=8.232218e-05	lam=8.0
# epoch=1124	loss_val=8.2322236e-05	lam=8.0
# epoch=1125	loss_val=8.232215e-05	lam=8.0
# epoch=1126	loss_val=8.232216e-05	lam=8.0
# epoch=1127	loss_val=8.232216e-05	lam=8.0
# epoch=1128	loss_val=8.23222e-05	lam=8.0
# epoch=1129	loss_val=8.232213e-05	lam=8.0
# epoch=1130	loss_val=8.2322185e-05	lam=8.0
# epoch=1131	loss_val=8.232211e-05	lam=8.0
# epoch=1132	loss_val=8.232219e-05	lam=8.0
# epoch=1133	loss_val=8.2322214e-05	lam=8.0
# epoch=1134	loss_val=8.232222e-05	lam=8.0
# epoch=1135	loss_val=8.2322236e-05	lam=8.0
# epoch=1136	loss_val=8.2322156e-05	lam=8.0
# epoch=1137	loss_val=8.2322214e-05	lam=8.0
# epoch=1138	loss_val=8.2322134e-05	lam=8.0
# epoch=1139	loss_val=8.232219e-05	lam=8.0
# epoch=1140	loss_val=8.2322214e-05	lam=8.0
# epoch=1141	loss_val=8.232217e-05	lam=8.0
# epoch=1142	loss_val=8.232222e-05	lam=8.0
# epoch=1143	loss_val=8.2322236e-05	lam=8.0
# epoch=1144	loss_val=8.2322214e-05	lam=8.0
# epoch=1145	loss_val=8.232216e-05	lam=8.0
# epoch=1146	loss_val=8.232224e-05	lam=8.0
# epoch=1147	loss_val=8.232223e-05	lam=8.0
# epoch=1148	loss_val=8.232218e-05	lam=8.0
# epoch=1149	loss_val=8.232218e-05	lam=8.0
# epoch=1150	loss_val=8.2322105e-05	lam=8.0
# epoch=1151	loss_val=8.232218e-05	lam=8.0
# epoch=1152	loss_val=8.2322185e-05	lam=8.0
# epoch=1153	loss_val=8.2322134e-05	lam=8.0
# epoch=1154	loss_val=8.232211e-05	lam=8.0
# epoch=1155	loss_val=8.232217e-05	lam=8.0
# epoch=1156	loss_val=8.232217e-05	lam=8.0
# epoch=1157	loss_val=8.232212e-05	lam=8.0
# epoch=1158	loss_val=8.2322134e-05	lam=8.0
# epoch=1159	loss_val=8.232211e-05	lam=8.0
# epoch=1160	loss_val=8.232217e-05	lam=8.0
# epoch=1161	loss_val=8.2322156e-05	lam=8.0
# epoch=1162	loss_val=8.2322156e-05	lam=8.0
# epoch=1163	loss_val=8.2322156e-05	lam=8.0
# epoch=1164	loss_val=8.2322185e-05	lam=8.0
# epoch=1165	loss_val=8.232211e-05	lam=8.0
# epoch=1166	loss_val=8.232215e-05	lam=8.0
# epoch=1167	loss_val=8.232217e-05	lam=8.0
# epoch=1168	loss_val=8.2322105e-05	lam=8.0
# epoch=1169	loss_val=8.232218e-05	lam=8.0
# epoch=1170	loss_val=8.23221e-05	lam=8.0
# epoch=1171	loss_val=8.232216e-05	lam=8.0
# epoch=1172	loss_val=8.2322054e-05	lam=8.0
# epoch=1173	loss_val=8.232216e-05	lam=8.0
# epoch=1174	loss_val=8.2322105e-05	lam=8.0
# epoch=1175	loss_val=8.2322214e-05	lam=8.0
# epoch=1176	loss_val=8.232217e-05	lam=8.0
# epoch=1177	loss_val=8.232221e-05	lam=8.0
# epoch=1178	loss_val=8.232209e-05	lam=8.0
# epoch=1179	loss_val=8.232221e-05	lam=8.0
# epoch=1180	loss_val=8.23221e-05	lam=8.0
# epoch=1181	loss_val=8.2322185e-05	lam=8.0
# epoch=1182	loss_val=8.232211e-05	lam=8.0
# epoch=1183	loss_val=8.23222e-05	lam=8.0
# epoch=1184	loss_val=8.232213e-05	lam=8.0
# epoch=1185	loss_val=8.232218e-05	lam=8.0
# epoch=1186	loss_val=8.2322134e-05	lam=8.0
# epoch=1187	loss_val=8.232216e-05	lam=8.0
# epoch=1188	loss_val=8.2322156e-05	lam=8.0
# epoch=1189	loss_val=8.2322214e-05	lam=8.0
# epoch=1190	loss_val=8.232212e-05	lam=8.0
# epoch=1191	loss_val=8.2322214e-05	lam=8.0
# ...
# epoch=4612	loss_val=8.232101e-05	lam=8.0
# epoch=4613	loss_val=8.232098e-05	lam=8.0
# epoch=4614	loss_val=8.232094e-05	lam=8.0
# epoch=4615	loss_val=8.2321014e-05	lam=8.0
# epoch=4616	loss_val=8.232097e-05	lam=8.0
# epoch=4617	loss_val=8.232101e-05	lam=8.0
# epoch=4618	loss_val=8.232101e-05	lam=8.0
# epoch=4619	loss_val=8.232095e-05	lam=8.0
# epoch=4620	loss_val=8.2321e-05	lam=8.0
# epoch=4621	loss_val=8.232103e-05	lam=8.0
# epoch=4622	loss_val=8.232103e-05	lam=8.0
# epoch=4623	loss_val=8.232089e-05	lam=8.0
# epoch=4624	loss_val=8.232103e-05	lam=8.0
# epoch=4625	loss_val=8.2320934e-05	lam=8.0
# epoch=4626	loss_val=8.2321e-05	lam=8.0
# epoch=4627	loss_val=8.23209e-05	lam=8.0
# epoch=4628	loss_val=8.2321014e-05	lam=8.0
# epoch=4629	loss_val=8.232095e-05	lam=8.0
# epoch=4630	loss_val=8.232103e-05	lam=8.0
# epoch=4631	loss_val=8.232095e-05	lam=8.0
# epoch=4632	loss_val=8.232096e-05	lam=8.0
# epoch=4633	loss_val=8.2320985e-05	lam=8.0
# epoch=4634	loss_val=8.232103e-05	lam=8.0
# epoch=4635	loss_val=8.232098e-05	lam=8.0
# epoch=4636	loss_val=8.2321036e-05	lam=8.0
# epoch=4637	loss_val=8.2320985e-05	lam=8.0
# epoch=4638	loss_val=8.232099e-05	lam=8.0
# epoch=4639	loss_val=8.232103e-05	lam=8.0
# epoch=4640	loss_val=8.232102e-05	lam=8.0
# epoch=4641	loss_val=8.232099e-05	lam=8.0
# epoch=4642	loss_val=8.232096e-05	lam=8.0
# epoch=4643	loss_val=8.232104e-05	lam=8.0
# epoch=4644	loss_val=8.2320934e-05	lam=8.0
# epoch=4645	loss_val=8.232097e-05	lam=8.0
# epoch=4646	loss_val=8.232097e-05	lam=8.0
# epoch=4647	loss_val=8.232099e-05	lam=8.0
# epoch=4648	loss_val=8.232095e-05	lam=8.0
# epoch=4649	loss_val=8.232099e-05	lam=8.0
# epoch=4650	loss_val=8.2321014e-05	lam=8.0
# epoch=4651	loss_val=8.2320934e-05	lam=8.0
# epoch=4652	loss_val=8.232095e-05	lam=8.0
# epoch=4653	loss_val=8.2320956e-05	lam=8.0
# epoch=4654	loss_val=8.2320934e-05	lam=8.0
# epoch=4655	loss_val=8.2321e-05	lam=8.0
# epoch=4656	loss_val=8.232099e-05	lam=8.0
# epoch=4657	loss_val=8.232099e-05	lam=8.0
# epoch=4658	loss_val=8.2320956e-05	lam=8.0
# epoch=4659	loss_val=8.2321036e-05	lam=8.0
# epoch=4660	loss_val=8.232096e-05	lam=8.0
# epoch=4661	loss_val=8.232097e-05	lam=8.0
# epoch=4662	loss_val=8.2320956e-05	lam=8.0
# epoch=4663	loss_val=8.2321014e-05	lam=8.0
# epoch=4664	loss_val=8.232098e-05	lam=8.0
# epoch=4665	loss_val=8.232099e-05	lam=8.0
# epoch=4666	loss_val=8.232098e-05	lam=8.0
# epoch=4667	loss_val=8.232101e-05	lam=8.0
# epoch=4668	loss_val=8.2320934e-05	lam=8.0
# epoch=4669	loss_val=8.232105e-05	lam=8.0
# epoch=4670	loss_val=8.232098e-05	lam=8.0
# epoch=4671	loss_val=8.2320985e-05	lam=8.0
# epoch=4672	loss_val=8.232094e-05	lam=8.0
# epoch=4673	loss_val=8.232104e-05	lam=8.0
# epoch=4674	loss_val=8.232096e-05	lam=8.0
# epoch=4675	loss_val=8.2321e-05	lam=8.0
# epoch=4676	loss_val=8.2320956e-05	lam=8.0
# epoch=4677	loss_val=8.232096e-05	lam=8.0
# epoch=4678	loss_val=8.232095e-05	lam=8.0
# epoch=4679	loss_val=8.2321e-05	lam=8.0
# epoch=4680	loss_val=8.232102e-05	lam=8.0
# epoch=4681	loss_val=8.232105e-05	lam=8.0
# epoch=4682	loss_val=8.2320985e-05	lam=8.0
# epoch=4683	loss_val=8.2320985e-05	lam=8.0
# epoch=4684	loss_val=8.2320956e-05	lam=8.0
# epoch=4685	loss_val=8.232103e-05	lam=8.0
# epoch=4686	loss_val=8.2321036e-05	lam=8.0
# epoch=4687	loss_val=8.2321014e-05	lam=8.0
# epoch=4688	loss_val=8.232103e-05	lam=8.0
# epoch=4689	loss_val=8.232103e-05	lam=8.0
# epoch=4690	loss_val=8.232101e-05	lam=8.0
# epoch=4691	loss_val=8.2320956e-05	lam=8.0
# epoch=4692	loss_val=8.2320985e-05	lam=8.0
# epoch=4693	loss_val=8.232096e-05	lam=8.0
# epoch=4694	loss_val=8.2321e-05	lam=8.0
# epoch=4695	loss_val=8.232098e-05	lam=8.0
# epoch=4696	loss_val=8.2320934e-05	lam=8.0
# epoch=4697	loss_val=8.232101e-05	lam=8.0
# epoch=4698	loss_val=8.232098e-05	lam=8.0
# epoch=4699	loss_val=8.232098e-05	lam=8.0
# epoch=4700	loss_val=8.232097e-05	lam=8.0
# epoch=4701	loss_val=8.232101e-05	lam=8.0
# epoch=4702	loss_val=8.232093e-05	lam=8.0
# epoch=4703	loss_val=8.232101e-05	lam=8.0
# epoch=4704	loss_val=8.2320956e-05	lam=8.0
# epoch=4705	loss_val=8.232098e-05	lam=8.0
# epoch=4706	loss_val=8.232092e-05	lam=8.0
# epoch=4707	loss_val=8.232101e-05	lam=8.0
# epoch=4708	loss_val=8.232095e-05	lam=8.0
# epoch=4709	loss_val=8.232098e-05	lam=8.0
# epoch=4710	loss_val=8.232089e-05	lam=8.0
# epoch=4711	loss_val=8.2320985e-05	lam=8.0
# epoch=4712	loss_val=8.2320956e-05	lam=8.0
# epoch=4713	loss_val=8.232096e-05	lam=8.0
# epoch=4714	loss_val=8.2321e-05	lam=8.0
# epoch=4715	loss_val=8.232093e-05	lam=8.0
# epoch=4716	loss_val=8.232095e-05	lam=8.0
# epoch=4717	loss_val=8.2320934e-05	lam=8.0
# epoch=4718	loss_val=8.23209e-05	lam=8.0
# epoch=4719	loss_val=8.232089e-05	lam=8.0
# epoch=4720	loss_val=8.2320854e-05	lam=8.0
# epoch=4721	loss_val=8.232091e-05	lam=8.0
# epoch=4722	loss_val=8.2320876e-05	lam=8.0
# epoch=4723	loss_val=8.232092e-05	lam=8.0
# epoch=4724	loss_val=8.232089e-05	lam=8.0
# epoch=4725	loss_val=8.232097e-05	lam=8.0
# epoch=4726	loss_val=8.232094e-05	lam=8.0
# epoch=4727	loss_val=8.232097e-05	lam=8.0
# epoch=4728	loss_val=8.2320905e-05	lam=8.0
# epoch=4729	loss_val=8.232098e-05	lam=8.0
# epoch=4730	loss_val=8.232097e-05	lam=8.0
# epoch=4731	loss_val=8.232095e-05	lam=8.0
# epoch=4732	loss_val=8.2321014e-05	lam=8.0
# epoch=4733	loss_val=8.2320905e-05	lam=8.0
# epoch=4734	loss_val=8.232099e-05	lam=8.0
# epoch=4735	loss_val=8.2320956e-05	lam=8.0
# epoch=4736	loss_val=8.2320985e-05	lam=8.0
# epoch=4737	loss_val=8.232097e-05	lam=8.0
# epoch=4738	loss_val=8.2321e-05	lam=8.0
# epoch=4739	loss_val=8.232098e-05	lam=8.0
# epoch=4740	loss_val=8.232097e-05	lam=8.0
# epoch=4741	loss_val=8.232099e-05	lam=8.0
# epoch=4742	loss_val=8.232104e-05	lam=8.0
# epoch=4743	loss_val=8.232103e-05	lam=8.0
# epoch=4744	loss_val=8.2321036e-05	lam=8.0
# epoch=4745	loss_val=8.232098e-05	lam=8.0
# epoch=4746	loss_val=8.2320985e-05	lam=8.0
# epoch=4747	loss_val=8.232099e-05	lam=8.0
# epoch=4748	loss_val=8.232096e-05	lam=8.0
# epoch=4749	loss_val=8.232098e-05	lam=8.0
# epoch=4750	loss_val=8.2321036e-05	lam=8.0
# epoch=4751	loss_val=8.2321036e-05	lam=8.0
# epoch=4752	loss_val=8.2321014e-05	lam=8.0
# epoch=4753	loss_val=8.232098e-05	lam=8.0
# epoch=4754	loss_val=8.232101e-05	lam=8.0
# epoch=4755	loss_val=8.2321e-05	lam=8.0
# epoch=4756	loss_val=8.232102e-05	lam=8.0
# epoch=4757	loss_val=8.232098e-05	lam=8.0
# epoch=4758	loss_val=8.232088e-05	lam=8.0
# epoch=4759	loss_val=8.2321014e-05	lam=8.0
# epoch=4760	loss_val=8.2321014e-05	lam=8.0
# epoch=4761	loss_val=8.232102e-05	lam=8.0
# epoch=4762	loss_val=8.232094e-05	lam=8.0
# epoch=4763	loss_val=8.2321036e-05	lam=8.0
# epoch=4764	loss_val=8.232103e-05	lam=8.0
# epoch=4765	loss_val=8.232101e-05	lam=8.0
# epoch=4766	loss_val=8.2320985e-05	lam=8.0
# epoch=4767	loss_val=8.232096e-05	lam=8.0
# epoch=4768	loss_val=8.2320956e-05	lam=8.0
# epoch=4769	loss_val=8.232096e-05	lam=8.0
# epoch=4770	loss_val=8.2320934e-05	lam=8.0
# epoch=4771	loss_val=8.232096e-05	lam=8.0
# epoch=4772	loss_val=8.2320985e-05	lam=8.0
# epoch=4773	loss_val=8.232091e-05	lam=8.0
# epoch=4774	loss_val=8.232096e-05	lam=8.0
# epoch=4775	loss_val=8.232091e-05	lam=8.0
# epoch=4776	loss_val=8.232095e-05	lam=8.0
# epoch=4777	loss_val=8.232096e-05	lam=8.0
# epoch=4778	loss_val=8.232096e-05	lam=8.0
# epoch=4779	loss_val=8.232095e-05	lam=8.0
# epoch=4780	loss_val=8.2321014e-05	lam=8.0
# epoch=4781	loss_val=8.2320956e-05	lam=8.0
# epoch=4782	loss_val=8.2321e-05	lam=8.0
# epoch=4783	loss_val=8.232093e-05	lam=8.0
# epoch=4784	loss_val=8.232101e-05	lam=8.0
# epoch=4785	loss_val=8.232096e-05	lam=8.0
# epoch=4786	loss_val=8.232099e-05	lam=8.0
# epoch=4787	loss_val=8.232106e-05	lam=8.0
# epoch=4788	loss_val=8.2321036e-05	lam=8.0
# epoch=4789	loss_val=8.2320985e-05	lam=8.0
# epoch=4790	loss_val=8.232097e-05	lam=8.0
# epoch=4791	loss_val=8.2321e-05	lam=8.0
# epoch=4792	loss_val=8.2321014e-05	lam=8.0
# epoch=4793	loss_val=8.232095e-05	lam=8.0
# epoch=4794	loss_val=8.232098e-05	lam=8.0
# epoch=4795	loss_val=8.232098e-05	lam=8.0
# epoch=4796	loss_val=8.232107e-05	lam=8.0
# epoch=4797	loss_val=8.2321036e-05	lam=8.0
# epoch=4798	loss_val=8.232109e-05	lam=8.0
# epoch=4799	loss_val=8.232097e-05	lam=8.0
# epoch=4800	loss_val=8.232094e-05	lam=8.0
# epoch=4801	loss_val=8.232107e-05	lam=8.0
# epoch=4802	loss_val=8.2320985e-05	lam=8.0
# epoch=4803	loss_val=8.232098e-05	lam=8.0
# epoch=4804	loss_val=8.232101e-05	lam=8.0
# epoch=4805	loss_val=8.232101e-05	lam=8.0
# epoch=4806	loss_val=8.232097e-05	lam=8.0
# epoch=4807	loss_val=8.232095e-05	lam=8.0
# epoch=4808	loss_val=8.2320956e-05	lam=8.0
# epoch=4809	loss_val=8.232099e-05	lam=8.0
# epoch=4810	loss_val=8.232102e-05	lam=8.0
# epoch=4811	loss_val=8.23209e-05	lam=8.0
# epoch=4812	loss_val=8.232093e-05	lam=8.0
# epoch=4813	loss_val=8.232093e-05	lam=8.0
# epoch=4814	loss_val=8.232092e-05	lam=8.0
# epoch=4815	loss_val=8.232094e-05	lam=8.0
# epoch=4816	loss_val=8.232091e-05	lam=8.0
# epoch=4817	loss_val=8.2320934e-05	lam=8.0
# epoch=4818	loss_val=8.2320934e-05	lam=8.0
# epoch=4819	loss_val=8.2320985e-05	lam=8.0
# epoch=4820	loss_val=8.2321e-05	lam=8.0
# epoch=4821	loss_val=8.2320956e-05	lam=8.0
# epoch=4822	loss_val=8.232099e-05	lam=8.0
# epoch=4823	loss_val=8.232096e-05	lam=8.0
# epoch=4824	loss_val=8.232093e-05	lam=8.0
# epoch=4825	loss_val=8.2321e-05	lam=8.0
# epoch=4826	loss_val=8.2321e-05	lam=8.0
# epoch=4827	loss_val=8.232097e-05	lam=8.0
# epoch=4828	loss_val=8.232102e-05	lam=8.0
# epoch=4829	loss_val=8.2320985e-05	lam=8.0
# epoch=4830	loss_val=8.232098e-05	lam=8.0
# epoch=4831	loss_val=8.232091e-05	lam=8.0
# epoch=4832	loss_val=8.232096e-05	lam=8.0
# epoch=4833	loss_val=8.232097e-05	lam=8.0
# epoch=4834	loss_val=8.2320985e-05	lam=8.0
# epoch=4835	loss_val=8.232099e-05	lam=8.0
# epoch=4836	loss_val=8.2321e-05	lam=8.0
# epoch=4837	loss_val=8.2320956e-05	lam=8.0
# epoch=4838	loss_val=8.2321014e-05	lam=8.0
# epoch=4839	loss_val=8.2320985e-05	lam=8.0
# epoch=4840	loss_val=8.232098e-05	lam=8.0
# epoch=4841	loss_val=8.232098e-05	lam=8.0
# epoch=4842	loss_val=8.232096e-05	lam=8.0
# epoch=4843	loss_val=8.2321036e-05	lam=8.0
# epoch=4844	loss_val=8.2320934e-05	lam=8.0
# epoch=4845	loss_val=8.232096e-05	lam=8.0
# epoch=4846	loss_val=8.232093e-05	lam=8.0
# epoch=4847	loss_val=8.2320985e-05	lam=8.0
# epoch=4848	loss_val=8.2320985e-05	lam=8.0
# epoch=4849	loss_val=8.232101e-05	lam=8.0
# epoch=4850	loss_val=8.232094e-05	lam=8.0
# epoch=4851	loss_val=8.232094e-05	lam=8.0
# epoch=4852	loss_val=8.232099e-05	lam=8.0
# epoch=4853	loss_val=8.2320985e-05	lam=8.0
# epoch=4854	loss_val=8.232099e-05	lam=8.0
# epoch=4855	loss_val=8.232098e-05	lam=8.0
# epoch=4856	loss_val=8.2320934e-05	lam=8.0
# epoch=4857	loss_val=8.232094e-05	lam=8.0
# epoch=4858	loss_val=8.232091e-05	lam=8.0
# epoch=4859	loss_val=8.232095e-05	lam=8.0
# epoch=4860	loss_val=8.2320985e-05	lam=8.0
# epoch=4861	loss_val=8.232092e-05	lam=8.0
# epoch=4862	loss_val=8.232098e-05	lam=8.0
# epoch=4863	loss_val=8.232099e-05	lam=8.0
# epoch=4864	loss_val=8.232102e-05	lam=8.0
# epoch=4865	loss_val=8.232104e-05	lam=8.0
# epoch=4866	loss_val=8.232092e-05	lam=8.0
# epoch=4867	loss_val=8.232098e-05	lam=8.0
# epoch=4868	loss_val=8.2320956e-05	lam=8.0
# epoch=4869	loss_val=8.232099e-05	lam=8.0
# epoch=4870	loss_val=8.232096e-05	lam=8.0
# epoch=4871	loss_val=8.2320985e-05	lam=8.0
# epoch=4872	loss_val=8.2321036e-05	lam=8.0
# epoch=4873	loss_val=8.232099e-05	lam=8.0
# epoch=4874	loss_val=8.232101e-05	lam=8.0
# epoch=4875	loss_val=8.232103e-05	lam=8.0
# epoch=4876	loss_val=8.232101e-05	lam=8.0
# epoch=4877	loss_val=8.232095e-05	lam=8.0
# epoch=4878	loss_val=8.2321e-05	lam=8.0
# epoch=4879	loss_val=8.232095e-05	lam=8.0
# epoch=4880	loss_val=8.2320985e-05	lam=8.0
# epoch=4881	loss_val=8.232097e-05	lam=8.0
# epoch=4882	loss_val=8.2321014e-05	lam=8.0
# epoch=4883	loss_val=8.232091e-05	lam=8.0
# epoch=4884	loss_val=8.232096e-05	lam=8.0
# epoch=4885	loss_val=8.232097e-05	lam=8.0
# epoch=4886	loss_val=8.232094e-05	lam=8.0
# epoch=4887	loss_val=8.232096e-05	lam=8.0
# epoch=4888	loss_val=8.232097e-05	lam=8.0
# epoch=4889	loss_val=8.232095e-05	lam=8.0
# epoch=4890	loss_val=8.232095e-05	lam=8.0
# epoch=4891	loss_val=8.232102e-05	lam=8.0
# epoch=4892	loss_val=8.232095e-05	lam=8.0
# epoch=4893	loss_val=8.232099e-05	lam=8.0
# epoch=4894	loss_val=8.232099e-05	lam=8.0
# epoch=4895	loss_val=8.232099e-05	lam=8.0
# epoch=4896	loss_val=8.2321036e-05	lam=8.0
# epoch=4897	loss_val=8.232094e-05	lam=8.0
# epoch=4898	loss_val=8.232097e-05	lam=8.0
# epoch=4899	loss_val=8.232106e-05	lam=8.0
# epoch=4900	loss_val=8.2321e-05	lam=8.0
# epoch=4901	loss_val=8.232097e-05	lam=8.0
# epoch=4902	loss_val=8.232091e-05	lam=8.0
# epoch=4903	loss_val=8.2320956e-05	lam=8.0
# epoch=4904	loss_val=8.232097e-05	lam=8.0
# epoch=4905	loss_val=8.232098e-05	lam=8.0
# epoch=4906	loss_val=8.232099e-05	lam=8.0
# epoch=4907	loss_val=8.2320905e-05	lam=8.0
# epoch=4908	loss_val=8.2321014e-05	lam=8.0
# epoch=4909	loss_val=8.232094e-05	lam=8.0
# epoch=4910	loss_val=8.2320934e-05	lam=8.0
# epoch=4911	loss_val=8.2320956e-05	lam=8.0
# epoch=4912	loss_val=8.232091e-05	lam=8.0
# epoch=4913	loss_val=8.232094e-05	lam=8.0
# epoch=4914	loss_val=8.2320905e-05	lam=8.0
# epoch=4915	loss_val=8.232096e-05	lam=8.0
# epoch=4916	loss_val=8.2320876e-05	lam=8.0
# epoch=4917	loss_val=8.23209e-05	lam=8.0
# epoch=4918	loss_val=8.232086e-05	lam=8.0
# epoch=4919	loss_val=8.232096e-05	lam=8.0
# epoch=4920	loss_val=8.232087e-05	lam=8.0
# epoch=4921	loss_val=8.232088e-05	lam=8.0
# epoch=4922	loss_val=8.2320956e-05	lam=8.0
# epoch=4923	loss_val=8.232093e-05	lam=8.0
# epoch=4924	loss_val=8.2321e-05	lam=8.0
# epoch=4925	loss_val=8.232096e-05	lam=8.0
# epoch=4926	loss_val=8.232096e-05	lam=8.0
# epoch=4927	loss_val=8.2321e-05	lam=8.0
# epoch=4928	loss_val=8.2320956e-05	lam=8.0
# epoch=4929	loss_val=8.2321036e-05	lam=8.0
# epoch=4930	loss_val=8.2320905e-05	lam=8.0
# epoch=4931	loss_val=8.23209e-05	lam=8.0
# epoch=4932	loss_val=8.232091e-05	lam=8.0
# epoch=4933	loss_val=8.232092e-05	lam=8.0
# epoch=4934	loss_val=8.232098e-05	lam=8.0
# epoch=4935	loss_val=8.232099e-05	lam=8.0
# epoch=4936	loss_val=8.232094e-05	lam=8.0
# epoch=4937	loss_val=8.2320985e-05	lam=8.0
# epoch=4938	loss_val=8.2321e-05	lam=8.0
# epoch=4939	loss_val=8.232092e-05	lam=8.0
# epoch=4940	loss_val=8.232095e-05	lam=8.0
# epoch=4941	loss_val=8.232093e-05	lam=8.0
# epoch=4942	loss_val=8.232096e-05	lam=8.0
# epoch=4943	loss_val=8.232084e-05	lam=8.0
# epoch=4944	loss_val=8.232099e-05	lam=8.0
# epoch=4945	loss_val=8.232089e-05	lam=8.0
# epoch=4946	loss_val=8.232101e-05	lam=8.0
# epoch=4947	loss_val=8.232093e-05	lam=8.0
# epoch=4948	loss_val=8.232096e-05	lam=8.0
# epoch=4949	loss_val=8.232094e-05	lam=8.0
# epoch=4950	loss_val=8.232102e-05	lam=8.0
# epoch=4951	loss_val=8.232096e-05	lam=8.0
# epoch=4952	loss_val=8.232095e-05	lam=8.0
# epoch=4953	loss_val=8.232097e-05	lam=8.0
# epoch=4954	loss_val=8.2321014e-05	lam=8.0
# epoch=4955	loss_val=8.232095e-05	lam=8.0
# epoch=4956	loss_val=8.232099e-05	lam=8.0
# epoch=4957	loss_val=8.2320956e-05	lam=8.0
# epoch=4958	loss_val=8.232095e-05	lam=8.0
# epoch=4959	loss_val=8.2320905e-05	lam=8.0
# epoch=4960	loss_val=8.232095e-05	lam=8.0
# epoch=4961	loss_val=8.232095e-05	lam=8.0
# epoch=4962	loss_val=8.2320934e-05	lam=8.0
# epoch=4963	loss_val=8.232088e-05	lam=8.0
# epoch=4964	loss_val=8.2320956e-05	lam=8.0
# epoch=4965	loss_val=8.2320956e-05	lam=8.0
# epoch=4966	loss_val=8.232095e-05	lam=8.0
# epoch=4967	loss_val=8.232091e-05	lam=8.0
# epoch=4968	loss_val=8.232096e-05	lam=8.0
# epoch=4969	loss_val=8.232089e-05	lam=8.0
# epoch=4970	loss_val=8.2320956e-05	lam=8.0
# epoch=4971	loss_val=8.232091e-05	lam=8.0
# epoch=4972	loss_val=8.2320985e-05	lam=8.0
# epoch=4973	loss_val=8.2320876e-05	lam=8.0
# epoch=4974	loss_val=8.2320956e-05	lam=8.0
# epoch=4975	loss_val=8.232095e-05	lam=8.0
# epoch=4976	loss_val=8.232097e-05	lam=8.0
# epoch=4977	loss_val=8.2320876e-05	lam=8.0
# epoch=4978	loss_val=8.2321e-05	lam=8.0
# epoch=4979	loss_val=8.232096e-05	lam=8.0
# epoch=4980	loss_val=8.2320985e-05	lam=8.0
# epoch=4981	loss_val=8.2320876e-05	lam=8.0
# epoch=4982	loss_val=8.232097e-05	lam=8.0
# epoch=4983	loss_val=8.232095e-05	lam=8.0
# epoch=4984	loss_val=8.232098e-05	lam=8.0
# epoch=4985	loss_val=8.232089e-05	lam=8.0
# epoch=4986	loss_val=8.232098e-05	lam=8.0
# epoch=4987	loss_val=8.2320934e-05	lam=8.0
# epoch=4988	loss_val=8.232091e-05	lam=8.0
# epoch=4989	loss_val=8.23209e-05	lam=8.0
# epoch=4990	loss_val=8.2320985e-05	lam=8.0
# epoch=4991	loss_val=8.232092e-05	lam=8.0
# epoch=4992	loss_val=8.232097e-05	lam=8.0
# epoch=4993	loss_val=8.2320905e-05	lam=8.0
# epoch=4994	loss_val=8.232094e-05	lam=8.0
# epoch=4995	loss_val=8.232088e-05	lam=8.0
# epoch=4996	loss_val=8.2320934e-05	lam=8.0
# epoch=4997	loss_val=8.232089e-05	lam=8.0
# epoch=4998	loss_val=8.2320985e-05	lam=8.0
# epoch=4999	loss_val=8.2320934e-05	lam=8.0

# %%
# predict the values at a grid of points (a mesh) so we can view predicted contour of the solution
# using the mean interpolated from trained values
import numpy as np

n = 20
ngrid = n * n
_xgrid = np.linspace(0.0, a, n)
_ygrid = np.linspace(0.0, b, n)
X, Y = np.meshgrid(_xgrid, _ygrid)
xgrid = np.reshape(X, newshape=(ngrid,1))
ygrid = np.reshape(Y, newshape=(ngrid,1))
x_grid = np.concatenate([xgrid, ygrid], axis=1)

# old non-vectorized way
# K_train = np.array([[kernel2d(x_all[i,:], x_all[j,:]) for j in range(num_all)] for i in range(num_all)])
# K_cross = np.array([[kernel2d(x_grid[i,:], x_all[j,:]) for j in range(num_all)] for i in range(ngrid)])

# vectorized way like 100x faster
K_train = kernel2d_tf(x_all_L, x_all_R)
x_grid_L = tf.expand_dims(tf.constant(x_grid, dtype=DTYPE), axis=1)
K_cross = kernel2d_tf(x_grid_L, x_all_R)

max_eigval = np.max(np.linalg.eigvalsh(K_train))
W_grid = K_cross @ np.linalg.solve(K_train + 1e-5 * max_eigval * np.eye(num_all), w_full[:num_all,:])
W = np.reshape(W_grid, newshape=(n, n))

# %%
import matplotlib.pyplot as plt
# now plot the predicted solution contour
plt.figure(figsize=(8, 6))
colors = plt.contourf(X, Y, W, levels=20, cmap='viridis', alpha=0.75)  # Filled contours
plt.gca().set_aspect('equal')
plt.colorbar(colors, label="w(x,y)")  # Colorbar for reference

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
# now plot the predicted solution surface in 3d
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, W, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=1)
ax.set_aspect('equalxy')
plt.show()
