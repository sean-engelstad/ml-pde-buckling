# %% [markdown]
# # Linear Buckling Analysis with ML GP PDE solver

# %%
# panel linear static inputs
# buckling inputs
# ----------------

# aluminum plate material properties
E = 70e9; nu = 0.3; thick = 0.005
D = E * thick**3 / 12.0 / (1 - nu**2)
(a, b) = (3, 1)

axial = True
if axial:
    Nxx, Nxy, Nyy = (1e3, 0, 0)
else:
    Nxx, Nxy, Nyy = (0, 1e2, 0)

# choose kernel hyperparameters
Lx = 0.4; Ly = 0.4
# took out smaller lower length scale bc cause regularization to fail for now

# predict the buckling load factor (BLF)
pi = 3.14159
if axial:
    pred_buckling_load = pi**2 * D / b**2 * 4.0 
    pred_load_factor = pred_buckling_load / Nxx
    sigma = 0.5 * pred_load_factor
    print(f"{pred_load_factor=}")
# Out:
# pred_load_factor=31.633294000320518

# %%
# compute the linear static analysis inputs and mesh domain of collocation pts
# ----------------------------------------------------------------------------
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# case = 'low'
# case = 'medium'
case = 'high'

if case == 'high':
    num_domain = 300
    num_bndry = 100
    num_test = 50
elif case == 'medium':
    num_domain = 40
    num_bndry = 10
    num_test = 50
elif case == 'low':
    num_domain = 10
    num_bndry = 5
    num_test = 5

num_interior = num_domain
DTYPE = tf.float32

# set the boundary of the panel
xmin = 0; xmax = a
ymin = 0; ymax = b

lb = tf.constant([xmin, ymin], dtype=DTYPE)
ub = tf.constant([xmax, ymax], dtype=DTYPE)

# generate the collocation points on the interior
def gen_collocation_points(num_domain, minval, maxval):
    x_r = tf.random.uniform((num_domain,1), minval[0], maxval[0], dtype=DTYPE)
    y_r = tf.random.uniform((num_domain,1), minval[1], maxval[1], dtype=DTYPE)
    X_r = tf.concat([x_r, y_r], axis=1)
    # data_init = tf.random_uniform_initializer(minval=minval, maxval=maxval, seed=0)
    # return tf.Variable(data_init(shape=[num_domain, 1]), dtype=tf.float32)
    return tf.Variable(X_r, dtype=DTYPE)

x_train = gen_collocation_points(num_domain, lb, ub)
x_test = gen_collocation_points(num_test, lb, ub)
print(f"{type(x_train)=}")

x = x_train[:,0:1]
y = x_train[:,1:2]

x2 = x_test[:,0:1]
y2 = x_test[:,1:2]

# generate boundary domain points
assert num_bndry % 2 == 0
N_b = int(num_bndry / 2)
x_b1 = tf.random.uniform((N_b,1), lb[0], ub[0], dtype=DTYPE)
y_b1 = lb[1] + (ub[1] - lb[1]) * \
    tf.keras.backend.random_bernoulli((N_b,1), 0.5, dtype=DTYPE)
X_b1 = tf.concat([x_b1, y_b1], axis=1)

# boundary data on x edges
y_b2 = tf.random.uniform((N_b,1), lb[1], ub[1], dtype=DTYPE)
x_b2 = lb[0] + (ub[0] - lb[0]) * \
    tf.keras.backend.random_bernoulli((N_b,1), 0.5, dtype=DTYPE)
# print(f"{x_b2=}")
X_b2 = tf.concat([x_b2, y_b2], axis=1)
# print(f"{X_b2=}")
# print(f"{x_b2=}")

x_bndry = tf.Variable(tf.concat([X_b1, X_b2], axis=0), dtype=DTYPE)

# plot the data to check
plt.scatter(x_bndry[:,0], x_bndry[:,1])
plt.scatter(x_train[:,0], x_train[:,1]) # only show 1000 of the points
plt.show()
# Out:
# type(x_train)=<class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>

# %%
# define vectorized versions of the kernel functions
# like 1000x faster at assembling covariance functions

L_tf = tf.constant(np.array([Lx, Ly]), dtype=DTYPE)
def kernel2d_tf(x, xp):
    # x input is N x 1 x 2 array, xp is 1 x M x 2 array
    # xbar is then an N x M x 2 shape array
    # print(f"{x=} {L_tf=}")
    xbar = (x - xp) / L_tf
    # output is N x M matrix of kernel matrix
    return tf.exp(-0.5 * tf.reduce_sum(tf.pow(xbar, 2.0), axis=-1))

def d_fact(xbar, L):
    return L**(-1.0) * (-xbar)

def d2_fact(xbar, L):
    return L**(-2.0) * (-1.0 + xbar**2)

def d4_fact(xbar,L):
    return L**(-4.0) * (3.0 - 6.0 * xbar**2 + xbar**4)

def d6_fact(xbar,L):
    return L**(-6.0) * (-15 + 45 * xbar**2 - 15 * xbar**4 + xbar**6)

def d8_fact(xbar,L):
    return L**(-8.0) * (105 - 420 * xbar**2 + 210 * xbar**4 - 28 * xbar**6 + xbar**8)

def dx2_kernel_tf(x, xp):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / L_tf # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L_tf[0]; Ly = L_tf[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    # TODO : shear or general case later (just axial now)
    return K * (d2_fact(x1bar, Lx))

def doubledx2_kernel_tf(x, xp):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / L_tf # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L_tf[0]; Ly = L_tf[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    # TODO : shear or general case later (just axial now)
    return K * (d4_fact(x1bar, Lx))

def kernel2d_bilapl_tf(x, xp):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / L_tf # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L_tf[0]; Ly = L_tf[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    return K * (d4_fact(x1bar,Lx) + 2.0 * d2_fact(x1bar, Lx) * d2_fact(x2bar, Ly) + d4_fact(x2bar, Ly))

def kernel2d_double_bilapl_tf(x, xp):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / L_tf # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L_tf[0]; Ly = L_tf[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    return K * (d8_fact(x1bar,Lx) + \
                4.0 * d6_fact(x1bar, Lx) * d2_fact(x2bar, Ly) +\
                6.0 * d4_fact(x1bar, Lx) * d4_fact(x2bar, Ly) +\
                4.0 * d2_fact(x1bar, Lx) * d6_fact(x2bar, Ly) +\
                d8_fact(x2bar, Ly))

def dx2_bilapl_kernel_tf(x, xp):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / L_tf # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L_tf[0]; Ly = L_tf[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    # TODO : shear or general case later (just axial now)
    return K * \
        (d6_fact(x1bar,Lx) + 2.0 * d4_fact(x1bar, Lx) * d2_fact(x2bar, Ly) + d2_fact(x1bar, Lx) * d4_fact(x2bar, Ly))

# %%
# compute the block matrix Sigma = [cov(w_int, w_int), cov(w_int, w_bndry), cov(w_int, nabla^4 w_int),
#                                   cov(w_bndry, w_int), cov(w_bndry, w_bndry), cov(w_bndry, nabla^4 w_bndry),
#                                   cov(nabla^4 w_int, w_int), cov(nabla^4 w_int, w_bndry), cov(nabla^4 w_int, nabla^4 w_int) ]
# not a function of theta..
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

n_block = 3 * num_interior + num_bndry
x_all = tf.concat([x_train, x_bndry], axis=0)
num_all = num_interior + num_bndry

# 11 - interior+bndry self-covariance
x_all_L = tf.expand_dims(x_all, axis=1)
x_all_R = tf.expand_dims(x_all, axis=0)
K11 = tf.constant(kernel2d_tf(x_all_L, x_all_R), dtype=DTYPE)

x_interior_L = tf.expand_dims(x_train, axis=1)
x_interior_R = tf.expand_dims(x_train, axis=0)

# 12 - w with Gw
K12 = tf.constant(dx2_kernel_tf(x_all_L, x_interior_R))
# 13 - w with nabla^4 w
K13 = tf.constant(kernel2d_bilapl_tf(x_all_L, x_interior_R))
# 22 - Gw with Gw
K22 = tf.constant(doubledx2_kernel_tf(x_interior_L, x_interior_R))
# 23 - Gw with nabla^4 w
K23 = tf.constant(dx2_bilapl_kernel_tf(x_interior_L, x_interior_R))
# 33 - nabla^4 w with nabla^4 w
K33 = tf.constant(kernel2d_double_bilapl_tf(x_interior_L, x_interior_R))

print(f"{num_interior=} {num_all=}")
# print(f"{K11.shape=} {K12.shape=} {K22.shape=}")
# print(f"{K13.shape=} {K23.shape=} {K33.shape=}")

# assemble full covariance matrix
_row1 = tf.constant(tf.concat([K11, K12, K13], axis=1))
_row2 = tf.constant(tf.concat([tf.transpose(K12), K22, K23], axis=1))
_row3 = tf.constant(tf.concat([tf.transpose(K13), tf.transpose(K23), K33], axis=1))
Kblock_prereg = tf.concat([_row1, _row2, _row3], axis=0)

print(f"done with full matrix assembly..")

# apply robust regularization w.r.t. the max eigenvalue, namely we add epsilon * I term to matrix
# where epsilon = alpha * lambda_max
alpha = 1e-5
eigvals = np.linalg.eigvalsh(Kblock_prereg)
min_eigval = np.min(eigvals)
max_eigval = np.max(eigvals)
print(f"{min_eigval=} {max_eigval=}")
eps = alpha * max_eigval

print("done with eigenvalues solve")

Kblock = tf.constant(Kblock_prereg + eps * tf.eye(n_block), dtype=DTYPE)

# double check eigvals again
print("double check eivals again--")
eigvals = np.linalg.eigvalsh(Kblock)
min_eigval = np.min(eigvals)
max_eigval = np.max(eigvals)
print(f"{min_eigval=} {max_eigval=}")

# show the matrix image to see if positive definite roughly
plt.imshow(Kblock)
plt.colorbar()
# Out:
# num_interior=300 num_all=400
# done with full matrix assembly..
# min_eigval=-0.52542436 max_eigval=12081101.0
# done with eigenvalues solve
# double check eivals again--
# min_eigval=120.28707 max_eigval=12081222.0

# %%
# define GP vectors and factor cov matrix into LU
# -----------------------------------------------

# setup lambda as trainable parameter too
# lam = tf.Variable(pred_load_factor, trainable=True, dtype=DTYPE)

K_lu = tf.linalg.lu(Kblock)

w_ext = tf.zeros(shape=(num_bndry,1), dtype=DTYPE)
# now theta includes the w int points and Gw interior points and also lam
# theta_arr = tf.zeros(shape=(num_domain * 2 + 1,1), dtype=DTYPE)
# theta_arr = np.random.rand(2 * num_domain + 1, 1)
# theta_arr = tf.ones(shape=(num_domain * 2 + 1, 1), dtype=DTYPE)

theta_arr = np.zeros(shape=(num_domain*2 + 1,1))
theta_arr[-1,0] = pred_load_factor # set lam init

# pick one of points nearest the middle a/2, b/2
cent_dist = (x_train[:,0] - a/2.0)**2 + (x_train[:,1] - b/2.0)**2
ind = tf.argmin(cent_dist)
theta_arr[ind,0] = 1e-5 # set init value of w somewhere so not 0 norm

# [5,0] = 1.0 # best to choose some middle point as the only nonzero part?
theta = tf.Variable(theta_arr, trainable=True, dtype=DTYPE)

# print(f"{w_ext.shape=}")
# nabla4_w = 
# nabla4_w2 = tf.reshape(nabla4_w, shape=(num_domain,1))
# print(f"{nabla4_w2.shape=}")

# _temp = tf.concat([w_ext, nabla4_w2], axis=0)
# fixed_vec = tf.constant(_temp, dtype=DTYPE)

# %%
num_epochs = 5000 # 5000
learning_rate = 1e-5 # can be much higher here?
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

for epoch in range(num_epochs):
    # record the loss gradient
    with tf.GradientTape(persistent=True) as tape:
        # construct full GP f vector
        w_int = theta[:num_interior]
        Gw = theta[num_interior:-1]
        lam = theta[-1]
        # lam = pred_load_factor # try constant for a minute
        # lam = 8.0
        nabla4_w = -lam / D * Nxx * Gw
        w_full = tf.concat([w_int, w_ext, Gw, nabla4_w], axis=0)

        # normalize w_full by w_norm to prevent trivial soln in buckling analysis
        w_norm = tf.linalg.norm(w_int)
        w_full_hat = w_full / w_norm

        # print(f"{w_full=}")
        ans = tf.linalg.lu_solve(*K_lu, rhs=w_full_hat)
        # print(f"{ans=}")

        loss = tf.tensordot(tf.transpose(w_full_hat), ans, axes=1)
        loss *= 1e3

        # add norm regularization term to prevent trivial soln (since buckling trivial w = 0 soln is technically a soln, but not one we care about)
        # this didn't work very well => just focuses on this term not PDE solving
        # loss += (w_norm - 1)**2 # * 1e4
        # # loss *= 1e3 # *= D

    loss_gradient = tape.gradient(loss, theta)
    # print(f"{loss_gradient=}")

    # could change to Gauss-newton algorithm here instead.. would prob be better

    # gradient descent with adam optimizer
    optimizer.apply_gradients(
        [(loss_gradient, theta)]
    )
    del tape

    loss_val = loss.numpy()[0,0]
    eigval = lam.numpy()[0]
    print(f"{epoch=}\t{loss_val=}\t{eigval=}")

# print(f"{theta=}")
# Out:
# epoch=0	loss_val=8.264277	eigval=31.633293
# epoch=1	loss_val=7015.1426	eigval=31.633293
# epoch=2	loss_val=470.36072	eigval=31.633286
# epoch=3	loss_val=406.3673	eigval=31.63328
# epoch=4	loss_val=757.8258	eigval=31.633274
# epoch=5	loss_val=975.9656	eigval=31.633268
# epoch=6	loss_val=1047.5857	eigval=31.633263
# epoch=7	loss_val=1023.55493	eigval=31.633257
# epoch=8	loss_val=947.53235	eigval=31.633251
# epoch=9	loss_val=848.0386	eigval=31.633245
# epoch=10	loss_val=741.8951	eigval=31.63324
# epoch=11	loss_val=638.4147	eigval=31.633234
# epoch=12	loss_val=542.412	eigval=31.633228
# epoch=13	loss_val=456.0838	eigval=31.633223
# epoch=14	loss_val=380.09604	eigval=31.633219
# epoch=15	loss_val=314.28806	eigval=31.633215
# epoch=16	loss_val=258.04175	eigval=31.633211
# epoch=17	loss_val=210.50296	eigval=31.633207
# epoch=18	loss_val=170.73917	eigval=31.633204
# epoch=19	loss_val=137.80913	eigval=31.6332
# epoch=20	loss_val=110.80619	eigval=31.633196
# epoch=21	loss_val=88.892265	eigval=31.633192
# epoch=22	loss_val=71.30296	eigval=31.63319
# epoch=23	loss_val=57.359142	eigval=31.633188
# epoch=24	loss_val=46.45798	eigval=31.633186
# epoch=25	loss_val=38.075027	eigval=31.633184
# epoch=26	loss_val=31.756933	eigval=31.633183
# epoch=27	loss_val=27.11209	eigval=31.63318
# epoch=28	loss_val=23.806913	eigval=31.633179
# epoch=29	loss_val=21.555862	eigval=31.633177
# epoch=30	loss_val=20.118195	eigval=31.633175
# epoch=31	loss_val=19.289246	eigval=31.633173
# epoch=32	loss_val=18.897984	eigval=31.633171
# epoch=33	loss_val=18.801138	eigval=31.63317
# epoch=34	loss_val=18.881798	eigval=31.633167
# epoch=35	loss_val=19.045055	eigval=31.633165
# epoch=36	loss_val=19.216085	eigval=31.633165
# epoch=37	loss_val=19.340714	eigval=31.633165
# epoch=38	loss_val=19.37818	eigval=31.633165
# epoch=39	loss_val=19.305843	eigval=31.633165
# epoch=40	loss_val=19.11067	eigval=31.633165
# epoch=41	loss_val=18.79124	eigval=31.633165
# epoch=42	loss_val=18.355125	eigval=31.633165
# epoch=43	loss_val=17.81413	eigval=31.633165
# epoch=44	loss_val=17.185757	eigval=31.633165
# epoch=45	loss_val=16.488583	eigval=31.633165
# epoch=46	loss_val=15.743032	eigval=31.633165
# epoch=47	loss_val=14.967051	eigval=31.633165
# epoch=48	loss_val=14.179588	eigval=31.633165
# epoch=49	loss_val=13.396162	eigval=31.633165
# epoch=50	loss_val=12.630182	eigval=31.633165
# epoch=51	loss_val=11.892967	eigval=31.633165
# epoch=52	loss_val=11.193459	eigval=31.633165
# epoch=53	loss_val=10.53809	eigval=31.633165
# epoch=54	loss_val=9.931962	eigval=31.633165
# epoch=55	loss_val=9.3779955	eigval=31.633165
# epoch=56	loss_val=8.878053	eigval=31.633165
# epoch=57	loss_val=8.432146	eigval=31.633165
# epoch=58	loss_val=8.040128	eigval=31.633165
# epoch=59	loss_val=7.6998086	eigval=31.633165
# epoch=60	loss_val=7.40889	eigval=31.633165
# epoch=61	loss_val=7.1641498	eigval=31.633165
# epoch=62	loss_val=6.9618325	eigval=31.633165
# epoch=63	loss_val=6.7976594	eigval=31.633165
# epoch=64	loss_val=6.6674447	eigval=31.633165
# epoch=65	loss_val=6.5667634	eigval=31.633165
# epoch=66	loss_val=6.4910707	eigval=31.633165
# epoch=67	loss_val=6.4358964	eigval=31.633165
# epoch=68	loss_val=6.397277	eigval=31.633165
# epoch=69	loss_val=6.371537	eigval=31.633165
# epoch=70	loss_val=6.35504	eigval=31.633165
# epoch=71	loss_val=6.345188	eigval=31.633165
# epoch=72	loss_val=6.339227	eigval=31.633165
# epoch=73	loss_val=6.3351703	eigval=31.633165
# epoch=74	loss_val=6.331561	eigval=31.633165
# epoch=75	loss_val=6.326936	eigval=31.633165
# epoch=76	loss_val=6.320665	eigval=31.633165
# epoch=77	loss_val=6.3118663	eigval=31.633165
# epoch=78	loss_val=6.3007345	eigval=31.633165
# epoch=79	loss_val=6.2869205	eigval=31.633165
# epoch=80	loss_val=6.2707043	eigval=31.633165
# epoch=81	loss_val=6.252526	eigval=31.633165
# epoch=82	loss_val=6.2327137	eigval=31.633165
# epoch=83	loss_val=6.211819	eigval=31.633165
# epoch=84	loss_val=6.1904016	eigval=31.633165
# epoch=85	loss_val=6.1689267	eigval=31.633165
# epoch=86	loss_val=6.1478615	eigval=31.633165
# epoch=87	loss_val=6.127725	eigval=31.633165
# epoch=88	loss_val=6.108775	eigval=31.633165
# epoch=89	loss_val=6.091381	eigval=31.633165
# epoch=90	loss_val=6.075723	eigval=31.633165
# epoch=91	loss_val=6.0618286	eigval=31.633165
# epoch=92	loss_val=6.04978	eigval=31.633165
# epoch=93	loss_val=6.039501	eigval=31.633165
# epoch=94	loss_val=6.030858	eigval=31.633165
# epoch=95	loss_val=6.0237617	eigval=31.633165
# epoch=96	loss_val=6.017999	eigval=31.633165
# epoch=97	loss_val=6.0134296	eigval=31.633165
# epoch=98	loss_val=6.0098186	eigval=31.633165
# epoch=99	loss_val=6.0070653	eigval=31.633165
# epoch=100	loss_val=6.0049486	eigval=31.633165
# epoch=101	loss_val=6.003369	eigval=31.633165
# epoch=102	loss_val=6.002175	eigval=31.633165
# epoch=103	loss_val=6.0012865	eigval=31.633165
# epoch=104	loss_val=6.0005727	eigval=31.633165
# epoch=105	loss_val=5.9999614	eigval=31.633165
# epoch=106	loss_val=5.9993715	eigval=31.633165
# epoch=107	loss_val=5.998736	eigval=31.633165
# epoch=108	loss_val=5.998038	eigval=31.633165
# epoch=109	loss_val=5.9972363	eigval=31.633165
# epoch=110	loss_val=5.996312	eigval=31.633165
# epoch=111	loss_val=5.995263	eigval=31.633165
# epoch=112	loss_val=5.994141	eigval=31.633165
# epoch=113	loss_val=5.9929547	eigval=31.633165
# epoch=114	loss_val=5.9917207	eigval=31.633165
# epoch=115	loss_val=5.9904985	eigval=31.633165
# epoch=116	loss_val=5.9892807	eigval=31.633165
# epoch=117	loss_val=5.988109	eigval=31.633165
# epoch=118	loss_val=5.986998	eigval=31.633165
# epoch=119	loss_val=5.9859486	eigval=31.633165
# epoch=120	loss_val=5.984993	eigval=31.633165
# epoch=121	loss_val=5.984118	eigval=31.633165
# epoch=122	loss_val=5.983332	eigval=31.633165
# epoch=123	loss_val=5.9826403	eigval=31.633165
# epoch=124	loss_val=5.982019	eigval=31.633165
# epoch=125	loss_val=5.9814696	eigval=31.633165
# epoch=126	loss_val=5.980988	eigval=31.633165
# epoch=127	loss_val=5.9805737	eigval=31.633165
# epoch=128	loss_val=5.980186	eigval=31.633165
# epoch=129	loss_val=5.9798503	eigval=31.633165
# epoch=130	loss_val=5.979545	eigval=31.633165
# epoch=131	loss_val=5.9792576	eigval=31.633165
# epoch=132	loss_val=5.978978	eigval=31.633165
# epoch=133	loss_val=5.9787016	eigval=31.633165
# epoch=134	loss_val=5.9784236	eigval=31.633165
# epoch=135	loss_val=5.978143	eigval=31.633165
# epoch=136	loss_val=5.977862	eigval=31.633165
# epoch=137	loss_val=5.9775786	eigval=31.633165
# epoch=138	loss_val=5.977289	eigval=31.633165
# epoch=139	loss_val=5.9769917	eigval=31.633165
# epoch=140	loss_val=5.976697	eigval=31.633165
# epoch=141	loss_val=5.9763837	eigval=31.633165
# epoch=142	loss_val=5.976091	eigval=31.633165
# epoch=143	loss_val=5.975788	eigval=31.633165
# epoch=144	loss_val=5.975484	eigval=31.633165
# epoch=145	loss_val=5.9751964	eigval=31.633165
# epoch=146	loss_val=5.9748955	eigval=31.633165
# epoch=147	loss_val=5.9746113	eigval=31.633165
# epoch=148	loss_val=5.9743237	eigval=31.633165
# epoch=149	loss_val=5.97405	eigval=31.633165
# epoch=150	loss_val=5.9737806	eigval=31.633165
# epoch=151	loss_val=5.973507	eigval=31.633165
# epoch=152	loss_val=5.973246	eigval=31.633165
# epoch=153	loss_val=5.972986	eigval=31.633165
# epoch=154	loss_val=5.9727273	eigval=31.633165
# epoch=155	loss_val=5.9724803	eigval=31.633165
# epoch=156	loss_val=5.9722266	eigval=31.633165
# epoch=157	loss_val=5.9719715	eigval=31.633165
# epoch=158	loss_val=5.9717326	eigval=31.633165
# epoch=159	loss_val=5.971487	eigval=31.633165
# epoch=160	loss_val=5.971238	eigval=31.633165
# epoch=161	loss_val=5.970988	eigval=31.633165
# epoch=162	loss_val=5.970747	eigval=31.633165
# epoch=163	loss_val=5.9704967	eigval=31.633165
# epoch=164	loss_val=5.9702587	eigval=31.633165
# epoch=165	loss_val=5.9700036	eigval=31.633165
# epoch=166	loss_val=5.969761	eigval=31.633165
# epoch=167	loss_val=5.969517	eigval=31.633165
# epoch=168	loss_val=5.969266	eigval=31.633165
# epoch=169	loss_val=5.9690228	eigval=31.633165
# epoch=170	loss_val=5.9687734	eigval=31.633165
# epoch=171	loss_val=5.968533	eigval=31.633165
# epoch=172	loss_val=5.968288	eigval=31.633165
# epoch=173	loss_val=5.968046	eigval=31.633165
# epoch=174	loss_val=5.967795	eigval=31.633165
# epoch=175	loss_val=5.967561	eigval=31.633165
# epoch=176	loss_val=5.9673114	eigval=31.633165
# epoch=177	loss_val=5.9670706	eigval=31.633165
# epoch=178	loss_val=5.9668317	eigval=31.633165
# epoch=179	loss_val=5.9665813	eigval=31.633165
# epoch=180	loss_val=5.9663463	eigval=31.633165
# epoch=181	loss_val=5.9661064	eigval=31.633165
# epoch=182	loss_val=5.9658675	eigval=31.633165
# epoch=183	loss_val=5.9656196	eigval=31.633165
# epoch=184	loss_val=5.9653816	eigval=31.633165
# epoch=185	loss_val=5.9651437	eigval=31.633165
# epoch=186	loss_val=5.9648976	eigval=31.633165
# epoch=187	loss_val=5.9646664	eigval=31.633165
# epoch=188	loss_val=5.96442	eigval=31.633165
# epoch=189	loss_val=5.964181	eigval=31.633165
# epoch=190	loss_val=5.9639397	eigval=31.633165
# epoch=191	loss_val=5.963698	eigval=31.633165
# epoch=192	loss_val=5.9634647	eigval=31.633165
# epoch=193	loss_val=5.9632154	eigval=31.633165
# epoch=194	loss_val=5.9629793	eigval=31.633165
# epoch=195	loss_val=5.962733	eigval=31.633165
# epoch=196	loss_val=5.962503	eigval=31.633165
# epoch=197	loss_val=5.962264	eigval=31.633165
# epoch=198	loss_val=5.9620247	eigval=31.633165
# epoch=199	loss_val=5.961777	eigval=31.633165
# epoch=200	loss_val=5.9615383	eigval=31.633165
# epoch=201	loss_val=5.9612947	eigval=31.633165
# epoch=202	loss_val=5.961057	eigval=31.633165
# epoch=203	loss_val=5.960822	eigval=31.633165
# epoch=204	loss_val=5.9605823	eigval=31.633165
# epoch=205	loss_val=5.960342	eigval=31.633165
# epoch=206	loss_val=5.9600997	eigval=31.633165
# epoch=207	loss_val=5.9598575	eigval=31.633165
# epoch=208	loss_val=5.9596224	eigval=31.633165
# epoch=209	loss_val=5.959382	eigval=31.633165
# epoch=210	loss_val=5.95914	eigval=31.633165
# epoch=211	loss_val=5.9589047	eigval=31.633165
# epoch=212	loss_val=5.9586577	eigval=31.633165
# epoch=213	loss_val=5.958419	eigval=31.633165
# epoch=214	loss_val=5.9581814	eigval=31.633165
# epoch=215	loss_val=5.9579434	eigval=31.633165
# epoch=216	loss_val=5.9577036	eigval=31.633165
# epoch=217	loss_val=5.957463	eigval=31.633165
# epoch=218	loss_val=5.9572253	eigval=31.633165
# epoch=219	loss_val=5.956986	eigval=31.633165
# epoch=220	loss_val=5.956747	eigval=31.633165
# epoch=221	loss_val=5.956499	eigval=31.633165
# epoch=222	loss_val=5.9562626	eigval=31.633165
# epoch=223	loss_val=5.9560137	eigval=31.633165
# epoch=224	loss_val=5.955782	eigval=31.633165
# epoch=225	loss_val=5.95554	eigval=31.633165
# epoch=226	loss_val=5.955311	eigval=31.633165
# epoch=227	loss_val=5.955066	eigval=31.633165
# epoch=228	loss_val=5.9548283	eigval=31.633165
# epoch=229	loss_val=5.954584	eigval=31.633165
# epoch=230	loss_val=5.9543414	eigval=31.633165
# epoch=231	loss_val=5.9540973	eigval=31.633165
# epoch=232	loss_val=5.953857	eigval=31.633165
# epoch=233	loss_val=5.9536204	eigval=31.633165
# epoch=234	loss_val=5.9533753	eigval=31.633165
# epoch=235	loss_val=5.953138	eigval=31.633165
# epoch=236	loss_val=5.9529047	eigval=31.633165
# epoch=237	loss_val=5.952671	eigval=31.633165
# epoch=238	loss_val=5.952428	eigval=31.633165
# epoch=239	loss_val=5.9521804	eigval=31.633165
# epoch=240	loss_val=5.9519367	eigval=31.633165
# epoch=241	loss_val=5.9517026	eigval=31.633165
# epoch=242	loss_val=5.9514585	eigval=31.633165
# epoch=243	loss_val=5.9512224	eigval=31.633165
# epoch=244	loss_val=5.9509807	eigval=31.633165
# epoch=245	loss_val=5.950734	eigval=31.633165
# epoch=246	loss_val=5.950501	eigval=31.633165
# epoch=247	loss_val=5.9502616	eigval=31.633165
# epoch=248	loss_val=5.950021	eigval=31.633165
# epoch=249	loss_val=5.9497833	eigval=31.633165
# epoch=250	loss_val=5.9495378	eigval=31.633165
# epoch=251	loss_val=5.949303	eigval=31.633165
# epoch=252	loss_val=5.949059	eigval=31.633165
# epoch=253	loss_val=5.9488177	eigval=31.633165
# epoch=254	loss_val=5.9485755	eigval=31.633165
# epoch=255	loss_val=5.9483333	eigval=31.633165
# epoch=256	loss_val=5.948094	eigval=31.633165
# epoch=257	loss_val=5.947857	eigval=31.633165
# epoch=258	loss_val=5.9476223	eigval=31.633165
# epoch=259	loss_val=5.947373	eigval=31.633165
# epoch=260	loss_val=5.9471326	eigval=31.633165
# epoch=261	loss_val=5.946891	eigval=31.633165
# epoch=262	loss_val=5.946654	eigval=31.633165
# epoch=263	loss_val=5.946414	eigval=31.633165
# epoch=264	loss_val=5.9461675	eigval=31.633165
# epoch=265	loss_val=5.945931	eigval=31.633165
# epoch=266	loss_val=5.945682	eigval=31.633165
# epoch=267	loss_val=5.945441	eigval=31.633165
# epoch=268	loss_val=5.945209	eigval=31.633165
# epoch=269	loss_val=5.944962	eigval=31.633165
# epoch=270	loss_val=5.9447255	eigval=31.633165
# epoch=271	loss_val=5.944482	eigval=31.633165
# epoch=272	loss_val=5.9442396	eigval=31.633165
# epoch=273	loss_val=5.944008	eigval=31.633165
# epoch=274	loss_val=5.9437623	eigval=31.633165
# epoch=275	loss_val=5.943524	eigval=31.633165
# epoch=276	loss_val=5.9432783	eigval=31.633165
# epoch=277	loss_val=5.943035	eigval=31.633165
# epoch=278	loss_val=5.9427905	eigval=31.633165
# epoch=279	loss_val=5.942548	eigval=31.633165
# epoch=280	loss_val=5.942304	eigval=31.633165
# epoch=281	loss_val=5.9420676	eigval=31.633165
# epoch=282	loss_val=5.9418263	eigval=31.633165
# epoch=283	loss_val=5.9415874	eigval=31.633165
# epoch=284	loss_val=5.941347	eigval=31.633165
# epoch=285	loss_val=5.941102	eigval=31.633165
# epoch=286	loss_val=5.940865	eigval=31.633165
# epoch=287	loss_val=5.9406233	eigval=31.633165
# epoch=288	loss_val=5.940379	eigval=31.633165
# epoch=289	loss_val=5.940143	eigval=31.633165
# epoch=290	loss_val=5.939895	eigval=31.633165
# epoch=291	loss_val=5.9396553	eigval=31.633165
# epoch=292	loss_val=5.9394116	eigval=31.633165
# epoch=293	loss_val=5.9391656	eigval=31.633165
# epoch=294	loss_val=5.938922	eigval=31.633165
# epoch=295	loss_val=5.9386826	eigval=31.633165
# epoch=296	loss_val=5.938443	eigval=31.633165
# epoch=297	loss_val=5.938202	eigval=31.633165
# epoch=298	loss_val=5.937958	eigval=31.633165
# epoch=299	loss_val=5.9377203	eigval=31.633165
# epoch=300	loss_val=5.937471	eigval=31.633165
# epoch=301	loss_val=5.9372334	eigval=31.633165
# epoch=302	loss_val=5.9369864	eigval=31.633165
# epoch=303	loss_val=5.936752	eigval=31.633165
# epoch=304	loss_val=5.9365096	eigval=31.633165
# epoch=305	loss_val=5.936264	eigval=31.633165
# epoch=306	loss_val=5.9360213	eigval=31.633165
# epoch=307	loss_val=5.9357877	eigval=31.633165
# epoch=308	loss_val=5.935539	eigval=31.633165
# epoch=309	loss_val=5.9352937	eigval=31.633165
# epoch=310	loss_val=5.9350576	eigval=31.633165
# epoch=311	loss_val=5.934812	eigval=31.633165
# epoch=312	loss_val=5.934565	eigval=31.633165
# epoch=313	loss_val=5.934323	eigval=31.633165
# epoch=314	loss_val=5.9340854	eigval=31.633165
# epoch=315	loss_val=5.933839	eigval=31.633165
# epoch=316	loss_val=5.9336076	eigval=31.633165
# epoch=317	loss_val=5.933355	eigval=31.633165
# epoch=318	loss_val=5.93311	eigval=31.633165
# epoch=319	loss_val=5.9328694	eigval=31.633165
# epoch=320	loss_val=5.9326286	eigval=31.633165
# epoch=321	loss_val=5.93239	eigval=31.633165
# epoch=322	loss_val=5.9321427	eigval=31.633165
# epoch=323	loss_val=5.9319024	eigval=31.633165
# epoch=324	loss_val=5.931645	eigval=31.633165
# epoch=325	loss_val=5.9314113	eigval=31.633165
# epoch=326	loss_val=5.9311676	eigval=31.633165
# epoch=327	loss_val=5.930929	eigval=31.633165
# epoch=328	loss_val=5.9306874	eigval=31.633165
# epoch=329	loss_val=5.930455	eigval=31.633165
# epoch=330	loss_val=5.930201	eigval=31.633165
# epoch=331	loss_val=5.929961	eigval=31.633165
# epoch=332	loss_val=5.9297132	eigval=31.633165
# epoch=333	loss_val=5.9294777	eigval=31.633165
# epoch=334	loss_val=5.929222	eigval=31.633165
# epoch=335	loss_val=5.9289823	eigval=31.633165
# epoch=336	loss_val=5.928743	eigval=31.633165
# epoch=337	loss_val=5.9285073	eigval=31.633165
# epoch=338	loss_val=5.9282565	eigval=31.633165
# epoch=339	loss_val=5.928014	eigval=31.633165
# epoch=340	loss_val=5.9277735	eigval=31.633165
# epoch=341	loss_val=5.927522	eigval=31.633165
# epoch=342	loss_val=5.9272857	eigval=31.633165
# epoch=343	loss_val=5.927042	eigval=31.633165
# epoch=344	loss_val=5.926798	eigval=31.633165
# epoch=345	loss_val=5.9265494	eigval=31.633165
# epoch=346	loss_val=5.926312	eigval=31.633165
# epoch=347	loss_val=5.926072	eigval=31.633165
# epoch=348	loss_val=5.925829	eigval=31.633165
# epoch=349	loss_val=5.9255824	eigval=31.633165
# epoch=350	loss_val=5.925342	eigval=31.633165
# epoch=351	loss_val=5.925101	eigval=31.633165
# epoch=352	loss_val=5.9248557	eigval=31.633165
# epoch=353	loss_val=5.924609	eigval=31.633165
# epoch=354	loss_val=5.9243665	eigval=31.633165
# epoch=355	loss_val=5.924121	eigval=31.633165
# epoch=356	loss_val=5.923872	eigval=31.633165
# epoch=357	loss_val=5.923637	eigval=31.633165
# epoch=358	loss_val=5.923395	eigval=31.633165
# epoch=359	loss_val=5.9231524	eigval=31.633165
# epoch=360	loss_val=5.9228997	eigval=31.633165
# epoch=361	loss_val=5.9226584	eigval=31.633165
# epoch=362	loss_val=5.92243	eigval=31.633165
# epoch=363	loss_val=5.9221673	eigval=31.633165
# epoch=364	loss_val=5.9219317	eigval=31.633165
# epoch=365	loss_val=5.92169	eigval=31.633165
# epoch=366	loss_val=5.921446	eigval=31.633165
# epoch=367	loss_val=5.9212003	eigval=31.633165
# epoch=368	loss_val=5.9209533	eigval=31.633165
# epoch=369	loss_val=5.9207153	eigval=31.633165
# epoch=370	loss_val=5.920471	eigval=31.633165
# epoch=371	loss_val=5.9202323	eigval=31.633165
# epoch=372	loss_val=5.9199862	eigval=31.633165
# epoch=373	loss_val=5.919742	eigval=31.633165
# epoch=374	loss_val=5.919496	eigval=31.633165
# epoch=375	loss_val=5.9192557	eigval=31.633165
# epoch=376	loss_val=5.9190083	eigval=31.633165
# epoch=377	loss_val=5.9187675	eigval=31.633165
# epoch=378	loss_val=5.918519	eigval=31.633165
# epoch=379	loss_val=5.9182835	eigval=31.633165
# epoch=380	loss_val=5.918033	eigval=31.633165
# epoch=381	loss_val=5.917787	eigval=31.633165
# epoch=382	loss_val=5.9175467	eigval=31.633165
# epoch=383	loss_val=5.9173045	eigval=31.633165
# epoch=384	loss_val=5.9170637	eigval=31.633165
# epoch=385	loss_val=5.916818	eigval=31.633165
# epoch=386	loss_val=5.9165673	eigval=31.633165
# epoch=387	loss_val=5.9163313	eigval=31.633165
# epoch=388	loss_val=5.916083	eigval=31.633165
# epoch=389	loss_val=5.915842	eigval=31.633165
# epoch=390	loss_val=5.915598	eigval=31.633165
# epoch=391	loss_val=5.915357	eigval=31.633165
# epoch=392	loss_val=5.915114	eigval=31.633165
# epoch=393	loss_val=5.914868	eigval=31.633165
# epoch=394	loss_val=5.9146185	eigval=31.633165
# epoch=395	loss_val=5.914377	eigval=31.633165
# epoch=396	loss_val=5.9141407	eigval=31.633165
# epoch=397	loss_val=5.913901	eigval=31.633165
# epoch=398	loss_val=5.9136457	eigval=31.633165
# epoch=399	loss_val=5.913407	eigval=31.633165
# epoch=400	loss_val=5.913163	eigval=31.633165
# epoch=401	loss_val=5.912916	eigval=31.633165
# epoch=402	loss_val=5.912675	eigval=31.633165
# epoch=403	loss_val=5.912433	eigval=31.633165
# epoch=404	loss_val=5.912187	eigval=31.633165
# epoch=405	loss_val=5.9119444	eigval=31.633165
# epoch=406	loss_val=5.911701	eigval=31.633165
# epoch=407	loss_val=5.9114523	eigval=31.633165
# epoch=408	loss_val=5.9112144	eigval=31.633165
# epoch=409	loss_val=5.9109683	eigval=31.633165
# epoch=410	loss_val=5.9107275	eigval=31.633165
# epoch=411	loss_val=5.9104824	eigval=31.633165
# epoch=412	loss_val=5.910239	eigval=31.633165
# epoch=413	loss_val=5.9100003	eigval=31.633165
# epoch=414	loss_val=5.9097524	eigval=31.633165
# epoch=415	loss_val=5.9095125	eigval=31.633165
# epoch=416	loss_val=5.909267	eigval=31.633165
# epoch=417	loss_val=5.909016	eigval=31.633165
# epoch=418	loss_val=5.9087677	eigval=31.633165
# epoch=419	loss_val=5.908535	eigval=31.633165
# epoch=420	loss_val=5.9082956	eigval=31.633165
# epoch=421	loss_val=5.9080453	eigval=31.633165
# epoch=422	loss_val=5.907794	eigval=31.633165
# epoch=423	loss_val=5.907556	eigval=31.633165
# epoch=424	loss_val=5.9073133	eigval=31.633165
# epoch=425	loss_val=5.907075	eigval=31.633165
# epoch=426	loss_val=5.9068274	eigval=31.633165
# epoch=427	loss_val=5.90659	eigval=31.633165
# epoch=428	loss_val=5.9063444	eigval=31.633165
# epoch=429	loss_val=5.906093	eigval=31.633165
# epoch=430	loss_val=5.905852	eigval=31.633165
# epoch=431	loss_val=5.9056153	eigval=31.633165
# epoch=432	loss_val=5.9053745	eigval=31.633165
# epoch=433	loss_val=5.9051194	eigval=31.633165
# epoch=434	loss_val=5.9048853	eigval=31.633165
# epoch=435	loss_val=5.904639	eigval=31.633165
# epoch=436	loss_val=5.904393	eigval=31.633165
# epoch=437	loss_val=5.9041476	eigval=31.633165
# epoch=438	loss_val=5.903904	eigval=31.633165
# epoch=439	loss_val=5.9036636	eigval=31.633165
# epoch=440	loss_val=5.9034243	eigval=31.633165
# epoch=441	loss_val=5.9031796	eigval=31.633165
# epoch=442	loss_val=5.9029307	eigval=31.633165
# epoch=443	loss_val=5.9026923	eigval=31.633165
# epoch=444	loss_val=5.9024525	eigval=31.633165
# epoch=445	loss_val=5.902202	eigval=31.633165
# epoch=446	loss_val=5.9019628	eigval=31.633165
# epoch=447	loss_val=5.901717	eigval=31.633165
# epoch=448	loss_val=5.9014826	eigval=31.633165
# epoch=449	loss_val=5.9012322	eigval=31.633165
# epoch=450	loss_val=5.90098	eigval=31.633165
# epoch=451	loss_val=5.9007425	eigval=31.633165
# epoch=452	loss_val=5.9005075	eigval=31.633165
# epoch=453	loss_val=5.900258	eigval=31.633165
# epoch=454	loss_val=5.900014	eigval=31.633165
# epoch=455	loss_val=5.899776	eigval=31.633165
# epoch=456	loss_val=5.8995304	eigval=31.633165
# epoch=457	loss_val=5.899287	eigval=31.633165
# epoch=458	loss_val=5.8990445	eigval=31.633165
# epoch=459	loss_val=5.898797	eigval=31.633165
# epoch=460	loss_val=5.8985567	eigval=31.633165
# epoch=461	loss_val=5.8983183	eigval=31.633165
# epoch=462	loss_val=5.8980703	eigval=31.633165
# epoch=463	loss_val=5.8978276	eigval=31.633165
# epoch=464	loss_val=5.897584	eigval=31.633165
# epoch=465	loss_val=5.897346	eigval=31.633165
# epoch=466	loss_val=5.897103	eigval=31.633165
# epoch=467	loss_val=5.8968596	eigval=31.633165
# epoch=468	loss_val=5.8966208	eigval=31.633165
# epoch=469	loss_val=5.896377	eigval=31.633165
# epoch=470	loss_val=5.8961334	eigval=31.633165
# epoch=471	loss_val=5.895886	eigval=31.633165
# epoch=472	loss_val=5.8956456	eigval=31.633165
# epoch=473	loss_val=5.8954144	eigval=31.633165
# epoch=474	loss_val=5.895165	eigval=31.633165
# epoch=475	loss_val=5.8949223	eigval=31.633165
# epoch=476	loss_val=5.894679	eigval=31.633165
# epoch=477	loss_val=5.8944416	eigval=31.633165
# epoch=478	loss_val=5.894197	eigval=31.633165
# epoch=479	loss_val=5.893949	eigval=31.633165
# epoch=480	loss_val=5.8937073	eigval=31.633165
# epoch=481	loss_val=5.893463	eigval=31.633165
# epoch=482	loss_val=5.8932195	eigval=31.633165
# epoch=483	loss_val=5.892989	eigval=31.633165
# epoch=484	loss_val=5.89274	eigval=31.633165
# epoch=485	loss_val=5.8925056	eigval=31.633165
# epoch=486	loss_val=5.8922586	eigval=31.633165
# epoch=487	loss_val=5.8920236	eigval=31.633165
# epoch=488	loss_val=5.8917756	eigval=31.633165
# epoch=489	loss_val=5.891527	eigval=31.633165
# epoch=490	loss_val=5.8912888	eigval=31.633165
# epoch=491	loss_val=5.8910446	eigval=31.633165
# epoch=492	loss_val=5.8908043	eigval=31.633165
# epoch=493	loss_val=5.890569	eigval=31.633165
# epoch=494	loss_val=5.8903165	eigval=31.633165
# epoch=495	loss_val=5.890079	eigval=31.633165
# epoch=496	loss_val=5.8898406	eigval=31.633165
# epoch=497	loss_val=5.8896065	eigval=31.633165
# epoch=498	loss_val=5.8893604	eigval=31.633165
# epoch=499	loss_val=5.889112	eigval=31.633165
# epoch=500	loss_val=5.8888726	eigval=31.633165
# epoch=501	loss_val=5.888628	eigval=31.633165
# epoch=502	loss_val=5.8883886	eigval=31.633165
# epoch=503	loss_val=5.888155	eigval=31.633165
# epoch=504	loss_val=5.8879046	eigval=31.633165
# epoch=505	loss_val=5.8876696	eigval=31.633165
# epoch=506	loss_val=5.887425	eigval=31.633165
# epoch=507	loss_val=5.887188	eigval=31.633165
# epoch=508	loss_val=5.886948	eigval=31.633165
# epoch=509	loss_val=5.886701	eigval=31.633165
# epoch=510	loss_val=5.8864555	eigval=31.633165
# epoch=511	loss_val=5.8862176	eigval=31.633165
# epoch=512	loss_val=5.885971	eigval=31.633165
# epoch=513	loss_val=5.885734	eigval=31.633165
# epoch=514	loss_val=5.8855014	eigval=31.633165
# epoch=515	loss_val=5.885253	eigval=31.633165
# epoch=516	loss_val=5.885019	eigval=31.633165
# epoch=517	loss_val=5.884778	eigval=31.633165
# epoch=518	loss_val=5.8845315	eigval=31.633165
# epoch=519	loss_val=5.8842998	eigval=31.633165
# epoch=520	loss_val=5.8840547	eigval=31.633165
# epoch=521	loss_val=5.8838162	eigval=31.633165
# epoch=522	loss_val=5.8835735	eigval=31.633165
# epoch=523	loss_val=5.8833323	eigval=31.633165
# epoch=524	loss_val=5.8830943	eigval=31.633165
# epoch=525	loss_val=5.882851	eigval=31.633165
# epoch=526	loss_val=5.8826156	eigval=31.633165
# epoch=527	loss_val=5.882375	eigval=31.633165
# epoch=528	loss_val=5.882132	eigval=31.633165
# epoch=529	loss_val=5.8819017	eigval=31.633165
# epoch=530	loss_val=5.8816543	eigval=31.633165
# epoch=531	loss_val=5.881416	eigval=31.633165
# epoch=532	loss_val=5.881165	eigval=31.633165
# epoch=533	loss_val=5.8809257	eigval=31.633165
# epoch=534	loss_val=5.8806896	eigval=31.633165
# epoch=535	loss_val=5.8804536	eigval=31.633165
# epoch=536	loss_val=5.880213	eigval=31.633165
# epoch=537	loss_val=5.8799677	eigval=31.633165
# epoch=538	loss_val=5.879733	eigval=31.633165
# epoch=539	loss_val=5.8794904	eigval=31.633165
# epoch=540	loss_val=5.8792496	eigval=31.633165
# epoch=541	loss_val=5.8790135	eigval=31.633165
# epoch=542	loss_val=5.878774	eigval=31.633165
# epoch=543	loss_val=5.878538	eigval=31.633165
# epoch=544	loss_val=5.8782997	eigval=31.633165
# epoch=545	loss_val=5.878057	eigval=31.633165
# epoch=546	loss_val=5.8778124	eigval=31.633165
# epoch=547	loss_val=5.877579	eigval=31.633165
# epoch=548	loss_val=5.877337	eigval=31.633165
# epoch=549	loss_val=5.8771024	eigval=31.633165
# epoch=550	loss_val=5.876863	eigval=31.633165
# epoch=551	loss_val=5.8766236	eigval=31.633165
# epoch=552	loss_val=5.87638	eigval=31.633165
# epoch=553	loss_val=5.8761473	eigval=31.633165
# epoch=554	loss_val=5.875907	eigval=31.633165
# epoch=555	loss_val=5.875669	eigval=31.633165
# epoch=556	loss_val=5.8754315	eigval=31.633165
# epoch=557	loss_val=5.875192	eigval=31.633165
# epoch=558	loss_val=5.8749485	eigval=31.633165
# epoch=559	loss_val=5.874712	eigval=31.633165
# epoch=560	loss_val=5.874472	eigval=31.633165
# epoch=561	loss_val=5.874238	eigval=31.633165
# epoch=562	loss_val=5.873997	eigval=31.633165
# epoch=563	loss_val=5.8737664	eigval=31.633165
# epoch=564	loss_val=5.873521	eigval=31.633165
# epoch=565	loss_val=5.873287	eigval=31.633165
# epoch=566	loss_val=5.873042	eigval=31.633165
# epoch=567	loss_val=5.872806	eigval=31.633165
# epoch=568	loss_val=5.8725724	eigval=31.633165
# epoch=569	loss_val=5.8723288	eigval=31.633165
# epoch=570	loss_val=5.8720965	eigval=31.633165
# epoch=571	loss_val=5.8718624	eigval=31.633165
# epoch=572	loss_val=5.8716245	eigval=31.633165
# epoch=573	loss_val=5.8713827	eigval=31.633165
# epoch=574	loss_val=5.871148	eigval=31.633165
# epoch=575	loss_val=5.870905	eigval=31.633165
# epoch=576	loss_val=5.8706636	eigval=31.633165
# epoch=577	loss_val=5.8704257	eigval=31.633165
# epoch=578	loss_val=5.870195	eigval=31.633165
# epoch=579	loss_val=5.869955	eigval=31.633165
# epoch=580	loss_val=5.8697166	eigval=31.633165
# epoch=581	loss_val=5.8694925	eigval=31.633165
# epoch=582	loss_val=5.869251	eigval=31.633165
# epoch=583	loss_val=5.869012	eigval=31.633165
# epoch=584	loss_val=5.868772	eigval=31.633165
# epoch=585	loss_val=5.8685365	eigval=31.633165
# epoch=586	loss_val=5.868305	eigval=31.633165
# epoch=587	loss_val=5.8680573	eigval=31.633165
# epoch=588	loss_val=5.867823	eigval=31.633165
# epoch=589	loss_val=5.8675947	eigval=31.633165
# epoch=590	loss_val=5.8673525	eigval=31.633165
# epoch=591	loss_val=5.8671136	eigval=31.633165
# epoch=592	loss_val=5.8668804	eigval=31.633165
# epoch=593	loss_val=5.8666425	eigval=31.633165
# epoch=594	loss_val=5.8664184	eigval=31.633165
# epoch=595	loss_val=5.866172	eigval=31.633165
# epoch=596	loss_val=5.8659387	eigval=31.633165
# epoch=597	loss_val=5.865695	eigval=31.633165
# epoch=598	loss_val=5.8654633	eigval=31.633165
# epoch=599	loss_val=5.8652244	eigval=31.633165
# epoch=600	loss_val=5.8649964	eigval=31.633165
# epoch=601	loss_val=5.864761	eigval=31.633165
# epoch=602	loss_val=5.864521	eigval=31.633165
# epoch=603	loss_val=5.864285	eigval=31.633165
# epoch=604	loss_val=5.864052	eigval=31.633165
# epoch=605	loss_val=5.8638153	eigval=31.633165
# epoch=606	loss_val=5.8635874	eigval=31.633165
# epoch=607	loss_val=5.8633466	eigval=31.633165
# epoch=608	loss_val=5.8631134	eigval=31.633165
# epoch=609	loss_val=5.8628817	eigval=31.633165
# epoch=610	loss_val=5.8626447	eigval=31.633165
# epoch=611	loss_val=5.8624115	eigval=31.633165
# epoch=612	loss_val=5.862175	eigval=31.633165
# epoch=613	loss_val=5.861935	eigval=31.633165
# epoch=614	loss_val=5.8617053	eigval=31.633165
# epoch=615	loss_val=5.8614717	eigval=31.633165
# epoch=616	loss_val=5.861229	eigval=31.633165
# epoch=617	loss_val=5.860995	eigval=31.633165
# epoch=618	loss_val=5.86077	eigval=31.633165
# epoch=619	loss_val=5.8605328	eigval=31.633165
# epoch=620	loss_val=5.860296	eigval=31.633165
# epoch=621	loss_val=5.8600636	eigval=31.633165
# epoch=622	loss_val=5.8598313	eigval=31.633165
# epoch=623	loss_val=5.8595934	eigval=31.633165
# epoch=624	loss_val=5.859354	eigval=31.633165
# epoch=625	loss_val=5.8591228	eigval=31.633165
# epoch=626	loss_val=5.858908	eigval=31.633165
# epoch=627	loss_val=5.858656	eigval=31.633165
# epoch=628	loss_val=5.8584247	eigval=31.633165
# epoch=629	loss_val=5.8581944	eigval=31.633165
# epoch=630	loss_val=5.8579516	eigval=31.633165
# epoch=631	loss_val=5.857721	eigval=31.633165
# epoch=632	loss_val=5.8574905	eigval=31.633165
# epoch=633	loss_val=5.857263	eigval=31.633165
# epoch=634	loss_val=5.85703	eigval=31.633165
# epoch=635	loss_val=5.8567934	eigval=31.633165
# epoch=636	loss_val=5.856563	eigval=31.633165
# epoch=637	loss_val=5.856328	eigval=31.633165
# epoch=638	loss_val=5.8560977	eigval=31.633165
# epoch=639	loss_val=5.8558574	eigval=31.633165
# epoch=640	loss_val=5.8556294	eigval=31.633165
# epoch=641	loss_val=5.855394	eigval=31.633165
# epoch=642	loss_val=5.855173	eigval=31.633165
# epoch=643	loss_val=5.8549347	eigval=31.633165
# epoch=644	loss_val=5.8547025	eigval=31.633165
# epoch=645	loss_val=5.8544602	eigval=31.633165
# epoch=646	loss_val=5.8542366	eigval=31.633165
# epoch=647	loss_val=5.8540025	eigval=31.633165
# epoch=648	loss_val=5.8537683	eigval=31.633165
# epoch=649	loss_val=5.8535304	eigval=31.633165
# epoch=650	loss_val=5.853307	eigval=31.633165
# epoch=651	loss_val=5.853077	eigval=31.633165
# epoch=652	loss_val=5.8528366	eigval=31.633165
# epoch=653	loss_val=5.8526163	eigval=31.633165
# epoch=654	loss_val=5.8523784	eigval=31.633165
# epoch=655	loss_val=5.852154	eigval=31.633165
# epoch=656	loss_val=5.851915	eigval=31.633165
# epoch=657	loss_val=5.8516836	eigval=31.633165
# epoch=658	loss_val=5.8514576	eigval=31.633165
# epoch=659	loss_val=5.851225	eigval=31.633165
# epoch=660	loss_val=5.8509936	eigval=31.633165
# epoch=661	loss_val=5.8507643	eigval=31.633165
# epoch=662	loss_val=5.850528	eigval=31.633165
# epoch=663	loss_val=5.850304	eigval=31.633165
# epoch=664	loss_val=5.850066	eigval=31.633165
# epoch=665	loss_val=5.849841	eigval=31.633165
# epoch=666	loss_val=5.849611	eigval=31.633165
# epoch=667	loss_val=5.8493714	eigval=31.633165
# epoch=668	loss_val=5.8491473	eigval=31.633165
# epoch=669	loss_val=5.848916	eigval=31.633165
# epoch=670	loss_val=5.848694	eigval=31.633165
# epoch=671	loss_val=5.8484635	eigval=31.633165
# epoch=672	loss_val=5.848224	eigval=31.633165
# epoch=673	loss_val=5.8479924	eigval=31.633165
# epoch=674	loss_val=5.8477654	eigval=31.633165
# epoch=675	loss_val=5.847543	eigval=31.633165
# epoch=676	loss_val=5.8473086	eigval=31.633165
# epoch=677	loss_val=5.8470774	eigval=31.633165
# epoch=678	loss_val=5.8468447	eigval=31.633165
# epoch=679	loss_val=5.846624	eigval=31.633165
# epoch=680	loss_val=5.846391	eigval=31.633165
# epoch=681	loss_val=5.846162	eigval=31.633165
# epoch=682	loss_val=5.8459344	eigval=31.633165
# epoch=683	loss_val=5.845699	eigval=31.633165
# epoch=684	loss_val=5.845478	eigval=31.633165
# epoch=685	loss_val=5.8452497	eigval=31.633165
# epoch=686	loss_val=5.8450146	eigval=31.633165
# epoch=687	loss_val=5.8447905	eigval=31.633165
# epoch=688	loss_val=5.844564	eigval=31.633165
# epoch=689	loss_val=5.8443336	eigval=31.633165
# epoch=690	loss_val=5.844109	eigval=31.633165
# epoch=691	loss_val=5.843876	eigval=31.633165
# epoch=692	loss_val=5.84364	eigval=31.633165
# epoch=693	loss_val=5.843416	eigval=31.633165
# epoch=694	loss_val=5.8431854	eigval=31.633165
# epoch=695	loss_val=5.8429604	eigval=31.633165
# epoch=696	loss_val=5.842735	eigval=31.633165
# epoch=697	loss_val=5.842517	eigval=31.633165
# epoch=698	loss_val=5.8422847	eigval=31.633165
# epoch=699	loss_val=5.8420568	eigval=31.633165
# epoch=700	loss_val=5.841817	eigval=31.633165
# epoch=701	loss_val=5.8416004	eigval=31.633165
# epoch=702	loss_val=5.841367	eigval=31.633165
# epoch=703	loss_val=5.8411455	eigval=31.633165
# epoch=704	loss_val=5.840914	eigval=31.633165
# epoch=705	loss_val=5.8406887	eigval=31.633165
# epoch=706	loss_val=5.8404717	eigval=31.633165
# epoch=707	loss_val=5.8402348	eigval=31.633165
# epoch=708	loss_val=5.8400064	eigval=31.633165
# epoch=709	loss_val=5.839779	eigval=31.633165
# epoch=710	loss_val=5.839561	eigval=31.633165
# epoch=711	loss_val=5.839328	eigval=31.633165
# epoch=712	loss_val=5.839099	eigval=31.633165
# epoch=713	loss_val=5.8388734	eigval=31.633165
# epoch=714	loss_val=5.838644	eigval=31.633165
# epoch=715	loss_val=5.8384247	eigval=31.633165
# epoch=716	loss_val=5.8382053	eigval=31.633165
# epoch=717	loss_val=5.8379717	eigval=31.633165
# epoch=718	loss_val=5.8377423	eigval=31.633165
# epoch=719	loss_val=5.8375163	eigval=31.633165
# epoch=720	loss_val=5.837287	eigval=31.633165
# epoch=721	loss_val=5.8370657	eigval=31.633165
# epoch=722	loss_val=5.836846	eigval=31.633165
# epoch=723	loss_val=5.836621	eigval=31.633165
# epoch=724	loss_val=5.836397	eigval=31.633165
# epoch=725	loss_val=5.8361745	eigval=31.633165
# epoch=726	loss_val=5.8359437	eigval=31.633165
# epoch=727	loss_val=5.83572	eigval=31.633165
# epoch=728	loss_val=5.835495	eigval=31.633165
# epoch=729	loss_val=5.8352757	eigval=31.633165
# epoch=730	loss_val=5.835042	eigval=31.633165
# epoch=731	loss_val=5.834821	eigval=31.633165
# epoch=732	loss_val=5.8346004	eigval=31.633165
# epoch=733	loss_val=5.8343735	eigval=31.633165
# epoch=734	loss_val=5.8341513	eigval=31.633165
# epoch=735	loss_val=5.833918	eigval=31.633165
# epoch=736	loss_val=5.833694	eigval=31.633165
# epoch=737	loss_val=5.8334684	eigval=31.633165
# epoch=738	loss_val=5.8332467	eigval=31.633165
# epoch=739	loss_val=5.8330264	eigval=31.633165
# epoch=740	loss_val=5.832802	eigval=31.633165
# epoch=741	loss_val=5.8325763	eigval=31.633165
# epoch=742	loss_val=5.832364	eigval=31.633165
# epoch=743	loss_val=5.832138	eigval=31.633165
# epoch=744	loss_val=5.8319116	eigval=31.633165
# epoch=745	loss_val=5.8316846	eigval=31.633165
# epoch=746	loss_val=5.8314614	eigval=31.633165
# epoch=747	loss_val=5.831237	eigval=31.633165
# epoch=748	loss_val=5.8310137	eigval=31.633165
# epoch=749	loss_val=5.830789	eigval=31.633165
# epoch=750	loss_val=5.830576	eigval=31.633165
# epoch=751	loss_val=5.830351	eigval=31.633165
# epoch=752	loss_val=5.830127	eigval=31.633165
# epoch=753	loss_val=5.8299007	eigval=31.633165
# epoch=754	loss_val=5.8296757	eigval=31.633165
# epoch=755	loss_val=5.8294635	eigval=31.633165
# epoch=756	loss_val=5.8292365	eigval=31.633165
# epoch=757	loss_val=5.829011	eigval=31.633165
# epoch=758	loss_val=5.8287916	eigval=31.633165
# epoch=759	loss_val=5.8285675	eigval=31.633165
# epoch=760	loss_val=5.8283443	eigval=31.633165
# epoch=761	loss_val=5.828125	eigval=31.633165
# epoch=762	loss_val=5.8279037	eigval=31.633165
# epoch=763	loss_val=5.827686	eigval=31.633165
# epoch=764	loss_val=5.8274565	eigval=31.633165
# epoch=765	loss_val=5.8272376	eigval=31.633165
# epoch=766	loss_val=5.827016	eigval=31.633165
# epoch=767	loss_val=5.826805	eigval=31.633165
# epoch=768	loss_val=5.826581	eigval=31.633165
# epoch=769	loss_val=5.8263564	eigval=31.633165
# epoch=770	loss_val=5.826142	eigval=31.633165
# epoch=771	loss_val=5.8259115	eigval=31.633165
# epoch=772	loss_val=5.8256946	eigval=31.633165
# epoch=773	loss_val=5.825476	eigval=31.633165
# epoch=774	loss_val=5.8252554	eigval=31.633165
# epoch=775	loss_val=5.825036	eigval=31.633165
# epoch=776	loss_val=5.8248186	eigval=31.633165
# epoch=777	loss_val=5.8245993	eigval=31.633165
# epoch=778	loss_val=5.8243723	eigval=31.633165
# epoch=779	loss_val=5.82415	eigval=31.633165
# epoch=780	loss_val=5.8239365	eigval=31.633165
# epoch=781	loss_val=5.823717	eigval=31.633165
# epoch=782	loss_val=5.8234897	eigval=31.633165
# epoch=783	loss_val=5.823268	eigval=31.633165
# epoch=784	loss_val=5.8230543	eigval=31.633165
# epoch=785	loss_val=5.8228436	eigval=31.633165
# epoch=786	loss_val=5.822621	eigval=31.633165
# epoch=787	loss_val=5.8224	eigval=31.633165
# epoch=788	loss_val=5.8221784	eigval=31.633165
# epoch=789	loss_val=5.821956	eigval=31.633165
# epoch=790	loss_val=5.821742	eigval=31.633165
# epoch=791	loss_val=5.8215265	eigval=31.633165
# epoch=792	loss_val=5.8213053	eigval=31.633165
# epoch=793	loss_val=5.821087	eigval=31.633165
# epoch=794	loss_val=5.8208666	eigval=31.633165
# epoch=795	loss_val=5.820648	eigval=31.633165
# epoch=796	loss_val=5.820433	eigval=31.633165
# epoch=797	loss_val=5.820211	eigval=31.633165
# epoch=798	loss_val=5.819992	eigval=31.633165
# epoch=799	loss_val=5.8197737	eigval=31.633165
# epoch=800	loss_val=5.8195605	eigval=31.633165
# epoch=801	loss_val=5.819337	eigval=31.633165
# epoch=802	loss_val=5.8191223	eigval=31.633165
# epoch=803	loss_val=5.818901	eigval=31.633165
# epoch=804	loss_val=5.8186846	eigval=31.633165
# epoch=805	loss_val=5.8184714	eigval=31.633165
# epoch=806	loss_val=5.8182564	eigval=31.633165
# epoch=807	loss_val=5.818034	eigval=31.633165
# epoch=808	loss_val=5.8178034	eigval=31.633165
# epoch=809	loss_val=5.817605	eigval=31.633165
# epoch=810	loss_val=5.8173847	eigval=31.633165
# epoch=811	loss_val=5.8171754	eigval=31.633165
# epoch=812	loss_val=5.8169546	eigval=31.633165
# epoch=813	loss_val=5.816738	eigval=31.633165
# epoch=814	loss_val=5.8165145	eigval=31.633165
# epoch=815	loss_val=5.816308	eigval=31.633165
# epoch=816	loss_val=5.8160815	eigval=31.633165
# epoch=817	loss_val=5.815869	eigval=31.633165
# epoch=818	loss_val=5.815646	eigval=31.633165
# epoch=819	loss_val=5.8154387	eigval=31.633165
# epoch=820	loss_val=5.815217	eigval=31.633165
# epoch=821	loss_val=5.8150077	eigval=31.633165
# epoch=822	loss_val=5.814787	eigval=31.633165
# epoch=823	loss_val=5.8145757	eigval=31.633165
# epoch=824	loss_val=5.8143687	eigval=31.633165
# epoch=825	loss_val=5.8141456	eigval=31.633165
# epoch=826	loss_val=5.813928	eigval=31.633165
# epoch=827	loss_val=5.8137217	eigval=31.633165
# epoch=828	loss_val=5.8135076	eigval=31.633165
# epoch=829	loss_val=5.813285	eigval=31.633165
# epoch=830	loss_val=5.8130717	eigval=31.633165
# epoch=831	loss_val=5.8128552	eigval=31.633165
# epoch=832	loss_val=5.8126383	eigval=31.633165
# epoch=833	loss_val=5.8124294	eigval=31.633165
# epoch=834	loss_val=5.812211	eigval=31.633165
# epoch=835	loss_val=5.812001	eigval=31.633165
# epoch=836	loss_val=5.811783	eigval=31.633165
# epoch=837	loss_val=5.8115745	eigval=31.633165
# epoch=838	loss_val=5.81136	eigval=31.633165
# epoch=839	loss_val=5.8111444	eigval=31.633165
# epoch=840	loss_val=5.8109264	eigval=31.633165
# epoch=841	loss_val=5.810718	eigval=31.633165
# epoch=842	loss_val=5.8104987	eigval=31.633165
# epoch=843	loss_val=5.810288	eigval=31.633165
# epoch=844	loss_val=5.8100824	eigval=31.633165
# epoch=845	loss_val=5.8098636	eigval=31.633165
# epoch=846	loss_val=5.8096547	eigval=31.633165
# epoch=847	loss_val=5.8094306	eigval=31.633165
# epoch=848	loss_val=5.809218	eigval=31.633165
# epoch=849	loss_val=5.809013	eigval=31.633165
# epoch=850	loss_val=5.8088	eigval=31.633165
# epoch=851	loss_val=5.808585	eigval=31.633165
# epoch=852	loss_val=5.8083797	eigval=31.633165
# epoch=853	loss_val=5.808169	eigval=31.633165
# epoch=854	loss_val=5.8079505	eigval=31.633165
# epoch=855	loss_val=5.8077345	eigval=31.633165
# epoch=856	loss_val=5.8075223	eigval=31.633165
# epoch=857	loss_val=5.8073053	eigval=31.633165
# epoch=858	loss_val=5.8070974	eigval=31.633165
# epoch=859	loss_val=5.806885	eigval=31.633165
# epoch=860	loss_val=5.806675	eigval=31.633165
# epoch=861	loss_val=5.806463	eigval=31.633165
# epoch=862	loss_val=5.8062525	eigval=31.633165
# epoch=863	loss_val=5.8060403	eigval=31.633165
# epoch=864	loss_val=5.8058305	eigval=31.633165
# epoch=865	loss_val=5.8056283	eigval=31.633165
# epoch=866	loss_val=5.8054047	eigval=31.633165
# epoch=867	loss_val=5.8051996	eigval=31.633165
# epoch=868	loss_val=5.804991	eigval=31.633165
# epoch=869	loss_val=5.8047733	eigval=31.633165
# epoch=870	loss_val=5.804559	eigval=31.633165
# epoch=871	loss_val=5.8043456	eigval=31.633165
# epoch=872	loss_val=5.804146	eigval=31.633165
# epoch=873	loss_val=5.8039255	eigval=31.633165
# epoch=874	loss_val=5.8037243	eigval=31.633165
# epoch=875	loss_val=5.8035054	eigval=31.633165
# epoch=876	loss_val=5.803302	eigval=31.633165
# epoch=877	loss_val=5.803089	eigval=31.633165
# epoch=878	loss_val=5.8028836	eigval=31.633165
# epoch=879	loss_val=5.802673	eigval=31.633165
# epoch=880	loss_val=5.802458	eigval=31.633165
# epoch=881	loss_val=5.8022504	eigval=31.633165
# epoch=882	loss_val=5.8020387	eigval=31.633165
# epoch=883	loss_val=5.801834	eigval=31.633165
# epoch=884	loss_val=5.801628	eigval=31.633165
# epoch=885	loss_val=5.8014193	eigval=31.633165
# epoch=886	loss_val=5.801207	eigval=31.633165
# epoch=887	loss_val=5.801	eigval=31.633165
# epoch=888	loss_val=5.800789	eigval=31.633165
# epoch=889	loss_val=5.8005776	eigval=31.633165
# epoch=890	loss_val=5.8003664	eigval=31.633165
# epoch=891	loss_val=5.8001585	eigval=31.633165
# epoch=892	loss_val=5.79995	eigval=31.633165
# epoch=893	loss_val=5.799746	eigval=31.633165
# epoch=894	loss_val=5.7995443	eigval=31.633165
# epoch=895	loss_val=5.7993264	eigval=31.633165
# epoch=896	loss_val=5.799123	eigval=31.633165
# epoch=897	loss_val=5.7989187	eigval=31.633165
# epoch=898	loss_val=5.798707	eigval=31.633165
# epoch=899	loss_val=5.798503	eigval=31.633165
# epoch=900	loss_val=5.7982945	eigval=31.633165
# epoch=901	loss_val=5.7980866	eigval=31.633165
# epoch=902	loss_val=5.797874	eigval=31.633165
# epoch=903	loss_val=5.797676	eigval=31.633165
# epoch=904	loss_val=5.797456	eigval=31.633165
# epoch=905	loss_val=5.7972536	eigval=31.633165
# epoch=906	loss_val=5.797053	eigval=31.633165
# epoch=907	loss_val=5.7968416	eigval=31.633165
# epoch=908	loss_val=5.7966332	eigval=31.633165
# epoch=909	loss_val=5.7964287	eigval=31.633165
# epoch=910	loss_val=5.796219	eigval=31.633165
# epoch=911	loss_val=5.796017	eigval=31.633165
# epoch=912	loss_val=5.7958117	eigval=31.633165
# epoch=913	loss_val=5.7956023	eigval=31.633165
# epoch=914	loss_val=5.7953973	eigval=31.633165
# epoch=915	loss_val=5.795193	eigval=31.633165
# epoch=916	loss_val=5.7949843	eigval=31.633165
# epoch=917	loss_val=5.794784	eigval=31.633165
# epoch=918	loss_val=5.794574	eigval=31.633165
# epoch=919	loss_val=5.794369	eigval=31.633165
# epoch=920	loss_val=5.7941575	eigval=31.633165
# epoch=921	loss_val=5.793957	eigval=31.633165
# epoch=922	loss_val=5.793752	eigval=31.633165
# epoch=923	loss_val=5.79355	eigval=31.633165
# epoch=924	loss_val=5.7933345	eigval=31.633165
# epoch=925	loss_val=5.793139	eigval=31.633165
# epoch=926	loss_val=5.7929354	eigval=31.633165
# epoch=927	loss_val=5.792737	eigval=31.633165
# epoch=928	loss_val=5.792523	eigval=31.633165
# epoch=929	loss_val=5.7923193	eigval=31.633165
# epoch=930	loss_val=5.7921104	eigval=31.633165
# epoch=931	loss_val=5.791911	eigval=31.633165
# epoch=932	loss_val=5.7917094	eigval=31.633165
# epoch=933	loss_val=5.7915072	eigval=31.633165
# epoch=934	loss_val=5.7913027	eigval=31.633165
# epoch=935	loss_val=5.7910933	eigval=31.633165
# epoch=936	loss_val=5.790891	eigval=31.633165
# epoch=937	loss_val=5.7906914	eigval=31.633165
# epoch=938	loss_val=5.7904897	eigval=31.633165
# epoch=939	loss_val=5.790271	eigval=31.633165
# epoch=940	loss_val=5.7900786	eigval=31.633165
# epoch=941	loss_val=5.789876	eigval=31.633165
# epoch=942	loss_val=5.789665	eigval=31.633165
# epoch=943	loss_val=5.7894673	eigval=31.633165
# epoch=944	loss_val=5.7892675	eigval=31.633165
# epoch=945	loss_val=5.789059	eigval=31.633165
# epoch=946	loss_val=5.7888517	eigval=31.633165
# epoch=947	loss_val=5.788654	eigval=31.633165
# epoch=948	loss_val=5.7884517	eigval=31.633165
# epoch=949	loss_val=5.788239	eigval=31.633165
# epoch=950	loss_val=5.788047	eigval=31.633165
# epoch=951	loss_val=5.7878423	eigval=31.633165
# epoch=952	loss_val=5.787646	eigval=31.633165
# epoch=953	loss_val=5.787438	eigval=31.633165
# epoch=954	loss_val=5.7872357	eigval=31.633165
# epoch=955	loss_val=5.787033	eigval=31.633165
# epoch=956	loss_val=5.78683	eigval=31.633165
# epoch=957	loss_val=5.7866335	eigval=31.633165
# epoch=958	loss_val=5.7864294	eigval=31.633165
# epoch=959	loss_val=5.7862315	eigval=31.633165
# epoch=960	loss_val=5.7860265	eigval=31.633165
# epoch=961	loss_val=5.7858243	eigval=31.633165
# epoch=962	loss_val=5.785624	eigval=31.633165
# epoch=963	loss_val=5.785431	eigval=31.633165
# epoch=964	loss_val=5.7852263	eigval=31.633165
# epoch=965	loss_val=5.7850223	eigval=31.633165
# epoch=966	loss_val=5.784827	eigval=31.633165
# epoch=967	loss_val=5.7846155	eigval=31.633165
# epoch=968	loss_val=5.784415	eigval=31.633165
# epoch=969	loss_val=5.784225	eigval=31.633165
# epoch=970	loss_val=5.784025	eigval=31.633165
# epoch=971	loss_val=5.783824	eigval=31.633165
# epoch=972	loss_val=5.7836175	eigval=31.633165
# epoch=973	loss_val=5.7834263	eigval=31.633165
# epoch=974	loss_val=5.7832184	eigval=31.633165
# epoch=975	loss_val=5.78302	eigval=31.633165
# epoch=976	loss_val=5.782817	eigval=31.633165
# epoch=977	loss_val=5.782627	eigval=31.633165
# epoch=978	loss_val=5.782423	eigval=31.633165
# epoch=979	loss_val=5.782221	eigval=31.633165
# epoch=980	loss_val=5.7820163	eigval=31.633165
# epoch=981	loss_val=5.781822	eigval=31.633165
# epoch=982	loss_val=5.781628	eigval=31.633165
# epoch=983	loss_val=5.7814193	eigval=31.633165
# epoch=984	loss_val=5.7812233	eigval=31.633165
# epoch=985	loss_val=5.781026	eigval=31.633165
# epoch=986	loss_val=5.780836	eigval=31.633165
# epoch=987	loss_val=5.7806354	eigval=31.633165
# epoch=988	loss_val=5.780436	eigval=31.633165
# epoch=989	loss_val=5.7802334	eigval=31.633165
# epoch=990	loss_val=5.7800384	eigval=31.633165
# epoch=991	loss_val=5.779832	eigval=31.633165
# epoch=992	loss_val=5.7796416	eigval=31.633165
# epoch=993	loss_val=5.7794414	eigval=31.633165
# epoch=994	loss_val=5.7792377	eigval=31.633165
# epoch=995	loss_val=5.7790413	eigval=31.633165
# epoch=996	loss_val=5.7788534	eigval=31.633165
# epoch=997	loss_val=5.7786546	eigval=31.633165
# epoch=998	loss_val=5.778452	eigval=31.633165
# epoch=999	loss_val=5.778253	eigval=31.633165
# epoch=1000	loss_val=5.778057	eigval=31.633165
# epoch=1001	loss_val=5.7778687	eigval=31.633165
# epoch=1002	loss_val=5.7776628	eigval=31.633165
# epoch=1003	loss_val=5.7774687	eigval=31.633165
# epoch=1004	loss_val=5.7772727	eigval=31.633165
# epoch=1005	loss_val=5.777071	eigval=31.633165
# epoch=1006	loss_val=5.776879	eigval=31.633165
# epoch=1007	loss_val=5.7766805	eigval=31.633165
# epoch=1008	loss_val=5.776482	eigval=31.633165
# epoch=1009	loss_val=5.7762914	eigval=31.633165
# epoch=1010	loss_val=5.7760973	eigval=31.633165
# epoch=1011	loss_val=5.775893	eigval=31.633165
# epoch=1012	loss_val=5.7756963	eigval=31.633165
# epoch=1013	loss_val=5.775505	eigval=31.633165
# epoch=1014	loss_val=5.7753067	eigval=31.633165
# epoch=1015	loss_val=5.7751236	eigval=31.633165
# epoch=1016	loss_val=5.774923	eigval=31.633165
# epoch=1017	loss_val=5.7747154	eigval=31.633165
# epoch=1018	loss_val=5.774527	eigval=31.633165
# epoch=1019	loss_val=5.774336	eigval=31.633165
# epoch=1020	loss_val=5.7741327	eigval=31.633165
# epoch=1021	loss_val=5.7739377	eigval=31.633165
# epoch=1022	loss_val=5.773741	eigval=31.633165
# epoch=1023	loss_val=5.773547	eigval=31.633165
# epoch=1024	loss_val=5.7733555	eigval=31.633165
# epoch=1025	loss_val=5.7731576	eigval=31.633165
# epoch=1026	loss_val=5.7729692	eigval=31.633165
# epoch=1027	loss_val=5.772774	eigval=31.633165
# epoch=1028	loss_val=5.772577	eigval=31.633165
# epoch=1029	loss_val=5.772382	eigval=31.633165
# epoch=1030	loss_val=5.7721934	eigval=31.633165
# epoch=1031	loss_val=5.7719913	eigval=31.633165
# epoch=1032	loss_val=5.771801	eigval=31.633165
# epoch=1033	loss_val=5.7716074	eigval=31.633165
# epoch=1034	loss_val=5.771415	eigval=31.633165
# epoch=1035	loss_val=5.7712226	eigval=31.633165
# epoch=1036	loss_val=5.771026	eigval=31.633165
# epoch=1037	loss_val=5.7708297	eigval=31.633165
# epoch=1038	loss_val=5.7706366	eigval=31.633165
# epoch=1039	loss_val=5.7704434	eigval=31.633165
# epoch=1040	loss_val=5.7702513	eigval=31.633165
# epoch=1041	loss_val=5.770056	eigval=31.633165
# epoch=1042	loss_val=5.7698665	eigval=31.633165
# epoch=1043	loss_val=5.7696705	eigval=31.633165
# epoch=1044	loss_val=5.7694774	eigval=31.633165
# epoch=1045	loss_val=5.769287	eigval=31.633165
# epoch=1046	loss_val=5.7690916	eigval=31.633165
# epoch=1047	loss_val=5.768901	eigval=31.633165
# epoch=1048	loss_val=5.768713	eigval=31.633165
# epoch=1049	loss_val=5.7685227	eigval=31.633165
# epoch=1050	loss_val=5.7683244	eigval=31.633165
# epoch=1051	loss_val=5.76813	eigval=31.633165
# epoch=1052	loss_val=5.7679462	eigval=31.633165
# epoch=1053	loss_val=5.767752	eigval=31.633165
# epoch=1054	loss_val=5.767561	eigval=31.633165
# epoch=1055	loss_val=5.76737	eigval=31.633165
# ...
# epoch=4656	loss_val=5.4483123	eigval=31.633165
# epoch=4657	loss_val=5.449816	eigval=31.633165
# epoch=4658	loss_val=5.4513726	eigval=31.633165
# epoch=4659	loss_val=5.4526253	eigval=31.633165
# epoch=4660	loss_val=5.4530487	eigval=31.633165
# epoch=4661	loss_val=5.4521613	eigval=31.633165
# epoch=4662	loss_val=5.449961	eigval=31.633165
# epoch=4663	loss_val=5.447102	eigval=31.633165
# epoch=4664	loss_val=5.44467	eigval=31.633165
# epoch=4665	loss_val=5.443509	eigval=31.633165
# epoch=4666	loss_val=5.443774	eigval=31.633165
# epoch=4667	loss_val=5.4449477	eigval=31.633165
# epoch=4668	loss_val=5.446179	eigval=31.633165
# epoch=4669	loss_val=5.4467406	eigval=31.633165
# epoch=4670	loss_val=5.446342	eigval=31.633165
# epoch=4671	loss_val=5.445248	eigval=31.633165
# epoch=4672	loss_val=5.444027	eigval=31.633165
# epoch=4673	loss_val=5.4433002	eigval=31.633165
# epoch=4674	loss_val=5.443265	eigval=31.633165
# epoch=4675	loss_val=5.4437594	eigval=31.633165
# epoch=4676	loss_val=5.4443293	eigval=31.633165
# epoch=4677	loss_val=5.44459	eigval=31.633165
# epoch=4678	loss_val=5.444404	eigval=31.633165
# epoch=4679	loss_val=5.443879	eigval=31.633165
# epoch=4680	loss_val=5.4433327	eigval=31.633165
# epoch=4681	loss_val=5.443022	eigval=31.633165
# epoch=4682	loss_val=5.443014	eigval=31.633165
# epoch=4683	loss_val=5.4432282	eigval=31.633165
# epoch=4684	loss_val=5.443466	eigval=31.633165
# epoch=4685	loss_val=5.4435625	eigval=31.633165
# epoch=4686	loss_val=5.4434466	eigval=31.633165
# epoch=4687	loss_val=5.443213	eigval=31.633165
# epoch=4688	loss_val=5.4429564	eigval=31.633165
# epoch=4689	loss_val=5.442801	eigval=31.633165
# epoch=4690	loss_val=5.442782	eigval=31.633165
# epoch=4691	loss_val=5.4428573	eigval=31.633165
# epoch=4692	loss_val=5.442951	eigval=31.633165
# epoch=4693	loss_val=5.4429913	eigval=31.633165
# epoch=4694	loss_val=5.4429455	eigval=31.633165
# epoch=4695	loss_val=5.442841	eigval=31.633165
# epoch=4696	loss_val=5.4427176	eigval=31.633165
# epoch=4697	loss_val=5.442632	eigval=31.633165
# epoch=4698	loss_val=5.442601	eigval=31.633165
# epoch=4699	loss_val=5.4426203	eigval=31.633165
# epoch=4700	loss_val=5.4426627	eigval=31.633165
# epoch=4701	loss_val=5.4427075	eigval=31.633165
# epoch=4702	loss_val=5.4427166	eigval=31.633165
# epoch=4703	loss_val=5.4427285	eigval=31.633165
# epoch=4704	loss_val=5.442748	eigval=31.633165
# epoch=4705	loss_val=5.4428115	eigval=31.633165
# epoch=4706	loss_val=5.4429393	eigval=31.633165
# epoch=4707	loss_val=5.4431686	eigval=31.633165
# epoch=4708	loss_val=5.4435077	eigval=31.633165
# epoch=4709	loss_val=5.4439898	eigval=31.633165
# epoch=4710	loss_val=5.4446754	eigval=31.633165
# epoch=4711	loss_val=5.445585	eigval=31.633165
# epoch=4712	loss_val=5.4466896	eigval=31.633165
# epoch=4713	loss_val=5.447874	eigval=31.633165
# epoch=4714	loss_val=5.4488573	eigval=31.633165
# epoch=4715	loss_val=5.4492393	eigval=31.633165
# epoch=4716	loss_val=5.4485993	eigval=31.633165
# epoch=4717	loss_val=5.446891	eigval=31.633165
# epoch=4718	loss_val=5.444697	eigval=31.633165
# epoch=4719	loss_val=5.442856	eigval=31.633165
# epoch=4720	loss_val=5.4420643	eigval=31.633165
# epoch=4721	loss_val=5.442385	eigval=31.633165
# epoch=4722	loss_val=5.443337	eigval=31.633165
# epoch=4723	loss_val=5.4442215	eigval=31.633165
# epoch=4724	loss_val=5.4444914	eigval=31.633165
# epoch=4725	loss_val=5.444007	eigval=31.633165
# epoch=4726	loss_val=5.4430795	eigval=31.633165
# epoch=4727	loss_val=5.442233	eigval=31.633165
# epoch=4728	loss_val=5.4418707	eigval=31.633165
# epoch=4729	loss_val=5.4420524	eigval=31.633165
# epoch=4730	loss_val=5.4425077	eigval=31.633165
# epoch=4731	loss_val=5.4428477	eigval=31.633165
# epoch=4732	loss_val=5.442882	eigval=31.633165
# epoch=4733	loss_val=5.4425626	eigval=31.633165
# epoch=4734	loss_val=5.442116	eigval=31.633165
# epoch=4735	loss_val=5.4417877	eigval=31.633165
# epoch=4736	loss_val=5.4416957	eigval=31.633165
# epoch=4737	loss_val=5.441828	eigval=31.633165
# epoch=4738	loss_val=5.442036	eigval=31.633165
# epoch=4739	loss_val=5.442159	eigval=31.633165
# epoch=4740	loss_val=5.4420953	eigval=31.633165
# epoch=4741	loss_val=5.441899	eigval=31.633165
# epoch=4742	loss_val=5.4416704	eigval=31.633165
# epoch=4743	loss_val=5.4415355	eigval=31.633165
# epoch=4744	loss_val=5.441517	eigval=31.633165
# epoch=4745	loss_val=5.4415812	eigval=31.633165
# epoch=4746	loss_val=5.441652	eigval=31.633165
# epoch=4747	loss_val=5.4416714	eigval=31.633165
# epoch=4748	loss_val=5.4416156	eigval=31.633165
# epoch=4749	loss_val=5.441517	eigval=31.633165
# epoch=4750	loss_val=5.441414	eigval=31.633165
# epoch=4751	loss_val=5.4413457	eigval=31.633165
# epoch=4752	loss_val=5.4413257	eigval=31.633165
# epoch=4753	loss_val=5.4413443	eigval=31.633165
# epoch=4754	loss_val=5.441359	eigval=31.633165
# epoch=4755	loss_val=5.441355	eigval=31.633165
# epoch=4756	loss_val=5.4413238	eigval=31.633165
# epoch=4757	loss_val=5.4412694	eigval=31.633165
# epoch=4758	loss_val=5.4412184	eigval=31.633165
# epoch=4759	loss_val=5.4411697	eigval=31.633165
# epoch=4760	loss_val=5.441138	eigval=31.633165
# epoch=4761	loss_val=5.4411263	eigval=31.633165
# epoch=4762	loss_val=5.4411106	eigval=31.633165
# epoch=4763	loss_val=5.441109	eigval=31.633165
# epoch=4764	loss_val=5.441091	eigval=31.633165
# epoch=4765	loss_val=5.4410625	eigval=31.633165
# epoch=4766	loss_val=5.441028	eigval=31.633165
# epoch=4767	loss_val=5.441001	eigval=31.633165
# epoch=4768	loss_val=5.440956	eigval=31.633165
# epoch=4769	loss_val=5.4409304	eigval=31.633165
# epoch=4770	loss_val=5.440915	eigval=31.633165
# epoch=4771	loss_val=5.4408975	eigval=31.633165
# epoch=4772	loss_val=5.4408827	eigval=31.633165
# epoch=4773	loss_val=5.4408607	eigval=31.633165
# epoch=4774	loss_val=5.440838	eigval=31.633165
# epoch=4775	loss_val=5.4408164	eigval=31.633165
# epoch=4776	loss_val=5.4407907	eigval=31.633165
# epoch=4777	loss_val=5.440759	eigval=31.633165
# epoch=4778	loss_val=5.4407425	eigval=31.633165
# epoch=4779	loss_val=5.4407167	eigval=31.633165
# epoch=4780	loss_val=5.440702	eigval=31.633165
# epoch=4781	loss_val=5.4406776	eigval=31.633165
# epoch=4782	loss_val=5.440655	eigval=31.633165
# epoch=4783	loss_val=5.4406385	eigval=31.633165
# epoch=4784	loss_val=5.4406123	eigval=31.633165
# epoch=4785	loss_val=5.440598	eigval=31.633165
# epoch=4786	loss_val=5.440574	eigval=31.633165
# epoch=4787	loss_val=5.4405565	eigval=31.633165
# epoch=4788	loss_val=5.4405484	eigval=31.633165
# epoch=4789	loss_val=5.4405274	eigval=31.633165
# epoch=4790	loss_val=5.4405203	eigval=31.633165
# epoch=4791	loss_val=5.4405046	eigval=31.633165
# epoch=4792	loss_val=5.440513	eigval=31.633165
# epoch=4793	loss_val=5.4405284	eigval=31.633165
# epoch=4794	loss_val=5.4405475	eigval=31.633165
# epoch=4795	loss_val=5.4406075	eigval=31.633165
# epoch=4796	loss_val=5.4406924	eigval=31.633165
# epoch=4797	loss_val=5.4408402	eigval=31.633165
# epoch=4798	loss_val=5.4410715	eigval=31.633165
# epoch=4799	loss_val=5.441425	eigval=31.633165
# epoch=4800	loss_val=5.441964	eigval=31.633165
# epoch=4801	loss_val=5.442781	eigval=31.633165
# epoch=4802	loss_val=5.443969	eigval=31.633165
# epoch=4803	loss_val=5.445614	eigval=31.633165
# epoch=4804	loss_val=5.447776	eigval=31.633165
# epoch=4805	loss_val=5.4502783	eigval=31.633165
# epoch=4806	loss_val=5.452706	eigval=31.633165
# epoch=4807	loss_val=5.4542046	eigval=31.633165
# epoch=4808	loss_val=5.4538274	eigval=31.633165
# epoch=4809	loss_val=5.451215	eigval=31.633165
# epoch=4810	loss_val=5.447153	eigval=31.633165
# epoch=4811	loss_val=5.4434094	eigval=31.633165
# epoch=4812	loss_val=5.441437	eigval=31.633165
# epoch=4813	loss_val=5.441447	eigval=31.633165
# epoch=4814	loss_val=5.4425616	eigval=31.633165
# epoch=4815	loss_val=5.443587	eigval=31.633165
# epoch=4816	loss_val=5.4437966	eigval=31.633165
# epoch=4817	loss_val=5.44312	eigval=31.633165
# epoch=4818	loss_val=5.442165	eigval=31.633165
# epoch=4819	loss_val=5.441583	eigval=31.633165
# epoch=4820	loss_val=5.4415727	eigval=31.633165
# epoch=4821	loss_val=5.4418154	eigval=31.633165
# epoch=4822	loss_val=5.44184	eigval=31.633165
# epoch=4823	loss_val=5.4414167	eigval=31.633165
# epoch=4824	loss_val=5.440721	eigval=31.633165
# epoch=4825	loss_val=5.440127	eigval=31.633165
# epoch=4826	loss_val=5.4399915	eigval=31.633165
# epoch=4827	loss_val=5.4402914	eigval=31.633165
# epoch=4828	loss_val=5.44075	eigval=31.633165
# epoch=4829	loss_val=5.441034	eigval=31.633165
# epoch=4830	loss_val=5.4409266	eigval=31.633165
# epoch=4831	loss_val=5.440486	eigval=31.633165
# epoch=4832	loss_val=5.439965	eigval=31.633165
# epoch=4833	loss_val=5.439617	eigval=31.633165
# epoch=4834	loss_val=5.4395537	eigval=31.633165
# epoch=4835	loss_val=5.4396973	eigval=31.633165
# epoch=4836	loss_val=5.4399066	eigval=31.633165
# epoch=4837	loss_val=5.4400225	eigval=31.633165
# epoch=4838	loss_val=5.439997	eigval=31.633165
# epoch=4839	loss_val=5.43985	eigval=31.633165
# epoch=4840	loss_val=5.4396796	eigval=31.633165
# epoch=4841	loss_val=5.4395566	eigval=31.633165
# epoch=4842	loss_val=5.4395022	eigval=31.633165
# epoch=4843	loss_val=5.4395013	eigval=31.633165
# epoch=4844	loss_val=5.43951	eigval=31.633165
# epoch=4845	loss_val=5.439466	eigval=31.633165
# epoch=4846	loss_val=5.4394026	eigval=31.633165
# epoch=4847	loss_val=5.4393425	eigval=31.633165
# epoch=4848	loss_val=5.4392915	eigval=31.633165
# epoch=4849	loss_val=5.439275	eigval=31.633165
# epoch=4850	loss_val=5.439289	eigval=31.633165
# epoch=4851	loss_val=5.439303	eigval=31.633165
# epoch=4852	loss_val=5.4393034	eigval=31.633165
# epoch=4853	loss_val=5.4392643	eigval=31.633165
# epoch=4854	loss_val=5.439199	eigval=31.633165
# epoch=4855	loss_val=5.439125	eigval=31.633165
# epoch=4856	loss_val=5.439073	eigval=31.633165
# epoch=4857	loss_val=5.439025	eigval=31.633165
# epoch=4858	loss_val=5.4390054	eigval=31.633165
# epoch=4859	loss_val=5.438999	eigval=31.633165
# epoch=4860	loss_val=5.439007	eigval=31.633165
# epoch=4861	loss_val=5.4389997	eigval=31.633165
# epoch=4862	loss_val=5.438989	eigval=31.633165
# epoch=4863	loss_val=5.438965	eigval=31.633165
# epoch=4864	loss_val=5.4389353	eigval=31.633165
# epoch=4865	loss_val=5.438914	eigval=31.633165
# epoch=4866	loss_val=5.4388885	eigval=31.633165
# epoch=4867	loss_val=5.4388647	eigval=31.633165
# epoch=4868	loss_val=5.438854	eigval=31.633165
# epoch=4869	loss_val=5.438825	eigval=31.633165
# epoch=4870	loss_val=5.4388237	eigval=31.633165
# epoch=4871	loss_val=5.4388084	eigval=31.633165
# epoch=4872	loss_val=5.4388065	eigval=31.633165
# epoch=4873	loss_val=5.438838	eigval=31.633165
# epoch=4874	loss_val=5.438906	eigval=31.633165
# epoch=4875	loss_val=5.4390335	eigval=31.633165
# epoch=4876	loss_val=5.4392757	eigval=31.633165
# epoch=4877	loss_val=5.439693	eigval=31.633165
# epoch=4878	loss_val=5.44041	eigval=31.633165
# epoch=4879	loss_val=5.4416285	eigval=31.633165
# epoch=4880	loss_val=5.443572	eigval=31.633165
# epoch=4881	loss_val=5.4464793	eigval=31.633165
# epoch=4882	loss_val=5.4502854	eigval=31.633165
# epoch=4883	loss_val=5.45434	eigval=31.633165
# epoch=4884	loss_val=5.456809	eigval=31.633165
# epoch=4885	loss_val=5.4556575	eigval=31.633165
# epoch=4886	loss_val=5.450746	eigval=31.633165
# epoch=4887	loss_val=5.4451156	eigval=31.633165
# epoch=4888	loss_val=5.44195	eigval=31.633165
# epoch=4889	loss_val=5.44175	eigval=31.633165
# epoch=4890	loss_val=5.442552	eigval=31.633165
# epoch=4891	loss_val=5.4426165	eigval=31.633165
# epoch=4892	loss_val=5.4419575	eigval=31.633165
# epoch=4893	loss_val=5.4417424	eigval=31.633165
# epoch=4894	loss_val=5.442455	eigval=31.633165
# epoch=4895	loss_val=5.4430947	eigval=31.633165
# epoch=4896	loss_val=5.4423747	eigval=31.633165
# epoch=4897	loss_val=5.440436	eigval=31.633165
# epoch=4898	loss_val=5.438828	eigval=31.633165
# epoch=4899	loss_val=5.4388485	eigval=31.633165
# epoch=4900	loss_val=5.440197	eigval=31.633165
# epoch=4901	loss_val=5.441427	eigval=31.633165
# epoch=4902	loss_val=5.441457	eigval=31.633165
# epoch=4903	loss_val=5.440561	eigval=31.633165
# epoch=4904	loss_val=5.4398065	eigval=31.633165
# epoch=4905	loss_val=5.439967	eigval=31.633165
# epoch=4906	loss_val=5.4409285	eigval=31.633165
# epoch=4907	loss_val=5.44204	eigval=31.633165
# epoch=4908	loss_val=5.442919	eigval=31.633165
# epoch=4909	loss_val=5.4437675	eigval=31.633165
# epoch=4910	loss_val=5.4449644	eigval=31.633165
# epoch=4911	loss_val=5.446646	eigval=31.633165
# epoch=4912	loss_val=5.448412	eigval=31.633165
# epoch=4913	loss_val=5.449903	eigval=31.633165
# epoch=4914	loss_val=5.450846	eigval=31.633165
# epoch=4915	loss_val=5.451124	eigval=31.633165
# epoch=4916	loss_val=5.4506774	eigval=31.633165
# epoch=4917	loss_val=5.449355	eigval=31.633165
# epoch=4918	loss_val=5.447187	eigval=31.633165
# epoch=4919	loss_val=5.444552	eigval=31.633165
# epoch=4920	loss_val=5.4419937	eigval=31.633165
# epoch=4921	loss_val=5.440055	eigval=31.633165
# epoch=4922	loss_val=5.439023	eigval=31.633165
# epoch=4923	loss_val=5.4387803	eigval=31.633165
# epoch=4924	loss_val=5.439075	eigval=31.633165
# epoch=4925	loss_val=5.439597	eigval=31.633165
# epoch=4926	loss_val=5.440122	eigval=31.633165
# epoch=4927	loss_val=5.440545	eigval=31.633165
# epoch=4928	loss_val=5.440777	eigval=31.633165
# epoch=4929	loss_val=5.440723	eigval=31.633165
# epoch=4930	loss_val=5.440326	eigval=31.633165
# epoch=4931	loss_val=5.4396358	eigval=31.633165
# epoch=4932	loss_val=5.438831	eigval=31.633165
# epoch=4933	loss_val=5.438137	eigval=31.633165
# epoch=4934	loss_val=5.4377155	eigval=31.633165
# epoch=4935	loss_val=5.437604	eigval=31.633165
# epoch=4936	loss_val=5.43773	eigval=31.633165
# epoch=4937	loss_val=5.4379973	eigval=31.633165
# epoch=4938	loss_val=5.438266	eigval=31.633165
# epoch=4939	loss_val=5.4384637	eigval=31.633165
# epoch=4940	loss_val=5.4385543	eigval=31.633165
# epoch=4941	loss_val=5.4384646	eigval=31.633165
# epoch=4942	loss_val=5.43821	eigval=31.633165
# epoch=4943	loss_val=5.437886	eigval=31.633165
# epoch=4944	loss_val=5.4375825	eigval=31.633165
# epoch=4945	loss_val=5.4373593	eigval=31.633165
# epoch=4946	loss_val=5.4372635	eigval=31.633165
# epoch=4947	loss_val=5.4372606	eigval=31.633165
# epoch=4948	loss_val=5.4373007	eigval=31.633165
# epoch=4949	loss_val=5.437344	eigval=31.633165
# epoch=4950	loss_val=5.43738	eigval=31.633165
# epoch=4951	loss_val=5.437399	eigval=31.633165
# epoch=4952	loss_val=5.4373894	eigval=31.633165
# epoch=4953	loss_val=5.4373574	eigval=31.633165
# epoch=4954	loss_val=5.43731	eigval=31.633165
# epoch=4955	loss_val=5.437252	eigval=31.633165
# epoch=4956	loss_val=5.4372044	eigval=31.633165
# epoch=4957	loss_val=5.4371524	eigval=31.633165
# epoch=4958	loss_val=5.437114	eigval=31.633165
# epoch=4959	loss_val=5.437069	eigval=31.633165
# epoch=4960	loss_val=5.4370337	eigval=31.633165
# epoch=4961	loss_val=5.436994	eigval=31.633165
# epoch=4962	loss_val=5.4369507	eigval=31.633165
# epoch=4963	loss_val=5.4369063	eigval=31.633165
# epoch=4964	loss_val=5.4368696	eigval=31.633165
# epoch=4965	loss_val=5.4368453	eigval=31.633165
# epoch=4966	loss_val=5.4368343	eigval=31.633165
# epoch=4967	loss_val=5.436812	eigval=31.633165
# epoch=4968	loss_val=5.4368033	eigval=31.633165
# epoch=4969	loss_val=5.436794	eigval=31.633165
# epoch=4970	loss_val=5.4367833	eigval=31.633165
# epoch=4971	loss_val=5.436778	eigval=31.633165
# epoch=4972	loss_val=5.436762	eigval=31.633165
# epoch=4973	loss_val=5.4367466	eigval=31.633165
# epoch=4974	loss_val=5.43674	eigval=31.633165
# epoch=4975	loss_val=5.4367228	eigval=31.633165
# epoch=4976	loss_val=5.436704	eigval=31.633165
# epoch=4977	loss_val=5.4366937	eigval=31.633165
# epoch=4978	loss_val=5.436674	eigval=31.633165
# epoch=4979	loss_val=5.436657	eigval=31.633165
# epoch=4980	loss_val=5.4366565	eigval=31.633165
# epoch=4981	loss_val=5.436649	eigval=31.633165
# epoch=4982	loss_val=5.436649	eigval=31.633165
# epoch=4983	loss_val=5.4366593	eigval=31.633165
# epoch=4984	loss_val=5.436667	eigval=31.633165
# epoch=4985	loss_val=5.4366837	eigval=31.633165
# epoch=4986	loss_val=5.4367166	eigval=31.633165
# epoch=4987	loss_val=5.436769	eigval=31.633165
# epoch=4988	loss_val=5.436835	eigval=31.633165
# epoch=4989	loss_val=5.4369345	eigval=31.633165
# epoch=4990	loss_val=5.437063	eigval=31.633165
# epoch=4991	loss_val=5.437247	eigval=31.633165
# epoch=4992	loss_val=5.4375052	eigval=31.633165
# epoch=4993	loss_val=5.4378467	eigval=31.633165
# epoch=4994	loss_val=5.438323	eigval=31.633165
# epoch=4995	loss_val=5.438968	eigval=31.633165
# epoch=4996	loss_val=5.439825	eigval=31.633165
# epoch=4997	loss_val=5.4409556	eigval=31.633165
# epoch=4998	loss_val=5.442444	eigval=31.633165
# epoch=4999	loss_val=5.4443207	eigval=31.633165

# %%
# predict the values at a grid of points (a mesh) so we can view predicted contour of the solution
# using the mean interpolated from trained values
import numpy as np

n = 20
ngrid = n * n
_xgrid = np.linspace(0.0, a, n)
_ygrid = np.linspace(0.0, b, n)
X, Y = np.meshgrid(_xgrid, _ygrid)
xgrid = np.reshape(X, newshape=(ngrid,1))
ygrid = np.reshape(Y, newshape=(ngrid,1))
x_grid = np.concatenate([xgrid, ygrid], axis=1)

# old non-vectorized way
# K_train = np.array([[kernel2d(x_all[i,:], x_all[j,:]) for j in range(num_all)] for i in range(num_all)])
# K_cross = np.array([[kernel2d(x_grid[i,:], x_all[j,:]) for j in range(num_all)] for i in range(ngrid)])

# vectorized way like 100x faster
K_train = kernel2d_tf(x_all_L, x_all_R)
x_grid_L = tf.expand_dims(tf.constant(x_grid, dtype=DTYPE), axis=1)
K_cross = kernel2d_tf(x_grid_L, x_all_R)

max_eigval = np.max(np.linalg.eigvalsh(K_train))
W_grid = K_cross @ np.linalg.solve(K_train + 1e-5 * max_eigval * np.eye(num_all), w_full[:num_all,:])
W = np.reshape(W_grid, newshape=(n, n))

# %%
import matplotlib.pyplot as plt
# now plot the predicted solution contour
plt.figure(figsize=(8, 6))
colors = plt.contourf(X, Y, W, levels=20, cmap='viridis', alpha=0.75)  # Filled contours
plt.gca().set_aspect('equal')
plt.colorbar(colors, label="w(x,y)")  # Colorbar for reference

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
# now plot the predicted solution surface in 3d
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, W, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=1)
ax.set_aspect('equalxy')
plt.show()
