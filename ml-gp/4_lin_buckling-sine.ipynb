# %% [markdown]
# # Linear Buckling Analysis with ML GP PDE solver
# V3 add sine kernels

# %%
# main ML inputs
# --------------
(num_interior, num_bndry, num_test) = (700, 400, 50)
# (num_interior, num_bndry, num_test) = (700, 500, 50)
# (num_interior, num_bndry, num_test) = (1000, 400, 50)
num_domain = num_interior
Lx, Ly = (0.4, 0.4)
px, py = (3, 1)
lam_scale = 1e0

num_epochs = 1000 #3000 # 5000
learning_rate = 1e-5 # 1e-5 # can be much higher here?
alpha = 1e-5 # 1e-5 # regularization constant

# %%
# panel linear static inputs
# buckling inputs
# ----------------

# aluminum plate material properties
E = 70e9; nu = 0.3; thick = 0.005
D = E * thick**3 / 12.0 / (1 - nu**2)
(a, b) = (3, 1)

axial = True
if axial:
    Nxx, Nxy, Nyy = (1e3, 0, 0)
else:
    Nxx, Nxy, Nyy = (0, 1e2, 0)

# predict the buckling load factor (BLF)
pi = 3.14159
if axial:
    pred_buckling_load = pi**2 * D / b**2 * 4.0 
    pred_load_factor = pred_buckling_load / Nxx
    sigma = 0.5 * pred_load_factor
    print(f"{pred_load_factor=}")

# corrected prediction from FEA
# lam[i]=(16.1634202010277+0j)
pred_load_factor = 16.163432
# Out:
# pred_load_factor=31.633294000320518

# %%
# compute the linear static analysis inputs and mesh domain of collocation pts
# ----------------------------------------------------------------------------
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

num_interior = num_domain
DTYPE = tf.float32

# set the boundary of the panel
xmin = 0; xmax = a
ymin = 0; ymax = b

lb = tf.constant([xmin, ymin], dtype=DTYPE)
ub = tf.constant([xmax, ymax], dtype=DTYPE)

# generate the collocation points on the interior
def gen_collocation_points(num_domain, minval, maxval):
    x_r = tf.random.uniform((num_domain,1), minval[0], maxval[0], dtype=DTYPE)
    y_r = tf.random.uniform((num_domain,1), minval[1], maxval[1], dtype=DTYPE)
    X_r = tf.concat([x_r, y_r], axis=1)
    # data_init = tf.random_uniform_initializer(minval=minval, maxval=maxval, seed=0)
    # return tf.Variable(data_init(shape=[num_domain, 1]), dtype=tf.float32)
    return tf.Variable(X_r, dtype=DTYPE)

x_train = gen_collocation_points(num_domain, lb, ub)
x_test = gen_collocation_points(num_test, lb, ub)
print(f"{type(x_train)=}")

x = x_train[:,0:1]
y = x_train[:,1:2]

x2 = x_test[:,0:1]
y2 = x_test[:,1:2]

# generate boundary domain points
assert num_bndry % 2 == 0
xb_frac = b / (a + b)
N_xb = int(xb_frac * num_bndry)
N_yb = num_bndry- N_xb
x_b1 = tf.random.uniform((N_yb,1), lb[0], ub[0], dtype=DTYPE)
y_b1 = lb[1] + (ub[1] - lb[1]) * \
    tf.keras.backend.random_bernoulli((N_yb,1), 0.5, dtype=DTYPE)
X_b1 = tf.concat([x_b1, y_b1], axis=1)

# boundary data on x edges
y_b2 = tf.random.uniform((N_xb,1), lb[1], ub[1], dtype=DTYPE)
x_b2 = lb[0] + (ub[0] - lb[0]) * \
    tf.keras.backend.random_bernoulli((N_xb,1), 0.5, dtype=DTYPE)
# print(f"{x_b2=}")
X_b2 = tf.concat([x_b2, y_b2], axis=1)
# print(f"{X_b2=}")
# print(f"{x_b2=}")

x_bndry = tf.Variable(tf.concat([X_b1, X_b2], axis=0), dtype=DTYPE)

# plot the data to check
plt.scatter(x_bndry[:,0], x_bndry[:,1])
plt.scatter(x_train[:,0], x_train[:,1]) # only show 1000 of the points
plt.gca().set_aspect('equal')
plt.show()
# Out:
# type(x_train)=<class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>

# %%
# define vectorized versions of the kernel functions
# like 1000x faster at assembling covariance functions

from _kernels._sine_kernels import *

L_tf = tf.constant(np.array([Lx, Ly]), dtype=DTYPE)
p_tf = tf.constant(np.array([px, py]), dtype=DTYPE)
def kernel2d_tf(x, xp, p, L):
    # x input is N x 1 x 2 array, xp is 1 x M x 2 array
    # xbar is then an N x M x 2 shape array
    # print(f"{x=} {L_tf=}")
    # xbar = (x - xp) / L_tf
    xbar = np.pi * (x - xp) / p
    # print(f"{xbar.shape=}")
    # output is N x M matrix of kernel matrix
    return tf.exp(tf.reduce_sum(-0.5 / L / L * tf.sin(xbar)**2, axis=-1))

def dx2_kernel_tf(x, xp, p, L):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = np.pi * (x - xp) / p
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L[0]; Ly = L[1]
    px = p[0]; py = p[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp,p,L)

    # TODO : shear or general case later (just axial now)
    return K * (d2_fact(x1bar, px, Lx))

def dy2_kernel_tf(x, xp, p, L):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = np.pi * (x - xp) / p
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L[0]; Ly = L[1]
    px = p[0]; py = p[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp,p,L)
    return K * (d2_fact(x2bar, py, Ly))

def doubledx2_kernel_tf(x, xp, p, L):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = np.pi * (x - xp) / p
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L[0]; Ly = L[1]
    px = p[0]; py = p[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp,p,L)

    # TODO : shear or general case later (just axial now)
    return K * (d4_fact(x1bar, px, Lx))

def doubledy2_kernel_tf(x, xp, p, L):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = np.pi * (x - xp) / p
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L[0]; Ly = L[1]
    px = p[0]; py = p[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp,p,L)
    return K * (d4_fact(x2bar, py, Ly))

def kernel2d_bilapl_tf(x, xp, p, L):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = np.pi * (x - xp) / p
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L[0]; Ly = L[1]
    px = p[0]; py = p[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp,p,L)

    return K * (d4_fact(x1bar,px, Lx) + 2.0 * d2_fact(x1bar, px, Lx) * d2_fact(x2bar, py, Ly) + d4_fact(x2bar, py, Ly))

def kernel2d_double_bilapl_tf(x, xp, p, L):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = np.pi * (x - xp) / p
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L[0]; Ly = L[1]
    px = p[0]; py = p[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp,p,L)

    return K * (d8_fact(x1bar,px,Lx) + \
                4.0 * d6_fact(x1bar, px, Lx) * d2_fact(x2bar, py, Ly) +\
                6.0 * d4_fact(x1bar, px, Lx) * d4_fact(x2bar, py, Ly) +\
                4.0 * d2_fact(x1bar, px, Lx) * d6_fact(x2bar, py, Ly) +\
                d8_fact(x2bar, py, Ly))

def dx2_bilapl_kernel_tf(x, xp, p, L):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = np.pi * (x - xp) / p
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L[0]; Ly = L[1]
    px = p[0]; py = p[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp,p,L)

    # TODO : shear or general case later (just axial now)
    return K * \
        (d6_fact(x1bar,px,Lx) + 2.0 * d4_fact(x1bar,px,Lx) * d2_fact(x2bar, py,Ly) + d2_fact(x1bar,px,Lx) * d4_fact(x2bar,py,Ly))

def dy2_bilapl_kernel_tf(x, xp, p, L):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = np.pi * (x - xp) / p
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L[0]; Ly = L[1]
    px = p[0]; py = p[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp,p,L)
    return K * \
        (d4_fact(x1bar,px,Lx) * d2_fact(x2bar,py,Ly) + 2.0 * d2_fact(x1bar,px,Lx) * d4_fact(x2bar,py,Ly) + d6_fact(x2bar,py,Ly))

def dx2_dy2_kernel_tf(x, xp, p, L):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = np.pi * (x - xp) / p
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = L[0]; Ly = L[1]
    px = p[0]; py = p[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp,p,L)
    return K * d2_fact(x1bar,px,Lx) * d2_fact(x2bar,py,Ly)

# %%
# compute the block matrix Sigma = [cov(w_int, w_int), cov(w_int, w_bndry), cov(w_int, nabla^4 w_int),
#                                   cov(w_bndry, w_int), cov(w_bndry, w_bndry), cov(w_bndry, nabla^4 w_bndry),
#                                   cov(nabla^4 w_int, w_int), cov(nabla^4 w_int, w_bndry), cov(nabla^4 w_int, nabla^4 w_int) ]
# not a function of theta..
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

n_block = 3 * num_interior + 3 * num_bndry
x_all = tf.concat([x_train, x_bndry], axis=0)
num_all = num_interior + num_bndry

# components of the multivariate GP
# 1 - w at interior and bndry points
# 2 - d^2w/dx^2 at interior and bndry points
# 3 - d^2w/dy^2 at bndry points
# 4 - nabla^4 w at interior points

# 11 - interior+bndry self-covariance
x_all_L = tf.expand_dims(x_all, axis=1)
x_all_R = tf.expand_dims(x_all, axis=0)
K11 = tf.constant(kernel2d_tf(x_all_L, x_all_R, p_tf, L_tf), dtype=DTYPE)

x_interior_L = tf.expand_dims(x_train, axis=1)
x_interior_R = tf.expand_dims(x_train, axis=0)
x_bndry_L = tf.expand_dims(x_bndry, axis=1)
x_bndry_R = tf.expand_dims(x_bndry, axis=0)

# 12 - w with dx2
K12 = tf.constant(dx2_kernel_tf(x_all_L, x_all_R, p_tf, L_tf))
# 13 - w with dy2
K13 = tf.constant(dy2_kernel_tf(x_all_L, x_bndry_R, p_tf, L_tf))
# 14 - w with nabla^4 w
K14 = tf.constant(kernel2d_bilapl_tf(x_all_L, x_interior_R, p_tf, L_tf))
# 22 - dx2 with dx2
K22 = tf.constant(doubledx2_kernel_tf(x_all_L, x_all_R, p_tf, L_tf))
# 23 - dx2 with dy2
K23 = tf.constant(dx2_dy2_kernel_tf(x_all_L, x_bndry_R, p_tf, L_tf))
# 24 - dx2 with nabla^4 w
K24 = tf.constant(dx2_bilapl_kernel_tf(x_all_L, x_interior_R, p_tf, L_tf))
# 33 - dy2 with dy2
K33 = tf.constant(doubledy2_kernel_tf(x_bndry_L, x_bndry_R, p_tf, L_tf))
# 34 - dy2 with nabla^4 w
K34 = tf.constant(dy2_bilapl_kernel_tf(x_bndry_L, x_interior_R, p_tf, L_tf))
# 44 - nabla^4 w with itself
K44 = tf.constant(kernel2d_double_bilapl_tf(x_interior_L, x_interior_R, p_tf, L_tf))

print(f"{num_interior=} {num_all=}")
# print(f"{K11.shape=} {K12.shape=} {K22.shape=}")
# print(f"{K13.shape=} {K23.shape=} {K33.shape=}")

# assemble full covariance matrix
_row1 = tf.constant(tf.concat([K11, K12, K13, K14], axis=1))
_row2 = tf.constant(tf.concat([tf.transpose(K12), K22, K23, K24], axis=1))
_row3 = tf.constant(tf.concat([tf.transpose(K13), tf.transpose(K23), K33, K34], axis=1))
_row4 = tf.constant(tf.concat([tf.transpose(K14), tf.transpose(K24), tf.transpose(K34), K44], axis=1))
Kblock_prereg = tf.concat([_row1, _row2, _row3, _row4], axis=0)

print(f"done with full matrix assembly..")

# apply robust regularization w.r.t. the max eigenvalue, namely we add epsilon * I term to matrix
# where epsilon = alpha * lambda_max
# alpha = 1e-5
# alpha = 1e-3
eigvals = np.linalg.eigvalsh(Kblock_prereg)
min_eigval = np.min(eigvals)
max_eigval = np.max(eigvals)
print(f"{min_eigval=} {max_eigval=}")
eps = alpha * max_eigval

print("done with eigenvalues solve")

Kblock = tf.constant(Kblock_prereg + eps * tf.eye(n_block), dtype=DTYPE)

# double check eigvals again
# print("double check eivals again--")
# eigvals = np.linalg.eigvalsh(Kblock)
# min_eigval = np.min(eigvals)
# max_eigval = np.max(eigvals)
# print(f"{min_eigval=} {max_eigval=}")

# show the matrix image to see if positive definite roughly
plt.imshow(Kblock)
plt.colorbar()
# Out:
# num_interior=700 num_all=1100
# done with full matrix assembly..
# min_eigval=-11144.577 max_eigval=160778670000.0
# done with eigenvalues solve

# %%
# define GP vectors and factor cov matrix into LU
# -----------------------------------------------

# setup lambda as trainable parameter too
# lam = tf.Variable(pred_load_factor, trainable=True, dtype=DTYPE)

K_lu = tf.linalg.lu(Kblock)

w_ext = tf.zeros(shape=(num_bndry,1), dtype=DTYPE)
# now theta includes the w int points and Gw interior points and also lam
# theta_arr = tf.zeros(shape=(num_domain * 2 + 1,1), dtype=DTYPE)
# theta_arr = np.random.rand(2 * num_domain + 1, 1)
# theta_arr = tf.ones(shape=(num_domain * 2 + 1, 1), dtype=DTYPE)

dx2_ext = w_ext * 0.0
dy2_ext = w_ext * 0.0

# theta sets [w_int, dx2_w_int, lam]
theta_arr = np.zeros(shape=(2 * num_domain + 1,1))
theta_arr[-1,0] = pred_load_factor * lam_scale # set lam init

init_scale = 1e0 # 1e-3

# pick one of points nearest the middle a/2, b/2
left_dist = (x_train[:,0] - a/6.0)**2 + (x_train[:,1] - b/2.0)**2
ind = tf.argmin(left_dist)
theta_arr[ind,0] = -1.0 * init_scale

left_dist = (x_train[:,0] - 5.0 * a/6.0)**2 + (x_train[:,1] - b/2.0)**2
ind = tf.argmin(left_dist)
theta_arr[ind,0] = -1.0 * init_scale

cent_dist = (x_train[:,0] - a/2.0)**2 + (x_train[:,1] - b/2.0)**2
ind = tf.argmin(cent_dist)
theta_arr[ind,0] = 1.0 * init_scale # set init value of w somewhere so not 0 norm

# [5,0] = 1.0 # best to choose some middle point as the only nonzero part?
theta = tf.Variable(theta_arr, trainable=True, dtype=DTYPE)

# print(f"{w_ext.shape=}")
# nabla4_w = 
# nabla4_w2 = tf.reshape(nabla4_w, shape=(num_domain,1))
# print(f"{nabla4_w2.shape=}")

# _temp = tf.concat([w_ext, nabla4_w2], axis=0)
# fixed_vec = tf.constant(_temp, dtype=DTYPE)

# %%
# define our optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# %%
num_epochs = 3000

for epoch in range(num_epochs):
    # record the loss gradient
    with tf.GradientTape(persistent=True) as tape:
        # construct full GP f vector
        w_int = theta[:num_interior]
        dx2_int = theta[num_interior:-1]
        lam = theta[-1]
        # lam = pred_load_factor # try constant for a minute
        # lam = 8.0
        nabla4_w = -lam / lam_scale / D * Nxx * dx2_int
        # nabla4_w = -lam / D * Nxx * dx2_int
        w_full = tf.concat([w_int, w_ext, dx2_int, dx2_ext, dy2_ext, nabla4_w], axis=0)

        # normalize w_full by w_norm to prevent trivial soln in buckling analysis
        w_norm = tf.linalg.norm(w_int) + 1e-12
        # w_full_hat = w_full / w_norm
        w_full_hat = w_full

        # print(f"{w_full=}")
        ans = tf.linalg.lu_solve(*K_lu, rhs=w_full_hat)
        # print(f"{ans=}")

        loss = tf.tensordot(tf.transpose(w_full_hat), ans, axes=1)
        loss *= 1e6 # 1e3

        loss += tf.nn.relu(-tf.math.log(w_norm))

        # add norm regularization term to prevent trivial soln (since buckling trivial w = 0 soln is technically a soln, but not one we care about)
        # this didn't work very well => just focuses on this term not PDE solving
        # loss += (w_norm - 1)**2 # * 1e4
        # # loss *= 1e3 # *= D

    loss_gradient = tape.gradient(loss, theta)
    loss_gradient = tf.clip_by_value(loss_gradient, -1.0, 1.0)  # Gradient clipping
    # print(f"{loss_gradient=}")

    # could change to Gauss-newton algorithm here instead.. would prob be better

    # gradient descent with adam optimizer
    optimizer.apply_gradients(
        [(loss_gradient, theta)]
    )
    del tape

    loss_val = loss.numpy()[0,0]
    eigval = lam.numpy()[0] #/ lam_scale
    print(f"{epoch=}\t{loss_val=}\t{eigval=}")

# print(f"{theta=}")
# Out:
# epoch=0	loss_val=1.6113671	eigval=16.162489
# epoch=1	loss_val=1.611332	eigval=16.162489
# epoch=2	loss_val=1.6112972	eigval=16.162489
# epoch=3	loss_val=1.6112624	eigval=16.162489
# epoch=4	loss_val=1.6112273	eigval=16.162489
# epoch=5	loss_val=1.6111925	eigval=16.162489
# epoch=6	loss_val=1.6111575	eigval=16.162489
# epoch=7	loss_val=1.6111227	eigval=16.162489
# epoch=8	loss_val=1.6110877	eigval=16.162489
# epoch=9	loss_val=1.6110526	eigval=16.162489
# epoch=10	loss_val=1.6110178	eigval=16.162489
# epoch=11	loss_val=1.6109829	eigval=16.162489
# epoch=12	loss_val=1.610948	eigval=16.162489
# epoch=13	loss_val=1.610913	eigval=16.162489
# epoch=14	loss_val=1.610878	eigval=16.162489
# epoch=15	loss_val=1.6108433	eigval=16.162489
# epoch=16	loss_val=1.6108083	eigval=16.162489
# epoch=17	loss_val=1.6107733	eigval=16.162489
# epoch=18	loss_val=1.6107384	eigval=16.162489
# epoch=19	loss_val=1.6107033	eigval=16.162489
# epoch=20	loss_val=1.6106685	eigval=16.162489
# epoch=21	loss_val=1.6106336	eigval=16.162489
# epoch=22	loss_val=1.6105986	eigval=16.162489
# epoch=23	loss_val=1.6105638	eigval=16.162489
# epoch=24	loss_val=1.6105287	eigval=16.162489
# epoch=25	loss_val=1.6104939	eigval=16.162489
# epoch=26	loss_val=1.6104589	eigval=16.162489
# epoch=27	loss_val=1.610424	eigval=16.162489
# epoch=28	loss_val=1.6103891	eigval=16.162489
# epoch=29	loss_val=1.6103543	eigval=16.162489
# epoch=30	loss_val=1.6103193	eigval=16.162489
# epoch=31	loss_val=1.6102843	eigval=16.162489
# epoch=32	loss_val=1.6102494	eigval=16.162489
# epoch=33	loss_val=1.6102146	eigval=16.162489
# epoch=34	loss_val=1.6101795	eigval=16.162489
# epoch=35	loss_val=1.6101447	eigval=16.162489
# epoch=36	loss_val=1.6101098	eigval=16.162489
# epoch=37	loss_val=1.610075	eigval=16.162489
# epoch=38	loss_val=1.61004	eigval=16.162489
# epoch=39	loss_val=1.610005	eigval=16.162489
# epoch=40	loss_val=1.60997	eigval=16.162489
# epoch=41	loss_val=1.6099352	eigval=16.162489
# epoch=42	loss_val=1.6099002	eigval=16.162489
# epoch=43	loss_val=1.6098653	eigval=16.162489
# epoch=44	loss_val=1.6098303	eigval=16.162489
# epoch=45	loss_val=1.6097953	eigval=16.162489
# epoch=46	loss_val=1.6097606	eigval=16.162489
# epoch=47	loss_val=1.6097256	eigval=16.162489
# epoch=48	loss_val=1.6096908	eigval=16.162489
# epoch=49	loss_val=1.6096559	eigval=16.162489
# epoch=50	loss_val=1.6096209	eigval=16.162489
# epoch=51	loss_val=1.609586	eigval=16.162489
# epoch=52	loss_val=1.6095511	eigval=16.162489
# epoch=53	loss_val=1.6095163	eigval=16.162489
# epoch=54	loss_val=1.6094812	eigval=16.162489
# epoch=55	loss_val=1.6094465	eigval=16.162489
# epoch=56	loss_val=1.6094115	eigval=16.162489
# epoch=57	loss_val=1.6093765	eigval=16.162489
# epoch=58	loss_val=1.6093416	eigval=16.162489
# epoch=59	loss_val=1.6093068	eigval=16.162489
# epoch=60	loss_val=1.6092718	eigval=16.162489
# epoch=61	loss_val=1.609237	eigval=16.162489
# epoch=62	loss_val=1.609202	eigval=16.162489
# epoch=63	loss_val=1.6091671	eigval=16.162489
# epoch=64	loss_val=1.6091322	eigval=16.162489
# epoch=65	loss_val=1.6090974	eigval=16.162489
# epoch=66	loss_val=1.6090624	eigval=16.162489
# epoch=67	loss_val=1.6090274	eigval=16.162489
# epoch=68	loss_val=1.6089927	eigval=16.162489
# epoch=69	loss_val=1.6089576	eigval=16.162489
# epoch=70	loss_val=1.6089227	eigval=16.162489
# epoch=71	loss_val=1.6088878	eigval=16.162489
# epoch=72	loss_val=1.6088529	eigval=16.162489
# epoch=73	loss_val=1.6088179	eigval=16.162489
# epoch=74	loss_val=1.6087831	eigval=16.162489
# epoch=75	loss_val=1.6087481	eigval=16.162489
# epoch=76	loss_val=1.6087133	eigval=16.162489
# epoch=77	loss_val=1.6086785	eigval=16.162489
# epoch=78	loss_val=1.6086434	eigval=16.162489
# epoch=79	loss_val=1.6086086	eigval=16.162489
# epoch=80	loss_val=1.6085737	eigval=16.162489
# epoch=81	loss_val=1.6085387	eigval=16.162489
# epoch=82	loss_val=1.6085039	eigval=16.162489
# epoch=83	loss_val=1.608469	eigval=16.162489
# epoch=84	loss_val=1.608434	eigval=16.162489
# epoch=85	loss_val=1.608399	eigval=16.162489
# epoch=86	loss_val=1.6083643	eigval=16.162489
# epoch=87	loss_val=1.6083293	eigval=16.162489
# epoch=88	loss_val=1.6082944	eigval=16.162489
# epoch=89	loss_val=1.6082596	eigval=16.162489
# epoch=90	loss_val=1.6082247	eigval=16.162489
# epoch=91	loss_val=1.6081898	eigval=16.162489
# epoch=92	loss_val=1.6081549	eigval=16.162489
# epoch=93	loss_val=1.6081198	eigval=16.162489
# epoch=94	loss_val=1.608085	eigval=16.162489
# epoch=95	loss_val=1.6080502	eigval=16.162489
# epoch=96	loss_val=1.6080154	eigval=16.162489
# epoch=97	loss_val=1.6079804	eigval=16.162489
# epoch=98	loss_val=1.6079456	eigval=16.162489
# epoch=99	loss_val=1.6079106	eigval=16.162489
# epoch=100	loss_val=1.6078757	eigval=16.162489
# epoch=101	loss_val=1.6078408	eigval=16.162489
# epoch=102	loss_val=1.6078058	eigval=16.162489
# epoch=103	loss_val=1.6077709	eigval=16.162489
# epoch=104	loss_val=1.6077361	eigval=16.162489
# epoch=105	loss_val=1.6077013	eigval=16.162489
# epoch=106	loss_val=1.6076663	eigval=16.162489
# epoch=107	loss_val=1.6076314	eigval=16.162489
# epoch=108	loss_val=1.6075965	eigval=16.162489
# epoch=109	loss_val=1.6075616	eigval=16.162489
# epoch=110	loss_val=1.6075268	eigval=16.162489
# epoch=111	loss_val=1.6074919	eigval=16.162489
# epoch=112	loss_val=1.6074569	eigval=16.162489
# epoch=113	loss_val=1.6074221	eigval=16.162489
# epoch=114	loss_val=1.6073872	eigval=16.162489
# epoch=115	loss_val=1.6073523	eigval=16.162489
# epoch=116	loss_val=1.6073174	eigval=16.162489
# epoch=117	loss_val=1.6072825	eigval=16.162489
# epoch=118	loss_val=1.6072477	eigval=16.162489
# epoch=119	loss_val=1.6072127	eigval=16.162489
# epoch=120	loss_val=1.6071779	eigval=16.162489
# epoch=121	loss_val=1.6071429	eigval=16.162489
# epoch=122	loss_val=1.607108	eigval=16.162489
# epoch=123	loss_val=1.6070732	eigval=16.162489
# epoch=124	loss_val=1.6070383	eigval=16.162489
# epoch=125	loss_val=1.6070033	eigval=16.162489
# epoch=126	loss_val=1.6069685	eigval=16.162489
# epoch=127	loss_val=1.6069337	eigval=16.162489
# epoch=128	loss_val=1.6068988	eigval=16.162489
# epoch=129	loss_val=1.606864	eigval=16.162489
# epoch=130	loss_val=1.6068289	eigval=16.162489
# epoch=131	loss_val=1.6067941	eigval=16.162489
# epoch=132	loss_val=1.6067593	eigval=16.162489
# epoch=133	loss_val=1.6067245	eigval=16.162489
# epoch=134	loss_val=1.6066895	eigval=16.162489
# epoch=135	loss_val=1.6066544	eigval=16.162489
# epoch=136	loss_val=1.6066198	eigval=16.162489
# epoch=137	loss_val=1.6065848	eigval=16.162489
# epoch=138	loss_val=1.60655	eigval=16.162489
# epoch=139	loss_val=1.606515	eigval=16.162489
# epoch=140	loss_val=1.6064801	eigval=16.162489
# epoch=141	loss_val=1.6064452	eigval=16.162489
# epoch=142	loss_val=1.6064104	eigval=16.162489
# epoch=143	loss_val=1.6063755	eigval=16.162489
# epoch=144	loss_val=1.6063405	eigval=16.162489
# epoch=145	loss_val=1.6063058	eigval=16.162489
# epoch=146	loss_val=1.6062708	eigval=16.162489
# epoch=147	loss_val=1.606236	eigval=16.162489
# epoch=148	loss_val=1.6062012	eigval=16.162489
# epoch=149	loss_val=1.6061662	eigval=16.162489
# epoch=150	loss_val=1.6061314	eigval=16.162489
# epoch=151	loss_val=1.6060965	eigval=16.162489
# epoch=152	loss_val=1.6060616	eigval=16.162489
# epoch=153	loss_val=1.6060268	eigval=16.162489
# epoch=154	loss_val=1.605992	eigval=16.162489
# epoch=155	loss_val=1.605957	eigval=16.162489
# epoch=156	loss_val=1.6059222	eigval=16.162489
# epoch=157	loss_val=1.6058872	eigval=16.162489
# epoch=158	loss_val=1.6058522	eigval=16.162489
# epoch=159	loss_val=1.6058174	eigval=16.162489
# epoch=160	loss_val=1.6057826	eigval=16.162489
# epoch=161	loss_val=1.6057478	eigval=16.162489
# epoch=162	loss_val=1.6057129	eigval=16.162489
# epoch=163	loss_val=1.605678	eigval=16.162489
# epoch=164	loss_val=1.605643	eigval=16.162489
# epoch=165	loss_val=1.6056083	eigval=16.162489
# epoch=166	loss_val=1.6055734	eigval=16.162489
# epoch=167	loss_val=1.6055385	eigval=16.162489
# epoch=168	loss_val=1.6055036	eigval=16.162489
# epoch=169	loss_val=1.6054689	eigval=16.162489
# epoch=170	loss_val=1.6054341	eigval=16.162489
# epoch=171	loss_val=1.605399	eigval=16.162489
# epoch=172	loss_val=1.6053642	eigval=16.162489
# epoch=173	loss_val=1.6053293	eigval=16.162489
# epoch=174	loss_val=1.6052946	eigval=16.162489
# epoch=175	loss_val=1.6052597	eigval=16.162489
# epoch=176	loss_val=1.6052246	eigval=16.162489
# epoch=177	loss_val=1.6051898	eigval=16.162489
# epoch=178	loss_val=1.6051549	eigval=16.162489
# epoch=179	loss_val=1.6051202	eigval=16.162489
# epoch=180	loss_val=1.6050854	eigval=16.162489
# epoch=181	loss_val=1.6050504	eigval=16.162489
# epoch=182	loss_val=1.6050154	eigval=16.162489
# epoch=183	loss_val=1.6049806	eigval=16.162489
# epoch=184	loss_val=1.6049459	eigval=16.162489
# epoch=185	loss_val=1.604911	eigval=16.162489
# epoch=186	loss_val=1.604876	eigval=16.162489
# epoch=187	loss_val=1.6048412	eigval=16.162489
# epoch=188	loss_val=1.6048063	eigval=16.162489
# epoch=189	loss_val=1.6047715	eigval=16.162489
# epoch=190	loss_val=1.6047366	eigval=16.162489
# epoch=191	loss_val=1.6047018	eigval=16.162489
# epoch=192	loss_val=1.604667	eigval=16.162489
# epoch=193	loss_val=1.604632	eigval=16.162489
# epoch=194	loss_val=1.6045973	eigval=16.162489
# epoch=195	loss_val=1.6045623	eigval=16.162489
# epoch=196	loss_val=1.6045275	eigval=16.162489
# epoch=197	loss_val=1.6044927	eigval=16.162489
# epoch=198	loss_val=1.6044577	eigval=16.162489
# epoch=199	loss_val=1.604423	eigval=16.162489
# epoch=200	loss_val=1.604388	eigval=16.162489
# epoch=201	loss_val=1.6043531	eigval=16.162489
# epoch=202	loss_val=1.6043184	eigval=16.162489
# epoch=203	loss_val=1.6042835	eigval=16.162489
# epoch=204	loss_val=1.6042485	eigval=16.162489
# epoch=205	loss_val=1.6042137	eigval=16.162489
# epoch=206	loss_val=1.6041789	eigval=16.162489
# epoch=207	loss_val=1.604144	eigval=16.162489
# epoch=208	loss_val=1.6041093	eigval=16.162489
# epoch=209	loss_val=1.6040742	eigval=16.162489
# epoch=210	loss_val=1.6040394	eigval=16.162489
# epoch=211	loss_val=1.6040046	eigval=16.162489
# epoch=212	loss_val=1.6039697	eigval=16.162489
# epoch=213	loss_val=1.603935	eigval=16.162489
# epoch=214	loss_val=1.6039001	eigval=16.162489
# epoch=215	loss_val=1.6038651	eigval=16.162489
# epoch=216	loss_val=1.6038303	eigval=16.162489
# epoch=217	loss_val=1.6037954	eigval=16.162489
# epoch=218	loss_val=1.6037607	eigval=16.162489
# epoch=219	loss_val=1.6037258	eigval=16.162489
# epoch=220	loss_val=1.603691	eigval=16.162489
# epoch=221	loss_val=1.603656	eigval=16.162489
# epoch=222	loss_val=1.6036211	eigval=16.162489
# epoch=223	loss_val=1.6035864	eigval=16.162489
# epoch=224	loss_val=1.6035515	eigval=16.162489
# epoch=225	loss_val=1.6035167	eigval=16.162489
# epoch=226	loss_val=1.6034819	eigval=16.162489
# epoch=227	loss_val=1.603447	eigval=16.162489
# epoch=228	loss_val=1.6034123	eigval=16.162489
# epoch=229	loss_val=1.6033773	eigval=16.162489
# epoch=230	loss_val=1.6033423	eigval=16.162489
# epoch=231	loss_val=1.6033075	eigval=16.162489
# epoch=232	loss_val=1.6032727	eigval=16.162489
# epoch=233	loss_val=1.6032379	eigval=16.162489
# epoch=234	loss_val=1.603203	eigval=16.162489
# epoch=235	loss_val=1.6031682	eigval=16.162489
# epoch=236	loss_val=1.6031334	eigval=16.162489
# epoch=237	loss_val=1.6030986	eigval=16.162489
# epoch=238	loss_val=1.6030637	eigval=16.162489
# epoch=239	loss_val=1.6030289	eigval=16.162489
# epoch=240	loss_val=1.602994	eigval=16.162489
# epoch=241	loss_val=1.6029593	eigval=16.162489
# epoch=242	loss_val=1.6029243	eigval=16.162489
# epoch=243	loss_val=1.6028895	eigval=16.162489
# epoch=244	loss_val=1.6028547	eigval=16.162489
# epoch=245	loss_val=1.6028198	eigval=16.162489
# epoch=246	loss_val=1.6027849	eigval=16.162489
# epoch=247	loss_val=1.6027501	eigval=16.162489
# epoch=248	loss_val=1.6027154	eigval=16.162489
# epoch=249	loss_val=1.6026804	eigval=16.162489
# epoch=250	loss_val=1.6026455	eigval=16.162489
# epoch=251	loss_val=1.6026107	eigval=16.162489
# epoch=252	loss_val=1.6025759	eigval=16.162489
# epoch=253	loss_val=1.6025411	eigval=16.162489
# epoch=254	loss_val=1.6025063	eigval=16.162489
# epoch=255	loss_val=1.6024715	eigval=16.162489
# epoch=256	loss_val=1.6024367	eigval=16.162489
# epoch=257	loss_val=1.6024017	eigval=16.162489
# epoch=258	loss_val=1.6023669	eigval=16.162489
# epoch=259	loss_val=1.6023321	eigval=16.162489
# epoch=260	loss_val=1.6022973	eigval=16.162489
# epoch=261	loss_val=1.6022625	eigval=16.162489
# epoch=262	loss_val=1.6022276	eigval=16.162489
# epoch=263	loss_val=1.6021928	eigval=16.162489
# epoch=264	loss_val=1.602158	eigval=16.162489
# epoch=265	loss_val=1.6021231	eigval=16.162489
# epoch=266	loss_val=1.6020882	eigval=16.162489
# epoch=267	loss_val=1.6020533	eigval=16.162489
# epoch=268	loss_val=1.6020185	eigval=16.162489
# epoch=269	loss_val=1.6019838	eigval=16.162489
# epoch=270	loss_val=1.6019489	eigval=16.162489
# epoch=271	loss_val=1.6019142	eigval=16.162489
# epoch=272	loss_val=1.6018794	eigval=16.162489
# epoch=273	loss_val=1.6018444	eigval=16.162489
# epoch=274	loss_val=1.6018097	eigval=16.162489
# epoch=275	loss_val=1.6017748	eigval=16.162489
# epoch=276	loss_val=1.6017399	eigval=16.162489
# epoch=277	loss_val=1.601705	eigval=16.162489
# epoch=278	loss_val=1.6016703	eigval=16.162489
# epoch=279	loss_val=1.6016356	eigval=16.162489
# epoch=280	loss_val=1.6016008	eigval=16.162489
# epoch=281	loss_val=1.6015658	eigval=16.162489
# epoch=282	loss_val=1.6015309	eigval=16.162489
# epoch=283	loss_val=1.6014961	eigval=16.162489
# epoch=284	loss_val=1.6014613	eigval=16.162489
# epoch=285	loss_val=1.6014266	eigval=16.162489
# epoch=286	loss_val=1.6013918	eigval=16.162489
# epoch=287	loss_val=1.6013569	eigval=16.162489
# epoch=288	loss_val=1.6013219	eigval=16.162489
# epoch=289	loss_val=1.6012871	eigval=16.162489
# epoch=290	loss_val=1.6012523	eigval=16.162489
# epoch=291	loss_val=1.6012175	eigval=16.162489
# epoch=292	loss_val=1.6011827	eigval=16.162489
# epoch=293	loss_val=1.6011478	eigval=16.162489
# epoch=294	loss_val=1.6011131	eigval=16.162489
# epoch=295	loss_val=1.6010784	eigval=16.162489
# epoch=296	loss_val=1.6010435	eigval=16.162489
# epoch=297	loss_val=1.6010084	eigval=16.162489
# epoch=298	loss_val=1.6009738	eigval=16.162489
# epoch=299	loss_val=1.6009389	eigval=16.162489
# epoch=300	loss_val=1.6009041	eigval=16.162489
# epoch=301	loss_val=1.6008693	eigval=16.162489
# epoch=302	loss_val=1.6008345	eigval=16.162489
# epoch=303	loss_val=1.6007997	eigval=16.162489
# epoch=304	loss_val=1.6007648	eigval=16.162489
# epoch=305	loss_val=1.60073	eigval=16.162489
# epoch=306	loss_val=1.6006954	eigval=16.162489
# epoch=307	loss_val=1.6006606	eigval=16.162489
# epoch=308	loss_val=1.6006256	eigval=16.162489
# epoch=309	loss_val=1.6005908	eigval=16.162489
# epoch=310	loss_val=1.600556	eigval=16.162489
# epoch=311	loss_val=1.6005211	eigval=16.162489
# epoch=312	loss_val=1.6004864	eigval=16.162489
# epoch=313	loss_val=1.6004516	eigval=16.162489
# epoch=314	loss_val=1.6004168	eigval=16.162489
# epoch=315	loss_val=1.6003817	eigval=16.162489
# epoch=316	loss_val=1.6003472	eigval=16.162489
# epoch=317	loss_val=1.6003122	eigval=16.162489
# epoch=318	loss_val=1.6002774	eigval=16.162489
# epoch=319	loss_val=1.6002426	eigval=16.162489
# epoch=320	loss_val=1.6002078	eigval=16.162489
# epoch=321	loss_val=1.600173	eigval=16.162489
# epoch=322	loss_val=1.6001383	eigval=16.162489
# epoch=323	loss_val=1.6001035	eigval=16.162489
# epoch=324	loss_val=1.6000687	eigval=16.162489
# epoch=325	loss_val=1.6000338	eigval=16.162489
# epoch=326	loss_val=1.5999988	eigval=16.162489
# epoch=327	loss_val=1.5999644	eigval=16.162489
# epoch=328	loss_val=1.5999293	eigval=16.162489
# epoch=329	loss_val=1.5998945	eigval=16.162489
# epoch=330	loss_val=1.5998597	eigval=16.162489
# epoch=331	loss_val=1.5998249	eigval=16.162489
# epoch=332	loss_val=1.5997901	eigval=16.162489
# epoch=333	loss_val=1.5997553	eigval=16.162489
# epoch=334	loss_val=1.5997205	eigval=16.162489
# epoch=335	loss_val=1.5996857	eigval=16.162489
# epoch=336	loss_val=1.5996507	eigval=16.162489
# epoch=337	loss_val=1.599616	eigval=16.162489
# epoch=338	loss_val=1.5995814	eigval=16.162489
# epoch=339	loss_val=1.5995464	eigval=16.162489
# epoch=340	loss_val=1.5995117	eigval=16.162489
# epoch=341	loss_val=1.5994769	eigval=16.162489
# epoch=342	loss_val=1.5994419	eigval=16.162489
# epoch=343	loss_val=1.5994072	eigval=16.162489
# epoch=344	loss_val=1.5993724	eigval=16.162489
# epoch=345	loss_val=1.5993377	eigval=16.162489
# epoch=346	loss_val=1.5993029	eigval=16.162489
# epoch=347	loss_val=1.5992681	eigval=16.162489
# epoch=348	loss_val=1.5992333	eigval=16.162489
# epoch=349	loss_val=1.5991985	eigval=16.162489
# epoch=350	loss_val=1.5991637	eigval=16.162489
# epoch=351	loss_val=1.5991288	eigval=16.162489
# epoch=352	loss_val=1.599094	eigval=16.162489
# epoch=353	loss_val=1.5990591	eigval=16.162489
# epoch=354	loss_val=1.5990244	eigval=16.162489
# epoch=355	loss_val=1.5989897	eigval=16.162489
# epoch=356	loss_val=1.5989549	eigval=16.162489
# epoch=357	loss_val=1.5989201	eigval=16.162489
# epoch=358	loss_val=1.5988853	eigval=16.162489
# epoch=359	loss_val=1.5988504	eigval=16.162489
# epoch=360	loss_val=1.5988158	eigval=16.162489
# epoch=361	loss_val=1.5987809	eigval=16.162489
# epoch=362	loss_val=1.5987461	eigval=16.162489
# epoch=363	loss_val=1.5987113	eigval=16.162489
# epoch=364	loss_val=1.5986764	eigval=16.162489
# epoch=365	loss_val=1.5986416	eigval=16.162489
# epoch=366	loss_val=1.598607	eigval=16.162489
# epoch=367	loss_val=1.5985721	eigval=16.162489
# epoch=368	loss_val=1.5985373	eigval=16.162489
# epoch=369	loss_val=1.5985025	eigval=16.162489
# epoch=370	loss_val=1.5984676	eigval=16.162489
# epoch=371	loss_val=1.5984329	eigval=16.162489
# epoch=372	loss_val=1.5983981	eigval=16.162489
# epoch=373	loss_val=1.5983634	eigval=16.162489
# epoch=374	loss_val=1.5983286	eigval=16.162489
# epoch=375	loss_val=1.5982935	eigval=16.162489
# epoch=376	loss_val=1.5982587	eigval=16.162489
# epoch=377	loss_val=1.5982243	eigval=16.162489
# epoch=378	loss_val=1.5981894	eigval=16.162489
# epoch=379	loss_val=1.5981547	eigval=16.162489
# epoch=380	loss_val=1.5981199	eigval=16.162489
# epoch=381	loss_val=1.5980849	eigval=16.162489
# epoch=382	loss_val=1.5980502	eigval=16.162489
# epoch=383	loss_val=1.5980154	eigval=16.162489
# epoch=384	loss_val=1.5979806	eigval=16.162489
# epoch=385	loss_val=1.5979458	eigval=16.162489
# epoch=386	loss_val=1.5979111	eigval=16.162489
# epoch=387	loss_val=1.5978762	eigval=16.162489
# epoch=388	loss_val=1.5978415	eigval=16.162489
# epoch=389	loss_val=1.5978068	eigval=16.162489
# epoch=390	loss_val=1.597772	eigval=16.162489
# epoch=391	loss_val=1.5977371	eigval=16.162489
# epoch=392	loss_val=1.5977024	eigval=16.162489
# epoch=393	loss_val=1.5976673	eigval=16.162489
# epoch=394	loss_val=1.5976329	eigval=16.162489
# epoch=395	loss_val=1.5975981	eigval=16.162489
# epoch=396	loss_val=1.5975631	eigval=16.162489
# epoch=397	loss_val=1.5975285	eigval=16.162489
# epoch=398	loss_val=1.5974936	eigval=16.162489
# epoch=399	loss_val=1.5974588	eigval=16.162489
# epoch=400	loss_val=1.5974241	eigval=16.162489
# epoch=401	loss_val=1.5973893	eigval=16.162489
# epoch=402	loss_val=1.5973544	eigval=16.162489
# epoch=403	loss_val=1.5973197	eigval=16.162489
# epoch=404	loss_val=1.5972849	eigval=16.162489
# epoch=405	loss_val=1.5972501	eigval=16.162489
# epoch=406	loss_val=1.5972154	eigval=16.162489
# epoch=407	loss_val=1.5971807	eigval=16.162489
# epoch=408	loss_val=1.5971458	eigval=16.162489
# epoch=409	loss_val=1.597111	eigval=16.162489
# epoch=410	loss_val=1.5970762	eigval=16.162489
# epoch=411	loss_val=1.5970415	eigval=16.162489
# epoch=412	loss_val=1.5970068	eigval=16.162489
# epoch=413	loss_val=1.596972	eigval=16.162489
# epoch=414	loss_val=1.5969372	eigval=16.162489
# epoch=415	loss_val=1.5969024	eigval=16.162489
# epoch=416	loss_val=1.5968674	eigval=16.162489
# epoch=417	loss_val=1.5968329	eigval=16.162489
# epoch=418	loss_val=1.5967982	eigval=16.162489
# epoch=419	loss_val=1.5967633	eigval=16.162489
# epoch=420	loss_val=1.5967286	eigval=16.162489
# epoch=421	loss_val=1.5966939	eigval=16.162489
# epoch=422	loss_val=1.596659	eigval=16.162489
# epoch=423	loss_val=1.5966241	eigval=16.162489
# epoch=424	loss_val=1.5965896	eigval=16.162489
# epoch=425	loss_val=1.5965546	eigval=16.162489
# epoch=426	loss_val=1.5965198	eigval=16.162489
# epoch=427	loss_val=1.596485	eigval=16.162489
# epoch=428	loss_val=1.5964502	eigval=16.162489
# epoch=429	loss_val=1.5964154	eigval=16.162489
# epoch=430	loss_val=1.5963808	eigval=16.162489
# epoch=431	loss_val=1.5963459	eigval=16.162489
# epoch=432	loss_val=1.5963112	eigval=16.162489
# epoch=433	loss_val=1.5962764	eigval=16.162489
# epoch=434	loss_val=1.5962416	eigval=16.162489
# epoch=435	loss_val=1.596207	eigval=16.162489
# epoch=436	loss_val=1.5961722	eigval=16.162489
# epoch=437	loss_val=1.5961373	eigval=16.162489
# epoch=438	loss_val=1.5961026	eigval=16.162489
# epoch=439	loss_val=1.5960678	eigval=16.162489
# epoch=440	loss_val=1.5960331	eigval=16.162489
# epoch=441	loss_val=1.5959983	eigval=16.162489
# epoch=442	loss_val=1.5959637	eigval=16.162489
# epoch=443	loss_val=1.5959287	eigval=16.162489
# epoch=444	loss_val=1.5958939	eigval=16.162489
# epoch=445	loss_val=1.5958592	eigval=16.162489
# epoch=446	loss_val=1.5958245	eigval=16.162489
# epoch=447	loss_val=1.5957898	eigval=16.162489
# epoch=448	loss_val=1.595755	eigval=16.162489
# epoch=449	loss_val=1.5957203	eigval=16.162489
# epoch=450	loss_val=1.5956855	eigval=16.162489
# epoch=451	loss_val=1.5956507	eigval=16.162489
# epoch=452	loss_val=1.5956159	eigval=16.162489
# epoch=453	loss_val=1.5955812	eigval=16.162489
# epoch=454	loss_val=1.5955465	eigval=16.162489
# epoch=455	loss_val=1.5955116	eigval=16.162489
# epoch=456	loss_val=1.595477	eigval=16.162489
# epoch=457	loss_val=1.5954422	eigval=16.162489
# epoch=458	loss_val=1.5954074	eigval=16.162489
# epoch=459	loss_val=1.5953727	eigval=16.162489
# epoch=460	loss_val=1.5953379	eigval=16.162489
# epoch=461	loss_val=1.5953032	eigval=16.162489
# epoch=462	loss_val=1.5952684	eigval=16.162489
# epoch=463	loss_val=1.5952336	eigval=16.162489
# epoch=464	loss_val=1.5951988	eigval=16.162489
# epoch=465	loss_val=1.5951641	eigval=16.162489
# epoch=466	loss_val=1.5951295	eigval=16.162489
# epoch=467	loss_val=1.5950946	eigval=16.162489
# epoch=468	loss_val=1.5950598	eigval=16.162489
# epoch=469	loss_val=1.5950251	eigval=16.162489
# epoch=470	loss_val=1.5949903	eigval=16.162489
# epoch=471	loss_val=1.5949556	eigval=16.162489
# epoch=472	loss_val=1.5949209	eigval=16.162489
# epoch=473	loss_val=1.594886	eigval=16.162489
# epoch=474	loss_val=1.5948511	eigval=16.162489
# epoch=475	loss_val=1.5948164	eigval=16.162489
# epoch=476	loss_val=1.5947818	eigval=16.162489
# epoch=477	loss_val=1.594747	eigval=16.162489
# epoch=478	loss_val=1.5947123	eigval=16.162489
# epoch=479	loss_val=1.5946776	eigval=16.162489
# epoch=480	loss_val=1.5946428	eigval=16.162489
# epoch=481	loss_val=1.594608	eigval=16.162489
# epoch=482	loss_val=1.5945733	eigval=16.162489
# epoch=483	loss_val=1.5945383	eigval=16.162489
# epoch=484	loss_val=1.5945038	eigval=16.162489
# epoch=485	loss_val=1.5944692	eigval=16.162489
# epoch=486	loss_val=1.5944343	eigval=16.162489
# epoch=487	loss_val=1.5943995	eigval=16.162489
# epoch=488	loss_val=1.5943648	eigval=16.162489
# epoch=489	loss_val=1.59433	eigval=16.162489
# epoch=490	loss_val=1.5942954	eigval=16.162489
# epoch=491	loss_val=1.5942606	eigval=16.162489
# epoch=492	loss_val=1.5942258	eigval=16.162489
# epoch=493	loss_val=1.5941908	eigval=16.162489
# epoch=494	loss_val=1.5941563	eigval=16.162489
# epoch=495	loss_val=1.5941215	eigval=16.162489
# epoch=496	loss_val=1.5940868	eigval=16.162489
# epoch=497	loss_val=1.5940521	eigval=16.162489
# epoch=498	loss_val=1.5940174	eigval=16.162489
# epoch=499	loss_val=1.5939823	eigval=16.162489
# epoch=500	loss_val=1.5939479	eigval=16.162489
# epoch=501	loss_val=1.593913	eigval=16.162489
# epoch=502	loss_val=1.5938783	eigval=16.162489
# epoch=503	loss_val=1.5938437	eigval=16.162489
# epoch=504	loss_val=1.5938088	eigval=16.162489
# epoch=505	loss_val=1.5937742	eigval=16.162489
# epoch=506	loss_val=1.5937393	eigval=16.162489
# epoch=507	loss_val=1.5937046	eigval=16.162489
# epoch=508	loss_val=1.5936697	eigval=16.162489
# epoch=509	loss_val=1.5936353	eigval=16.162489
# epoch=510	loss_val=1.5936004	eigval=16.162489
# epoch=511	loss_val=1.5935657	eigval=16.162489
# epoch=512	loss_val=1.5935309	eigval=16.162489
# epoch=513	loss_val=1.5934961	eigval=16.162489
# epoch=514	loss_val=1.5934613	eigval=16.162489
# epoch=515	loss_val=1.5934267	eigval=16.162489
# epoch=516	loss_val=1.593392	eigval=16.162489
# epoch=517	loss_val=1.5933571	eigval=16.162489
# epoch=518	loss_val=1.5933224	eigval=16.162489
# epoch=519	loss_val=1.5932877	eigval=16.162489
# epoch=520	loss_val=1.593253	eigval=16.162489
# epoch=521	loss_val=1.5932181	eigval=16.162489
# epoch=522	loss_val=1.5931835	eigval=16.162489
# epoch=523	loss_val=1.5931488	eigval=16.162489
# epoch=524	loss_val=1.5931141	eigval=16.162489
# epoch=525	loss_val=1.5930793	eigval=16.162489
# epoch=526	loss_val=1.5930448	eigval=16.162489
# epoch=527	loss_val=1.5930098	eigval=16.162489
# epoch=528	loss_val=1.5929751	eigval=16.162489
# epoch=529	loss_val=1.5929404	eigval=16.162489
# epoch=530	loss_val=1.5929056	eigval=16.162489
# epoch=531	loss_val=1.5928708	eigval=16.162489
# epoch=532	loss_val=1.5928361	eigval=16.162489
# epoch=533	loss_val=1.5928013	eigval=16.162489
# epoch=534	loss_val=1.5927666	eigval=16.162489
# epoch=535	loss_val=1.5927321	eigval=16.162489
# epoch=536	loss_val=1.5926971	eigval=16.162489
# epoch=537	loss_val=1.5926625	eigval=16.162489
# epoch=538	loss_val=1.5926278	eigval=16.162489
# epoch=539	loss_val=1.5925931	eigval=16.162489
# epoch=540	loss_val=1.5925581	eigval=16.162489
# epoch=541	loss_val=1.5925236	eigval=16.162489
# epoch=542	loss_val=1.592489	eigval=16.162489
# epoch=543	loss_val=1.5924542	eigval=16.162489
# epoch=544	loss_val=1.5924194	eigval=16.162489
# epoch=545	loss_val=1.5923846	eigval=16.162489
# epoch=546	loss_val=1.5923499	eigval=16.162489
# epoch=547	loss_val=1.5923152	eigval=16.162489
# epoch=548	loss_val=1.5922805	eigval=16.162489
# epoch=549	loss_val=1.5922458	eigval=16.162489
# epoch=550	loss_val=1.592211	eigval=16.162489
# epoch=551	loss_val=1.5921763	eigval=16.162489
# epoch=552	loss_val=1.5921416	eigval=16.162489
# epoch=553	loss_val=1.5921068	eigval=16.162489
# epoch=554	loss_val=1.5920721	eigval=16.162489
# epoch=555	loss_val=1.5920374	eigval=16.162489
# epoch=556	loss_val=1.5920027	eigval=16.162489
# epoch=557	loss_val=1.5919679	eigval=16.162489
# epoch=558	loss_val=1.5919334	eigval=16.162489
# epoch=559	loss_val=1.5918986	eigval=16.162489
# epoch=560	loss_val=1.5918639	eigval=16.162489
# epoch=561	loss_val=1.5918291	eigval=16.162489
# epoch=562	loss_val=1.5917944	eigval=16.162489
# epoch=563	loss_val=1.5917596	eigval=16.162489
# epoch=564	loss_val=1.591725	eigval=16.162489
# epoch=565	loss_val=1.5916902	eigval=16.162489
# epoch=566	loss_val=1.5916555	eigval=16.162489
# epoch=567	loss_val=1.5916207	eigval=16.162489
# epoch=568	loss_val=1.5915861	eigval=16.162489
# epoch=569	loss_val=1.5915514	eigval=16.162489
# epoch=570	loss_val=1.5915166	eigval=16.162489
# epoch=571	loss_val=1.5914819	eigval=16.162489
# epoch=572	loss_val=1.5914472	eigval=16.162489
# epoch=573	loss_val=1.5914125	eigval=16.162489
# epoch=574	loss_val=1.5913777	eigval=16.162489
# epoch=575	loss_val=1.5913432	eigval=16.162489
# epoch=576	loss_val=1.5913084	eigval=16.162489
# epoch=577	loss_val=1.5912737	eigval=16.162489
# epoch=578	loss_val=1.591239	eigval=16.162489
# epoch=579	loss_val=1.5912042	eigval=16.162489
# epoch=580	loss_val=1.5911695	eigval=16.162489
# epoch=581	loss_val=1.5911347	eigval=16.162489
# epoch=582	loss_val=1.5911001	eigval=16.162489
# epoch=583	loss_val=1.5910654	eigval=16.162489
# epoch=584	loss_val=1.5910306	eigval=16.162489
# epoch=585	loss_val=1.5909959	eigval=16.162489
# epoch=586	loss_val=1.5909611	eigval=16.162489
# epoch=587	loss_val=1.5909264	eigval=16.162489
# epoch=588	loss_val=1.5908917	eigval=16.162489
# epoch=589	loss_val=1.590857	eigval=16.162489
# epoch=590	loss_val=1.5908225	eigval=16.162489
# epoch=591	loss_val=1.5907876	eigval=16.162489
# epoch=592	loss_val=1.590753	eigval=16.162489
# epoch=593	loss_val=1.5907183	eigval=16.162489
# epoch=594	loss_val=1.5906833	eigval=16.162489
# epoch=595	loss_val=1.5906489	eigval=16.162489
# epoch=596	loss_val=1.5906141	eigval=16.162489
# epoch=597	loss_val=1.5905795	eigval=16.162489
# epoch=598	loss_val=1.5905447	eigval=16.162489
# epoch=599	loss_val=1.59051	eigval=16.162489
# epoch=600	loss_val=1.5904752	eigval=16.162489
# epoch=601	loss_val=1.5904405	eigval=16.162489
# epoch=602	loss_val=1.5904058	eigval=16.162489
# epoch=603	loss_val=1.5903714	eigval=16.162489
# epoch=604	loss_val=1.5903363	eigval=16.162489
# epoch=605	loss_val=1.5903018	eigval=16.162489
# epoch=606	loss_val=1.5902671	eigval=16.162489
# epoch=607	loss_val=1.5902324	eigval=16.162489
# epoch=608	loss_val=1.5901979	eigval=16.162489
# epoch=609	loss_val=1.5901632	eigval=16.162489
# epoch=610	loss_val=1.5901288	eigval=16.162489
# epoch=611	loss_val=1.5900943	eigval=16.162489
# epoch=612	loss_val=1.5900599	eigval=16.162489
# epoch=613	loss_val=1.5900253	eigval=16.162489
# epoch=614	loss_val=1.5899909	eigval=16.162489
# epoch=615	loss_val=1.5899565	eigval=16.162489
# epoch=616	loss_val=1.5899218	eigval=16.162489
# epoch=617	loss_val=1.5898874	eigval=16.162489
# epoch=618	loss_val=1.5898529	eigval=16.162489
# epoch=619	loss_val=1.5898185	eigval=16.162489
# epoch=620	loss_val=1.5897839	eigval=16.162489
# epoch=621	loss_val=1.5897492	eigval=16.162489
# epoch=622	loss_val=1.589715	eigval=16.162489
# epoch=623	loss_val=1.5896804	eigval=16.162489
# epoch=624	loss_val=1.5896459	eigval=16.162489
# epoch=625	loss_val=1.5896115	eigval=16.162489
# epoch=626	loss_val=1.589577	eigval=16.162489
# epoch=627	loss_val=1.5895425	eigval=16.162489
# epoch=628	loss_val=1.5895079	eigval=16.162489
# epoch=629	loss_val=1.5894734	eigval=16.162489
# epoch=630	loss_val=1.5894389	eigval=16.162489
# epoch=631	loss_val=1.5894045	eigval=16.162489
# epoch=632	loss_val=1.58937	eigval=16.162489
# epoch=633	loss_val=1.5893356	eigval=16.162489
# epoch=634	loss_val=1.5893011	eigval=16.162489
# epoch=635	loss_val=1.5892665	eigval=16.162489
# epoch=636	loss_val=1.5892322	eigval=16.162489
# epoch=637	loss_val=1.5891976	eigval=16.162489
# epoch=638	loss_val=1.5891631	eigval=16.162489
# epoch=639	loss_val=1.5891286	eigval=16.162489
# epoch=640	loss_val=1.5890942	eigval=16.162489
# epoch=641	loss_val=1.5890596	eigval=16.162489
# epoch=642	loss_val=1.5890251	eigval=16.162489
# epoch=643	loss_val=1.5889907	eigval=16.162489
# epoch=644	loss_val=1.5889561	eigval=16.162489
# epoch=645	loss_val=1.5889215	eigval=16.162489
# epoch=646	loss_val=1.5888871	eigval=16.162489
# epoch=647	loss_val=1.5888526	eigval=16.162489
# epoch=648	loss_val=1.5888182	eigval=16.162489
# epoch=649	loss_val=1.5887839	eigval=16.162489
# epoch=650	loss_val=1.5887492	eigval=16.162489
# epoch=651	loss_val=1.5887147	eigval=16.162489
# epoch=652	loss_val=1.5886804	eigval=16.162489
# epoch=653	loss_val=1.5886458	eigval=16.162489
# epoch=654	loss_val=1.5886112	eigval=16.162489
# epoch=655	loss_val=1.5885769	eigval=16.162489
# epoch=656	loss_val=1.5885423	eigval=16.162489
# epoch=657	loss_val=1.5885078	eigval=16.162489
# epoch=658	loss_val=1.5884734	eigval=16.162489
# epoch=659	loss_val=1.5884389	eigval=16.162489
# epoch=660	loss_val=1.5884044	eigval=16.162489
# epoch=661	loss_val=1.58837	eigval=16.162489
# epoch=662	loss_val=1.5883355	eigval=16.162489
# epoch=663	loss_val=1.5883011	eigval=16.162489
# epoch=664	loss_val=1.5882665	eigval=16.162489
# epoch=665	loss_val=1.588232	eigval=16.162489
# epoch=666	loss_val=1.5881976	eigval=16.162489
# epoch=667	loss_val=1.588163	eigval=16.162489
# epoch=668	loss_val=1.5881286	eigval=16.162489
# epoch=669	loss_val=1.5880941	eigval=16.162489
# epoch=670	loss_val=1.5880597	eigval=16.162489
# epoch=671	loss_val=1.5880252	eigval=16.162489
# epoch=672	loss_val=1.5879908	eigval=16.162489
# epoch=673	loss_val=1.5879563	eigval=16.162489
# epoch=674	loss_val=1.5879219	eigval=16.162489
# epoch=675	loss_val=1.5878874	eigval=16.162489
# epoch=676	loss_val=1.587853	eigval=16.162489
# epoch=677	loss_val=1.5878184	eigval=16.162489
# epoch=678	loss_val=1.5877839	eigval=16.162489
# epoch=679	loss_val=1.5877494	eigval=16.162489
# epoch=680	loss_val=1.587715	eigval=16.162489
# epoch=681	loss_val=1.5876805	eigval=16.162489
# epoch=682	loss_val=1.5876461	eigval=16.162489
# epoch=683	loss_val=1.5876116	eigval=16.162489
# epoch=684	loss_val=1.5875771	eigval=16.162489
# epoch=685	loss_val=1.5875427	eigval=16.162489
# epoch=686	loss_val=1.5875081	eigval=16.162489
# epoch=687	loss_val=1.5874736	eigval=16.162489
# epoch=688	loss_val=1.5874391	eigval=16.162489
# epoch=689	loss_val=1.5874047	eigval=16.162489
# epoch=690	loss_val=1.5873702	eigval=16.162489
# epoch=691	loss_val=1.5873357	eigval=16.162489
# epoch=692	loss_val=1.5873014	eigval=16.162489
# epoch=693	loss_val=1.5872669	eigval=16.162489
# epoch=694	loss_val=1.5872325	eigval=16.162489
# epoch=695	loss_val=1.587198	eigval=16.162489
# epoch=696	loss_val=1.5871636	eigval=16.162489
# epoch=697	loss_val=1.587129	eigval=16.162489
# epoch=698	loss_val=1.5870945	eigval=16.162489
# epoch=699	loss_val=1.5870601	eigval=16.162489
# epoch=700	loss_val=1.5870256	eigval=16.162489
# epoch=701	loss_val=1.5869912	eigval=16.162489
# epoch=702	loss_val=1.5869567	eigval=16.162489
# epoch=703	loss_val=1.5869222	eigval=16.162489
# epoch=704	loss_val=1.5868877	eigval=16.162489
# epoch=705	loss_val=1.5868533	eigval=16.162489
# epoch=706	loss_val=1.5868189	eigval=16.162489
# epoch=707	loss_val=1.5867845	eigval=16.162489
# epoch=708	loss_val=1.5867499	eigval=16.162489
# epoch=709	loss_val=1.5867155	eigval=16.162489
# epoch=710	loss_val=1.586681	eigval=16.162489
# epoch=711	loss_val=1.5866466	eigval=16.162489
# epoch=712	loss_val=1.5866121	eigval=16.162489
# epoch=713	loss_val=1.5865775	eigval=16.162489
# epoch=714	loss_val=1.5865432	eigval=16.162489
# epoch=715	loss_val=1.5865086	eigval=16.162489
# epoch=716	loss_val=1.5864743	eigval=16.162489
# epoch=717	loss_val=1.5864397	eigval=16.162489
# epoch=718	loss_val=1.5864054	eigval=16.162489
# epoch=719	loss_val=1.5863708	eigval=16.162489
# epoch=720	loss_val=1.5863366	eigval=16.162489
# epoch=721	loss_val=1.5863019	eigval=16.162489
# epoch=722	loss_val=1.5862675	eigval=16.162489
# epoch=723	loss_val=1.586233	eigval=16.162489
# epoch=724	loss_val=1.5861986	eigval=16.162489
# epoch=725	loss_val=1.5861641	eigval=16.162489
# epoch=726	loss_val=1.5861298	eigval=16.162489
# epoch=727	loss_val=1.5860952	eigval=16.162489
# epoch=728	loss_val=1.5860606	eigval=16.162489
# epoch=729	loss_val=1.5860263	eigval=16.162489
# epoch=730	loss_val=1.585992	eigval=16.162489
# epoch=731	loss_val=1.5859574	eigval=16.162489
# epoch=732	loss_val=1.585923	eigval=16.162489
# epoch=733	loss_val=1.5858886	eigval=16.162489
# epoch=734	loss_val=1.585854	eigval=16.162489
# epoch=735	loss_val=1.5858196	eigval=16.162489
# epoch=736	loss_val=1.5857852	eigval=16.162489
# epoch=737	loss_val=1.5857507	eigval=16.162489
# epoch=738	loss_val=1.5857162	eigval=16.162489
# epoch=739	loss_val=1.5856818	eigval=16.162489
# epoch=740	loss_val=1.5856472	eigval=16.162489
# epoch=741	loss_val=1.5856129	eigval=16.162489
# epoch=742	loss_val=1.5855786	eigval=16.162489
# epoch=743	loss_val=1.5855441	eigval=16.162489
# epoch=744	loss_val=1.5855097	eigval=16.162489
# epoch=745	loss_val=1.5854752	eigval=16.162489
# epoch=746	loss_val=1.5854408	eigval=16.162489
# epoch=747	loss_val=1.5854063	eigval=16.162489
# epoch=748	loss_val=1.5853719	eigval=16.162489
# epoch=749	loss_val=1.5853374	eigval=16.162489
# epoch=750	loss_val=1.585303	eigval=16.162489
# epoch=751	loss_val=1.5852685	eigval=16.162489
# epoch=752	loss_val=1.585234	eigval=16.162489
# epoch=753	loss_val=1.5851996	eigval=16.162489
# epoch=754	loss_val=1.5851651	eigval=16.162489
# epoch=755	loss_val=1.5851307	eigval=16.162489
# epoch=756	loss_val=1.5850965	eigval=16.162489
# epoch=757	loss_val=1.5850618	eigval=16.162489
# epoch=758	loss_val=1.5850272	eigval=16.162489
# epoch=759	loss_val=1.5849929	eigval=16.162489
# epoch=760	loss_val=1.5849584	eigval=16.162489
# epoch=761	loss_val=1.584924	eigval=16.162489
# epoch=762	loss_val=1.5848895	eigval=16.162489
# epoch=763	loss_val=1.5848552	eigval=16.162489
# epoch=764	loss_val=1.5848207	eigval=16.162489
# epoch=765	loss_val=1.5847862	eigval=16.162489
# epoch=766	loss_val=1.5847518	eigval=16.162489
# epoch=767	loss_val=1.5847173	eigval=16.162489
# epoch=768	loss_val=1.584683	eigval=16.162489
# epoch=769	loss_val=1.5846485	eigval=16.162489
# epoch=770	loss_val=1.584614	eigval=16.162489
# epoch=771	loss_val=1.5845797	eigval=16.162489
# epoch=772	loss_val=1.5845454	eigval=16.162489
# epoch=773	loss_val=1.5845108	eigval=16.162489
# epoch=774	loss_val=1.5844765	eigval=16.162489
# epoch=775	loss_val=1.5844418	eigval=16.162489
# epoch=776	loss_val=1.5844076	eigval=16.162489
# epoch=777	loss_val=1.5843731	eigval=16.162489
# epoch=778	loss_val=1.5843387	eigval=16.162489
# epoch=779	loss_val=1.5843042	eigval=16.162489
# epoch=780	loss_val=1.5842698	eigval=16.162489
# epoch=781	loss_val=1.5842353	eigval=16.162489
# epoch=782	loss_val=1.5842009	eigval=16.162489
# epoch=783	loss_val=1.5841665	eigval=16.162489
# epoch=784	loss_val=1.5841321	eigval=16.162489
# epoch=785	loss_val=1.5840975	eigval=16.162489
# epoch=786	loss_val=1.5840633	eigval=16.162489
# epoch=787	loss_val=1.5840287	eigval=16.162489
# epoch=788	loss_val=1.5839942	eigval=16.162489
# epoch=789	loss_val=1.5839598	eigval=16.162489
# epoch=790	loss_val=1.5839254	eigval=16.162489
# epoch=791	loss_val=1.5838909	eigval=16.162489
# epoch=792	loss_val=1.5838566	eigval=16.162489
# epoch=793	loss_val=1.5838221	eigval=16.162489
# epoch=794	loss_val=1.5837876	eigval=16.162489
# epoch=795	loss_val=1.5837533	eigval=16.162489
# epoch=796	loss_val=1.5837188	eigval=16.162489
# epoch=797	loss_val=1.5836843	eigval=16.162489
# epoch=798	loss_val=1.5836499	eigval=16.162489
# epoch=799	loss_val=1.5836155	eigval=16.162489
# epoch=800	loss_val=1.5835811	eigval=16.162489
# epoch=801	loss_val=1.5835466	eigval=16.162489
# epoch=802	loss_val=1.5835122	eigval=16.162489
# epoch=803	loss_val=1.5834779	eigval=16.162489
# epoch=804	loss_val=1.5834435	eigval=16.162489
# epoch=805	loss_val=1.583409	eigval=16.162489
# epoch=806	loss_val=1.5833746	eigval=16.162489
# epoch=807	loss_val=1.5833403	eigval=16.162489
# epoch=808	loss_val=1.583306	eigval=16.162489
# epoch=809	loss_val=1.5832714	eigval=16.162489
# epoch=810	loss_val=1.5832369	eigval=16.162489
# epoch=811	loss_val=1.5832026	eigval=16.162489
# epoch=812	loss_val=1.583168	eigval=16.162489
# epoch=813	loss_val=1.5831337	eigval=16.162489
# epoch=814	loss_val=1.5830992	eigval=16.162489
# epoch=815	loss_val=1.5830649	eigval=16.162489
# epoch=816	loss_val=1.5830305	eigval=16.162489
# epoch=817	loss_val=1.582996	eigval=16.162489
# epoch=818	loss_val=1.5829616	eigval=16.162489
# epoch=819	loss_val=1.5829272	eigval=16.162489
# epoch=820	loss_val=1.5828927	eigval=16.162489
# epoch=821	loss_val=1.5828583	eigval=16.162489
# epoch=822	loss_val=1.582824	eigval=16.162489
# epoch=823	loss_val=1.5827894	eigval=16.162489
# epoch=824	loss_val=1.582755	eigval=16.162489
# epoch=825	loss_val=1.5827206	eigval=16.162489
# epoch=826	loss_val=1.5826862	eigval=16.162489
# epoch=827	loss_val=1.5826517	eigval=16.162489
# epoch=828	loss_val=1.5826174	eigval=16.162489
# epoch=829	loss_val=1.5825828	eigval=16.162489
# epoch=830	loss_val=1.5825486	eigval=16.162489
# epoch=831	loss_val=1.582514	eigval=16.162489
# epoch=832	loss_val=1.5824796	eigval=16.162489
# epoch=833	loss_val=1.5824453	eigval=16.162489
# epoch=834	loss_val=1.5824108	eigval=16.162489
# epoch=835	loss_val=1.5823765	eigval=16.162489
# epoch=836	loss_val=1.582342	eigval=16.162489
# epoch=837	loss_val=1.5823077	eigval=16.162489
# epoch=838	loss_val=1.5822731	eigval=16.162489
# epoch=839	loss_val=1.5822388	eigval=16.162489
# epoch=840	loss_val=1.5822043	eigval=16.162489
# epoch=841	loss_val=1.58217	eigval=16.162489
# epoch=842	loss_val=1.5821354	eigval=16.162489
# epoch=843	loss_val=1.5821012	eigval=16.162489
# epoch=844	loss_val=1.5820668	eigval=16.162489
# epoch=845	loss_val=1.5820323	eigval=16.162489
# epoch=846	loss_val=1.581998	eigval=16.162489
# epoch=847	loss_val=1.5819637	eigval=16.162489
# epoch=848	loss_val=1.5819292	eigval=16.162489
# epoch=849	loss_val=1.5818949	eigval=16.162489
# epoch=850	loss_val=1.5818603	eigval=16.162489
# epoch=851	loss_val=1.5818261	eigval=16.162489
# epoch=852	loss_val=1.5817915	eigval=16.162489
# epoch=853	loss_val=1.5817572	eigval=16.162489
# epoch=854	loss_val=1.5817227	eigval=16.162489
# epoch=855	loss_val=1.5816884	eigval=16.162489
# epoch=856	loss_val=1.5816538	eigval=16.162489
# epoch=857	loss_val=1.5816195	eigval=16.162489
# epoch=858	loss_val=1.5815852	eigval=16.162489
# epoch=859	loss_val=1.5815508	eigval=16.162489
# epoch=860	loss_val=1.5815163	eigval=16.162489
# epoch=861	loss_val=1.5814817	eigval=16.162489
# epoch=862	loss_val=1.5814475	eigval=16.162489
# epoch=863	loss_val=1.5814131	eigval=16.162489
# epoch=864	loss_val=1.5813788	eigval=16.162489
# epoch=865	loss_val=1.5813442	eigval=16.162489
# epoch=866	loss_val=1.5813098	eigval=16.162489
# epoch=867	loss_val=1.5812753	eigval=16.162489
# epoch=868	loss_val=1.581241	eigval=16.162489
# epoch=869	loss_val=1.5812066	eigval=16.162489
# epoch=870	loss_val=1.5811722	eigval=16.162489
# epoch=871	loss_val=1.5811378	eigval=16.162489
# epoch=872	loss_val=1.5811033	eigval=16.162489
# epoch=873	loss_val=1.581069	eigval=16.162489
# epoch=874	loss_val=1.5810347	eigval=16.162489
# epoch=875	loss_val=1.5810003	eigval=16.162489
# epoch=876	loss_val=1.5809659	eigval=16.162489
# epoch=877	loss_val=1.5809314	eigval=16.162489
# epoch=878	loss_val=1.580897	eigval=16.162489
# epoch=879	loss_val=1.5808626	eigval=16.162489
# epoch=880	loss_val=1.5808282	eigval=16.162489
# epoch=881	loss_val=1.580794	eigval=16.162489
# epoch=882	loss_val=1.5807595	eigval=16.162489
# epoch=883	loss_val=1.5807251	eigval=16.162489
# epoch=884	loss_val=1.5806907	eigval=16.162489
# epoch=885	loss_val=1.5806563	eigval=16.162489
# epoch=886	loss_val=1.5806218	eigval=16.162489
# epoch=887	loss_val=1.5805875	eigval=16.162489
# epoch=888	loss_val=1.5805529	eigval=16.162489
# epoch=889	loss_val=1.5805187	eigval=16.162489
# epoch=890	loss_val=1.5804844	eigval=16.162489
# epoch=891	loss_val=1.5804499	eigval=16.162489
# epoch=892	loss_val=1.5804155	eigval=16.162489
# epoch=893	loss_val=1.5803812	eigval=16.162489
# epoch=894	loss_val=1.5803468	eigval=16.162489
# epoch=895	loss_val=1.5803124	eigval=16.162489
# epoch=896	loss_val=1.5802779	eigval=16.162489
# epoch=897	loss_val=1.5802436	eigval=16.162489
# epoch=898	loss_val=1.5802091	eigval=16.162489
# epoch=899	loss_val=1.5801747	eigval=16.162489
# epoch=900	loss_val=1.5801405	eigval=16.162489
# epoch=901	loss_val=1.580106	eigval=16.162489
# epoch=902	loss_val=1.5800716	eigval=16.162489
# epoch=903	loss_val=1.5800372	eigval=16.162489
# epoch=904	loss_val=1.5800029	eigval=16.162489
# epoch=905	loss_val=1.5799685	eigval=16.162489
# epoch=906	loss_val=1.5799341	eigval=16.162489
# epoch=907	loss_val=1.5798998	eigval=16.162489
# epoch=908	loss_val=1.5798653	eigval=16.162489
# epoch=909	loss_val=1.5798309	eigval=16.162489
# epoch=910	loss_val=1.5797966	eigval=16.162489
# epoch=911	loss_val=1.5797622	eigval=16.162489
# epoch=912	loss_val=1.5797278	eigval=16.162489
# epoch=913	loss_val=1.5796936	eigval=16.162489
# epoch=914	loss_val=1.5796591	eigval=16.162489
# epoch=915	loss_val=1.5796247	eigval=16.162489
# epoch=916	loss_val=1.5795902	eigval=16.162489
# epoch=917	loss_val=1.579556	eigval=16.162489
# epoch=918	loss_val=1.5795215	eigval=16.162489
# epoch=919	loss_val=1.5794872	eigval=16.162489
# epoch=920	loss_val=1.5794528	eigval=16.162489
# epoch=921	loss_val=1.5794184	eigval=16.162489
# epoch=922	loss_val=1.579384	eigval=16.162489
# epoch=923	loss_val=1.5793498	eigval=16.162489
# epoch=924	loss_val=1.5793153	eigval=16.162489
# epoch=925	loss_val=1.579281	eigval=16.162489
# epoch=926	loss_val=1.5792465	eigval=16.162489
# epoch=927	loss_val=1.5792122	eigval=16.162489
# epoch=928	loss_val=1.5791777	eigval=16.162489
# epoch=929	loss_val=1.5791433	eigval=16.162489
# epoch=930	loss_val=1.579109	eigval=16.162489
# epoch=931	loss_val=1.5790746	eigval=16.162489
# epoch=932	loss_val=1.5790403	eigval=16.162489
# epoch=933	loss_val=1.5790058	eigval=16.162489
# epoch=934	loss_val=1.5789714	eigval=16.162489
# epoch=935	loss_val=1.578937	eigval=16.162489
# epoch=936	loss_val=1.5789026	eigval=16.162489
# epoch=937	loss_val=1.5788683	eigval=16.162489
# epoch=938	loss_val=1.5788339	eigval=16.162489
# epoch=939	loss_val=1.5787995	eigval=16.162489
# epoch=940	loss_val=1.5787652	eigval=16.162489
# epoch=941	loss_val=1.578731	eigval=16.162489
# epoch=942	loss_val=1.5786964	eigval=16.162489
# epoch=943	loss_val=1.578662	eigval=16.162489
# epoch=944	loss_val=1.5786278	eigval=16.162489
# epoch=945	loss_val=1.5785933	eigval=16.162489
# epoch=946	loss_val=1.5785589	eigval=16.162489
# epoch=947	loss_val=1.5785246	eigval=16.162489
# epoch=948	loss_val=1.5784903	eigval=16.162489
# epoch=949	loss_val=1.5784558	eigval=16.162489
# epoch=950	loss_val=1.5784215	eigval=16.162489
# epoch=951	loss_val=1.578387	eigval=16.162489
# epoch=952	loss_val=1.5783527	eigval=16.162489
# epoch=953	loss_val=1.5783184	eigval=16.162489
# epoch=954	loss_val=1.578284	eigval=16.162489
# epoch=955	loss_val=1.5782497	eigval=16.162489
# epoch=956	loss_val=1.5782152	eigval=16.162489
# epoch=957	loss_val=1.5781809	eigval=16.162489
# epoch=958	loss_val=1.5781465	eigval=16.162489
# epoch=959	loss_val=1.5781122	eigval=16.162489
# epoch=960	loss_val=1.5780778	eigval=16.162489
# epoch=961	loss_val=1.5780433	eigval=16.162489
# epoch=962	loss_val=1.578009	eigval=16.162489
# epoch=963	loss_val=1.5779748	eigval=16.162489
# epoch=964	loss_val=1.5779403	eigval=16.162489
# epoch=965	loss_val=1.5779059	eigval=16.162489
# epoch=966	loss_val=1.5778716	eigval=16.162489
# epoch=967	loss_val=1.5778372	eigval=16.162489
# epoch=968	loss_val=1.5778029	eigval=16.162489
# epoch=969	loss_val=1.5777686	eigval=16.162489
# epoch=970	loss_val=1.5777341	eigval=16.162489
# epoch=971	loss_val=1.5776998	eigval=16.162489
# epoch=972	loss_val=1.5776653	eigval=16.162489
# epoch=973	loss_val=1.577631	eigval=16.162489
# epoch=974	loss_val=1.5775968	eigval=16.162489
# epoch=975	loss_val=1.5775625	eigval=16.162489
# epoch=976	loss_val=1.577528	eigval=16.162489
# epoch=977	loss_val=1.5774937	eigval=16.162489
# epoch=978	loss_val=1.5774593	eigval=16.162489
# epoch=979	loss_val=1.5774248	eigval=16.162489
# epoch=980	loss_val=1.5773906	eigval=16.162489
# epoch=981	loss_val=1.5773561	eigval=16.162489
# epoch=982	loss_val=1.5773219	eigval=16.162489
# epoch=983	loss_val=1.5772874	eigval=16.162489
# epoch=984	loss_val=1.5772531	eigval=16.162489
# epoch=985	loss_val=1.5772187	eigval=16.162489
# epoch=986	loss_val=1.5771844	eigval=16.162489
# epoch=987	loss_val=1.5771501	eigval=16.162489
# epoch=988	loss_val=1.5771157	eigval=16.162489
# epoch=989	loss_val=1.5770812	eigval=16.162489
# epoch=990	loss_val=1.577047	eigval=16.162489
# epoch=991	loss_val=1.5770127	eigval=16.162489
# epoch=992	loss_val=1.5769782	eigval=16.162489
# epoch=993	loss_val=1.5769439	eigval=16.162489
# epoch=994	loss_val=1.5769095	eigval=16.162489
# epoch=995	loss_val=1.5768752	eigval=16.162489
# epoch=996	loss_val=1.5768409	eigval=16.162489
# epoch=997	loss_val=1.5768065	eigval=16.162489
# epoch=998	loss_val=1.5767722	eigval=16.162489
# epoch=999	loss_val=1.5767378	eigval=16.162489
# epoch=1000	loss_val=1.5767034	eigval=16.162489
# epoch=1001	loss_val=1.5766692	eigval=16.162489
# epoch=1002	loss_val=1.5766346	eigval=16.162489
# epoch=1003	loss_val=1.5766004	eigval=16.162489
# epoch=1004	loss_val=1.5765661	eigval=16.162489
# epoch=1005	loss_val=1.5765318	eigval=16.162489
# epoch=1006	loss_val=1.5764973	eigval=16.162489
# epoch=1007	loss_val=1.576463	eigval=16.162489
# epoch=1008	loss_val=1.5764287	eigval=16.162489
# epoch=1009	loss_val=1.5763943	eigval=16.162489
# epoch=1010	loss_val=1.5763601	eigval=16.162489
# epoch=1011	loss_val=1.5763257	eigval=16.162489
# epoch=1012	loss_val=1.5762912	eigval=16.162489
# epoch=1013	loss_val=1.5762569	eigval=16.162489
# epoch=1014	loss_val=1.5762225	eigval=16.162489
# epoch=1015	loss_val=1.5761881	eigval=16.162489
# epoch=1016	loss_val=1.576154	eigval=16.162489
# epoch=1017	loss_val=1.5761197	eigval=16.162489
# epoch=1018	loss_val=1.5760852	eigval=16.162489
# epoch=1019	loss_val=1.5760509	eigval=16.162489
# epoch=1020	loss_val=1.5760164	eigval=16.162489
# epoch=1021	loss_val=1.5759821	eigval=16.162489
# epoch=1022	loss_val=1.5759478	eigval=16.162489
# epoch=1023	loss_val=1.5759134	eigval=16.162489
# epoch=1024	loss_val=1.5758791	eigval=16.162489
# epoch=1025	loss_val=1.5758448	eigval=16.162489
# epoch=1026	loss_val=1.5758104	eigval=16.162489
# epoch=1027	loss_val=1.5757761	eigval=16.162489
# epoch=1028	loss_val=1.5757418	eigval=16.162489
# epoch=1029	loss_val=1.5757074	eigval=16.162489
# epoch=1030	loss_val=1.5756731	eigval=16.162489
# epoch=1031	loss_val=1.5756389	eigval=16.162489
# epoch=1032	loss_val=1.5756044	eigval=16.162489
# epoch=1033	loss_val=1.5755701	eigval=16.162489
# epoch=1034	loss_val=1.5755357	eigval=16.162489
# epoch=1035	loss_val=1.5755014	eigval=16.162489
# epoch=1036	loss_val=1.575467	eigval=16.162489
# epoch=1037	loss_val=1.5754327	eigval=16.162489
# epoch=1038	loss_val=1.5753984	eigval=16.162489
# epoch=1039	loss_val=1.5753641	eigval=16.162489
# epoch=1040	loss_val=1.5753297	eigval=16.162489
# epoch=1041	loss_val=1.5752954	eigval=16.162489
# epoch=1042	loss_val=1.5752611	eigval=16.162489
# epoch=1043	loss_val=1.5752268	eigval=16.162489
# epoch=1044	loss_val=1.5751925	eigval=16.162489
# epoch=1045	loss_val=1.575158	eigval=16.162489
# epoch=1046	loss_val=1.5751237	eigval=16.162489
# ...
# epoch=2659	loss_val=1.5202299	eigval=16.162489
# epoch=2660	loss_val=1.5201963	eigval=16.162489
# epoch=2661	loss_val=1.5201625	eigval=16.162489
# epoch=2662	loss_val=1.5201288	eigval=16.162489
# epoch=2663	loss_val=1.520095	eigval=16.162489
# epoch=2664	loss_val=1.5200614	eigval=16.162489
# epoch=2665	loss_val=1.5200276	eigval=16.162489
# epoch=2666	loss_val=1.5199939	eigval=16.162489
# epoch=2667	loss_val=1.51996	eigval=16.162489
# epoch=2668	loss_val=1.5199263	eigval=16.162489
# epoch=2669	loss_val=1.5198927	eigval=16.162489
# epoch=2670	loss_val=1.5198587	eigval=16.162489
# epoch=2671	loss_val=1.5198251	eigval=16.162489
# epoch=2672	loss_val=1.5197915	eigval=16.162489
# epoch=2673	loss_val=1.5197577	eigval=16.162489
# epoch=2674	loss_val=1.519724	eigval=16.162489
# epoch=2675	loss_val=1.5196903	eigval=16.162489
# epoch=2676	loss_val=1.5196567	eigval=16.162489
# epoch=2677	loss_val=1.5196228	eigval=16.162489
# epoch=2678	loss_val=1.5195891	eigval=16.162489
# epoch=2679	loss_val=1.5195554	eigval=16.162489
# epoch=2680	loss_val=1.5195217	eigval=16.162489
# epoch=2681	loss_val=1.5194877	eigval=16.162489
# epoch=2682	loss_val=1.5194542	eigval=16.162489
# epoch=2683	loss_val=1.5194205	eigval=16.162489
# epoch=2684	loss_val=1.5193868	eigval=16.162489
# epoch=2685	loss_val=1.519353	eigval=16.162489
# epoch=2686	loss_val=1.5193192	eigval=16.162489
# epoch=2687	loss_val=1.5192856	eigval=16.162489
# epoch=2688	loss_val=1.5192521	eigval=16.162489
# epoch=2689	loss_val=1.5192182	eigval=16.162489
# epoch=2690	loss_val=1.5191845	eigval=16.162489
# epoch=2691	loss_val=1.5191509	eigval=16.162489
# epoch=2692	loss_val=1.519117	eigval=16.162489
# epoch=2693	loss_val=1.5190833	eigval=16.162489
# epoch=2694	loss_val=1.5190496	eigval=16.162489
# epoch=2695	loss_val=1.5190159	eigval=16.162489
# epoch=2696	loss_val=1.5189822	eigval=16.162489
# epoch=2697	loss_val=1.5189484	eigval=16.162489
# epoch=2698	loss_val=1.5189147	eigval=16.162489
# epoch=2699	loss_val=1.5188811	eigval=16.162489
# epoch=2700	loss_val=1.5188472	eigval=16.162489
# epoch=2701	loss_val=1.5188135	eigval=16.162489
# epoch=2702	loss_val=1.5187799	eigval=16.162489
# epoch=2703	loss_val=1.5187461	eigval=16.162489
# epoch=2704	loss_val=1.5187124	eigval=16.162489
# epoch=2705	loss_val=1.5186788	eigval=16.162489
# epoch=2706	loss_val=1.518645	eigval=16.162489
# epoch=2707	loss_val=1.5186113	eigval=16.162489
# epoch=2708	loss_val=1.5185775	eigval=16.162489
# epoch=2709	loss_val=1.5185438	eigval=16.162489
# epoch=2710	loss_val=1.5185102	eigval=16.162489
# epoch=2711	loss_val=1.5184765	eigval=16.162489
# epoch=2712	loss_val=1.5184427	eigval=16.162489
# epoch=2713	loss_val=1.518409	eigval=16.162489
# epoch=2714	loss_val=1.5183754	eigval=16.162489
# epoch=2715	loss_val=1.5183415	eigval=16.162489
# epoch=2716	loss_val=1.5183079	eigval=16.162489
# epoch=2717	loss_val=1.5182742	eigval=16.162489
# epoch=2718	loss_val=1.5182406	eigval=16.162489
# epoch=2719	loss_val=1.5182067	eigval=16.162489
# epoch=2720	loss_val=1.518173	eigval=16.162489
# epoch=2721	loss_val=1.5181394	eigval=16.162489
# epoch=2722	loss_val=1.5181056	eigval=16.162489
# epoch=2723	loss_val=1.518072	eigval=16.162489
# epoch=2724	loss_val=1.5180382	eigval=16.162489
# epoch=2725	loss_val=1.5180044	eigval=16.162489
# epoch=2726	loss_val=1.5179708	eigval=16.162489
# epoch=2727	loss_val=1.517937	eigval=16.162489
# epoch=2728	loss_val=1.5179033	eigval=16.162489
# epoch=2729	loss_val=1.5178697	eigval=16.162489
# epoch=2730	loss_val=1.517836	eigval=16.162489
# epoch=2731	loss_val=1.5178022	eigval=16.162489
# epoch=2732	loss_val=1.5177685	eigval=16.162489
# epoch=2733	loss_val=1.5177349	eigval=16.162489
# epoch=2734	loss_val=1.5177011	eigval=16.162489
# epoch=2735	loss_val=1.5176674	eigval=16.162489
# epoch=2736	loss_val=1.5176339	eigval=16.162489
# epoch=2737	loss_val=1.5176002	eigval=16.162489
# epoch=2738	loss_val=1.5175663	eigval=16.162489
# epoch=2739	loss_val=1.5175327	eigval=16.162489
# epoch=2740	loss_val=1.517499	eigval=16.162489
# epoch=2741	loss_val=1.5174654	eigval=16.162489
# epoch=2742	loss_val=1.5174315	eigval=16.162489
# epoch=2743	loss_val=1.517398	eigval=16.162489
# epoch=2744	loss_val=1.517364	eigval=16.162489
# epoch=2745	loss_val=1.5173305	eigval=16.162489
# epoch=2746	loss_val=1.5172968	eigval=16.162489
# epoch=2747	loss_val=1.517263	eigval=16.162489
# epoch=2748	loss_val=1.5172293	eigval=16.162489
# epoch=2749	loss_val=1.5171957	eigval=16.162489
# epoch=2750	loss_val=1.5171621	eigval=16.162489
# epoch=2751	loss_val=1.5171283	eigval=16.162489
# epoch=2752	loss_val=1.5170946	eigval=16.162489
# epoch=2753	loss_val=1.5170608	eigval=16.162489
# epoch=2754	loss_val=1.5170271	eigval=16.162489
# epoch=2755	loss_val=1.5169936	eigval=16.162489
# epoch=2756	loss_val=1.5169599	eigval=16.162489
# epoch=2757	loss_val=1.516926	eigval=16.162489
# epoch=2758	loss_val=1.5168924	eigval=16.162489
# epoch=2759	loss_val=1.5168588	eigval=16.162489
# epoch=2760	loss_val=1.5168251	eigval=16.162489
# epoch=2761	loss_val=1.5167913	eigval=16.162489
# epoch=2762	loss_val=1.5167576	eigval=16.162489
# epoch=2763	loss_val=1.5167241	eigval=16.162489
# epoch=2764	loss_val=1.5166903	eigval=16.162489
# epoch=2765	loss_val=1.5166565	eigval=16.162489
# epoch=2766	loss_val=1.516623	eigval=16.162489
# epoch=2767	loss_val=1.5165893	eigval=16.162489
# epoch=2768	loss_val=1.5165555	eigval=16.162489
# epoch=2769	loss_val=1.5165218	eigval=16.162489
# epoch=2770	loss_val=1.5164881	eigval=16.162489
# epoch=2771	loss_val=1.5164545	eigval=16.162489
# epoch=2772	loss_val=1.5164206	eigval=16.162489
# epoch=2773	loss_val=1.5163871	eigval=16.162489
# epoch=2774	loss_val=1.5163535	eigval=16.162489
# epoch=2775	loss_val=1.5163196	eigval=16.162489
# epoch=2776	loss_val=1.516286	eigval=16.162489
# epoch=2777	loss_val=1.5162524	eigval=16.162489
# epoch=2778	loss_val=1.5162188	eigval=16.162489
# epoch=2779	loss_val=1.5161849	eigval=16.162489
# epoch=2780	loss_val=1.5161514	eigval=16.162489
# epoch=2781	loss_val=1.5161176	eigval=16.162489
# epoch=2782	loss_val=1.516084	eigval=16.162489
# epoch=2783	loss_val=1.5160502	eigval=16.162489
# epoch=2784	loss_val=1.5160165	eigval=16.162489
# epoch=2785	loss_val=1.515983	eigval=16.162489
# epoch=2786	loss_val=1.5159491	eigval=16.162489
# epoch=2787	loss_val=1.5159154	eigval=16.162489
# epoch=2788	loss_val=1.5158819	eigval=16.162489
# epoch=2789	loss_val=1.5158482	eigval=16.162489
# epoch=2790	loss_val=1.5158145	eigval=16.162489
# epoch=2791	loss_val=1.5157808	eigval=16.162489
# epoch=2792	loss_val=1.5157471	eigval=16.162489
# epoch=2793	loss_val=1.5157133	eigval=16.162489
# epoch=2794	loss_val=1.5156797	eigval=16.162489
# epoch=2795	loss_val=1.5156461	eigval=16.162489
# epoch=2796	loss_val=1.5156125	eigval=16.162489
# epoch=2797	loss_val=1.5155786	eigval=16.162489
# epoch=2798	loss_val=1.515545	eigval=16.162489
# epoch=2799	loss_val=1.5155113	eigval=16.162489
# epoch=2800	loss_val=1.5154777	eigval=16.162489
# epoch=2801	loss_val=1.5154439	eigval=16.162489
# epoch=2802	loss_val=1.5154103	eigval=16.162489
# epoch=2803	loss_val=1.5153767	eigval=16.162489
# epoch=2804	loss_val=1.515343	eigval=16.162489
# epoch=2805	loss_val=1.5153092	eigval=16.162489
# epoch=2806	loss_val=1.5152757	eigval=16.162489
# epoch=2807	loss_val=1.515242	eigval=16.162489
# epoch=2808	loss_val=1.5152081	eigval=16.162489
# epoch=2809	loss_val=1.5151745	eigval=16.162489
# epoch=2810	loss_val=1.5151409	eigval=16.162489
# epoch=2811	loss_val=1.5151073	eigval=16.162489
# epoch=2812	loss_val=1.5150734	eigval=16.162489
# epoch=2813	loss_val=1.5150399	eigval=16.162489
# epoch=2814	loss_val=1.5150062	eigval=16.162489
# epoch=2815	loss_val=1.5149726	eigval=16.162489
# epoch=2816	loss_val=1.514939	eigval=16.162489
# epoch=2817	loss_val=1.5149052	eigval=16.162489
# epoch=2818	loss_val=1.5148716	eigval=16.162489
# epoch=2819	loss_val=1.5148377	eigval=16.162489
# epoch=2820	loss_val=1.514804	eigval=16.162489
# epoch=2821	loss_val=1.5147706	eigval=16.162489
# epoch=2822	loss_val=1.5147369	eigval=16.162489
# epoch=2823	loss_val=1.5147033	eigval=16.162489
# epoch=2824	loss_val=1.5146695	eigval=16.162489
# epoch=2825	loss_val=1.5146359	eigval=16.162489
# epoch=2826	loss_val=1.5146023	eigval=16.162489
# epoch=2827	loss_val=1.5145684	eigval=16.162489
# epoch=2828	loss_val=1.5145348	eigval=16.162489
# epoch=2829	loss_val=1.5145011	eigval=16.162489
# epoch=2830	loss_val=1.5144675	eigval=16.162489
# epoch=2831	loss_val=1.5144337	eigval=16.162489
# epoch=2832	loss_val=1.5144002	eigval=16.162489
# epoch=2833	loss_val=1.5143666	eigval=16.162489
# epoch=2834	loss_val=1.5143329	eigval=16.162489
# epoch=2835	loss_val=1.5142992	eigval=16.162489
# epoch=2836	loss_val=1.5142654	eigval=16.162489
# epoch=2837	loss_val=1.5142319	eigval=16.162489
# epoch=2838	loss_val=1.5141983	eigval=16.162489
# epoch=2839	loss_val=1.5141646	eigval=16.162489
# epoch=2840	loss_val=1.514131	eigval=16.162489
# epoch=2841	loss_val=1.5140971	eigval=16.162489
# epoch=2842	loss_val=1.5140636	eigval=16.162489
# epoch=2843	loss_val=1.5140299	eigval=16.162489
# epoch=2844	loss_val=1.5139962	eigval=16.162489
# epoch=2845	loss_val=1.5139625	eigval=16.162489
# epoch=2846	loss_val=1.5139289	eigval=16.162489
# epoch=2847	loss_val=1.5138952	eigval=16.162489
# epoch=2848	loss_val=1.5138615	eigval=16.162489
# epoch=2849	loss_val=1.5138279	eigval=16.162489
# epoch=2850	loss_val=1.5137943	eigval=16.162489
# epoch=2851	loss_val=1.5137606	eigval=16.162489
# epoch=2852	loss_val=1.513727	eigval=16.162489
# epoch=2853	loss_val=1.5136933	eigval=16.162489
# epoch=2854	loss_val=1.5136596	eigval=16.162489
# epoch=2855	loss_val=1.513626	eigval=16.162489
# epoch=2856	loss_val=1.5135922	eigval=16.162489
# epoch=2857	loss_val=1.5135586	eigval=16.162489
# epoch=2858	loss_val=1.513525	eigval=16.162489
# epoch=2859	loss_val=1.5134913	eigval=16.162489
# epoch=2860	loss_val=1.5134578	eigval=16.162489
# epoch=2861	loss_val=1.5134239	eigval=16.162489
# epoch=2862	loss_val=1.5133902	eigval=16.162489
# epoch=2863	loss_val=1.5133568	eigval=16.162489
# epoch=2864	loss_val=1.5133231	eigval=16.162489
# epoch=2865	loss_val=1.5132893	eigval=16.162489
# epoch=2866	loss_val=1.5132557	eigval=16.162489
# epoch=2867	loss_val=1.5132221	eigval=16.162489
# epoch=2868	loss_val=1.5131885	eigval=16.162489
# epoch=2869	loss_val=1.5131547	eigval=16.162489
# epoch=2870	loss_val=1.5131212	eigval=16.162489
# epoch=2871	loss_val=1.5130875	eigval=16.162489
# epoch=2872	loss_val=1.5130538	eigval=16.162489
# epoch=2873	loss_val=1.5130202	eigval=16.162489
# epoch=2874	loss_val=1.5129865	eigval=16.162489
# epoch=2875	loss_val=1.5129529	eigval=16.162489
# epoch=2876	loss_val=1.5129192	eigval=16.162489
# epoch=2877	loss_val=1.5128857	eigval=16.162489
# epoch=2878	loss_val=1.5128518	eigval=16.162489
# epoch=2879	loss_val=1.5128182	eigval=16.162489
# epoch=2880	loss_val=1.5127847	eigval=16.162489
# epoch=2881	loss_val=1.5127511	eigval=16.162489
# epoch=2882	loss_val=1.5127172	eigval=16.162489
# epoch=2883	loss_val=1.5126837	eigval=16.162489
# epoch=2884	loss_val=1.51265	eigval=16.162489
# epoch=2885	loss_val=1.5126164	eigval=16.162489
# epoch=2886	loss_val=1.5125827	eigval=16.162489
# epoch=2887	loss_val=1.5125492	eigval=16.162489
# epoch=2888	loss_val=1.5125155	eigval=16.162489
# epoch=2889	loss_val=1.5124818	eigval=16.162489
# epoch=2890	loss_val=1.5124482	eigval=16.162489
# epoch=2891	loss_val=1.5124147	eigval=16.162489
# epoch=2892	loss_val=1.5123808	eigval=16.162489
# epoch=2893	loss_val=1.5123473	eigval=16.162489
# epoch=2894	loss_val=1.5123136	eigval=16.162489
# epoch=2895	loss_val=1.5122801	eigval=16.162489
# epoch=2896	loss_val=1.5122463	eigval=16.162489
# epoch=2897	loss_val=1.5122126	eigval=16.162489
# epoch=2898	loss_val=1.5121791	eigval=16.162489
# epoch=2899	loss_val=1.5121454	eigval=16.162489
# epoch=2900	loss_val=1.5121117	eigval=16.162489
# epoch=2901	loss_val=1.5120782	eigval=16.162489
# epoch=2902	loss_val=1.5120445	eigval=16.162489
# epoch=2903	loss_val=1.5120107	eigval=16.162489
# epoch=2904	loss_val=1.5119772	eigval=16.162489
# epoch=2905	loss_val=1.5119436	eigval=16.162489
# epoch=2906	loss_val=1.5119098	eigval=16.162489
# epoch=2907	loss_val=1.5118763	eigval=16.162489
# epoch=2908	loss_val=1.5118426	eigval=16.162489
# epoch=2909	loss_val=1.511809	eigval=16.162489
# epoch=2910	loss_val=1.5117753	eigval=16.162489
# epoch=2911	loss_val=1.5117419	eigval=16.162489
# epoch=2912	loss_val=1.5117081	eigval=16.162489
# epoch=2913	loss_val=1.5116745	eigval=16.162489
# epoch=2914	loss_val=1.5116409	eigval=16.162489
# epoch=2915	loss_val=1.5116073	eigval=16.162489
# epoch=2916	loss_val=1.5115734	eigval=16.162489
# epoch=2917	loss_val=1.51154	eigval=16.162489
# epoch=2918	loss_val=1.5115063	eigval=16.162489
# epoch=2919	loss_val=1.5114727	eigval=16.162489
# epoch=2920	loss_val=1.5114391	eigval=16.162489
# epoch=2921	loss_val=1.5114053	eigval=16.162489
# epoch=2922	loss_val=1.5113717	eigval=16.162489
# epoch=2923	loss_val=1.5113381	eigval=16.162489
# epoch=2924	loss_val=1.5113045	eigval=16.162489
# epoch=2925	loss_val=1.5112709	eigval=16.162489
# epoch=2926	loss_val=1.5112371	eigval=16.162489
# epoch=2927	loss_val=1.5112036	eigval=16.162489
# epoch=2928	loss_val=1.5111699	eigval=16.162489
# epoch=2929	loss_val=1.5111364	eigval=16.162489
# epoch=2930	loss_val=1.5111028	eigval=16.162489
# epoch=2931	loss_val=1.5110693	eigval=16.162489
# epoch=2932	loss_val=1.5110356	eigval=16.162489
# epoch=2933	loss_val=1.5110018	eigval=16.162489
# epoch=2934	loss_val=1.5109682	eigval=16.162489
# epoch=2935	loss_val=1.5109347	eigval=16.162489
# epoch=2936	loss_val=1.510901	eigval=16.162489
# epoch=2937	loss_val=1.5108674	eigval=16.162489
# epoch=2938	loss_val=1.5108337	eigval=16.162489
# epoch=2939	loss_val=1.5108001	eigval=16.162489
# epoch=2940	loss_val=1.5107664	eigval=16.162489
# epoch=2941	loss_val=1.5107328	eigval=16.162489
# epoch=2942	loss_val=1.5106993	eigval=16.162489
# epoch=2943	loss_val=1.5106654	eigval=16.162489
# epoch=2944	loss_val=1.5106319	eigval=16.162489
# epoch=2945	loss_val=1.5105984	eigval=16.162489
# epoch=2946	loss_val=1.5105647	eigval=16.162489
# epoch=2947	loss_val=1.5105311	eigval=16.162489
# epoch=2948	loss_val=1.5104975	eigval=16.162489
# epoch=2949	loss_val=1.510464	eigval=16.162489
# epoch=2950	loss_val=1.5104302	eigval=16.162489
# epoch=2951	loss_val=1.5103965	eigval=16.162489
# epoch=2952	loss_val=1.510363	eigval=16.162489
# epoch=2953	loss_val=1.5103294	eigval=16.162489
# epoch=2954	loss_val=1.5102957	eigval=16.162489
# epoch=2955	loss_val=1.5102621	eigval=16.162489
# epoch=2956	loss_val=1.5102285	eigval=16.162489
# epoch=2957	loss_val=1.5101949	eigval=16.162489
# epoch=2958	loss_val=1.5101613	eigval=16.162489
# epoch=2959	loss_val=1.5101277	eigval=16.162489
# epoch=2960	loss_val=1.5100939	eigval=16.162489
# epoch=2961	loss_val=1.5100604	eigval=16.162489
# epoch=2962	loss_val=1.5100268	eigval=16.162489
# epoch=2963	loss_val=1.5099932	eigval=16.162489
# epoch=2964	loss_val=1.5099595	eigval=16.162489
# epoch=2965	loss_val=1.5099258	eigval=16.162489
# epoch=2966	loss_val=1.5098923	eigval=16.162489
# epoch=2967	loss_val=1.5098587	eigval=16.162489
# epoch=2968	loss_val=1.5098252	eigval=16.162489
# epoch=2969	loss_val=1.5097916	eigval=16.162489
# epoch=2970	loss_val=1.5097579	eigval=16.162489
# epoch=2971	loss_val=1.5097243	eigval=16.162489
# epoch=2972	loss_val=1.5096906	eigval=16.162489
# epoch=2973	loss_val=1.509657	eigval=16.162489
# epoch=2974	loss_val=1.5096233	eigval=16.162489
# epoch=2975	loss_val=1.5095898	eigval=16.162489
# epoch=2976	loss_val=1.509556	eigval=16.162489
# epoch=2977	loss_val=1.5095228	eigval=16.162489
# epoch=2978	loss_val=1.5094889	eigval=16.162489
# epoch=2979	loss_val=1.5094554	eigval=16.162489
# epoch=2980	loss_val=1.5094217	eigval=16.162489
# epoch=2981	loss_val=1.5093882	eigval=16.162489
# epoch=2982	loss_val=1.5093546	eigval=16.162489
# epoch=2983	loss_val=1.509321	eigval=16.162489
# epoch=2984	loss_val=1.5092874	eigval=16.162489
# epoch=2985	loss_val=1.5092537	eigval=16.162489
# epoch=2986	loss_val=1.50922	eigval=16.162489
# epoch=2987	loss_val=1.5091866	eigval=16.162489
# epoch=2988	loss_val=1.509153	eigval=16.162489
# epoch=2989	loss_val=1.5091193	eigval=16.162489
# epoch=2990	loss_val=1.5090858	eigval=16.162489
# epoch=2991	loss_val=1.5090522	eigval=16.162489
# epoch=2992	loss_val=1.5090185	eigval=16.162489
# epoch=2993	loss_val=1.5089849	eigval=16.162489
# epoch=2994	loss_val=1.5089512	eigval=16.162489
# epoch=2995	loss_val=1.5089177	eigval=16.162489
# epoch=2996	loss_val=1.5088841	eigval=16.162489
# epoch=2997	loss_val=1.5088506	eigval=16.162489
# epoch=2998	loss_val=1.5088168	eigval=16.162489
# epoch=2999	loss_val=1.5087832	eigval=16.162489

# %%
# predict the values at a grid of points (a mesh) so we can view predicted contour of the solution
# using the mean interpolated from trained values
import numpy as np

n = 100
ngrid = n * n
_xgrid = np.linspace(0.0, a, n)
_ygrid = np.linspace(0.0, b, n)
X, Y = np.meshgrid(_xgrid, _ygrid)
xgrid = np.reshape(X, newshape=(ngrid,1))
ygrid = np.reshape(Y, newshape=(ngrid,1))
x_grid = np.concatenate([xgrid, ygrid], axis=1)

# old non-vectorized way
# K_train = np.array([[kernel2d(x_all[i,:], x_all[j,:]) for j in range(num_all)] for i in range(num_all)])
# K_cross = np.array([[kernel2d(x_grid[i,:], x_all[j,:]) for j in range(num_all)] for i in range(ngrid)])

# vectorized way like 100x faster
K_train = kernel2d_tf(x_all_L, x_all_R, p_tf, L_tf)
x_grid_L = tf.expand_dims(tf.constant(x_grid, dtype=DTYPE), axis=1)
K_cross = kernel2d_tf(x_grid_L, x_all_R, p_tf, L_tf)

max_eigval = np.max(np.linalg.eigvalsh(K_train))
W_grid = K_cross @ np.linalg.solve(K_train + 1e-5 * max_eigval * np.eye(num_all), w_full[:num_all,:])
W = np.reshape(W_grid, newshape=(n, n))

# %%
import matplotlib.pyplot as plt
# now plot the predicted solution contour
plt.figure(figsize=(8, 6))
colors = plt.contourf(X, Y, W, levels=20, cmap='viridis', alpha=0.75)  # Filled contours
plt.gca().set_aspect('equal')
plt.colorbar(colors, label="w(x,y)")  # Colorbar for reference

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
# now plot the predicted solution surface in 3d
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, W, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=1)
ax.set_aspect('equalxy')
plt.show()
