# %% [markdown]
# # TUNED or Cleaned up version of Linear Static Analysis
# TODO : add either relu kernel zero at boundary
# and/or add kernels of different length scales.
# Also could try Matern kernel or other kernels that can mix different length scales.
# For buckling could try some type of sine kernel?

# %%
# panel linear static inputs
# buckling inputs
# ----------------

# aluminum plate material properties
E = 70e9; nu = 0.3; thick = 0.005
D = E * thick**3 / 12.0 / (1 - nu**2)
(a, b) = (3, 1)

# choose kernel hyperparameters
Lx = 0.4; Ly = 0.4
Lx2 = 0.25; Ly2 = 0.25
c2 = 0.0

def q_load(x,y): # distributed load across the panel
    return 1.0 + 3.0 * x

# %%
# compute the linear static analysis inputs and mesh domain of collocation pts
# ----------------------------------------------------------------------------
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# case = 'low'
# case = 'medium'
case = 'high'

if case == 'high':
    num_domain = 300
    num_bndry = 100
    num_test = 50
elif case == 'medium':
    num_domain = 40
    num_bndry = 10
    num_test = 50
elif case == 'low':
    num_domain = 10
    num_bndry = 5
    num_test = 5

num_interior = num_domain
DTYPE = tf.float32

# set the boundary of the panel
xmin = 0; xmax = a
ymin = 0; ymax = b

lb = tf.constant([xmin, ymin], dtype=DTYPE)
ub = tf.constant([xmax, ymax], dtype=DTYPE)

# generate the collocation points on the interior
def gen_collocation_points(num_domain, minval, maxval):
    x_r = tf.random.uniform((num_domain,1), minval[0], maxval[0], dtype=DTYPE)
    y_r = tf.random.uniform((num_domain,1), minval[1], maxval[1], dtype=DTYPE)
    X_r = tf.concat([x_r, y_r], axis=1)
    # data_init = tf.random_uniform_initializer(minval=minval, maxval=maxval, seed=0)
    # return tf.Variable(data_init(shape=[num_domain, 1]), dtype=tf.float32)
    return tf.Variable(X_r, dtype=DTYPE)

x_train = gen_collocation_points(num_domain, lb, ub)
x_test = gen_collocation_points(num_test, lb, ub)
print(f"{type(x_train)=}")

x = x_train[:,0:1]
y = x_train[:,1:2]

x2 = x_test[:,0:1]
y2 = x_test[:,1:2]

# generate boundary domain points
assert num_bndry % 2 == 0
N_b = int(num_bndry / 2)
x_b1 = tf.random.uniform((N_b,1), lb[0], ub[0], dtype=DTYPE)
y_b1 = lb[1] + (ub[1] - lb[1]) * \
    tf.keras.backend.random_bernoulli((N_b,1), 0.5, dtype=DTYPE)
X_b1 = tf.concat([x_b1, y_b1], axis=1)

# boundary data on x edges
y_b2 = tf.random.uniform((N_b,1), lb[1], ub[1], dtype=DTYPE)
x_b2 = lb[0] + (ub[0] - lb[0]) * \
    tf.keras.backend.random_bernoulli((N_b,1), 0.5, dtype=DTYPE)
# print(f"{x_b2=}")
X_b2 = tf.concat([x_b2, y_b2], axis=1)
# print(f"{X_b2=}")
# print(f"{x_b2=}")

x_bndry = tf.Variable(tf.concat([X_b1, X_b2], axis=0), dtype=DTYPE)

# plot the data to check
plt.scatter(x_bndry[:,0], x_bndry[:,1])
plt.scatter(x_train[:,0], x_train[:,1]) # only show 1000 of the points
plt.show()

# q vector
_temp = np.array([q_load(x[i], y[i]) for i in range(num_domain)])
q = tf.constant(_temp, shape=(num_domain,1), dtype=DTYPE)
# Out:
# type(x_train)=<class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>

# %%
# define vectorized versions of the kernel functions
# like 1000x faster at assembling covariance functions

L_tf = tf.constant(np.array([Lx, Ly]), dtype=DTYPE)
L_tf2 = tf.constant(np.array([Lx2, Ly2]), dtype=DTYPE)
def SE_kernel2d_tf(x, xp, Lvec):
    # x input is N x 1 x 2 array, xp is 1 x M x 2 array
    # xbar is then an N x M x 2 shape array
    # print(f"{x=} {L_tf=}")
    xbar = (x - xp) / Lvec
    # output is N x M matrix of kernel matrix
    return tf.exp(-0.5 * tf.reduce_sum(tf.pow(xbar, 2.0), axis=-1))

def kernel2d_tf(x, xp):
    """composite kernel definition"""
    return SE_kernel2d_tf(x, xp, L_tf) + c2 * SE_kernel2d_tf(x, xp, L_tf2)

def d2_fact(xbar, L):
    return L**(-2.0) * (-1.0 + xbar**2)

def d4_fact(xbar,L):
    return L**(-4.0) * (3.0 - 6.0 * xbar**2 + xbar**4)

def d6_fact(xbar,L):
    return L**(-6.0) * (-15 + 45 * xbar**2 - 15 * xbar**4 + xbar**6)

def d8_fact(xbar,L):
    return L**(-8.0) * (105 - 420 * xbar**2 + 210 * xbar**4 - 28 * xbar**6 + xbar**8)

def SE_kernel2d_bilapl_tf(x, xp, Lvec):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / Lvec # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = Lvec[0]; Ly = Lvec[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    return K * (d4_fact(x1bar,Lx) + 2.0 * d2_fact(x1bar, Lx) * d2_fact(x2bar, Ly) + d4_fact(x2bar, Ly))

def kernel2d_bilapl_tf(x, xp):
    """composite kernel definition"""
    return SE_kernel2d_bilapl_tf(x, xp, L_tf) + c2 * SE_kernel2d_bilapl_tf(x, xp, L_tf2)

def SE_kernel2d_double_bilapl_tf(x, xp, Lvec):
    # first two dimensions are NxN matrix parts
    # x is N x 1 x 2 matrix, xp is 1 x M x 2 matrix
    xbar = (x - xp) / Lvec # N x M x 2 matrix
    x1bar = xbar[:,:,0]
    x2bar = xbar[:,:,1]
    Lx = Lvec[0]; Ly = Lvec[1]

    # baseline kernel matrix which we will scale and add some terms
    K = kernel2d_tf(x,xp)

    return K * (d8_fact(x1bar,Lx) + \
                4.0 * d6_fact(x1bar, Lx) * d2_fact(x2bar, Ly) +\
                6.0 * d4_fact(x1bar, Lx) * d4_fact(x2bar, Ly) +\
                4.0 * d2_fact(x1bar, Lx) * d6_fact(x2bar, Ly) +\
                d8_fact(x2bar, Ly))

def kernel2d_double_bilapl_tf(x, xp):
    """composite kernel definition"""
    return SE_kernel2d_double_bilapl_tf(x, xp, L_tf) + c2 * SE_kernel2d_double_bilapl_tf(x, xp, L_tf2)

# %%
# compute the block matrix Sigma = [cov(w_int, w_int), cov(w_int, w_bndry), cov(w_int, nabla^4 w_int),
#                                   cov(w_bndry, w_int), cov(w_bndry, w_bndry), cov(w_bndry, nabla^4 w_bndry),
#                                   cov(nabla^4 w_int, w_int), cov(nabla^4 w_int, w_bndry), cov(nabla^4 w_int, nabla^4 w_int) ]
# not a function of theta..
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

n_block = 2 * num_interior + num_bndry
x_all = tf.concat([x_train, x_bndry], axis=0)
num_all = num_interior + num_bndry

# 11 - interior+bndry self-covariance
x_all_L = tf.expand_dims(x_all, axis=1)
x_all_R = tf.expand_dims(x_all, axis=0)
K11 = tf.constant(kernel2d_tf(x_all_L, x_all_R), dtype=DTYPE)

# 12 - interior+bndry cov with nabla^4 w on interior
x_interior_L = tf.expand_dims(x_train, axis=1)
K12 = tf.constant(kernel2d_bilapl_tf(x_interior_L, x_all_R), dtype=DTYPE)
# K21 = tf.transpose(K12)

# 22 - self-cov with nabla^4 w in interior
x_interior_R = tf.expand_dims(x_train, axis=0)
K22 = tf.constant(kernel2d_double_bilapl_tf(x_interior_L, x_interior_R), dtype=DTYPE)

print(f"{num_interior=} {num_all=}")
print(f"{K11.shape=} {K12.shape=} {K22.shape=}")

# assemble full covariance matrix
_row1 = tf.constant(tf.concat([K11, tf.transpose(K12)], axis=1))
_row2 = tf.constant(tf.concat([K12, K22], axis=1))
Kblock_prereg = tf.concat([_row1, _row2], axis=0)

print(f"done with full matrix assembly..")

# apply robust regularization w.r.t. the max eigenvalue, namely we add epsilon * I term to matrix
# where epsilon = alpha * lambda_max
alpha = 1e-5
eigvals = np.linalg.eigvalsh(Kblock_prereg)
max_eigval = np.max(eigvals)
eps = alpha * max_eigval

print("done with eigenvalues solve")

Kblock = tf.constant(Kblock_prereg + eps * tf.eye(n_block), dtype=DTYPE)

# show the matrix image to see if positive definite roughly
plt.imshow(Kblock)
plt.colorbar()
# Out:
# num_interior=300 num_all=400
# K11.shape=TensorShape([400, 400]) K12.shape=TensorShape([300, 400]) K22.shape=TensorShape([300, 300])
# done with full matrix assembly..
# done with eigenvalues solve

# %%
# define GP vectors and factor cov matrix into LU
# -----------------------------------------------

K_lu = tf.linalg.lu(Kblock)

w_ext = tf.zeros(shape=(num_bndry,1), dtype=DTYPE)
print(f"{w_ext.shape=}")
nabla4_w = q / D
nabla4_w2 = tf.reshape(nabla4_w, shape=(num_domain,1))
print(f"{nabla4_w2.shape=}")

_temp = tf.concat([w_ext, nabla4_w2], axis=0)
fixed_vec = tf.constant(_temp, dtype=DTYPE)

theta_arr = tf.zeros(shape=(num_domain,1), dtype=DTYPE)
theta = tf.Variable(theta_arr, trainable=True, dtype=DTYPE)
# Out:
# w_ext.shape=TensorShape([100, 1])
# nabla4_w2.shape=TensorShape([300, 1])

# %%
num_epochs = 2000
learning_rate = 1e-5 # can be much higher here?
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

for epoch in range(num_epochs):
    # record the loss gradient
    with tf.GradientTape(persistent=True) as tape:
        w_full = tf.concat([theta, fixed_vec], axis=0)
        ans = tf.linalg.lu_solve(*K_lu, rhs=w_full)

        loss = tf.tensordot(tf.transpose(w_full), ans, axes=1)
        loss *= 1e3 # *= D

    loss_gradient = tape.gradient(loss, theta)
    # print(f"{loss_gradient=}")

    # could change to Gauss-newton algorithm here instead.. would prob be better

    # gradient descent with adam optimizer
    optimizer.apply_gradients(
        [(loss_gradient, theta)]
    )
    del tape

    loss_val = loss.numpy()[0,0]
    print(f"{epoch=}\t{loss_val=}")

# print(f"{theta=}")
# Out:
# epoch=0	loss_val=8.213804e-05
# epoch=1	loss_val=8.075055e-05
# epoch=2	loss_val=7.9639125e-05
# epoch=3	loss_val=7.8782825e-05
# epoch=4	loss_val=7.814394e-05
# epoch=5	loss_val=7.7678786e-05
# epoch=6	loss_val=7.73536e-05
# epoch=7	loss_val=7.7140816e-05
# epoch=8	loss_val=7.701751e-05
# epoch=9	loss_val=7.696211e-05
# epoch=10	loss_val=7.6954704e-05
# epoch=11	loss_val=7.697737e-05
# epoch=12	loss_val=7.7016375e-05
# epoch=13	loss_val=7.706109e-05
# epoch=14	loss_val=7.710259e-05
# epoch=15	loss_val=7.7133656e-05
# epoch=16	loss_val=7.715035e-05
# epoch=17	loss_val=7.7150704e-05
# epoch=18	loss_val=7.71369e-05
# epoch=19	loss_val=7.711058e-05
# epoch=20	loss_val=7.707497e-05
# epoch=21	loss_val=7.703329e-05
# epoch=22	loss_val=7.69892e-05
# epoch=23	loss_val=7.6945755e-05
# epoch=24	loss_val=7.690645e-05
# epoch=25	loss_val=7.687258e-05
# epoch=26	loss_val=7.684548e-05
# epoch=27	loss_val=7.6825316e-05
# epoch=28	loss_val=7.6812204e-05
# epoch=29	loss_val=7.680546e-05
# epoch=30	loss_val=7.680362e-05
# epoch=31	loss_val=7.680514e-05
# epoch=32	loss_val=7.680867e-05
# epoch=33	loss_val=7.681288e-05
# epoch=34	loss_val=7.681656e-05
# epoch=35	loss_val=7.68192e-05
# epoch=36	loss_val=7.682031e-05
# epoch=37	loss_val=7.681915e-05
# epoch=38	loss_val=7.681602e-05
# epoch=39	loss_val=7.681128e-05
# epoch=40	loss_val=7.6805925e-05
# epoch=41	loss_val=7.679996e-05
# epoch=42	loss_val=7.6794066e-05
# epoch=43	loss_val=7.678871e-05
# epoch=44	loss_val=7.678406e-05
# epoch=45	loss_val=7.6780605e-05
# epoch=46	loss_val=7.677802e-05
# epoch=47	loss_val=7.677637e-05
# epoch=48	loss_val=7.6775694e-05
# epoch=49	loss_val=7.6775694e-05
# epoch=50	loss_val=7.677615e-05
# epoch=51	loss_val=7.67768e-05
# epoch=52	loss_val=7.677696e-05
# epoch=53	loss_val=7.6777345e-05
# epoch=54	loss_val=7.677718e-05
# epoch=55	loss_val=7.677674e-05
# epoch=56	loss_val=7.677619e-05
# epoch=57	loss_val=7.677557e-05
# epoch=58	loss_val=7.677466e-05
# epoch=59	loss_val=7.67737e-05
# epoch=60	loss_val=7.677289e-05
# epoch=61	loss_val=7.677221e-05
# epoch=62	loss_val=7.677151e-05
# epoch=63	loss_val=7.677102e-05
# epoch=64	loss_val=7.677062e-05
# epoch=65	loss_val=7.677066e-05
# epoch=66	loss_val=7.67705e-05
# epoch=67	loss_val=7.677041e-05
# epoch=68	loss_val=7.677044e-05
# epoch=69	loss_val=7.67706e-05
# epoch=70	loss_val=7.677079e-05
# epoch=71	loss_val=7.677053e-05
# epoch=72	loss_val=7.677059e-05
# epoch=73	loss_val=7.677041e-05
# epoch=74	loss_val=7.677026e-05
# epoch=75	loss_val=7.676994e-05
# epoch=76	loss_val=7.6769866e-05
# epoch=77	loss_val=7.676987e-05
# epoch=78	loss_val=7.676948e-05
# epoch=79	loss_val=7.6769524e-05
# epoch=80	loss_val=7.676939e-05
# epoch=81	loss_val=7.676941e-05
# epoch=82	loss_val=7.676938e-05
# epoch=83	loss_val=7.676916e-05
# epoch=84	loss_val=7.6769444e-05
# epoch=85	loss_val=7.6769385e-05
# epoch=86	loss_val=7.67694e-05
# epoch=87	loss_val=7.676947e-05
# epoch=88	loss_val=7.676946e-05
# epoch=89	loss_val=7.676929e-05
# epoch=90	loss_val=7.676942e-05
# epoch=91	loss_val=7.676932e-05
# epoch=92	loss_val=7.67693e-05
# epoch=93	loss_val=7.676912e-05
# epoch=94	loss_val=7.6769276e-05
# epoch=95	loss_val=7.676907e-05
# epoch=96	loss_val=7.676934e-05
# epoch=97	loss_val=7.676904e-05
# epoch=98	loss_val=7.6769174e-05
# epoch=99	loss_val=7.67693e-05
# epoch=100	loss_val=7.676913e-05
# epoch=101	loss_val=7.67691e-05
# epoch=102	loss_val=7.676938e-05
# epoch=103	loss_val=7.676932e-05
# epoch=104	loss_val=7.676909e-05
# epoch=105	loss_val=7.676922e-05
# epoch=106	loss_val=7.6769385e-05
# epoch=107	loss_val=7.6769065e-05
# epoch=108	loss_val=7.676905e-05
# epoch=109	loss_val=7.676934e-05
# epoch=110	loss_val=7.676917e-05
# epoch=111	loss_val=7.6768985e-05
# epoch=112	loss_val=7.6769196e-05
# epoch=113	loss_val=7.6769116e-05
# epoch=114	loss_val=7.6769014e-05
# epoch=115	loss_val=7.6769116e-05
# epoch=116	loss_val=7.676921e-05
# epoch=117	loss_val=7.676929e-05
# epoch=118	loss_val=7.67692e-05
# epoch=119	loss_val=7.676905e-05
# epoch=120	loss_val=7.6769e-05
# epoch=121	loss_val=7.676926e-05
# epoch=122	loss_val=7.676921e-05
# epoch=123	loss_val=7.676916e-05
# epoch=124	loss_val=7.6769196e-05
# epoch=125	loss_val=7.676901e-05
# epoch=126	loss_val=7.6769e-05
# epoch=127	loss_val=7.6769094e-05
# epoch=128	loss_val=7.676898e-05
# epoch=129	loss_val=7.67689e-05
# epoch=130	loss_val=7.676916e-05
# epoch=131	loss_val=7.6769036e-05
# epoch=132	loss_val=7.67693e-05
# epoch=133	loss_val=7.676908e-05
# epoch=134	loss_val=7.676924e-05
# epoch=135	loss_val=7.676909e-05
# epoch=136	loss_val=7.676923e-05
# epoch=137	loss_val=7.676896e-05
# epoch=138	loss_val=7.6769094e-05
# epoch=139	loss_val=7.676923e-05
# epoch=140	loss_val=7.6769094e-05
# epoch=141	loss_val=7.676917e-05
# epoch=142	loss_val=7.6769145e-05
# epoch=143	loss_val=7.676907e-05
# epoch=144	loss_val=7.676918e-05
# epoch=145	loss_val=7.6769196e-05
# epoch=146	loss_val=7.676922e-05
# epoch=147	loss_val=7.6769116e-05
# epoch=148	loss_val=7.676927e-05
# epoch=149	loss_val=7.676905e-05
# epoch=150	loss_val=7.676918e-05
# epoch=151	loss_val=7.676915e-05
# epoch=152	loss_val=7.676924e-05
# epoch=153	loss_val=7.6769065e-05
# epoch=154	loss_val=7.676927e-05
# epoch=155	loss_val=7.676906e-05
# epoch=156	loss_val=7.676916e-05
# epoch=157	loss_val=7.676908e-05
# epoch=158	loss_val=7.676917e-05
# epoch=159	loss_val=7.676893e-05
# epoch=160	loss_val=7.676908e-05
# epoch=161	loss_val=7.6769116e-05
# epoch=162	loss_val=7.676911e-05
# epoch=163	loss_val=7.6769196e-05
# epoch=164	loss_val=7.6769014e-05
# epoch=165	loss_val=7.676902e-05
# epoch=166	loss_val=7.676895e-05
# epoch=167	loss_val=7.6769094e-05
# epoch=168	loss_val=7.676924e-05
# epoch=169	loss_val=7.676915e-05
# epoch=170	loss_val=7.676911e-05
# epoch=171	loss_val=7.676933e-05
# epoch=172	loss_val=7.676927e-05
# epoch=173	loss_val=7.676917e-05
# epoch=174	loss_val=7.6769225e-05
# epoch=175	loss_val=7.6769145e-05
# epoch=176	loss_val=7.6769036e-05
# epoch=177	loss_val=7.676905e-05
# epoch=178	loss_val=7.676919e-05
# epoch=179	loss_val=7.676907e-05
# epoch=180	loss_val=7.676912e-05
# epoch=181	loss_val=7.6769116e-05
# epoch=182	loss_val=7.676894e-05
# epoch=183	loss_val=7.6769065e-05
# epoch=184	loss_val=7.676922e-05
# epoch=185	loss_val=7.676921e-05
# epoch=186	loss_val=7.676909e-05
# epoch=187	loss_val=7.676919e-05
# epoch=188	loss_val=7.676911e-05
# epoch=189	loss_val=7.6768985e-05
# epoch=190	loss_val=7.6769065e-05
# epoch=191	loss_val=7.6768956e-05
# epoch=192	loss_val=7.676908e-05
# epoch=193	loss_val=7.676919e-05
# epoch=194	loss_val=7.67692e-05
# epoch=195	loss_val=7.676906e-05
# epoch=196	loss_val=7.6769145e-05
# epoch=197	loss_val=7.67692e-05
# epoch=198	loss_val=7.67692e-05
# epoch=199	loss_val=7.67692e-05
# epoch=200	loss_val=7.676903e-05
# epoch=201	loss_val=7.6769116e-05
# epoch=202	loss_val=7.6769174e-05
# epoch=203	loss_val=7.6769276e-05
# epoch=204	loss_val=7.676923e-05
# epoch=205	loss_val=7.676919e-05
# epoch=206	loss_val=7.67691e-05
# epoch=207	loss_val=7.676914e-05
# epoch=208	loss_val=7.6769364e-05
# epoch=209	loss_val=7.676908e-05
# epoch=210	loss_val=7.67691e-05
# epoch=211	loss_val=7.676901e-05
# epoch=212	loss_val=7.676925e-05
# epoch=213	loss_val=7.67691e-05
# epoch=214	loss_val=7.676926e-05
# epoch=215	loss_val=7.676914e-05
# epoch=216	loss_val=7.676894e-05
# epoch=217	loss_val=7.676911e-05
# epoch=218	loss_val=7.6769065e-05
# epoch=219	loss_val=7.676911e-05
# epoch=220	loss_val=7.6769094e-05
# epoch=221	loss_val=7.6769014e-05
# epoch=222	loss_val=7.676909e-05
# epoch=223	loss_val=7.6769276e-05
# epoch=224	loss_val=7.6768956e-05
# epoch=225	loss_val=7.676909e-05
# epoch=226	loss_val=7.6769036e-05
# epoch=227	loss_val=7.67692e-05
# epoch=228	loss_val=7.676912e-05
# epoch=229	loss_val=7.676919e-05
# epoch=230	loss_val=7.6769335e-05
# epoch=231	loss_val=7.676912e-05
# epoch=232	loss_val=7.676912e-05
# epoch=233	loss_val=7.676893e-05
# epoch=234	loss_val=7.6769065e-05
# epoch=235	loss_val=7.676908e-05
# epoch=236	loss_val=7.6769174e-05
# epoch=237	loss_val=7.676912e-05
# epoch=238	loss_val=7.6769364e-05
# epoch=239	loss_val=7.676901e-05
# epoch=240	loss_val=7.676912e-05
# epoch=241	loss_val=7.676911e-05
# epoch=242	loss_val=7.676912e-05
# epoch=243	loss_val=7.676928e-05
# epoch=244	loss_val=7.6769036e-05
# epoch=245	loss_val=7.676916e-05
# epoch=246	loss_val=7.676921e-05
# epoch=247	loss_val=7.676927e-05
# epoch=248	loss_val=7.6769145e-05
# epoch=249	loss_val=7.6769116e-05
# epoch=250	loss_val=7.6769e-05
# epoch=251	loss_val=7.676908e-05
# epoch=252	loss_val=7.676898e-05
# epoch=253	loss_val=7.676908e-05
# epoch=254	loss_val=7.6769065e-05
# epoch=255	loss_val=7.676913e-05
# epoch=256	loss_val=7.6769065e-05
# epoch=257	loss_val=7.676949e-05
# epoch=258	loss_val=7.676909e-05
# epoch=259	loss_val=7.676911e-05
# epoch=260	loss_val=7.6769196e-05
# epoch=261	loss_val=7.676897e-05
# epoch=262	loss_val=7.6769174e-05
# epoch=263	loss_val=7.676924e-05
# epoch=264	loss_val=7.676907e-05
# epoch=265	loss_val=7.676927e-05
# epoch=266	loss_val=7.6769225e-05
# epoch=267	loss_val=7.676924e-05
# epoch=268	loss_val=7.676894e-05
# epoch=269	loss_val=7.676915e-05
# epoch=270	loss_val=7.676921e-05
# epoch=271	loss_val=7.6769116e-05
# epoch=272	loss_val=7.676909e-05
# epoch=273	loss_val=7.676911e-05
# epoch=274	loss_val=7.6769094e-05
# epoch=275	loss_val=7.6769145e-05
# epoch=276	loss_val=7.676922e-05
# epoch=277	loss_val=7.676908e-05
# epoch=278	loss_val=7.676907e-05
# epoch=279	loss_val=7.676913e-05
# epoch=280	loss_val=7.67689e-05
# epoch=281	loss_val=7.6769116e-05
# epoch=282	loss_val=7.6769145e-05
# epoch=283	loss_val=7.676914e-05
# epoch=284	loss_val=7.676925e-05
# epoch=285	loss_val=7.6769145e-05
# epoch=286	loss_val=7.676914e-05
# epoch=287	loss_val=7.6769036e-05
# epoch=288	loss_val=7.6769094e-05
# epoch=289	loss_val=7.676912e-05
# epoch=290	loss_val=7.676916e-05
# epoch=291	loss_val=7.676927e-05
# epoch=292	loss_val=7.676932e-05
# epoch=293	loss_val=7.6768796e-05
# epoch=294	loss_val=7.676908e-05
# epoch=295	loss_val=7.676911e-05
# epoch=296	loss_val=7.676929e-05
# epoch=297	loss_val=7.6769036e-05
# epoch=298	loss_val=7.676891e-05
# epoch=299	loss_val=7.676906e-05
# epoch=300	loss_val=7.67692e-05
# epoch=301	loss_val=7.6769174e-05
# epoch=302	loss_val=7.676933e-05
# epoch=303	loss_val=7.676911e-05
# epoch=304	loss_val=7.676933e-05
# epoch=305	loss_val=7.676892e-05
# epoch=306	loss_val=7.676922e-05
# epoch=307	loss_val=7.6769094e-05
# epoch=308	loss_val=7.676922e-05
# epoch=309	loss_val=7.676903e-05
# epoch=310	loss_val=7.676915e-05
# epoch=311	loss_val=7.676907e-05
# epoch=312	loss_val=7.6769225e-05
# epoch=313	loss_val=7.676927e-05
# epoch=314	loss_val=7.676915e-05
# epoch=315	loss_val=7.676929e-05
# epoch=316	loss_val=7.676908e-05
# epoch=317	loss_val=7.676892e-05
# epoch=318	loss_val=7.6769225e-05
# epoch=319	loss_val=7.676915e-05
# epoch=320	loss_val=7.676914e-05
# epoch=321	loss_val=7.676911e-05
# epoch=322	loss_val=7.676917e-05
# epoch=323	loss_val=7.676904e-05
# epoch=324	loss_val=7.6769145e-05
# epoch=325	loss_val=7.6769255e-05
# epoch=326	loss_val=7.6769145e-05
# epoch=327	loss_val=7.676908e-05
# epoch=328	loss_val=7.676908e-05
# epoch=329	loss_val=7.676897e-05
# epoch=330	loss_val=7.6769276e-05
# epoch=331	loss_val=7.67691e-05
# epoch=332	loss_val=7.676923e-05
# epoch=333	loss_val=7.6769174e-05
# epoch=334	loss_val=7.676908e-05
# epoch=335	loss_val=7.6769094e-05
# epoch=336	loss_val=7.676907e-05
# epoch=337	loss_val=7.676912e-05
# epoch=338	loss_val=7.676904e-05
# epoch=339	loss_val=7.676926e-05
# epoch=340	loss_val=7.676916e-05
# epoch=341	loss_val=7.676901e-05
# epoch=342	loss_val=7.676902e-05
# epoch=343	loss_val=7.676924e-05
# epoch=344	loss_val=7.6769174e-05
# epoch=345	loss_val=7.676917e-05
# epoch=346	loss_val=7.6769014e-05
# epoch=347	loss_val=7.6769065e-05
# epoch=348	loss_val=7.676907e-05
# epoch=349	loss_val=7.676922e-05
# epoch=350	loss_val=7.676929e-05
# epoch=351	loss_val=7.6769145e-05
# epoch=352	loss_val=7.676905e-05
# epoch=353	loss_val=7.6769276e-05
# epoch=354	loss_val=7.676908e-05
# epoch=355	loss_val=7.6769225e-05
# epoch=356	loss_val=7.676908e-05
# epoch=357	loss_val=7.67691e-05
# epoch=358	loss_val=7.676912e-05
# epoch=359	loss_val=7.6769116e-05
# epoch=360	loss_val=7.67692e-05
# epoch=361	loss_val=7.676914e-05
# epoch=362	loss_val=7.676917e-05
# epoch=363	loss_val=7.676926e-05
# epoch=364	loss_val=7.6769335e-05
# epoch=365	loss_val=7.6768985e-05
# epoch=366	loss_val=7.6769174e-05
# epoch=367	loss_val=7.6769225e-05
# epoch=368	loss_val=7.676902e-05
# epoch=369	loss_val=7.676936e-05
# epoch=370	loss_val=7.676899e-05
# epoch=371	loss_val=7.67692e-05
# epoch=372	loss_val=7.676904e-05
# epoch=373	loss_val=7.676907e-05
# epoch=374	loss_val=7.6769065e-05
# epoch=375	loss_val=7.676911e-05
# epoch=376	loss_val=7.676918e-05
# epoch=377	loss_val=7.676918e-05
# epoch=378	loss_val=7.676936e-05
# epoch=379	loss_val=7.676906e-05
# epoch=380	loss_val=7.67691e-05
# epoch=381	loss_val=7.676908e-05
# epoch=382	loss_val=7.676934e-05
# epoch=383	loss_val=7.67691e-05
# epoch=384	loss_val=7.676902e-05
# epoch=385	loss_val=7.676911e-05
# epoch=386	loss_val=7.6769014e-05
# epoch=387	loss_val=7.676918e-05
# epoch=388	loss_val=7.6769276e-05
# epoch=389	loss_val=7.676904e-05
# epoch=390	loss_val=7.6769116e-05
# epoch=391	loss_val=7.6769335e-05
# epoch=392	loss_val=7.676902e-05
# epoch=393	loss_val=7.676907e-05
# epoch=394	loss_val=7.676894e-05
# epoch=395	loss_val=7.676903e-05
# epoch=396	loss_val=7.6769094e-05
# epoch=397	loss_val=7.676913e-05
# epoch=398	loss_val=7.676906e-05
# epoch=399	loss_val=7.6769174e-05
# epoch=400	loss_val=7.676915e-05
# epoch=401	loss_val=7.6769094e-05
# epoch=402	loss_val=7.676908e-05
# epoch=403	loss_val=7.676931e-05
# epoch=404	loss_val=7.6769036e-05
# epoch=405	loss_val=7.676901e-05
# epoch=406	loss_val=7.676911e-05
# epoch=407	loss_val=7.6769094e-05
# epoch=408	loss_val=7.6769094e-05
# epoch=409	loss_val=7.676911e-05
# epoch=410	loss_val=7.6769145e-05
# epoch=411	loss_val=7.676924e-05
# epoch=412	loss_val=7.6769145e-05
# epoch=413	loss_val=7.676899e-05
# epoch=414	loss_val=7.676913e-05
# epoch=415	loss_val=7.676925e-05
# epoch=416	loss_val=7.6768956e-05
# epoch=417	loss_val=7.676917e-05
# epoch=418	loss_val=7.676907e-05
# epoch=419	loss_val=7.676904e-05
# epoch=420	loss_val=7.6769145e-05
# epoch=421	loss_val=7.676892e-05
# epoch=422	loss_val=7.676908e-05
# epoch=423	loss_val=7.6769225e-05
# epoch=424	loss_val=7.6769116e-05
# epoch=425	loss_val=7.676932e-05
# epoch=426	loss_val=7.676922e-05
# epoch=427	loss_val=7.67693e-05
# epoch=428	loss_val=7.676919e-05
# epoch=429	loss_val=7.67691e-05
# epoch=430	loss_val=7.67693e-05
# epoch=431	loss_val=7.6769225e-05
# epoch=432	loss_val=7.676901e-05
# epoch=433	loss_val=7.676903e-05
# epoch=434	loss_val=7.676907e-05
# epoch=435	loss_val=7.676922e-05
# epoch=436	loss_val=7.6769094e-05
# epoch=437	loss_val=7.6769116e-05
# epoch=438	loss_val=7.676905e-05
# epoch=439	loss_val=7.676914e-05
# epoch=440	loss_val=7.6769305e-05
# epoch=441	loss_val=7.676904e-05
# epoch=442	loss_val=7.6769305e-05
# epoch=443	loss_val=7.676911e-05
# epoch=444	loss_val=7.6769065e-05
# epoch=445	loss_val=7.6769276e-05
# epoch=446	loss_val=7.676902e-05
# epoch=447	loss_val=7.676914e-05
# epoch=448	loss_val=7.676919e-05
# epoch=449	loss_val=7.676918e-05
# epoch=450	loss_val=7.67689e-05
# epoch=451	loss_val=7.676922e-05
# epoch=452	loss_val=7.676917e-05
# epoch=453	loss_val=7.67691e-05
# epoch=454	loss_val=7.676917e-05
# epoch=455	loss_val=7.6768985e-05
# epoch=456	loss_val=7.676916e-05
# epoch=457	loss_val=7.676906e-05
# epoch=458	loss_val=7.676903e-05
# epoch=459	loss_val=7.6769036e-05
# epoch=460	loss_val=7.6769225e-05
# epoch=461	loss_val=7.67693e-05
# epoch=462	loss_val=7.676914e-05
# epoch=463	loss_val=7.676926e-05
# epoch=464	loss_val=7.67691e-05
# epoch=465	loss_val=7.676926e-05
# epoch=466	loss_val=7.67693e-05
# epoch=467	loss_val=7.676913e-05
# epoch=468	loss_val=7.676927e-05
# epoch=469	loss_val=7.676929e-05
# epoch=470	loss_val=7.6769145e-05
# epoch=471	loss_val=7.676918e-05
# epoch=472	loss_val=7.676927e-05
# epoch=473	loss_val=7.676927e-05
# epoch=474	loss_val=7.676917e-05
# epoch=475	loss_val=7.6769255e-05
# epoch=476	loss_val=7.6769014e-05
# epoch=477	loss_val=7.676917e-05
# epoch=478	loss_val=7.6769116e-05
# epoch=479	loss_val=7.67691e-05
# epoch=480	loss_val=7.6769036e-05
# epoch=481	loss_val=7.6769065e-05
# epoch=482	loss_val=7.676901e-05
# epoch=483	loss_val=7.676916e-05
# epoch=484	loss_val=7.676904e-05
# epoch=485	loss_val=7.6769196e-05
# epoch=486	loss_val=7.676906e-05
# epoch=487	loss_val=7.676908e-05
# epoch=488	loss_val=7.676919e-05
# epoch=489	loss_val=7.676918e-05
# epoch=490	loss_val=7.67692e-05
# epoch=491	loss_val=7.67691e-05
# epoch=492	loss_val=7.676918e-05
# epoch=493	loss_val=7.676925e-05
# epoch=494	loss_val=7.676912e-05
# epoch=495	loss_val=7.6769116e-05
# epoch=496	loss_val=7.676912e-05
# epoch=497	loss_val=7.676905e-05
# epoch=498	loss_val=7.676929e-05
# epoch=499	loss_val=7.676896e-05
# epoch=500	loss_val=7.676905e-05
# epoch=501	loss_val=7.676937e-05
# epoch=502	loss_val=7.67691e-05
# epoch=503	loss_val=7.6769014e-05
# epoch=504	loss_val=7.676919e-05
# epoch=505	loss_val=7.676903e-05
# epoch=506	loss_val=7.6769225e-05
# epoch=507	loss_val=7.6769e-05
# epoch=508	loss_val=7.676905e-05
# epoch=509	loss_val=7.676914e-05
# epoch=510	loss_val=7.676893e-05
# epoch=511	loss_val=7.676917e-05
# epoch=512	loss_val=7.676922e-05
# epoch=513	loss_val=7.676906e-05
# epoch=514	loss_val=7.6769094e-05
# epoch=515	loss_val=7.676922e-05
# epoch=516	loss_val=7.676902e-05
# epoch=517	loss_val=7.676904e-05
# epoch=518	loss_val=7.6769225e-05
# epoch=519	loss_val=7.676911e-05
# epoch=520	loss_val=7.676908e-05
# epoch=521	loss_val=7.676907e-05
# epoch=522	loss_val=7.6769116e-05
# epoch=523	loss_val=7.676909e-05
# epoch=524	loss_val=7.676923e-05
# epoch=525	loss_val=7.6769065e-05
# epoch=526	loss_val=7.676913e-05
# epoch=527	loss_val=7.676896e-05
# epoch=528	loss_val=7.6769094e-05
# epoch=529	loss_val=7.676903e-05
# epoch=530	loss_val=7.6769036e-05
# epoch=531	loss_val=7.676918e-05
# epoch=532	loss_val=7.676908e-05
# epoch=533	loss_val=7.676903e-05
# epoch=534	loss_val=7.676919e-05
# epoch=535	loss_val=7.676913e-05
# epoch=536	loss_val=7.676915e-05
# epoch=537	loss_val=7.676924e-05
# epoch=538	loss_val=7.676892e-05
# epoch=539	loss_val=7.676903e-05
# epoch=540	loss_val=7.676929e-05
# epoch=541	loss_val=7.676911e-05
# epoch=542	loss_val=7.676915e-05
# epoch=543	loss_val=7.676914e-05
# epoch=544	loss_val=7.676907e-05
# epoch=545	loss_val=7.6769116e-05
# epoch=546	loss_val=7.676903e-05
# epoch=547	loss_val=7.676926e-05
# epoch=548	loss_val=7.676924e-05
# epoch=549	loss_val=7.676897e-05
# epoch=550	loss_val=7.676926e-05
# epoch=551	loss_val=7.6769116e-05
# epoch=552	loss_val=7.6769225e-05
# epoch=553	loss_val=7.6769e-05
# epoch=554	loss_val=7.676903e-05
# epoch=555	loss_val=7.676899e-05
# epoch=556	loss_val=7.67691e-05
# epoch=557	loss_val=7.676909e-05
# epoch=558	loss_val=7.6769255e-05
# epoch=559	loss_val=7.6769276e-05
# epoch=560	loss_val=7.6769065e-05
# epoch=561	loss_val=7.6769174e-05
# epoch=562	loss_val=7.6768956e-05
# epoch=563	loss_val=7.676892e-05
# epoch=564	loss_val=7.676905e-05
# epoch=565	loss_val=7.6769196e-05
# epoch=566	loss_val=7.6769065e-05
# epoch=567	loss_val=7.6769196e-05
# epoch=568	loss_val=7.676934e-05
# epoch=569	loss_val=7.676919e-05
# epoch=570	loss_val=7.676914e-05
# epoch=571	loss_val=7.676907e-05
# epoch=572	loss_val=7.676895e-05
# epoch=573	loss_val=7.676905e-05
# epoch=574	loss_val=7.676924e-05
# epoch=575	loss_val=7.6769014e-05
# epoch=576	loss_val=7.676909e-05
# epoch=577	loss_val=7.67691e-05
# epoch=578	loss_val=7.676916e-05
# epoch=579	loss_val=7.676921e-05
# epoch=580	loss_val=7.676919e-05
# epoch=581	loss_val=7.676912e-05
# epoch=582	loss_val=7.67692e-05
# epoch=583	loss_val=7.676915e-05
# epoch=584	loss_val=7.6769196e-05
# epoch=585	loss_val=7.676908e-05
# epoch=586	loss_val=7.676908e-05
# epoch=587	loss_val=7.676905e-05
# epoch=588	loss_val=7.676891e-05
# epoch=589	loss_val=7.6769196e-05
# epoch=590	loss_val=7.6768934e-05
# epoch=591	loss_val=7.676908e-05
# epoch=592	loss_val=7.676903e-05
# epoch=593	loss_val=7.6769305e-05
# epoch=594	loss_val=7.6768956e-05
# epoch=595	loss_val=7.6769145e-05
# epoch=596	loss_val=7.676903e-05
# epoch=597	loss_val=7.676908e-05
# epoch=598	loss_val=7.6769116e-05
# epoch=599	loss_val=7.676919e-05
# epoch=600	loss_val=7.676914e-05
# epoch=601	loss_val=7.67692e-05
# epoch=602	loss_val=7.676911e-05
# epoch=603	loss_val=7.67692e-05
# epoch=604	loss_val=7.676906e-05
# epoch=605	loss_val=7.6769094e-05
# epoch=606	loss_val=7.676925e-05
# epoch=607	loss_val=7.676916e-05
# epoch=608	loss_val=7.6769196e-05
# epoch=609	loss_val=7.676915e-05
# epoch=610	loss_val=7.6769255e-05
# epoch=611	loss_val=7.6769e-05
# epoch=612	loss_val=7.676925e-05
# epoch=613	loss_val=7.676915e-05
# epoch=614	loss_val=7.676919e-05
# epoch=615	loss_val=7.676904e-05
# epoch=616	loss_val=7.6769335e-05
# epoch=617	loss_val=7.676904e-05
# epoch=618	loss_val=7.676926e-05
# epoch=619	loss_val=7.676922e-05
# epoch=620	loss_val=7.676896e-05
# epoch=621	loss_val=7.6768934e-05
# epoch=622	loss_val=7.676905e-05
# epoch=623	loss_val=7.676904e-05
# epoch=624	loss_val=7.6769276e-05
# epoch=625	loss_val=7.676908e-05
# epoch=626	loss_val=7.676916e-05
# epoch=627	loss_val=7.67691e-05
# epoch=628	loss_val=7.6769225e-05
# epoch=629	loss_val=7.676912e-05
# epoch=630	loss_val=7.67692e-05
# epoch=631	loss_val=7.676916e-05
# epoch=632	loss_val=7.676904e-05
# epoch=633	loss_val=7.676905e-05
# epoch=634	loss_val=7.676912e-05
# epoch=635	loss_val=7.6769335e-05
# epoch=636	loss_val=7.676924e-05
# epoch=637	loss_val=7.67692e-05
# epoch=638	loss_val=7.676916e-05
# epoch=639	loss_val=7.676917e-05
# epoch=640	loss_val=7.676913e-05
# epoch=641	loss_val=7.67693e-05
# epoch=642	loss_val=7.676919e-05
# epoch=643	loss_val=7.6768985e-05
# epoch=644	loss_val=7.676918e-05
# epoch=645	loss_val=7.6769116e-05
# epoch=646	loss_val=7.6768876e-05
# epoch=647	loss_val=7.676929e-05
# epoch=648	loss_val=7.676927e-05
# epoch=649	loss_val=7.676925e-05
# epoch=650	loss_val=7.676905e-05
# epoch=651	loss_val=7.676918e-05
# epoch=652	loss_val=7.6768934e-05
# epoch=653	loss_val=7.676918e-05
# epoch=654	loss_val=7.6769364e-05
# epoch=655	loss_val=7.676917e-05
# epoch=656	loss_val=7.676914e-05
# epoch=657	loss_val=7.6769e-05
# epoch=658	loss_val=7.6769466e-05
# epoch=659	loss_val=7.676896e-05
# epoch=660	loss_val=7.6769e-05
# epoch=661	loss_val=7.676905e-05
# epoch=662	loss_val=7.676914e-05
# epoch=663	loss_val=7.676937e-05
# epoch=664	loss_val=7.6769255e-05
# epoch=665	loss_val=7.6769225e-05
# epoch=666	loss_val=7.676903e-05
# epoch=667	loss_val=7.676914e-05
# epoch=668	loss_val=7.676907e-05
# epoch=669	loss_val=7.676915e-05
# epoch=670	loss_val=7.676917e-05
# epoch=671	loss_val=7.6768876e-05
# epoch=672	loss_val=7.676915e-05
# epoch=673	loss_val=7.676911e-05
# epoch=674	loss_val=7.6769014e-05
# epoch=675	loss_val=7.676924e-05
# epoch=676	loss_val=7.676902e-05
# epoch=677	loss_val=7.676919e-05
# epoch=678	loss_val=7.676908e-05
# epoch=679	loss_val=7.676913e-05
# epoch=680	loss_val=7.676909e-05
# epoch=681	loss_val=7.6769014e-05
# epoch=682	loss_val=7.676924e-05
# epoch=683	loss_val=7.67692e-05
# epoch=684	loss_val=7.676913e-05
# epoch=685	loss_val=7.676909e-05
# epoch=686	loss_val=7.676923e-05
# epoch=687	loss_val=7.676916e-05
# epoch=688	loss_val=7.676921e-05
# epoch=689	loss_val=7.67692e-05
# epoch=690	loss_val=7.67691e-05
# epoch=691	loss_val=7.676928e-05
# epoch=692	loss_val=7.6769065e-05
# epoch=693	loss_val=7.676906e-05
# epoch=694	loss_val=7.67692e-05
# epoch=695	loss_val=7.676908e-05
# epoch=696	loss_val=7.6769036e-05
# epoch=697	loss_val=7.676905e-05
# epoch=698	loss_val=7.67692e-05
# epoch=699	loss_val=7.676903e-05
# epoch=700	loss_val=7.676907e-05
# epoch=701	loss_val=7.67693e-05
# epoch=702	loss_val=7.676908e-05
# epoch=703	loss_val=7.676911e-05
# epoch=704	loss_val=7.6769e-05
# epoch=705	loss_val=7.676894e-05
# epoch=706	loss_val=7.6769014e-05
# epoch=707	loss_val=7.6769225e-05
# epoch=708	loss_val=7.676896e-05
# epoch=709	loss_val=7.67691e-05
# epoch=710	loss_val=7.6769225e-05
# epoch=711	loss_val=7.676924e-05
# epoch=712	loss_val=7.6769065e-05
# epoch=713	loss_val=7.6768985e-05
# epoch=714	loss_val=7.676916e-05
# epoch=715	loss_val=7.6769145e-05
# epoch=716	loss_val=7.676914e-05
# epoch=717	loss_val=7.676906e-05
# epoch=718	loss_val=7.676919e-05
# epoch=719	loss_val=7.676895e-05
# epoch=720	loss_val=7.676893e-05
# epoch=721	loss_val=7.676923e-05
# epoch=722	loss_val=7.676913e-05
# epoch=723	loss_val=7.676914e-05
# epoch=724	loss_val=7.6769094e-05
# epoch=725	loss_val=7.676913e-05
# epoch=726	loss_val=7.676904e-05
# epoch=727	loss_val=7.676898e-05
# epoch=728	loss_val=7.676918e-05
# epoch=729	loss_val=7.676916e-05
# epoch=730	loss_val=7.676906e-05
# epoch=731	loss_val=7.6769065e-05
# epoch=732	loss_val=7.676933e-05
# epoch=733	loss_val=7.6769036e-05
# epoch=734	loss_val=7.676906e-05
# epoch=735	loss_val=7.6769305e-05
# epoch=736	loss_val=7.676916e-05
# epoch=737	loss_val=7.676932e-05
# epoch=738	loss_val=7.6769145e-05
# epoch=739	loss_val=7.676927e-05
# epoch=740	loss_val=7.676915e-05
# epoch=741	loss_val=7.676916e-05
# epoch=742	loss_val=7.676915e-05
# epoch=743	loss_val=7.67692e-05
# epoch=744	loss_val=7.676917e-05
# epoch=745	loss_val=7.676912e-05
# epoch=746	loss_val=7.676919e-05
# epoch=747	loss_val=7.676913e-05
# epoch=748	loss_val=7.67692e-05
# epoch=749	loss_val=7.676922e-05
# epoch=750	loss_val=7.676921e-05
# epoch=751	loss_val=7.676922e-05
# epoch=752	loss_val=7.676916e-05
# epoch=753	loss_val=7.676914e-05
# epoch=754	loss_val=7.676912e-05
# epoch=755	loss_val=7.6769335e-05
# epoch=756	loss_val=7.6769225e-05
# epoch=757	loss_val=7.676909e-05
# epoch=758	loss_val=7.676929e-05
# epoch=759	loss_val=7.6769014e-05
# epoch=760	loss_val=7.676914e-05
# epoch=761	loss_val=7.676915e-05
# epoch=762	loss_val=7.67689e-05
# epoch=763	loss_val=7.676914e-05
# epoch=764	loss_val=7.6769036e-05
# epoch=765	loss_val=7.676915e-05
# epoch=766	loss_val=7.6768934e-05
# epoch=767	loss_val=7.676939e-05
# epoch=768	loss_val=7.676913e-05
# epoch=769	loss_val=7.6769116e-05
# epoch=770	loss_val=7.676897e-05
# epoch=771	loss_val=7.6768985e-05
# epoch=772	loss_val=7.676928e-05
# epoch=773	loss_val=7.676905e-05
# epoch=774	loss_val=7.676909e-05
# epoch=775	loss_val=7.676897e-05
# epoch=776	loss_val=7.676915e-05
# epoch=777	loss_val=7.676933e-05
# epoch=778	loss_val=7.676917e-05
# epoch=779	loss_val=7.676906e-05
# epoch=780	loss_val=7.6769255e-05
# epoch=781	loss_val=7.676917e-05
# epoch=782	loss_val=7.676908e-05
# epoch=783	loss_val=7.6769094e-05
# epoch=784	loss_val=7.676928e-05
# epoch=785	loss_val=7.6769174e-05
# epoch=786	loss_val=7.67692e-05
# epoch=787	loss_val=7.6769305e-05
# epoch=788	loss_val=7.6769145e-05
# epoch=789	loss_val=7.67693e-05
# epoch=790	loss_val=7.676926e-05
# epoch=791	loss_val=7.6769036e-05
# epoch=792	loss_val=7.676923e-05
# epoch=793	loss_val=7.676914e-05
# epoch=794	loss_val=7.6768985e-05
# epoch=795	loss_val=7.6769225e-05
# epoch=796	loss_val=7.6769225e-05
# epoch=797	loss_val=7.676922e-05
# epoch=798	loss_val=7.676916e-05
# epoch=799	loss_val=7.676898e-05
# epoch=800	loss_val=7.6769276e-05
# epoch=801	loss_val=7.67691e-05
# epoch=802	loss_val=7.676929e-05
# epoch=803	loss_val=7.676923e-05
# epoch=804	loss_val=7.676913e-05
# epoch=805	loss_val=7.676908e-05
# epoch=806	loss_val=7.67691e-05
# epoch=807	loss_val=7.6769116e-05
# epoch=808	loss_val=7.676923e-05
# epoch=809	loss_val=7.676906e-05
# epoch=810	loss_val=7.6769065e-05
# epoch=811	loss_val=7.6769036e-05
# epoch=812	loss_val=7.676912e-05
# epoch=813	loss_val=7.6769116e-05
# epoch=814	loss_val=7.676902e-05
# epoch=815	loss_val=7.6769094e-05
# epoch=816	loss_val=7.676914e-05
# epoch=817	loss_val=7.676921e-05
# epoch=818	loss_val=7.676907e-05
# epoch=819	loss_val=7.676913e-05
# epoch=820	loss_val=7.676918e-05
# epoch=821	loss_val=7.676914e-05
# epoch=822	loss_val=7.676931e-05
# epoch=823	loss_val=7.676908e-05
# epoch=824	loss_val=7.676908e-05
# epoch=825	loss_val=7.676907e-05
# epoch=826	loss_val=7.676918e-05
# epoch=827	loss_val=7.67691e-05
# epoch=828	loss_val=7.676927e-05
# epoch=829	loss_val=7.676918e-05
# epoch=830	loss_val=7.676905e-05
# epoch=831	loss_val=7.676918e-05
# epoch=832	loss_val=7.67692e-05
# epoch=833	loss_val=7.676915e-05
# epoch=834	loss_val=7.67691e-05
# epoch=835	loss_val=7.676914e-05
# epoch=836	loss_val=7.676905e-05
# epoch=837	loss_val=7.6769116e-05
# epoch=838	loss_val=7.676907e-05
# epoch=839	loss_val=7.676928e-05
# epoch=840	loss_val=7.676901e-05
# epoch=841	loss_val=7.67693e-05
# epoch=842	loss_val=7.676926e-05
# epoch=843	loss_val=7.6769335e-05
# epoch=844	loss_val=7.676908e-05
# epoch=845	loss_val=7.6769065e-05
# epoch=846	loss_val=7.676925e-05
# epoch=847	loss_val=7.676926e-05
# epoch=848	loss_val=7.676915e-05
# epoch=849	loss_val=7.6769255e-05
# epoch=850	loss_val=7.67691e-05
# epoch=851	loss_val=7.6769116e-05
# epoch=852	loss_val=7.676919e-05
# epoch=853	loss_val=7.6769065e-05
# epoch=854	loss_val=7.676927e-05
# epoch=855	loss_val=7.676911e-05
# epoch=856	loss_val=7.676895e-05
# epoch=857	loss_val=7.676908e-05
# epoch=858	loss_val=7.676926e-05
# epoch=859	loss_val=7.6769196e-05
# epoch=860	loss_val=7.676913e-05
# epoch=861	loss_val=7.676919e-05
# epoch=862	loss_val=7.676941e-05
# epoch=863	loss_val=7.676916e-05
# epoch=864	loss_val=7.676914e-05
# epoch=865	loss_val=7.676905e-05
# epoch=866	loss_val=7.676899e-05
# epoch=867	loss_val=7.676928e-05
# epoch=868	loss_val=7.676909e-05
# epoch=869	loss_val=7.6769116e-05
# epoch=870	loss_val=7.676908e-05
# epoch=871	loss_val=7.6769065e-05
# epoch=872	loss_val=7.6769174e-05
# epoch=873	loss_val=7.6769145e-05
# epoch=874	loss_val=7.676932e-05
# epoch=875	loss_val=7.676931e-05
# epoch=876	loss_val=7.67692e-05
# epoch=877	loss_val=7.676912e-05
# epoch=878	loss_val=7.6769174e-05
# epoch=879	loss_val=7.676911e-05
# epoch=880	loss_val=7.676908e-05
# epoch=881	loss_val=7.676912e-05
# epoch=882	loss_val=7.676915e-05
# epoch=883	loss_val=7.676914e-05
# epoch=884	loss_val=7.6769065e-05
# epoch=885	loss_val=7.676908e-05
# epoch=886	loss_val=7.6769065e-05
# epoch=887	loss_val=7.676911e-05
# epoch=888	loss_val=7.6769174e-05
# epoch=889	loss_val=7.676926e-05
# epoch=890	loss_val=7.6769e-05
# epoch=891	loss_val=7.6769255e-05
# epoch=892	loss_val=7.67691e-05
# epoch=893	loss_val=7.6769014e-05
# epoch=894	loss_val=7.676914e-05
# epoch=895	loss_val=7.676906e-05
# epoch=896	loss_val=7.676936e-05
# epoch=897	loss_val=7.6769145e-05
# epoch=898	loss_val=7.676928e-05
# epoch=899	loss_val=7.676915e-05
# epoch=900	loss_val=7.6768956e-05
# epoch=901	loss_val=7.6769116e-05
# epoch=902	loss_val=7.676922e-05
# epoch=903	loss_val=7.676921e-05
# epoch=904	loss_val=7.676915e-05
# epoch=905	loss_val=7.676907e-05
# epoch=906	loss_val=7.676902e-05
# epoch=907	loss_val=7.676903e-05
# epoch=908	loss_val=7.676913e-05
# epoch=909	loss_val=7.676903e-05
# epoch=910	loss_val=7.6768934e-05
# epoch=911	loss_val=7.6769036e-05
# epoch=912	loss_val=7.676898e-05
# epoch=913	loss_val=7.676909e-05
# epoch=914	loss_val=7.676917e-05
# epoch=915	loss_val=7.6769225e-05
# epoch=916	loss_val=7.676905e-05
# epoch=917	loss_val=7.676893e-05
# epoch=918	loss_val=7.676908e-05
# epoch=919	loss_val=7.676904e-05
# epoch=920	loss_val=7.676913e-05
# epoch=921	loss_val=7.6769225e-05
# epoch=922	loss_val=7.6769196e-05
# epoch=923	loss_val=7.676907e-05
# epoch=924	loss_val=7.67692e-05
# epoch=925	loss_val=7.676888e-05
# epoch=926	loss_val=7.676911e-05
# epoch=927	loss_val=7.676909e-05
# epoch=928	loss_val=7.676891e-05
# epoch=929	loss_val=7.676922e-05
# epoch=930	loss_val=7.676904e-05
# epoch=931	loss_val=7.6769116e-05
# epoch=932	loss_val=7.676902e-05
# epoch=933	loss_val=7.676921e-05
# epoch=934	loss_val=7.676907e-05
# epoch=935	loss_val=7.6769094e-05
# epoch=936	loss_val=7.676906e-05
# epoch=937	loss_val=7.67688e-05
# epoch=938	loss_val=7.676922e-05
# epoch=939	loss_val=7.676926e-05
# epoch=940	loss_val=7.67692e-05
# epoch=941	loss_val=7.676914e-05
# epoch=942	loss_val=7.676907e-05
# epoch=943	loss_val=7.676943e-05
# epoch=944	loss_val=7.676908e-05
# epoch=945	loss_val=7.676925e-05
# epoch=946	loss_val=7.676897e-05
# epoch=947	loss_val=7.676923e-05
# epoch=948	loss_val=7.676908e-05
# epoch=949	loss_val=7.676912e-05
# epoch=950	loss_val=7.6769174e-05
# epoch=951	loss_val=7.6769196e-05
# epoch=952	loss_val=7.676919e-05
# epoch=953	loss_val=7.676921e-05
# epoch=954	loss_val=7.676922e-05
# epoch=955	loss_val=7.676894e-05
# epoch=956	loss_val=7.6769e-05
# epoch=957	loss_val=7.6769014e-05
# epoch=958	loss_val=7.6769036e-05
# epoch=959	loss_val=7.676912e-05
# epoch=960	loss_val=7.67691e-05
# epoch=961	loss_val=7.6769094e-05
# epoch=962	loss_val=7.676923e-05
# epoch=963	loss_val=7.676929e-05
# epoch=964	loss_val=7.676908e-05
# epoch=965	loss_val=7.676919e-05
# epoch=966	loss_val=7.676899e-05
# epoch=967	loss_val=7.676913e-05
# epoch=968	loss_val=7.676904e-05
# epoch=969	loss_val=7.676925e-05
# epoch=970	loss_val=7.676903e-05
# epoch=971	loss_val=7.676886e-05
# epoch=972	loss_val=7.676916e-05
# epoch=973	loss_val=7.676914e-05
# epoch=974	loss_val=7.676934e-05
# epoch=975	loss_val=7.676897e-05
# epoch=976	loss_val=7.6769276e-05
# epoch=977	loss_val=7.676906e-05
# epoch=978	loss_val=7.676933e-05
# epoch=979	loss_val=7.676902e-05
# epoch=980	loss_val=7.676922e-05
# epoch=981	loss_val=7.6769065e-05
# epoch=982	loss_val=7.676916e-05
# epoch=983	loss_val=7.6769036e-05
# epoch=984	loss_val=7.6769014e-05
# epoch=985	loss_val=7.676908e-05
# epoch=986	loss_val=7.6769094e-05
# epoch=987	loss_val=7.676916e-05
# epoch=988	loss_val=7.676917e-05
# epoch=989	loss_val=7.676918e-05
# epoch=990	loss_val=7.676927e-05
# epoch=991	loss_val=7.67691e-05
# epoch=992	loss_val=7.676913e-05
# epoch=993	loss_val=7.676916e-05
# epoch=994	loss_val=7.676929e-05
# epoch=995	loss_val=7.67691e-05
# epoch=996	loss_val=7.676921e-05
# epoch=997	loss_val=7.676923e-05
# epoch=998	loss_val=7.676921e-05
# epoch=999	loss_val=7.676898e-05
# epoch=1000	loss_val=7.676939e-05
# epoch=1001	loss_val=7.676907e-05
# epoch=1002	loss_val=7.67689e-05
# epoch=1003	loss_val=7.676896e-05
# epoch=1004	loss_val=7.676908e-05
# epoch=1005	loss_val=7.6769305e-05
# epoch=1006	loss_val=7.6769385e-05
# epoch=1007	loss_val=7.676895e-05
# epoch=1008	loss_val=7.676912e-05
# epoch=1009	loss_val=7.676911e-05
# epoch=1010	loss_val=7.6769225e-05
# epoch=1011	loss_val=7.676912e-05
# epoch=1012	loss_val=7.676913e-05
# epoch=1013	loss_val=7.676917e-05
# epoch=1014	loss_val=7.6769145e-05
# epoch=1015	loss_val=7.676913e-05
# epoch=1016	loss_val=7.6769145e-05
# epoch=1017	loss_val=7.676921e-05
# epoch=1018	loss_val=7.676911e-05
# epoch=1019	loss_val=7.676925e-05
# epoch=1020	loss_val=7.676921e-05
# epoch=1021	loss_val=7.676912e-05
# epoch=1022	loss_val=7.676905e-05
# epoch=1023	loss_val=7.6769225e-05
# epoch=1024	loss_val=7.6769116e-05
# epoch=1025	loss_val=7.6769094e-05
# epoch=1026	loss_val=7.676924e-05
# epoch=1027	loss_val=7.676927e-05
# epoch=1028	loss_val=7.676927e-05
# epoch=1029	loss_val=7.6768956e-05
# epoch=1030	loss_val=7.67691e-05
# epoch=1031	loss_val=7.676911e-05
# epoch=1032	loss_val=7.676897e-05
# epoch=1033	loss_val=7.676916e-05
# epoch=1034	loss_val=7.676911e-05
# epoch=1035	loss_val=7.676913e-05
# epoch=1036	loss_val=7.676912e-05
# epoch=1037	loss_val=7.6768985e-05
# epoch=1038	loss_val=7.676903e-05
# epoch=1039	loss_val=7.676915e-05
# epoch=1040	loss_val=7.676927e-05
# epoch=1041	loss_val=7.676901e-05
# epoch=1042	loss_val=7.676921e-05
# epoch=1043	loss_val=7.676896e-05
# epoch=1044	loss_val=7.6769094e-05
# epoch=1045	loss_val=7.676904e-05
# epoch=1046	loss_val=7.676928e-05
# epoch=1047	loss_val=7.676906e-05
# epoch=1048	loss_val=7.676919e-05
# epoch=1049	loss_val=7.6769e-05
# epoch=1050	loss_val=7.676901e-05
# epoch=1051	loss_val=7.676905e-05
# epoch=1052	loss_val=7.676934e-05
# epoch=1053	loss_val=7.676902e-05
# epoch=1054	loss_val=7.676897e-05
# epoch=1055	loss_val=7.676915e-05
# epoch=1056	loss_val=7.676897e-05
# epoch=1057	loss_val=7.676927e-05
# epoch=1058	loss_val=7.676914e-05
# epoch=1059	loss_val=7.676909e-05
# epoch=1060	loss_val=7.676926e-05
# epoch=1061	loss_val=7.6769174e-05
# epoch=1062	loss_val=7.676925e-05
# epoch=1063	loss_val=7.676919e-05
# epoch=1064	loss_val=7.676912e-05
# epoch=1065	loss_val=7.676923e-05
# epoch=1066	loss_val=7.676903e-05
# epoch=1067	loss_val=7.676923e-05
# epoch=1068	loss_val=7.676909e-05
# epoch=1069	loss_val=7.676901e-05
# epoch=1070	loss_val=7.6769305e-05
# epoch=1071	loss_val=7.676884e-05
# epoch=1072	loss_val=7.676928e-05
# epoch=1073	loss_val=7.676908e-05
# epoch=1074	loss_val=7.676912e-05
# epoch=1075	loss_val=7.676937e-05
# epoch=1076	loss_val=7.6769094e-05
# epoch=1077	loss_val=7.6769145e-05
# epoch=1078	loss_val=7.676917e-05
# epoch=1079	loss_val=7.6769196e-05
# epoch=1080	loss_val=7.676913e-05
# epoch=1081	loss_val=7.67691e-05
# epoch=1082	loss_val=7.6769196e-05
# epoch=1083	loss_val=7.676911e-05
# epoch=1084	loss_val=7.6769305e-05
# epoch=1085	loss_val=7.676901e-05
# epoch=1086	loss_val=7.676901e-05
# epoch=1087	loss_val=7.676918e-05
# epoch=1088	loss_val=7.676916e-05
# epoch=1089	loss_val=7.676898e-05
# epoch=1090	loss_val=7.676944e-05
# epoch=1091	loss_val=7.676922e-05
# epoch=1092	loss_val=7.676911e-05
# epoch=1093	loss_val=7.676924e-05
# epoch=1094	loss_val=7.676928e-05
# epoch=1095	loss_val=7.6769094e-05
# epoch=1096	loss_val=7.6769036e-05
# epoch=1097	loss_val=7.676922e-05
# epoch=1098	loss_val=7.676897e-05
# epoch=1099	loss_val=7.676921e-05
# epoch=1100	loss_val=7.67691e-05
# epoch=1101	loss_val=7.6769065e-05
# epoch=1102	loss_val=7.6768934e-05
# epoch=1103	loss_val=7.6769174e-05
# epoch=1104	loss_val=7.676946e-05
# epoch=1105	loss_val=7.6769094e-05
# epoch=1106	loss_val=7.676922e-05
# epoch=1107	loss_val=7.676906e-05
# epoch=1108	loss_val=7.6769065e-05
# epoch=1109	loss_val=7.67692e-05
# epoch=1110	loss_val=7.676921e-05
# epoch=1111	loss_val=7.676917e-05
# epoch=1112	loss_val=7.676922e-05
# epoch=1113	loss_val=7.676932e-05
# epoch=1114	loss_val=7.6769276e-05
# epoch=1115	loss_val=7.6769255e-05
# epoch=1116	loss_val=7.676908e-05
# epoch=1117	loss_val=7.6769014e-05
# epoch=1118	loss_val=7.676911e-05
# epoch=1119	loss_val=7.676925e-05
# epoch=1120	loss_val=7.676929e-05
# epoch=1121	loss_val=7.676922e-05
# epoch=1122	loss_val=7.6769094e-05
# epoch=1123	loss_val=7.6769196e-05
# epoch=1124	loss_val=7.676908e-05
# epoch=1125	loss_val=7.6769225e-05
# epoch=1126	loss_val=7.6769116e-05
# epoch=1127	loss_val=7.676905e-05
# epoch=1128	loss_val=7.676925e-05
# epoch=1129	loss_val=7.676914e-05
# epoch=1130	loss_val=7.6769276e-05
# epoch=1131	loss_val=7.676918e-05
# epoch=1132	loss_val=7.676911e-05
# epoch=1133	loss_val=7.676912e-05
# epoch=1134	loss_val=7.676899e-05
# epoch=1135	loss_val=7.676933e-05
# epoch=1136	loss_val=7.676916e-05
# epoch=1137	loss_val=7.676917e-05
# epoch=1138	loss_val=7.676895e-05
# epoch=1139	loss_val=7.676911e-05
# epoch=1140	loss_val=7.676903e-05
# epoch=1141	loss_val=7.676909e-05
# epoch=1142	loss_val=7.676912e-05
# epoch=1143	loss_val=7.676905e-05
# epoch=1144	loss_val=7.676915e-05
# epoch=1145	loss_val=7.676907e-05
# epoch=1146	loss_val=7.676917e-05
# epoch=1147	loss_val=7.676914e-05
# epoch=1148	loss_val=7.6769094e-05
# epoch=1149	loss_val=7.676912e-05
# epoch=1150	loss_val=7.6769116e-05
# epoch=1151	loss_val=7.676932e-05
# epoch=1152	loss_val=7.676928e-05
# epoch=1153	loss_val=7.6769225e-05
# epoch=1154	loss_val=7.676927e-05
# epoch=1155	loss_val=7.6769225e-05
# epoch=1156	loss_val=7.6769065e-05
# epoch=1157	loss_val=7.6769014e-05
# epoch=1158	loss_val=7.676908e-05
# epoch=1159	loss_val=7.676915e-05
# epoch=1160	loss_val=7.676902e-05
# epoch=1161	loss_val=7.676916e-05
# epoch=1162	loss_val=7.676919e-05
# epoch=1163	loss_val=7.676908e-05
# epoch=1164	loss_val=7.6769225e-05
# epoch=1165	loss_val=7.676932e-05
# epoch=1166	loss_val=7.676939e-05
# epoch=1167	loss_val=7.676918e-05
# epoch=1168	loss_val=7.6769305e-05
# epoch=1169	loss_val=7.676896e-05
# epoch=1170	loss_val=7.676923e-05
# epoch=1171	loss_val=7.6769305e-05
# epoch=1172	loss_val=7.676901e-05
# epoch=1173	loss_val=7.6769116e-05
# epoch=1174	loss_val=7.676911e-05
# epoch=1175	loss_val=7.6769e-05
# epoch=1176	loss_val=7.6769145e-05
# epoch=1177	loss_val=7.676898e-05
# epoch=1178	loss_val=7.67691e-05
# epoch=1179	loss_val=7.676923e-05
# epoch=1180	loss_val=7.6769145e-05
# epoch=1181	loss_val=7.676909e-05
# epoch=1182	loss_val=7.6769415e-05
# epoch=1183	loss_val=7.676896e-05
# epoch=1184	loss_val=7.6769225e-05
# epoch=1185	loss_val=7.676922e-05
# epoch=1186	loss_val=7.676915e-05
# epoch=1187	loss_val=7.6769145e-05
# epoch=1188	loss_val=7.676932e-05
# epoch=1189	loss_val=7.676911e-05
# epoch=1190	loss_val=7.676914e-05
# epoch=1191	loss_val=7.676938e-05
# epoch=1192	loss_val=7.6769116e-05
# epoch=1193	loss_val=7.676906e-05
# epoch=1194	loss_val=7.676934e-05
# epoch=1195	loss_val=7.676899e-05
# epoch=1196	loss_val=7.67692e-05
# epoch=1197	loss_val=7.6769364e-05
# epoch=1198	loss_val=7.676908e-05
# epoch=1199	loss_val=7.676917e-05
# epoch=1200	loss_val=7.676909e-05
# epoch=1201	loss_val=7.6769116e-05
# epoch=1202	loss_val=7.6769255e-05
# epoch=1203	loss_val=7.67692e-05
# epoch=1204	loss_val=7.676911e-05
# epoch=1205	loss_val=7.676917e-05
# epoch=1206	loss_val=7.676906e-05
# epoch=1207	loss_val=7.676924e-05
# epoch=1208	loss_val=7.67691e-05
# epoch=1209	loss_val=7.676908e-05
# epoch=1210	loss_val=7.676896e-05
# epoch=1211	loss_val=7.6768985e-05
# epoch=1212	loss_val=7.676913e-05
# epoch=1213	loss_val=7.6769174e-05
# epoch=1214	loss_val=7.6769065e-05
# epoch=1215	loss_val=7.676924e-05
# epoch=1216	loss_val=7.6769e-05
# epoch=1217	loss_val=7.6768956e-05
# epoch=1218	loss_val=7.676901e-05
# epoch=1219	loss_val=7.676915e-05
# epoch=1220	loss_val=7.676913e-05
# epoch=1221	loss_val=7.676907e-05
# epoch=1222	loss_val=7.6769276e-05
# epoch=1223	loss_val=7.676922e-05
# epoch=1224	loss_val=7.676909e-05
# epoch=1225	loss_val=7.676921e-05
# epoch=1226	loss_val=7.676917e-05
# epoch=1227	loss_val=7.676912e-05
# epoch=1228	loss_val=7.676907e-05
# epoch=1229	loss_val=7.676925e-05
# epoch=1230	loss_val=7.6769145e-05
# epoch=1231	loss_val=7.676904e-05
# epoch=1232	loss_val=7.676929e-05
# epoch=1233	loss_val=7.676935e-05
# epoch=1234	loss_val=7.676912e-05
# epoch=1235	loss_val=7.676912e-05
# epoch=1236	loss_val=7.676914e-05
# epoch=1237	loss_val=7.6769116e-05
# epoch=1238	loss_val=7.6769145e-05
# epoch=1239	loss_val=7.676908e-05
# epoch=1240	loss_val=7.676908e-05
# epoch=1241	loss_val=7.676935e-05
# epoch=1242	loss_val=7.6769255e-05
# epoch=1243	loss_val=7.676908e-05
# epoch=1244	loss_val=7.676913e-05
# epoch=1245	loss_val=7.67692e-05
# epoch=1246	loss_val=7.6769225e-05
# epoch=1247	loss_val=7.6769276e-05
# epoch=1248	loss_val=7.676928e-05
# epoch=1249	loss_val=7.676922e-05
# epoch=1250	loss_val=7.6768956e-05
# epoch=1251	loss_val=7.676923e-05
# epoch=1252	loss_val=7.6768956e-05
# epoch=1253	loss_val=7.676925e-05
# epoch=1254	loss_val=7.676922e-05
# epoch=1255	loss_val=7.676907e-05
# epoch=1256	loss_val=7.6769094e-05
# epoch=1257	loss_val=7.676906e-05
# epoch=1258	loss_val=7.676914e-05
# epoch=1259	loss_val=7.676918e-05
# epoch=1260	loss_val=7.676914e-05
# epoch=1261	loss_val=7.67692e-05
# epoch=1262	loss_val=7.67693e-05
# epoch=1263	loss_val=7.676901e-05
# epoch=1264	loss_val=7.676914e-05
# epoch=1265	loss_val=7.676928e-05
# epoch=1266	loss_val=7.676902e-05
# epoch=1267	loss_val=7.6769196e-05
# epoch=1268	loss_val=7.676935e-05
# epoch=1269	loss_val=7.6769196e-05
# epoch=1270	loss_val=7.676911e-05
# epoch=1271	loss_val=7.67691e-05
# epoch=1272	loss_val=7.6769116e-05
# epoch=1273	loss_val=7.676907e-05
# epoch=1274	loss_val=7.676896e-05
# epoch=1275	loss_val=7.676923e-05
# epoch=1276	loss_val=7.6769036e-05
# epoch=1277	loss_val=7.676901e-05
# epoch=1278	loss_val=7.676911e-05
# epoch=1279	loss_val=7.676908e-05
# epoch=1280	loss_val=7.676911e-05
# epoch=1281	loss_val=7.6769116e-05
# epoch=1282	loss_val=7.676912e-05
# epoch=1283	loss_val=7.676924e-05
# epoch=1284	loss_val=7.6769116e-05
# epoch=1285	loss_val=7.676908e-05
# epoch=1286	loss_val=7.676926e-05
# epoch=1287	loss_val=7.676916e-05
# epoch=1288	loss_val=7.6769116e-05
# epoch=1289	loss_val=7.6769065e-05
# epoch=1290	loss_val=7.676908e-05
# epoch=1291	loss_val=7.676931e-05
# epoch=1292	loss_val=7.676919e-05
# epoch=1293	loss_val=7.6769276e-05
# epoch=1294	loss_val=7.6769094e-05
# epoch=1295	loss_val=7.676918e-05
# epoch=1296	loss_val=7.676922e-05
# epoch=1297	loss_val=7.676911e-05
# epoch=1298	loss_val=7.676932e-05
# epoch=1299	loss_val=7.676913e-05
# epoch=1300	loss_val=7.676899e-05
# epoch=1301	loss_val=7.6769014e-05
# epoch=1302	loss_val=7.676915e-05
# epoch=1303	loss_val=7.676922e-05
# epoch=1304	loss_val=7.676918e-05
# epoch=1305	loss_val=7.676915e-05
# epoch=1306	loss_val=7.676912e-05
# epoch=1307	loss_val=7.6768796e-05
# epoch=1308	loss_val=7.6769094e-05
# epoch=1309	loss_val=7.676917e-05
# epoch=1310	loss_val=7.676928e-05
# epoch=1311	loss_val=7.6769174e-05
# epoch=1312	loss_val=7.676915e-05
# epoch=1313	loss_val=7.6769255e-05
# epoch=1314	loss_val=7.6768985e-05
# epoch=1315	loss_val=7.676927e-05
# epoch=1316	loss_val=7.676916e-05
# epoch=1317	loss_val=7.676915e-05
# epoch=1318	loss_val=7.676905e-05
# epoch=1319	loss_val=7.676907e-05
# epoch=1320	loss_val=7.676922e-05
# epoch=1321	loss_val=7.6769225e-05
# epoch=1322	loss_val=7.676927e-05
# epoch=1323	loss_val=7.676895e-05
# epoch=1324	loss_val=7.676909e-05
# epoch=1325	loss_val=7.676914e-05
# epoch=1326	loss_val=7.676911e-05
# epoch=1327	loss_val=7.6769e-05
# epoch=1328	loss_val=7.676927e-05
# epoch=1329	loss_val=7.676918e-05
# epoch=1330	loss_val=7.6769225e-05
# epoch=1331	loss_val=7.676908e-05
# epoch=1332	loss_val=7.676917e-05
# epoch=1333	loss_val=7.676908e-05
# epoch=1334	loss_val=7.6769305e-05
# epoch=1335	loss_val=7.676909e-05
# epoch=1336	loss_val=7.676906e-05
# epoch=1337	loss_val=7.676892e-05
# epoch=1338	loss_val=7.6769e-05
# epoch=1339	loss_val=7.676908e-05
# epoch=1340	loss_val=7.6769255e-05
# epoch=1341	loss_val=7.676899e-05
# epoch=1342	loss_val=7.676911e-05
# epoch=1343	loss_val=7.676932e-05
# epoch=1344	loss_val=7.676908e-05
# epoch=1345	loss_val=7.676916e-05
# epoch=1346	loss_val=7.6768985e-05
# epoch=1347	loss_val=7.676931e-05
# epoch=1348	loss_val=7.676923e-05
# epoch=1349	loss_val=7.676915e-05
# epoch=1350	loss_val=7.676927e-05
# epoch=1351	loss_val=7.6769036e-05
# epoch=1352	loss_val=7.676908e-05
# epoch=1353	loss_val=7.6769196e-05
# epoch=1354	loss_val=7.676918e-05
# epoch=1355	loss_val=7.676917e-05
# epoch=1356	loss_val=7.6769065e-05
# epoch=1357	loss_val=7.6769094e-05
# epoch=1358	loss_val=7.67692e-05
# epoch=1359	loss_val=7.676925e-05
# epoch=1360	loss_val=7.6769014e-05
# epoch=1361	loss_val=7.676919e-05
# epoch=1362	loss_val=7.676929e-05
# epoch=1363	loss_val=7.676923e-05
# epoch=1364	loss_val=7.676913e-05
# epoch=1365	loss_val=7.6769116e-05
# epoch=1366	loss_val=7.6769335e-05
# epoch=1367	loss_val=7.676916e-05
# epoch=1368	loss_val=7.67691e-05
# epoch=1369	loss_val=7.676914e-05
# epoch=1370	loss_val=7.676908e-05
# epoch=1371	loss_val=7.6769385e-05
# epoch=1372	loss_val=7.676931e-05
# epoch=1373	loss_val=7.676911e-05
# epoch=1374	loss_val=7.676906e-05
# epoch=1375	loss_val=7.6769065e-05
# epoch=1376	loss_val=7.6769094e-05
# epoch=1377	loss_val=7.676916e-05
# epoch=1378	loss_val=7.676933e-05
# epoch=1379	loss_val=7.676919e-05
# epoch=1380	loss_val=7.676912e-05
# epoch=1381	loss_val=7.676908e-05
# epoch=1382	loss_val=7.6769225e-05
# epoch=1383	loss_val=7.676918e-05
# epoch=1384	loss_val=7.676909e-05
# epoch=1385	loss_val=7.67691e-05
# epoch=1386	loss_val=7.6769e-05
# epoch=1387	loss_val=7.676917e-05
# epoch=1388	loss_val=7.676902e-05
# epoch=1389	loss_val=7.676914e-05
# epoch=1390	loss_val=7.67692e-05
# epoch=1391	loss_val=7.6769145e-05
# epoch=1392	loss_val=7.676923e-05
# epoch=1393	loss_val=7.6769196e-05
# epoch=1394	loss_val=7.67693e-05
# epoch=1395	loss_val=7.6769094e-05
# epoch=1396	loss_val=7.6769305e-05
# epoch=1397	loss_val=7.6769174e-05
# epoch=1398	loss_val=7.676908e-05
# epoch=1399	loss_val=7.6769305e-05
# epoch=1400	loss_val=7.676905e-05
# epoch=1401	loss_val=7.67693e-05
# epoch=1402	loss_val=7.6769065e-05
# epoch=1403	loss_val=7.676908e-05
# epoch=1404	loss_val=7.6769225e-05
# epoch=1405	loss_val=7.676907e-05
# epoch=1406	loss_val=7.676926e-05
# epoch=1407	loss_val=7.67692e-05
# epoch=1408	loss_val=7.676918e-05
# epoch=1409	loss_val=7.676923e-05
# epoch=1410	loss_val=7.676911e-05
# epoch=1411	loss_val=7.676916e-05
# epoch=1412	loss_val=7.6769174e-05
# epoch=1413	loss_val=7.676893e-05
# epoch=1414	loss_val=7.676905e-05
# epoch=1415	loss_val=7.676909e-05
# epoch=1416	loss_val=7.67691e-05
# epoch=1417	loss_val=7.676916e-05
# epoch=1418	loss_val=7.676911e-05
# epoch=1419	loss_val=7.676908e-05
# epoch=1420	loss_val=7.67692e-05
# epoch=1421	loss_val=7.676908e-05
# epoch=1422	loss_val=7.6769116e-05
# epoch=1423	loss_val=7.676917e-05
# epoch=1424	loss_val=7.676915e-05
# epoch=1425	loss_val=7.67692e-05
# epoch=1426	loss_val=7.676922e-05
# epoch=1427	loss_val=7.676921e-05
# epoch=1428	loss_val=7.676905e-05
# epoch=1429	loss_val=7.676909e-05
# epoch=1430	loss_val=7.6769305e-05
# epoch=1431	loss_val=7.676908e-05
# epoch=1432	loss_val=7.6769116e-05
# epoch=1433	loss_val=7.67691e-05
# epoch=1434	loss_val=7.676923e-05
# epoch=1435	loss_val=7.676913e-05
# epoch=1436	loss_val=7.676907e-05
# epoch=1437	loss_val=7.676903e-05
# epoch=1438	loss_val=7.6769036e-05
# epoch=1439	loss_val=7.676934e-05
# epoch=1440	loss_val=7.676925e-05
# epoch=1441	loss_val=7.676911e-05
# epoch=1442	loss_val=7.6769116e-05
# epoch=1443	loss_val=7.676922e-05
# epoch=1444	loss_val=7.6769225e-05
# epoch=1445	loss_val=7.676909e-05
# epoch=1446	loss_val=7.676914e-05
# epoch=1447	loss_val=7.676902e-05
# epoch=1448	loss_val=7.676916e-05
# epoch=1449	loss_val=7.676931e-05
# epoch=1450	loss_val=7.676909e-05
# epoch=1451	loss_val=7.676918e-05
# epoch=1452	loss_val=7.6769225e-05
# epoch=1453	loss_val=7.676919e-05
# epoch=1454	loss_val=7.676911e-05
# epoch=1455	loss_val=7.676916e-05
# epoch=1456	loss_val=7.676925e-05
# epoch=1457	loss_val=7.6769e-05
# epoch=1458	loss_val=7.676909e-05
# epoch=1459	loss_val=7.676904e-05
# epoch=1460	loss_val=7.6769094e-05
# epoch=1461	loss_val=7.67692e-05
# epoch=1462	loss_val=7.676912e-05
# epoch=1463	loss_val=7.676908e-05
# epoch=1464	loss_val=7.676905e-05
# epoch=1465	loss_val=7.676927e-05
# epoch=1466	loss_val=7.676912e-05
# epoch=1467	loss_val=7.6769174e-05
# epoch=1468	loss_val=7.676923e-05
# epoch=1469	loss_val=7.676903e-05
# epoch=1470	loss_val=7.6769305e-05
# epoch=1471	loss_val=7.6769225e-05
# epoch=1472	loss_val=7.676907e-05
# epoch=1473	loss_val=7.6769196e-05
# epoch=1474	loss_val=7.6769196e-05
# epoch=1475	loss_val=7.6769094e-05
# epoch=1476	loss_val=7.6769116e-05
# epoch=1477	loss_val=7.67693e-05
# epoch=1478	loss_val=7.676916e-05
# epoch=1479	loss_val=7.6769385e-05
# ...
# epoch=1519	loss_val=7.676914e-05
# epoch=1520	loss_val=7.676932e-05
# epoch=1521	loss_val=7.676917e-05
# epoch=1522	loss_val=7.676911e-05
# epoch=1523	loss_val=7.676926e-05
# epoch=1524	loss_val=7.676907e-05
# epoch=1525	loss_val=7.676925e-05
# epoch=1526	loss_val=7.6769116e-05
# epoch=1527	loss_val=7.67691e-05
# epoch=1528	loss_val=7.676916e-05
# epoch=1529	loss_val=7.6769145e-05
# epoch=1530	loss_val=7.676923e-05
# epoch=1531	loss_val=7.6769116e-05
# epoch=1532	loss_val=7.6769116e-05
# epoch=1533	loss_val=7.676938e-05
# epoch=1534	loss_val=7.6769196e-05
# epoch=1535	loss_val=7.676912e-05
# epoch=1536	loss_val=7.6769196e-05
# epoch=1537	loss_val=7.676903e-05
# epoch=1538	loss_val=7.676918e-05
# epoch=1539	loss_val=7.67691e-05
# epoch=1540	loss_val=7.676915e-05
# epoch=1541	loss_val=7.676933e-05
# epoch=1542	loss_val=7.676936e-05
# epoch=1543	loss_val=7.6769225e-05
# epoch=1544	loss_val=7.676906e-05
# epoch=1545	loss_val=7.676934e-05
# epoch=1546	loss_val=7.676915e-05
# epoch=1547	loss_val=7.676912e-05
# epoch=1548	loss_val=7.676937e-05
# epoch=1549	loss_val=7.676928e-05
# epoch=1550	loss_val=7.676917e-05
# epoch=1551	loss_val=7.676907e-05
# epoch=1552	loss_val=7.676914e-05
# epoch=1553	loss_val=7.6769116e-05
# epoch=1554	loss_val=7.676916e-05
# epoch=1555	loss_val=7.676929e-05
# epoch=1556	loss_val=7.6769116e-05
# epoch=1557	loss_val=7.6769305e-05
# epoch=1558	loss_val=7.6769116e-05
# epoch=1559	loss_val=7.676909e-05
# epoch=1560	loss_val=7.6769415e-05
# epoch=1561	loss_val=7.676918e-05
# epoch=1562	loss_val=7.6769065e-05
# epoch=1563	loss_val=7.6769116e-05
# epoch=1564	loss_val=7.676936e-05
# epoch=1565	loss_val=7.6769065e-05
# epoch=1566	loss_val=7.676914e-05
# epoch=1567	loss_val=7.67693e-05
# epoch=1568	loss_val=7.6769065e-05
# epoch=1569	loss_val=7.6769225e-05
# epoch=1570	loss_val=7.67691e-05
# epoch=1571	loss_val=7.676911e-05
# epoch=1572	loss_val=7.676915e-05
# epoch=1573	loss_val=7.676927e-05
# epoch=1574	loss_val=7.6769335e-05
# epoch=1575	loss_val=7.676915e-05
# epoch=1576	loss_val=7.6769196e-05
# epoch=1577	loss_val=7.676929e-05
# epoch=1578	loss_val=7.676907e-05
# epoch=1579	loss_val=7.67691e-05
# epoch=1580	loss_val=7.6769276e-05
# epoch=1581	loss_val=7.676929e-05
# epoch=1582	loss_val=7.6768985e-05
# epoch=1583	loss_val=7.676926e-05
# epoch=1584	loss_val=7.676925e-05
# epoch=1585	loss_val=7.67692e-05
# epoch=1586	loss_val=7.676912e-05
# epoch=1587	loss_val=7.676906e-05
# epoch=1588	loss_val=7.676914e-05
# epoch=1589	loss_val=7.6769174e-05
# epoch=1590	loss_val=7.676923e-05
# epoch=1591	loss_val=7.676911e-05
# epoch=1592	loss_val=7.6769196e-05
# epoch=1593	loss_val=7.676918e-05
# epoch=1594	loss_val=7.6769036e-05
# epoch=1595	loss_val=7.676915e-05
# epoch=1596	loss_val=7.676916e-05
# epoch=1597	loss_val=7.676911e-05
# epoch=1598	loss_val=7.6769094e-05
# epoch=1599	loss_val=7.676927e-05
# epoch=1600	loss_val=7.676907e-05
# epoch=1601	loss_val=7.676918e-05
# epoch=1602	loss_val=7.6769255e-05
# epoch=1603	loss_val=7.676924e-05
# epoch=1604	loss_val=7.67691e-05
# epoch=1605	loss_val=7.676946e-05
# epoch=1606	loss_val=7.6769225e-05
# epoch=1607	loss_val=7.676908e-05
# epoch=1608	loss_val=7.676915e-05
# epoch=1609	loss_val=7.676917e-05
# epoch=1610	loss_val=7.676924e-05
# epoch=1611	loss_val=7.6769305e-05
# epoch=1612	loss_val=7.676915e-05
# epoch=1613	loss_val=7.676912e-05
# epoch=1614	loss_val=7.6769065e-05
# epoch=1615	loss_val=7.676918e-05
# epoch=1616	loss_val=7.6769145e-05
# epoch=1617	loss_val=7.676926e-05
# epoch=1618	loss_val=7.676935e-05
# epoch=1619	loss_val=7.676931e-05
# epoch=1620	loss_val=7.6769335e-05
# epoch=1621	loss_val=7.6769036e-05
# epoch=1622	loss_val=7.6769225e-05
# epoch=1623	loss_val=7.676917e-05
# epoch=1624	loss_val=7.676914e-05
# epoch=1625	loss_val=7.67691e-05
# epoch=1626	loss_val=7.676905e-05
# epoch=1627	loss_val=7.676923e-05
# epoch=1628	loss_val=7.676905e-05
# epoch=1629	loss_val=7.676916e-05
# epoch=1630	loss_val=7.676908e-05
# epoch=1631	loss_val=7.676912e-05
# epoch=1632	loss_val=7.676917e-05
# epoch=1633	loss_val=7.67689e-05
# epoch=1634	loss_val=7.6769174e-05
# epoch=1635	loss_val=7.676928e-05
# epoch=1636	loss_val=7.6769385e-05
# epoch=1637	loss_val=7.6769014e-05
# epoch=1638	loss_val=7.676935e-05
# epoch=1639	loss_val=7.676928e-05
# epoch=1640	loss_val=7.676914e-05
# epoch=1641	loss_val=7.676915e-05
# epoch=1642	loss_val=7.676917e-05
# epoch=1643	loss_val=7.676928e-05
# epoch=1644	loss_val=7.676926e-05
# epoch=1645	loss_val=7.676917e-05
# epoch=1646	loss_val=7.6769145e-05
# epoch=1647	loss_val=7.676911e-05
# epoch=1648	loss_val=7.676918e-05
# epoch=1649	loss_val=7.6769305e-05
# epoch=1650	loss_val=7.676924e-05
# epoch=1651	loss_val=7.676912e-05
# epoch=1652	loss_val=7.676918e-05
# epoch=1653	loss_val=7.6769014e-05
# epoch=1654	loss_val=7.676919e-05
# epoch=1655	loss_val=7.6769225e-05
# epoch=1656	loss_val=7.676908e-05
# epoch=1657	loss_val=7.6769276e-05
# epoch=1658	loss_val=7.676926e-05
# epoch=1659	loss_val=7.6768876e-05
# epoch=1660	loss_val=7.676913e-05
# epoch=1661	loss_val=7.6769116e-05
# epoch=1662	loss_val=7.676901e-05
# epoch=1663	loss_val=7.676902e-05
# epoch=1664	loss_val=7.676938e-05
# epoch=1665	loss_val=7.6769225e-05
# epoch=1666	loss_val=7.676911e-05
# epoch=1667	loss_val=7.676928e-05
# epoch=1668	loss_val=7.676927e-05
# epoch=1669	loss_val=7.676931e-05
# epoch=1670	loss_val=7.67692e-05
# epoch=1671	loss_val=7.6769225e-05
# epoch=1672	loss_val=7.676909e-05
# epoch=1673	loss_val=7.676911e-05
# epoch=1674	loss_val=7.6769196e-05
# epoch=1675	loss_val=7.676927e-05
# epoch=1676	loss_val=7.676911e-05
# epoch=1677	loss_val=7.676917e-05
# epoch=1678	loss_val=7.6769065e-05
# epoch=1679	loss_val=7.676897e-05
# epoch=1680	loss_val=7.6769094e-05
# epoch=1681	loss_val=7.676917e-05
# epoch=1682	loss_val=7.676918e-05
# epoch=1683	loss_val=7.676918e-05
# epoch=1684	loss_val=7.676905e-05
# epoch=1685	loss_val=7.676913e-05
# epoch=1686	loss_val=7.6769385e-05
# epoch=1687	loss_val=7.6769255e-05
# epoch=1688	loss_val=7.6769335e-05
# epoch=1689	loss_val=7.6769364e-05
# epoch=1690	loss_val=7.676929e-05
# epoch=1691	loss_val=7.676922e-05
# epoch=1692	loss_val=7.6769065e-05
# epoch=1693	loss_val=7.6769385e-05
# epoch=1694	loss_val=7.676915e-05
# epoch=1695	loss_val=7.676906e-05
# epoch=1696	loss_val=7.6769196e-05
# epoch=1697	loss_val=7.676914e-05
# epoch=1698	loss_val=7.676924e-05
# epoch=1699	loss_val=7.6769255e-05
# epoch=1700	loss_val=7.6769255e-05
# epoch=1701	loss_val=7.676917e-05
# epoch=1702	loss_val=7.676933e-05
# epoch=1703	loss_val=7.676907e-05
# epoch=1704	loss_val=7.676912e-05
# epoch=1705	loss_val=7.6769196e-05
# epoch=1706	loss_val=7.676927e-05
# epoch=1707	loss_val=7.676927e-05
# epoch=1708	loss_val=7.676929e-05
# epoch=1709	loss_val=7.6769335e-05
# epoch=1710	loss_val=7.676925e-05
# epoch=1711	loss_val=7.67691e-05
# epoch=1712	loss_val=7.676937e-05
# epoch=1713	loss_val=7.676923e-05
# epoch=1714	loss_val=7.676908e-05
# epoch=1715	loss_val=7.6769196e-05
# epoch=1716	loss_val=7.6769225e-05
# epoch=1717	loss_val=7.67692e-05
# epoch=1718	loss_val=7.676927e-05
# epoch=1719	loss_val=7.676926e-05
# epoch=1720	loss_val=7.676934e-05
# epoch=1721	loss_val=7.676931e-05
# epoch=1722	loss_val=7.676922e-05
# epoch=1723	loss_val=7.676917e-05
# epoch=1724	loss_val=7.676925e-05
# epoch=1725	loss_val=7.676934e-05
# epoch=1726	loss_val=7.6769255e-05
# epoch=1727	loss_val=7.6769174e-05
# epoch=1728	loss_val=7.676906e-05
# epoch=1729	loss_val=7.676917e-05
# epoch=1730	loss_val=7.676907e-05
# epoch=1731	loss_val=7.676924e-05
# epoch=1732	loss_val=7.6769385e-05
# epoch=1733	loss_val=7.676905e-05
# epoch=1734	loss_val=7.676936e-05
# epoch=1735	loss_val=7.676922e-05
# epoch=1736	loss_val=7.6769174e-05
# epoch=1737	loss_val=7.676893e-05
# epoch=1738	loss_val=7.6769225e-05
# epoch=1739	loss_val=7.676914e-05
# epoch=1740	loss_val=7.676913e-05
# epoch=1741	loss_val=7.676903e-05
# epoch=1742	loss_val=7.6769036e-05
# epoch=1743	loss_val=7.6769276e-05
# epoch=1744	loss_val=7.67692e-05
# epoch=1745	loss_val=7.6769065e-05
# epoch=1746	loss_val=7.676934e-05
# epoch=1747	loss_val=7.676916e-05
# epoch=1748	loss_val=7.676928e-05
# epoch=1749	loss_val=7.676928e-05
# epoch=1750	loss_val=7.67693e-05
# epoch=1751	loss_val=7.6769196e-05
# epoch=1752	loss_val=7.676918e-05
# epoch=1753	loss_val=7.6769145e-05
# epoch=1754	loss_val=7.676902e-05
# epoch=1755	loss_val=7.676917e-05
# epoch=1756	loss_val=7.6768934e-05
# epoch=1757	loss_val=7.676914e-05
# epoch=1758	loss_val=7.676918e-05
# epoch=1759	loss_val=7.676896e-05
# epoch=1760	loss_val=7.676914e-05
# epoch=1761	loss_val=7.6769305e-05
# epoch=1762	loss_val=7.676913e-05
# epoch=1763	loss_val=7.676915e-05
# epoch=1764	loss_val=7.676924e-05
# epoch=1765	loss_val=7.6769196e-05
# epoch=1766	loss_val=7.676909e-05
# epoch=1767	loss_val=7.676901e-05
# epoch=1768	loss_val=7.67691e-05
# epoch=1769	loss_val=7.676917e-05
# epoch=1770	loss_val=7.676922e-05
# epoch=1771	loss_val=7.676923e-05
# epoch=1772	loss_val=7.676926e-05
# epoch=1773	loss_val=7.676936e-05
# epoch=1774	loss_val=7.676902e-05
# epoch=1775	loss_val=7.676921e-05
# epoch=1776	loss_val=7.6769116e-05
# epoch=1777	loss_val=7.676925e-05
# epoch=1778	loss_val=7.676901e-05
# epoch=1779	loss_val=7.676932e-05
# epoch=1780	loss_val=7.676926e-05
# epoch=1781	loss_val=7.676921e-05
# epoch=1782	loss_val=7.676918e-05
# epoch=1783	loss_val=7.676894e-05
# epoch=1784	loss_val=7.676922e-05
# epoch=1785	loss_val=7.67693e-05
# epoch=1786	loss_val=7.676912e-05
# epoch=1787	loss_val=7.676939e-05
# epoch=1788	loss_val=7.6769094e-05
# epoch=1789	loss_val=7.676921e-05
# epoch=1790	loss_val=7.6769255e-05
# epoch=1791	loss_val=7.676927e-05
# epoch=1792	loss_val=7.67691e-05
# epoch=1793	loss_val=7.676909e-05
# epoch=1794	loss_val=7.676915e-05
# epoch=1795	loss_val=7.676907e-05
# epoch=1796	loss_val=7.676902e-05
# epoch=1797	loss_val=7.676916e-05
# epoch=1798	loss_val=7.676915e-05
# epoch=1799	loss_val=7.676907e-05
# epoch=1800	loss_val=7.676916e-05
# epoch=1801	loss_val=7.676933e-05
# epoch=1802	loss_val=7.676918e-05
# epoch=1803	loss_val=7.676909e-05
# epoch=1804	loss_val=7.6769196e-05
# epoch=1805	loss_val=7.67691e-05
# epoch=1806	loss_val=7.6769276e-05
# epoch=1807	loss_val=7.6769174e-05
# epoch=1808	loss_val=7.676924e-05
# epoch=1809	loss_val=7.67692e-05
# epoch=1810	loss_val=7.676922e-05
# epoch=1811	loss_val=7.6769255e-05
# epoch=1812	loss_val=7.676929e-05
# epoch=1813	loss_val=7.676922e-05
# epoch=1814	loss_val=7.676922e-05
# epoch=1815	loss_val=7.676906e-05
# epoch=1816	loss_val=7.676912e-05
# epoch=1817	loss_val=7.676914e-05
# epoch=1818	loss_val=7.676899e-05
# epoch=1819	loss_val=7.676908e-05
# epoch=1820	loss_val=7.6769276e-05
# epoch=1821	loss_val=7.676926e-05
# epoch=1822	loss_val=7.676904e-05
# epoch=1823	loss_val=7.6769196e-05
# epoch=1824	loss_val=7.676922e-05
# epoch=1825	loss_val=7.6769225e-05
# epoch=1826	loss_val=7.676904e-05
# epoch=1827	loss_val=7.6769065e-05
# epoch=1828	loss_val=7.676902e-05
# epoch=1829	loss_val=7.676932e-05
# epoch=1830	loss_val=7.676908e-05
# epoch=1831	loss_val=7.676908e-05
# epoch=1832	loss_val=7.676917e-05
# epoch=1833	loss_val=7.6769174e-05
# epoch=1834	loss_val=7.676909e-05
# epoch=1835	loss_val=7.6769255e-05
# epoch=1836	loss_val=7.676919e-05
# epoch=1837	loss_val=7.6769094e-05
# epoch=1838	loss_val=7.676919e-05
# epoch=1839	loss_val=7.676901e-05
# epoch=1840	loss_val=7.676907e-05
# epoch=1841	loss_val=7.676952e-05
# epoch=1842	loss_val=7.676906e-05
# epoch=1843	loss_val=7.676906e-05
# epoch=1844	loss_val=7.676918e-05
# epoch=1845	loss_val=7.67692e-05
# epoch=1846	loss_val=7.676929e-05
# epoch=1847	loss_val=7.676923e-05
# epoch=1848	loss_val=7.676904e-05
# epoch=1849	loss_val=7.676919e-05
# epoch=1850	loss_val=7.676925e-05
# epoch=1851	loss_val=7.676908e-05
# epoch=1852	loss_val=7.676921e-05
# epoch=1853	loss_val=7.676928e-05
# epoch=1854	loss_val=7.6769364e-05
# epoch=1855	loss_val=7.6769065e-05
# epoch=1856	loss_val=7.676911e-05
# epoch=1857	loss_val=7.67692e-05
# epoch=1858	loss_val=7.6769116e-05
# epoch=1859	loss_val=7.676906e-05
# epoch=1860	loss_val=7.67691e-05
# epoch=1861	loss_val=7.676921e-05
# epoch=1862	loss_val=7.676916e-05
# epoch=1863	loss_val=7.676906e-05
# epoch=1864	loss_val=7.676909e-05
# epoch=1865	loss_val=7.6769e-05
# epoch=1866	loss_val=7.676929e-05
# epoch=1867	loss_val=7.676894e-05
# epoch=1868	loss_val=7.6769145e-05
# epoch=1869	loss_val=7.67692e-05
# epoch=1870	loss_val=7.6769094e-05
# epoch=1871	loss_val=7.676919e-05
# epoch=1872	loss_val=7.676915e-05
# epoch=1873	loss_val=7.676938e-05
# epoch=1874	loss_val=7.676904e-05
# epoch=1875	loss_val=7.676921e-05
# epoch=1876	loss_val=7.676898e-05
# epoch=1877	loss_val=7.676906e-05
# epoch=1878	loss_val=7.67692e-05
# epoch=1879	loss_val=7.6769065e-05
# epoch=1880	loss_val=7.676912e-05
# epoch=1881	loss_val=7.6769335e-05
# epoch=1882	loss_val=7.6769364e-05
# epoch=1883	loss_val=7.676927e-05
# epoch=1884	loss_val=7.6768985e-05
# epoch=1885	loss_val=7.6769094e-05
# epoch=1886	loss_val=7.676906e-05
# epoch=1887	loss_val=7.6768985e-05
# epoch=1888	loss_val=7.67693e-05
# epoch=1889	loss_val=7.676927e-05
# epoch=1890	loss_val=7.676913e-05
# epoch=1891	loss_val=7.67692e-05
# epoch=1892	loss_val=7.6769116e-05
# epoch=1893	loss_val=7.676919e-05
# epoch=1894	loss_val=7.6769225e-05
# epoch=1895	loss_val=7.676915e-05
# epoch=1896	loss_val=7.676903e-05
# epoch=1897	loss_val=7.676927e-05
# epoch=1898	loss_val=7.67691e-05
# epoch=1899	loss_val=7.676921e-05
# epoch=1900	loss_val=7.676917e-05
# epoch=1901	loss_val=7.676911e-05
# epoch=1902	loss_val=7.6769305e-05
# epoch=1903	loss_val=7.676917e-05
# epoch=1904	loss_val=7.6769174e-05
# epoch=1905	loss_val=7.676907e-05
# epoch=1906	loss_val=7.6769174e-05
# epoch=1907	loss_val=7.676917e-05
# epoch=1908	loss_val=7.676914e-05
# epoch=1909	loss_val=7.676928e-05
# epoch=1910	loss_val=7.676921e-05
# epoch=1911	loss_val=7.676931e-05
# epoch=1912	loss_val=7.676924e-05
# epoch=1913	loss_val=7.676913e-05
# epoch=1914	loss_val=7.6769174e-05
# epoch=1915	loss_val=7.6769094e-05
# epoch=1916	loss_val=7.676903e-05
# epoch=1917	loss_val=7.6769145e-05
# epoch=1918	loss_val=7.6769116e-05
# epoch=1919	loss_val=7.676919e-05
# epoch=1920	loss_val=7.676933e-05
# epoch=1921	loss_val=7.6769276e-05
# epoch=1922	loss_val=7.6769255e-05
# epoch=1923	loss_val=7.6769335e-05
# epoch=1924	loss_val=7.676913e-05
# epoch=1925	loss_val=7.67691e-05
# epoch=1926	loss_val=7.676924e-05
# epoch=1927	loss_val=7.6769255e-05
# epoch=1928	loss_val=7.676909e-05
# epoch=1929	loss_val=7.676908e-05
# epoch=1930	loss_val=7.676913e-05
# epoch=1931	loss_val=7.676928e-05
# epoch=1932	loss_val=7.676905e-05
# epoch=1933	loss_val=7.676918e-05
# epoch=1934	loss_val=7.676911e-05
# epoch=1935	loss_val=7.676903e-05
# epoch=1936	loss_val=7.6769335e-05
# epoch=1937	loss_val=7.676902e-05
# epoch=1938	loss_val=7.6769094e-05
# epoch=1939	loss_val=7.676914e-05
# epoch=1940	loss_val=7.676918e-05
# epoch=1941	loss_val=7.676939e-05
# epoch=1942	loss_val=7.6769014e-05
# epoch=1943	loss_val=7.676928e-05
# epoch=1944	loss_val=7.67692e-05
# epoch=1945	loss_val=7.676916e-05
# epoch=1946	loss_val=7.6769196e-05
# epoch=1947	loss_val=7.6769036e-05
# epoch=1948	loss_val=7.6769276e-05
# epoch=1949	loss_val=7.676918e-05
# epoch=1950	loss_val=7.676926e-05
# epoch=1951	loss_val=7.676925e-05
# epoch=1952	loss_val=7.676916e-05
# epoch=1953	loss_val=7.67693e-05
# epoch=1954	loss_val=7.676906e-05
# epoch=1955	loss_val=7.676935e-05
# epoch=1956	loss_val=7.6769335e-05
# epoch=1957	loss_val=7.676919e-05
# epoch=1958	loss_val=7.6769385e-05
# epoch=1959	loss_val=7.6769225e-05
# epoch=1960	loss_val=7.676926e-05
# epoch=1961	loss_val=7.6769145e-05
# epoch=1962	loss_val=7.676912e-05
# epoch=1963	loss_val=7.6769335e-05
# epoch=1964	loss_val=7.676915e-05
# epoch=1965	loss_val=7.67693e-05
# epoch=1966	loss_val=7.676919e-05
# epoch=1967	loss_val=7.67694e-05
# epoch=1968	loss_val=7.6769364e-05
# epoch=1969	loss_val=7.6769255e-05
# epoch=1970	loss_val=7.6768956e-05
# epoch=1971	loss_val=7.6769276e-05
# epoch=1972	loss_val=7.6769255e-05
# epoch=1973	loss_val=7.676911e-05
# epoch=1974	loss_val=7.676914e-05
# epoch=1975	loss_val=7.676912e-05
# epoch=1976	loss_val=7.676914e-05
# epoch=1977	loss_val=7.6769065e-05
# epoch=1978	loss_val=7.676927e-05
# epoch=1979	loss_val=7.676902e-05
# epoch=1980	loss_val=7.67691e-05
# epoch=1981	loss_val=7.676908e-05
# epoch=1982	loss_val=7.6769174e-05
# epoch=1983	loss_val=7.676903e-05
# epoch=1984	loss_val=7.6769276e-05
# epoch=1985	loss_val=7.6769094e-05
# epoch=1986	loss_val=7.6769036e-05
# epoch=1987	loss_val=7.676936e-05
# epoch=1988	loss_val=7.6769145e-05
# epoch=1989	loss_val=7.676916e-05
# epoch=1990	loss_val=7.676923e-05
# epoch=1991	loss_val=7.676907e-05
# epoch=1992	loss_val=7.6769196e-05
# epoch=1993	loss_val=7.676925e-05
# epoch=1994	loss_val=7.676923e-05
# epoch=1995	loss_val=7.6769225e-05
# epoch=1996	loss_val=7.676906e-05
# epoch=1997	loss_val=7.676923e-05
# epoch=1998	loss_val=7.6769145e-05
# epoch=1999	loss_val=7.6769225e-05

# %%
# predict the values at a grid of points (a mesh) so we can view predicted contour of the solution
# using the mean interpolated from trained values
import numpy as np

n = 20
ngrid = n * n
_xgrid = np.linspace(0.0, a, n)
_ygrid = np.linspace(0.0, b, n)
X, Y = np.meshgrid(_xgrid, _ygrid)
xgrid = np.reshape(X, newshape=(ngrid,1))
ygrid = np.reshape(Y, newshape=(ngrid,1))
x_grid = np.concatenate([xgrid, ygrid], axis=1)

# old non-vectorized way
# K_train = np.array([[kernel2d(x_all[i,:], x_all[j,:]) for j in range(num_all)] for i in range(num_all)])
# K_cross = np.array([[kernel2d(x_grid[i,:], x_all[j,:]) for j in range(num_all)] for i in range(ngrid)])

# vectorized way like 100x faster
K_train = kernel2d_tf(x_all_L, x_all_R)
x_grid_L = tf.expand_dims(tf.constant(x_grid, dtype=DTYPE), axis=1)
K_cross = kernel2d_tf(x_grid_L, x_all_R)

max_eigval = np.max(np.linalg.eigvalsh(K_train))
W_grid = K_cross @ np.linalg.solve(K_train + 1e-5 * max_eigval * np.eye(num_all), w_full[:num_all,:])
W = np.reshape(W_grid, newshape=(n, n))

# %%
import matplotlib.pyplot as plt
# now plot the predicted solution contour
plt.figure(figsize=(8, 6))
colors = plt.contourf(X, Y, W, levels=20, cmap='viridis', alpha=0.75)  # Filled contours
plt.gca().set_aspect('equal')
plt.colorbar(colors, label="w(x,y)")  # Colorbar for reference

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
# now plot the predicted solution surface in 3d
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, W, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=1)
ax.set_aspect('equalxy')
plt.show()
